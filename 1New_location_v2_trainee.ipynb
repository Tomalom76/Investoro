# %%
# ==============================================================================
# KOMÓRKA 1: WCZYTANIE DANYCH I SZYBKA NAPRAWA KOLUMN `loc_*`
# ==============================================================================
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import os
import json
import joblib
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

print("TensorFlow version:", tf.__version__)
ARTIFACTS_DIR = '1_Artifacts_Polska'
if not os.path.exists(ARTIFACTS_DIR): os.makedirs(ARTIFACTS_DIR)

# Wczytujemy wyniki ciężkiej pracy - plik .pkl
print("Wczytuję przetworzone dane z pliku 'df_flats_processed.pkl'...")
df_flats = pd.read_pickle('df_flats_processed.pkl')
print(f"Dane wczytane. Liczba ogłoszeń: {len(df_flats)}")

# Wczytujemy też plik z lokalizacjami
LOKALIZACJA_FILE = 'lokalizacja.csv'
LOK_COLUMNS = ['Id', 'ParentId', 'Name', 'AdditionalName', 'FullName']
df_lok = pd.read_csv(LOKALIZACJA_FILE, header=None, names=LOK_COLUMNS, na_values='\\N', low_memory=False)
df_lok['ParentId'] = df_lok['ParentId'].fillna(0).astype('Int64')
lok_dict = df_lok.set_index('Id')['Name'].to_dict()

# =================================================================
# SERCE OPERACJI: SZYBKA NAPRAWA BŁĘDNIE PRZETWORZONYCH KOLUMN
# =================================================================
print("\nNaprawiam kolumny 'loc_*' na podstawie oryginalnej 'locationPath'...")

loc_path_cols = [f'loc_{i}' for i in range(1, 8)]

# Usuwamy stare, błędne kolumny, jeśli istnieją
for col in loc_path_cols:
    if col in df_flats.columns:
        df_flats.drop(col, axis=1, inplace=True)
if 'city_name' in df_flats.columns:
    df_flats.drop('city_name', axis=1, inplace=True)


# Używamy nowej, odpornej metody do stworzenia poprawnych kolumn
path_lists = df_flats['locationPath'].astype(str).str.split(',')
processed_paths = pd.DataFrame(path_lists.tolist(), index=df_flats.index)
if processed_paths.shape[1] < 7:
    for i in range(processed_paths.shape[1], 7):
        processed_paths[i] = None
processed_paths = processed_paths.iloc[:, :7]
processed_paths.columns = loc_path_cols
df_flats[loc_path_cols] = processed_paths.fillna(0).astype(int)

# Tworzymy na nowo 'city_name'
df_flats['city_name'] = df_flats['loc_4'].map(lok_dict)
df_flats.dropna(subset=['city_name'], inplace=True) # Usuwamy ogłoszenia bez przypisanego miasta
print("Kolumny 'loc_*' i 'city_name' zostały naprawione.")


# --- DIAGNOSTYKA PO POPRAWCE ---
print("\n--- Diagnostyka po naprawie ---")
train_data_check = df_flats[(df_flats['loc_5'] != 0) & (df_flats['loc_6'] != 0) & (df_flats['loc_7'] != 0)]
print(f"Liczba wierszy z PEŁNĄ lokalizacją: {len(train_data_check)}")
if len(train_data_check) > 0:
    print("[SUKCES] Dane treningowe zostały poprawnie zidentyfikowane!")
else:
    print("[BŁĄD] Wciąż brak danych treningowych.")

print("\nDane gotowe do treningu modelu.")
# Out:
# TensorFlow version: 2.19.0
# Wczytuję przetworzone dane z pliku 'df_flats_processed.pkl'...
# Dane wczytane. Liczba ogłoszeń: 1100194
#
# Naprawiam kolumny 'loc_*' na podstawie oryginalnej 'locationPath'...
# Kolumny 'loc_*' i 'city_name' zostały naprawione.
#
# --- Diagnostyka po naprawie ---
# Liczba wierszy z PEŁNĄ lokalizacją: 153562
# [SUKCES] Dane treningowe zostały poprawnie zidentyfikowane!
#
# Dane gotowe do treningu modelu.

# %%
# ==============================================================================
# KOMÓRKA 2: TRENING MODELI
# ==============================================================================
print("\n--- Krok 3: Trening Modeli ---")

# Definicje cech, upewnijmy się, że wszystkie kolumny istnieją
numerical_features = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuiltYear']
categorical_features = ['BuldingType']
text_based_features = ['text_district_id', 'text_subdistrict_id', 'text_street_id']
similarity_based_features = ['similar_district_id', 'similar_subdistrict_id', 'similar_street_id']

# Pętla po miastach i trening
for city_name in df_flats['city_name'].unique():
    if pd.isna(city_name): continue
    
    print(f"\n--- Trenowanie modelu dla miasta: {city_name} ---")
    
    df_city = df_flats[df_flats['city_name'] == city_name].copy()
    # Dane treningowe to tylko te z PEŁNĄ lokalizacją
    train_data = df_city[(df_city['loc_5'] != 0) & (df_city['loc_6'] != 0) & (df_city['loc_7'] != 0)].copy()
    
    if len(train_data) < 50:
        print(f"Pominięto {city_name} z powodu zbyt małej ilości danych treningowych ({len(train_data)} ogłoszeń).")
        continue

    # Przygotowanie cech wejściowych (X)
    X_num = train_data[numerical_features].values
    X_cat_dummies = pd.get_dummies(train_data[categorical_features], prefix='type').values
    X_text = train_data[text_based_features].values
    X_sim = train_data[similarity_based_features].values
    
    scaler = MinMaxScaler()
    X_num_scaled = scaler.fit_transform(X_num)
    
    X = np.hstack([X_num_scaled, X_cat_dummies, X_text, X_sim])
    
    # Przygotowanie etykiet (y)
    encoders = {}
    targets = {}
    target_cols = {'district': 'loc_5', 'subdistrict': 'loc_6', 'street': 'loc_7'}

    for name, col in target_cols.items():
        le = LabelEncoder()
        targets[name] = le.fit_transform(train_data[col])
        encoders[name] = {'classes': le.classes_.tolist(), 'mapping': {i: int(cls) for i, cls in enumerate(le.classes_)}}

    # Zapisanie artefaktów
    joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, f'{city_name}_scaler.gz'))
    ohe_columns = pd.get_dummies(train_data[categorical_features], prefix='type').columns.tolist()
    encoders['ohe_columns'] = ohe_columns
    with open(os.path.join(ARTIFACTS_DIR, f'{city_name}_encoders.json'), 'w') as f:
        json.dump(encoders, f, indent=4)

    # Definicja i trening modelu Keras
    input_shape = (X.shape[1],)
    input_layer = layers.Input(shape=input_shape, name='input')
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu')(x)
    
    output_district = layers.Dense(len(encoders['district']['classes']), activation='softmax', name='district_output')(x)
    output_subdistrict = layers.Dense(len(encoders['subdistrict']['classes']), activation='softmax', name='subdistrict_output')(x)
    output_street = layers.Dense(len(encoders['street']['classes']), activation='softmax', name='street_output')(x)
    
    model = keras.Model(inputs=input_layer, outputs=[output_district, output_subdistrict, output_street])
    model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics={
        'district_output': 'accuracy',
        'subdistrict_output': 'accuracy',
        'street_output': 'accuracy'
    }
)
    
    print(f"Rozpoczynam trening na {len(train_data)} próbkach...")
    model.fit(X, [targets['district'], targets['subdistrict'], targets['street']], epochs=30, batch_size=32, verbose=0)
    
    model_path = os.path.join(ARTIFACTS_DIR, f'{city_name}_location_model.keras')
    model.save(model_path)
    print(f"Model dla {city_name} został zapisany w: {model_path}")
# Out:
# --- Krok 3: Trening Modeli ---
#
# --- Trenowanie modelu dla miasta: Białystok ---
# Pominięto Białystok z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piaski ---
# Pominięto Piaski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lipowa ---
# Pominięto Lipowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bydgoszcz ---
# Pominięto Bydgoszcz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Osówiec ---
# Pominięto Osówiec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gdynia ---
# Pominięto Gdynia z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gdańsk ---
# Pominięto Gdańsk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Częstochowa ---
# Pominięto Częstochowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jasień ---
# Pominięto Jasień z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łódź ---
# Rozpoczynam trening na 18148 próbkach...
# Model dla Łódź został zapisany w: 1_Artifacts_Polska\Łódź_location_model.keras
#
# --- Trenowanie modelu dla miasta: Kraków ---
# Rozpoczynam trening na 36322 próbkach...
# Model dla Kraków został zapisany w: 1_Artifacts_Polska\Kraków_location_model.keras
#
# --- Trenowanie modelu dla miasta: Lublin ---
# Pominięto Lublin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Warszawa ---
# Rozpoczynam trening na 52461 próbkach...
# Model dla Warszawa został zapisany w: 1_Artifacts_Polska\Warszawa_location_model.keras
#
# --- Trenowanie modelu dla miasta: Katowice ---
# Pominięto Katowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radom ---
# Pominięto Radom z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sosnowiec ---
# Pominięto Sosnowiec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Siemianowice śląskie ---
# Pominięto Siemianowice śląskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gliwice ---
# Pominięto Gliwice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szczecin ---
# Pominięto Szczecin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Poznań ---
# Rozpoczynam trening na 16567 próbkach...
# Model dla Poznań został zapisany w: 1_Artifacts_Polska\Poznań_location_model.keras
#
# --- Trenowanie modelu dla miasta: Toruń ---
# Pominięto Toruń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Plewiska ---
# Pominięto Plewiska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Biedrusko ---
# Pominięto Biedrusko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bielawy ---
# Pominięto Bielawy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Olsztyn ---
# Pominięto Olsztyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Robakowo ---
# Pominięto Robakowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sopot ---
# Pominięto Sopot z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Opole ---
# Pominięto Opole z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mieroszów ---
# Pominięto Mieroszów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Siedlce ---
# Pominięto Siedlce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kętrzyn ---
# Pominięto Kętrzyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kłodzko ---
# Pominięto Kłodzko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dziwnówek ---
# Pominięto Dziwnówek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dziwnów ---
# Pominięto Dziwnów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pobierowo ---
# Pominięto Pobierowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Iława ---
# Pominięto Iława z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szczecinek ---
# Pominięto Szczecinek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pabianice ---
# Pominięto Pabianice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gniezno ---
# Pominięto Gniezno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Otwock ---
# Pominięto Otwock z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kędzierzyn-koźle ---
# Pominięto Kędzierzyn-koźle z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bielsko-biała ---
# Pominięto Bielsko-biała z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dzierżoniów ---
# Pominięto Dzierżoniów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gozdnica ---
# Pominięto Gozdnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chorzów ---
# Pominięto Chorzów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tychy ---
# Pominięto Tychy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zduńska wola ---
# Pominięto Zduńska wola z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tarnów ---
# Pominięto Tarnów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piotrków trybunalski ---
# Pominięto Piotrków trybunalski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mińsk mazowiecki ---
# Pominięto Mińsk mazowiecki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Skarżysko-kamienna ---
# Pominięto Skarżysko-kamienna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzemeszno ---
# Pominięto Trzemeszno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wiślinka ---
# Pominięto Wiślinka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Włocławek ---
# Pominięto Włocławek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Owińska ---
# Pominięto Owińska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gorzów wielkopolski ---
# Pominięto Gorzów wielkopolski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowy sącz ---
# Pominięto Nowy sącz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mielec ---
# Pominięto Mielec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Konin ---
# Pominięto Konin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bielsk podlaski ---
# Pominięto Bielsk podlaski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łabędnik ---
# Pominięto Łabędnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kościan ---
# Pominięto Kościan z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Janczewice ---
# Pominięto Janczewice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sokołów małopolski ---
# Pominięto Sokołów małopolski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rzeszów ---
# Pominięto Rzeszów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ruda śląska ---
# Pominięto Ruda śląska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wyszków ---
# Pominięto Wyszków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Słupsk ---
# Pominięto Słupsk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rumia ---
# Pominięto Rumia z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bytom ---
# Pominięto Bytom z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pruszków ---
# Pominięto Pruszków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ustronie morskie ---
# Pominięto Ustronie morskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kielce ---
# Pominięto Kielce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowy staw ---
# Pominięto Nowy staw z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ząbki ---
# Pominięto Ząbki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Leszno ---
# Pominięto Leszno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Garwolin ---
# Pominięto Garwolin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Giżycko ---
# Pominięto Giżycko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Namysłów ---
# Pominięto Namysłów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bolszewo ---
# Pominięto Bolszewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tczew ---
# Pominięto Tczew z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jawor ---
# Pominięto Jawor z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zabrze ---
# Pominięto Zabrze z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dąbrowa górnicza ---
# Pominięto Dąbrowa górnicza z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kwidzyn ---
# Pominięto Kwidzyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Miastko ---
# Pominięto Miastko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świeradów-zdrój ---
# Pominięto Świeradów-zdrój z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świdwin ---
# Pominięto Świdwin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piekary śląskie ---
# Pominięto Piekary śląskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Banino ---
# Pominięto Banino z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brzeg ---
# Pominięto Brzeg z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wąbrzeźno ---
# Pominięto Wąbrzeźno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rybnik ---
# Pominięto Rybnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kołobrzeg ---
# Pominięto Kołobrzeg z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ryki ---
# Pominięto Ryki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radomsko ---
# Pominięto Radomsko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Połczyn-zdrój ---
# Pominięto Połczyn-zdrój z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Golub-dobrzyń ---
# Pominięto Golub-dobrzyń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ciechanów ---
# Pominięto Ciechanów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Błonie ---
# Pominięto Błonie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Luboń ---
# Pominięto Luboń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lesznowola ---
# Pominięto Lesznowola z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wrocław ---
# Rozpoczynam trening na 30064 próbkach...
# Model dla Wrocław został zapisany w: 1_Artifacts_Polska\Wrocław_location_model.keras
#
# --- Trenowanie modelu dla miasta: Szamotuły ---
# Pominięto Szamotuły z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radzymin ---
# Pominięto Radzymin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sobótka ---
# Pominięto Sobótka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zakręt ---
# Pominięto Zakręt z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Legnica ---
# Pominięto Legnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sandomierz ---
# Pominięto Sandomierz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Psarskie ---
# Pominięto Psarskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rokitki ---
# Pominięto Rokitki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzebiatów ---
# Pominięto Trzebiatów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wrzosowa ---
# Pominięto Wrzosowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Darłowo ---
# Pominięto Darłowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jelenia góra ---
# Pominięto Jelenia góra z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grójec ---
# Pominięto Grójec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piaseczno ---
# Pominięto Piaseczno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Inowrocław ---
# Pominięto Inowrocław z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dobczyce ---
# Pominięto Dobczyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zielona góra ---
# Pominięto Zielona góra z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Racibórz ---
# Pominięto Racibórz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Polanica-zdrój ---
# Pominięto Polanica-zdrój z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ustka ---
# Pominięto Ustka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zalasewo ---
# Pominięto Zalasewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Malbork ---
# Pominięto Malbork z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piła ---
# Pominięto Piła z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szczawnica ---
# Pominięto Szczawnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Elbląg ---
# Pominięto Elbląg z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Miłkowice ---
# Pominięto Miłkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Puławy ---
# Pominięto Puławy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świebodzin ---
# Pominięto Świebodzin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rząska ---
# Pominięto Rząska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Białogard ---
# Pominięto Białogard z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wielka wieś ---
# Pominięto Wielka wieś z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Śrem ---
# Pominięto Śrem z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowy dwór ---
# Pominięto Nowy dwór z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ostrów wielkopolski ---
# Pominięto Ostrów wielkopolski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świdnica ---
# Pominięto Świdnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bartoszyce ---
# Pominięto Bartoszyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żagań ---
# Pominięto Żagań z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wejherowo ---
# Pominięto Wejherowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Stargard ---
# Pominięto Stargard z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rutkowice ---
# Pominięto Rutkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ustroń ---
# Pominięto Ustroń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Józefosław ---
# Pominięto Józefosław z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pyrzyce ---
# Pominięto Pyrzyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Morąg ---
# Pominięto Morąg z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bełchatów ---
# Pominięto Bełchatów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jastrzębie-zdrój ---
# Pominięto Jastrzębie-zdrój z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Księginice ---
# Pominięto Księginice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Czapury ---
# Pominięto Czapury z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Starogard gdański ---
# Pominięto Starogard gdański z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Będzin ---
# Pominięto Będzin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grodków ---
# Pominięto Grodków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Czechowice-dziedzice ---
# Pominięto Czechowice-dziedzice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pruszcz gdański ---
# Pominięto Pruszcz gdański z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kozienice ---
# Pominięto Kozienice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowa sól ---
# Pominięto Nowa sól z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wolbrom ---
# Pominięto Wolbrom z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dęblin ---
# Pominięto Dęblin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Julianów ---
# Pominięto Julianów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Osielsko ---
# Pominięto Osielsko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pleszew ---
# Pominięto Pleszew z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wieliczka ---
# Pominięto Wieliczka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zakopane ---
# Pominięto Zakopane z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bielany wrocławskie ---
# Pominięto Bielany wrocławskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Boguszów-gorce ---
# Pominięto Boguszów-gorce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kleszczewo ---
# Pominięto Kleszczewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świętochłowice ---
# Pominięto Świętochłowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Busko-zdrój ---
# Pominięto Busko-zdrój z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tarnobrzeg ---
# Pominięto Tarnobrzeg z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Iwiny ---
# Pominięto Iwiny z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rydułtowy ---
# Pominięto Rydułtowy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kalisz ---
# Pominięto Kalisz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ełk ---
# Pominięto Ełk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jonkowo ---
# Pominięto Jonkowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Podłęże ---
# Pominięto Podłęże z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Stalowa wola ---
# Pominięto Stalowa wola z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Skawina ---
# Pominięto Skawina z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zgorzelec ---
# Pominięto Zgorzelec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Strzelce ---
# Pominięto Strzelce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zdzieszowice ---
# Pominięto Zdzieszowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wierchlesie ---
# Pominięto Wierchlesie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Police ---
# Pominięto Police z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Popowo kościelne ---
# Pominięto Popowo kościelne z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lubin ---
# Pominięto Lubin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kolbuszowa ---
# Pominięto Kolbuszowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Stara iwiczna ---
# Pominięto Stara iwiczna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sochaczew ---
# Pominięto Sochaczew z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Suwałki ---
# Pominięto Suwałki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Markowo ---
# Pominięto Markowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wieliszew ---
# Pominięto Wieliszew z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kutno ---
# Pominięto Kutno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zielonki ---
# Pominięto Zielonki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Barlinek ---
# Pominięto Barlinek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kobyłka ---
# Pominięto Kobyłka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brzesko ---
# Pominięto Brzesko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łuków ---
# Pominięto Łuków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pińczów ---
# Pominięto Pińczów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mysłowice ---
# Pominięto Mysłowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pionki ---
# Pominięto Pionki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bobolice ---
# Pominięto Bobolice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Międzyzdroje ---
# Pominięto Międzyzdroje z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jeleniów ---
# Pominięto Jeleniów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żory ---
# Pominięto Żory z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Milicz ---
# Pominięto Milicz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rypin ---
# Pominięto Rypin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Maszewo ---
# Pominięto Maszewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żędowice ---
# Pominięto Żędowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Konstantynów łódzki ---
# Pominięto Konstantynów łódzki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kieźliny ---
# Pominięto Kieźliny z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lubartów ---
# Pominięto Lubartów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Korsze ---
# Pominięto Korsze z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żary ---
# Pominięto Żary z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Głogów ---
# Pominięto Głogów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Blizne łaszczyńskiego ---
# Pominięto Blizne łaszczyńskiego z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Niepołomice ---
# Pominięto Niepołomice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kamionki ---
# Pominięto Kamionki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bolesławiec ---
# Pominięto Bolesławiec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Walim ---
# Pominięto Walim z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kowale ---
# Pominięto Kowale z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Koszalin ---
# Pominięto Koszalin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wągrowiec ---
# Pominięto Wągrowiec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kraśnik ---
# Pominięto Kraśnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Złotów ---
# Pominięto Złotów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Krynica morska ---
# Pominięto Krynica morska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żyrardów ---
# Pominięto Żyrardów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łomża ---
# Pominięto Łomża z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wałcz ---
# Pominięto Wałcz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Resko ---
# Pominięto Resko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mikołów ---
# Pominięto Mikołów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowogard ---
# Pominięto Nowogard z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mońki ---
# Pominięto Mońki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brzeg dolny ---
# Pominięto Brzeg dolny z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przewłoki ---
# Pominięto Przewłoki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chełm ---
# Pominięto Chełm z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świdnik ---
# Pominięto Świdnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chełmek ---
# Pominięto Chełmek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mława ---
# Pominięto Mława z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jaworzno ---
# Pominięto Jaworzno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Słupca ---
# Pominięto Słupca z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szklarska poręba ---
# Pominięto Szklarska poręba z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sianożęty ---
# Pominięto Sianożęty z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Środa wielkopolska ---
# Pominięto Środa wielkopolska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Białobrzegi ---
# Pominięto Białobrzegi z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzcianka ---
# Pominięto Trzcianka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dębica ---
# Pominięto Dębica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowe oborzyska ---
# Pominięto Nowe oborzyska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Straszyn ---
# Pominięto Straszyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dziekanów nowy ---
# Pominięto Dziekanów nowy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brześć kujawski ---
# Pominięto Brześć kujawski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rzepin ---
# Pominięto Rzepin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radwanice ---
# Pominięto Radwanice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzcinica wołowska ---
# Pominięto Trzcinica wołowska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zamość ---
# Pominięto Zamość z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lębork ---
# Pominięto Lębork z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grodzisk mazowiecki ---
# Pominięto Grodzisk mazowiecki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bielawa ---
# Pominięto Bielawa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Redzikowo ---
# Pominięto Redzikowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Koziegłowy ---
# Pominięto Koziegłowy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Drezdenko ---
# Pominięto Drezdenko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łęczna ---
# Pominięto Łęczna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lipiany ---
# Pominięto Lipiany z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rewal ---
# Pominięto Rewal z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zieleniewo ---
# Pominięto Zieleniewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Maksymilianowo ---
# Pominięto Maksymilianowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mierzyn ---
# Pominięto Mierzyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chojnów ---
# Pominięto Chojnów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chojniczki ---
# Pominięto Chojniczki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pasłęk ---
# Pominięto Pasłęk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Spalice ---
# Pominięto Spalice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Marki ---
# Pominięto Marki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Barczewo ---
# Pominięto Barczewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dzierzążenko ---
# Pominięto Dzierzążenko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ostrowiec świętokrzyski ---
# Pominięto Ostrowiec świętokrzyski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Płońsk ---
# Pominięto Płońsk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pszczyna ---
# Pominięto Pszczyna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sanok ---
# Pominięto Sanok z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Oświęcim ---
# Pominięto Oświęcim z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Iwno ---
# Pominięto Iwno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Murzynowo ---
# Pominięto Murzynowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rabowice ---
# Pominięto Rabowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brodnica ---
# Pominięto Brodnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żabnica ---
# Pominięto Żabnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kęty ---
# Pominięto Kęty z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nakło nad notecią ---
# Pominięto Nakło nad notecią z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Włodawa ---
# Pominięto Włodawa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Września ---
# Pominięto Września z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wołomin ---
# Pominięto Wołomin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Oleśnica ---
# Pominięto Oleśnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Legionowo ---
# Pominięto Legionowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zielonka ---
# Pominięto Zielonka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Góra kalwaria ---
# Pominięto Góra kalwaria z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mielno ---
# Pominięto Mielno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ciechocinek ---
# Pominięto Ciechocinek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wiączyń dolny ---
# Pominięto Wiączyń dolny z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wodzisław śląski ---
# Pominięto Wodzisław śląski z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Derczewo ---
# Pominięto Derczewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chojnice ---
# Pominięto Chojnice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dąbrówka ---
# Pominięto Dąbrówka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lipno ---
# Pominięto Lipno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zwoleń ---
# Pominięto Zwoleń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Suchy las ---
# Pominięto Suchy las z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wądzyn ---
# Pominięto Wądzyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mrągowo ---
# Pominięto Mrągowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wolsztyn ---
# Pominięto Wolsztyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wałbrzych ---
# Pominięto Wałbrzych z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grudziądz ---
# Pominięto Grudziądz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zgierz ---
# Pominięto Zgierz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Działdowo ---
# Pominięto Działdowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Staniszów ---
# Pominięto Staniszów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bytów ---
# Pominięto Bytów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Siechnice ---
# Pominięto Siechnice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nysa ---
# Pominięto Nysa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Reda ---
# Pominięto Reda z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jastrowie ---
# Pominięto Jastrowie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gryfice ---
# Pominięto Gryfice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przemyśl ---
# Pominięto Przemyśl z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Świnoujście ---
# Pominięto Świnoujście z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Staszów ---
# Pominięto Staszów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lubawa ---
# Pominięto Lubawa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ostrołęka ---
# Pominięto Ostrołęka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mała kępa ---
# Pominięto Mała kępa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mroków ---
# Pominięto Mroków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brwinów ---
# Pominięto Brwinów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowy dwór mazowiecki ---
# Pominięto Nowy dwór mazowiecki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Opoczno ---
# Pominięto Opoczno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kruszwica ---
# Pominięto Kruszwica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tarnowskie góry ---
# Pominięto Tarnowskie góry z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bolków ---
# Pominięto Bolków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Skierniewice ---
# Pominięto Skierniewice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przelewice ---
# Pominięto Przelewice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Drawsko pomorskie ---
# Pominięto Drawsko pomorskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kartuzy ---
# Pominięto Kartuzy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Święta katarzyna ---
# Pominięto Święta katarzyna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Milanówek ---
# Pominięto Milanówek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Słubice ---
# Pominięto Słubice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przechlewo ---
# Pominięto Przechlewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grzybowo ---
# Pominięto Grzybowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Włostowo ---
# Pominięto Włostowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Łobez ---
# Pominięto Łobez z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Siewierz ---
# Pominięto Siewierz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chełmno ---
# Pominięto Chełmno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dolice ---
# Pominięto Dolice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Biała ---
# Pominięto Biała z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Cieszyn ---
# Pominięto Cieszyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Międzyrzecz ---
# Pominięto Międzyrzecz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Krapkowice ---
# Pominięto Krapkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radzionków ---
# Pominięto Radzionków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Domanin ---
# Pominięto Domanin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Swarzędz ---
# Pominięto Swarzędz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Czeladź ---
# Pominięto Czeladź z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kargowa ---
# Pominięto Kargowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Puck ---
# Pominięto Puck z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jabłonna ---
# Pominięto Jabłonna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Radomierzyce ---
# Pominięto Radomierzyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Michałówek ---
# Pominięto Michałówek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Włoszczowa ---
# Pominięto Włoszczowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Górowo iławeckie ---
# Pominięto Górowo iławeckie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pogorzelica ---
# Pominięto Pogorzelica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zawiercie ---
# Pominięto Zawiercie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dziekanowice ---
# Pominięto Dziekanowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Porosły ---
# Pominięto Porosły z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gniechowice ---
# Pominięto Gniechowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wadowice ---
# Pominięto Wadowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wola mrokowska ---
# Pominięto Wola mrokowska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nadma ---
# Pominięto Nadma z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Złotoryja ---
# Pominięto Złotoryja z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gromadka ---
# ...
#
# --- Trenowanie modelu dla miasta: Kłudno ---
# Pominięto Kłudno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Piduń ---
# Pominięto Piduń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Popielewko ---
# Pominięto Popielewko z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lipia góra ---
# Pominięto Lipia góra z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Obra ---
# Pominięto Obra z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Urbanowo ---
# Pominięto Urbanowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Werdun ---
# Pominięto Werdun z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żelazów ---
# Pominięto Żelazów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kuranów ---
# Pominięto Kuranów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Leszczyniec ---
# Pominięto Leszczyniec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Karczyn ---
# Pominięto Karczyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chinów ---
# Pominięto Chinów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tolcz ---
# Pominięto Tolcz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Opolnica ---
# Pominięto Opolnica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Posadowice ---
# Pominięto Posadowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kusin ---
# Pominięto Kusin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żelechowo ---
# Pominięto Żelechowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Płutowo ---
# Pominięto Płutowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gójsk ---
# Pominięto Gójsk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kościernica ---
# Pominięto Kościernica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lewków ---
# Pominięto Lewków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kanibród ---
# Pominięto Kanibród z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Stolno ---
# Pominięto Stolno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tuchla ---
# Pominięto Tuchla z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Równia ---
# Pominięto Równia z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Niećkowo ---
# Pominięto Niećkowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Raszowa ---
# Pominięto Raszowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ocice ---
# Pominięto Ocice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Janopole ---
# Pominięto Janopole z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nienowice ---
# Pominięto Nienowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sufczyn ---
# Pominięto Sufczyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gnatowo ---
# Pominięto Gnatowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Warszawianka ---
# Pominięto Warszawianka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tatynia ---
# Pominięto Tatynia z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Powidz ---
# Pominięto Powidz z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wytok ---
# Pominięto Wytok z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gołębiewek stary ---
# Pominięto Gołębiewek stary z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mochała ---
# Pominięto Mochała z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Pniewite ---
# Pominięto Pniewite z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jeże ---
# Pominięto Jeże z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Grabowska huta ---
# Pominięto Grabowska huta z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Donosy ---
# Pominięto Donosy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Polanka ---
# Pominięto Polanka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szamoty ---
# Pominięto Szamoty z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zastawie ---
# Pominięto Zastawie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bocheniec ---
# Pominięto Bocheniec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Stare kozłowice ---
# Pominięto Stare kozłowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Głuszyn ---
# Pominięto Głuszyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kłódka ---
# Pominięto Kłódka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tropy sztumskie ---
# Pominięto Tropy sztumskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mroczeń ---
# Pominięto Mroczeń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kąp ---
# Pominięto Kąp z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wola błędowa ---
# Pominięto Wola błędowa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Powroźnik ---
# Pominięto Powroźnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Czostków ---
# Pominięto Czostków z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mieszewo ---
# Pominięto Mieszewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kozierów ---
# Pominięto Kozierów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Surmaczówka ---
# Pominięto Surmaczówka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jeziórki ---
# Pominięto Jeziórki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kopaszyce ---
# Pominięto Kopaszyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Płużnica wielka ---
# Pominięto Płużnica wielka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Wiszniów ---
# Pominięto Wiszniów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sulin ---
# Pominięto Sulin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzciana ---
# Pominięto Trzciana z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rogóźno ---
# Pominięto Rogóźno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szemudzka huta ---
# Pominięto Szemudzka huta z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Cieszkowo stare ---
# Pominięto Cieszkowo stare z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Obodowo ---
# Pominięto Obodowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jarząbkowice ---
# Pominięto Jarząbkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Zosin ---
# Pominięto Zosin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Żmigródek ---
# Pominięto Żmigródek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Trzemosna ---
# Pominięto Trzemosna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Niedźwiednik ---
# Pominięto Niedźwiednik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Czyżew-siedliska ---
# Pominięto Czyżew-siedliska z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rudziczka ---
# Pominięto Rudziczka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kaniów ---
# Pominięto Kaniów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Roszkowice ---
# Pominięto Roszkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mątawy ---
# Pominięto Mątawy z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Palczewo ---
# Pominięto Palczewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Mieszałki ---
# Pominięto Mieszałki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Lubstówek ---
# Pominięto Lubstówek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Krzaki czaplinkowskie ---
# Pominięto Krzaki czaplinkowskie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rudunki ---
# Pominięto Rudunki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kwiecewo ---
# Pominięto Kwiecewo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bulowice ---
# Pominięto Bulowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szczukowskie górki ---
# Pominięto Szczukowskie górki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Bąkówka ---
# Pominięto Bąkówka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Ligota książęca ---
# Pominięto Ligota książęca z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Karsinka ---
# Pominięto Karsinka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Cypriany ---
# Pominięto Cypriany z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Potulin ---
# Pominięto Potulin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brzozie ---
# Pominięto Brzozie z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Boreczek ---
# Pominięto Boreczek z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Więcław ---
# Pominięto Więcław z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Dulsk ---
# Pominięto Dulsk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Chlastawa ---
# Pominięto Chlastawa z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Cekanowo ---
# Pominięto Cekanowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rawka ---
# Pominięto Rawka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowa góra ---
# Pominięto Nowa góra z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Sąpolno ---
# Pominięto Sąpolno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Brynica ---
# Pominięto Brynica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Goryń ---
# Pominięto Goryń z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Nowe objezierze ---
# Pominięto Nowe objezierze z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Strączno ---
# Pominięto Strączno z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Tłokinia wielka ---
# Pominięto Tłokinia wielka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kostrza ---
# Pominięto Kostrza z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szczuka ---
# Pominięto Szczuka z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gniewowo ---
# Pominięto Gniewowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Malenin ---
# Pominięto Malenin z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Orchowiec ---
# Pominięto Orchowiec z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Haczów ---
# Pominięto Haczów z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Szarejki ---
# Pominięto Szarejki z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Borysew ---
# Pominięto Borysew z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gajkowice ---
# Pominięto Gajkowice z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Jaroszyn ---
# Pominięto Jaroszyn z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przytyk ---
# Pominięto Przytyk z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Potkanna ---
# Pominięto Potkanna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gierczyce ---
# Pominięto Gierczyce z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Frank ---
# Pominięto Frank z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Gnojnik ---
# Pominięto Gnojnik z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Rakowo ---
# Pominięto Rakowo z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Przyczyna dolna ---
# Pominięto Przyczyna dolna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Kopanica ---
# Pominięto Kopanica z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).
#
# --- Trenowanie modelu dla miasta: Berzyna ---
# Pominięto Berzyna z powodu zbyt małej ilości danych treningowych (0 ogłoszeń).

# %%
# ==============================================================================
# KOMÓRKA 3: PREDYKCJA I GENEROWANIE WYNIKÓW
# ==============================================================================
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

print("\n--- Krok 4: Generowanie Predykcji i Wyników ---")

df_flats['Predict_Loc'] = df_flats['locationPath'].astype(str) # Domyślnie używamy oryginalnej ścieżki
predictions_made_count = 0

numerical_features = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuiltYear']
categorical_features = ['BuldingType']
text_based_features = ['text_district_id', 'text_subdistrict_id', 'text_street_id']
similarity_based_features = ['similar_district_id', 'similar_subdistrict_id', 'similar_street_id']

for city_name in df_flats['city_name'].unique():
    if pd.isna(city_name): continue
    
    model_path = os.path.join(ARTIFACTS_DIR, f'{city_name}_location_model.keras')
    if not os.path.exists(model_path):
        print(f"Brak modelu dla {city_name}, pomijam predykcję.")
        continue
        
    print(f"Przetwarzam predykcje dla: {city_name}")
    
    # Wczytanie artefaktów
    model = keras.models.load_model(model_path)
    scaler = joblib.load(os.path.join(ARTIFACTS_DIR, f'{city_name}_scaler.gz'))
    with open(os.path.join(ARTIFACTS_DIR, f'{city_name}_encoders.json'), 'r') as f:
        encoders = json.load(f)

    df_to_predict = df_flats[(df_flats['city_name'] == city_name) & (df_flats['loc_5'] == 0)].copy()
    if df_to_predict.empty: continue

    # Przygotowanie cech wejściowych do predykcji
    X_pred_num = scaler.transform(df_to_predict[numerical_features])
    X_pred_cat_df = pd.get_dummies(df_to_predict[categorical_features], prefix='type')
    X_pred_cat_reindexed = X_pred_cat_df.reindex(columns=encoders['ohe_columns'], fill_value=0)
    
    X_pred = np.hstack([
        X_pred_num, 
        X_pred_cat_reindexed.values, 
        df_to_predict[text_based_features].values, 
        df_to_predict[similarity_based_features].values
    ])
    
    predictions = model.predict(X_pred, verbose=0)
    
    pred_district_idx = np.argmax(predictions[0], axis=1)
    pred_subdistrict_idx = np.argmax(predictions[1], axis=1)
    pred_street_idx = np.argmax(predictions[2], axis=1)

    df_to_predict['pred_loc_5'] = [encoders['district']['mapping'].get(str(i), 0) for i in pred_district_idx]
    df_to_predict['pred_loc_6'] = [encoders['subdistrict']['mapping'].get(str(i), 0) for i in pred_subdistrict_idx]
    df_to_predict['pred_loc_7'] = [encoders['street']['mapping'].get(str(i), 0) for i in pred_street_idx]
    
    predict_loc_series = df_to_predict.apply(lambda row: f"{int(row['loc_1'])},{int(row['loc_2'])},{int(row['loc_3'])},{int(row['loc_4'])},{int(row['pred_loc_5'])},{int(row['pred_loc_6'])},{int(row['pred_loc_7'])}", axis=1)
    df_flats.loc[df_to_predict.index, 'Predict_Loc'] = predict_loc_series
    predictions_made_count += len(df_to_predict)

print(f"\nWykonano predykcje dla {predictions_made_count} ogłoszeń.")

# --- Zapis i wyświetlenie wyników ---
output_filename = 'Location_Polska.csv'
df_flats.to_csv(output_filename, index=False)
print(f"Ostateczny plik został zapisany jako: {output_filename}")

print("\n--- 20 losowych przykładów predykcji ---")
predicted_rows = df_flats[df_flats['loc_5'] == 0].copy()

if not predicted_rows.empty:
    predicted_rows['pred_loc_5_name'] = predicted_rows['Predict_Loc'].apply(lambda x: lok_dict.get(int(x.split(',')[4]), 'Brak'))
    predicted_rows['pred_loc_7_name'] = predicted_rows['Predict_Loc'].apply(lambda x: lok_dict.get(int(x.split(',')[6]), 'Brak'))

    display_cols = ['city_name', 'Price', 'Area', 'locationPath', 'Predict_Loc', 'pred_loc_5_name', 'pred_loc_7_name', 'Description']
    
    with pd.option_context('display.max_colwidth', 100):
        display(predicted_rows.sample(min(20, len(predicted_rows)))[display_cols])
else:
    print("Nie znaleziono wierszy, dla których wykonano predykcję.")

print("\nZadanie zakończone pomyślnie!")
# Out:
# --- Krok 4: Generowanie Predykcji i Wyników ---
# Brak modelu dla Białystok, pomijam predykcję.
# Brak modelu dla Piaski, pomijam predykcję.
# Brak modelu dla Lipowa, pomijam predykcję.
# Brak modelu dla Bydgoszcz, pomijam predykcję.
# Brak modelu dla Osówiec, pomijam predykcję.
# Brak modelu dla Gdynia, pomijam predykcję.
# Brak modelu dla Gdańsk, pomijam predykcję.
# Brak modelu dla Częstochowa, pomijam predykcję.
# Brak modelu dla Jasień, pomijam predykcję.
# Przetwarzam predykcje dla: Łódź
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# Przetwarzam predykcje dla: Kraków
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# Brak modelu dla Lublin, pomijam predykcję.
# Przetwarzam predykcje dla: Warszawa
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# Brak modelu dla Katowice, pomijam predykcję.
# Brak modelu dla Radom, pomijam predykcję.
# Brak modelu dla Sosnowiec, pomijam predykcję.
# Brak modelu dla Siemianowice śląskie, pomijam predykcję.
# Brak modelu dla Gliwice, pomijam predykcję.
# Brak modelu dla Szczecin, pomijam predykcję.
# Przetwarzam predykcje dla: Poznań
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# Brak modelu dla Toruń, pomijam predykcję.
# Brak modelu dla Plewiska, pomijam predykcję.
# Brak modelu dla Biedrusko, pomijam predykcję.
# Brak modelu dla Bielawy, pomijam predykcję.
# Brak modelu dla Olsztyn, pomijam predykcję.
# Brak modelu dla Robakowo, pomijam predykcję.
# Brak modelu dla Sopot, pomijam predykcję.
# Brak modelu dla Opole, pomijam predykcję.
# Brak modelu dla Mieroszów, pomijam predykcję.
# Brak modelu dla Siedlce, pomijam predykcję.
# Brak modelu dla Kętrzyn, pomijam predykcję.
# Brak modelu dla Kłodzko, pomijam predykcję.
# Brak modelu dla Dziwnówek, pomijam predykcję.
# Brak modelu dla Dziwnów, pomijam predykcję.
# Brak modelu dla Pobierowo, pomijam predykcję.
# Brak modelu dla Iława, pomijam predykcję.
# Brak modelu dla Szczecinek, pomijam predykcję.
# Brak modelu dla Pabianice, pomijam predykcję.
# Brak modelu dla Gniezno, pomijam predykcję.
# Brak modelu dla Otwock, pomijam predykcję.
# Brak modelu dla Kędzierzyn-koźle, pomijam predykcję.
# Brak modelu dla Bielsko-biała, pomijam predykcję.
# Brak modelu dla Dzierżoniów, pomijam predykcję.
# Brak modelu dla Gozdnica, pomijam predykcję.
# Brak modelu dla Chorzów, pomijam predykcję.
# Brak modelu dla Tychy, pomijam predykcję.
# Brak modelu dla Zduńska wola, pomijam predykcję.
# Brak modelu dla Tarnów, pomijam predykcję.
# Brak modelu dla Piotrków trybunalski, pomijam predykcję.
# Brak modelu dla Mińsk mazowiecki, pomijam predykcję.
# Brak modelu dla Skarżysko-kamienna, pomijam predykcję.
# Brak modelu dla Trzemeszno, pomijam predykcję.
# Brak modelu dla Wiślinka, pomijam predykcję.
# Brak modelu dla Włocławek, pomijam predykcję.
# Brak modelu dla Owińska, pomijam predykcję.
# Brak modelu dla Gorzów wielkopolski, pomijam predykcję.
# Brak modelu dla Nowy sącz, pomijam predykcję.
# Brak modelu dla Mielec, pomijam predykcję.
# Brak modelu dla Konin, pomijam predykcję.
# Brak modelu dla Bielsk podlaski, pomijam predykcję.
# Brak modelu dla Łabędnik, pomijam predykcję.
# Brak modelu dla Kościan, pomijam predykcję.
# Brak modelu dla Janczewice, pomijam predykcję.
# Brak modelu dla Sokołów małopolski, pomijam predykcję.
# Brak modelu dla Rzeszów, pomijam predykcję.
# Brak modelu dla Ruda śląska, pomijam predykcję.
# Brak modelu dla Wyszków, pomijam predykcję.
# Brak modelu dla Słupsk, pomijam predykcję.
# Brak modelu dla Rumia, pomijam predykcję.
# Brak modelu dla Bytom, pomijam predykcję.
# Brak modelu dla Pruszków, pomijam predykcję.
# Brak modelu dla Ustronie morskie, pomijam predykcję.
# Brak modelu dla Kielce, pomijam predykcję.
# Brak modelu dla Nowy staw, pomijam predykcję.
# Brak modelu dla Ząbki, pomijam predykcję.
# Brak modelu dla Leszno, pomijam predykcję.
# Brak modelu dla Garwolin, pomijam predykcję.
# Brak modelu dla Giżycko, pomijam predykcję.
# Brak modelu dla Namysłów, pomijam predykcję.
# Brak modelu dla Bolszewo, pomijam predykcję.
# Brak modelu dla Tczew, pomijam predykcję.
# Brak modelu dla Jawor, pomijam predykcję.
# Brak modelu dla Zabrze, pomijam predykcję.
# Brak modelu dla Dąbrowa górnicza, pomijam predykcję.
# Brak modelu dla Kwidzyn, pomijam predykcję.
# Brak modelu dla Miastko, pomijam predykcję.
# Brak modelu dla Świeradów-zdrój, pomijam predykcję.
# Brak modelu dla Świdwin, pomijam predykcję.
# Brak modelu dla Piekary śląskie, pomijam predykcję.
# Brak modelu dla Banino, pomijam predykcję.
# Brak modelu dla Brzeg, pomijam predykcję.
# Brak modelu dla Wąbrzeźno, pomijam predykcję.
# Brak modelu dla Rybnik, pomijam predykcję.
# Brak modelu dla Kołobrzeg, pomijam predykcję.
# Brak modelu dla Ryki, pomijam predykcję.
# Brak modelu dla Radomsko, pomijam predykcję.
# Brak modelu dla Połczyn-zdrój, pomijam predykcję.
# Brak modelu dla Golub-dobrzyń, pomijam predykcję.
# Brak modelu dla Ciechanów, pomijam predykcję.
# Brak modelu dla Błonie, pomijam predykcję.
# Brak modelu dla Luboń, pomijam predykcję.
# Brak modelu dla Lesznowola, pomijam predykcję.
# Przetwarzam predykcje dla: Wrocław
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# Brak modelu dla Szamotuły, pomijam predykcję.
# Brak modelu dla Radzymin, pomijam predykcję.
# Brak modelu dla Sobótka, pomijam predykcję.
# Brak modelu dla Zakręt, pomijam predykcję.
# Brak modelu dla Legnica, pomijam predykcję.
# Brak modelu dla Sandomierz, pomijam predykcję.
# Brak modelu dla Psarskie, pomijam predykcję.
# Brak modelu dla Rokitki, pomijam predykcję.
# Brak modelu dla Trzebiatów, pomijam predykcję.
# Brak modelu dla Wrzosowa, pomijam predykcję.
# Brak modelu dla Darłowo, pomijam predykcję.
# Brak modelu dla Jelenia góra, pomijam predykcję.
# Brak modelu dla Grójec, pomijam predykcję.
# Brak modelu dla Piaseczno, pomijam predykcję.
# Brak modelu dla Inowrocław, pomijam predykcję.
# Brak modelu dla Dobczyce, pomijam predykcję.
# Brak modelu dla Zielona góra, pomijam predykcję.
# Brak modelu dla Racibórz, pomijam predykcję.
# Brak modelu dla Polanica-zdrój, pomijam predykcję.
# Brak modelu dla Ustka, pomijam predykcję.
# Brak modelu dla Zalasewo, pomijam predykcję.
# Brak modelu dla Malbork, pomijam predykcję.
# Brak modelu dla Piła, pomijam predykcję.
# Brak modelu dla Szczawnica, pomijam predykcję.
# Brak modelu dla Elbląg, pomijam predykcję.
# Brak modelu dla Miłkowice, pomijam predykcję.
# Brak modelu dla Puławy, pomijam predykcję.
# Brak modelu dla Świebodzin, pomijam predykcję.
# Brak modelu dla Rząska, pomijam predykcję.
# Brak modelu dla Białogard, pomijam predykcję.
# Brak modelu dla Wielka wieś, pomijam predykcję.
# Brak modelu dla Śrem, pomijam predykcję.
# Brak modelu dla Nowy dwór, pomijam predykcję.
# Brak modelu dla Ostrów wielkopolski, pomijam predykcję.
# Brak modelu dla Świdnica, pomijam predykcję.
# Brak modelu dla Bartoszyce, pomijam predykcję.
# Brak modelu dla Żagań, pomijam predykcję.
# Brak modelu dla Wejherowo, pomijam predykcję.
# Brak modelu dla Stargard, pomijam predykcję.
# Brak modelu dla Rutkowice, pomijam predykcję.
# Brak modelu dla Ustroń, pomijam predykcję.
# Brak modelu dla Józefosław, pomijam predykcję.
# Brak modelu dla Pyrzyce, pomijam predykcję.
# Brak modelu dla Morąg, pomijam predykcję.
# Brak modelu dla Bełchatów, pomijam predykcję.
# Brak modelu dla Jastrzębie-zdrój, pomijam predykcję.
# Brak modelu dla Księginice, pomijam predykcję.
# Brak modelu dla Czapury, pomijam predykcję.
# Brak modelu dla Starogard gdański, pomijam predykcję.
# Brak modelu dla Będzin, pomijam predykcję.
# Brak modelu dla Grodków, pomijam predykcję.
# Brak modelu dla Czechowice-dziedzice, pomijam predykcję.
# Brak modelu dla Pruszcz gdański, pomijam predykcję.
# Brak modelu dla Kozienice, pomijam predykcję.
# Brak modelu dla Nowa sól, pomijam predykcję.
# Brak modelu dla Wolbrom, pomijam predykcję.
# Brak modelu dla Dęblin, pomijam predykcję.
# Brak modelu dla Julianów, pomijam predykcję.
# Brak modelu dla Osielsko, pomijam predykcję.
# Brak modelu dla Pleszew, pomijam predykcję.
# Brak modelu dla Wieliczka, pomijam predykcję.
# Brak modelu dla Zakopane, pomijam predykcję.
# Brak modelu dla Bielany wrocławskie, pomijam predykcję.
# Brak modelu dla Boguszów-gorce, pomijam predykcję.
# Brak modelu dla Kleszczewo, pomijam predykcję.
# Brak modelu dla Świętochłowice, pomijam predykcję.
# Brak modelu dla Busko-zdrój, pomijam predykcję.
# Brak modelu dla Tarnobrzeg, pomijam predykcję.
# Brak modelu dla Iwiny, pomijam predykcję.
# Brak modelu dla Rydułtowy, pomijam predykcję.
# Brak modelu dla Kalisz, pomijam predykcję.
# Brak modelu dla Ełk, pomijam predykcję.
# Brak modelu dla Jonkowo, pomijam predykcję.
# Brak modelu dla Podłęże, pomijam predykcję.
# Brak modelu dla Stalowa wola, pomijam predykcję.
# Brak modelu dla Skawina, pomijam predykcję.
# Brak modelu dla Zgorzelec, pomijam predykcję.
# Brak modelu dla Strzelce, pomijam predykcję.
# Brak modelu dla Zdzieszowice, pomijam predykcję.
# Brak modelu dla Wierchlesie, pomijam predykcję.
# Brak modelu dla Police, pomijam predykcję.
# Brak modelu dla Popowo kościelne, pomijam predykcję.
# Brak modelu dla Lubin, pomijam predykcję.
# Brak modelu dla Kolbuszowa, pomijam predykcję.
# Brak modelu dla Stara iwiczna, pomijam predykcję.
# Brak modelu dla Sochaczew, pomijam predykcję.
# Brak modelu dla Suwałki, pomijam predykcję.
# Brak modelu dla Markowo, pomijam predykcję.
# Brak modelu dla Wieliszew, pomijam predykcję.
# Brak modelu dla Kutno, pomijam predykcję.
# Brak modelu dla Zielonki, pomijam predykcję.
# Brak modelu dla Barlinek, pomijam predykcję.
# Brak modelu dla Kobyłka, pomijam predykcję.
# Brak modelu dla Brzesko, pomijam predykcję.
# Brak modelu dla Łuków, pomijam predykcję.
# Brak modelu dla Pińczów, pomijam predykcję.
# Brak modelu dla Mysłowice, pomijam predykcję.
# Brak modelu dla Pionki, pomijam predykcję.
# Brak modelu dla Bobolice, pomijam predykcję.
# Brak modelu dla Międzyzdroje, pomijam predykcję.
# Brak modelu dla Jeleniów, pomijam predykcję.
# Brak modelu dla Żory, pomijam predykcję.
# Brak modelu dla Milicz, pomijam predykcję.
# Brak modelu dla Rypin, pomijam predykcję.
# Brak modelu dla Maszewo, pomijam predykcję.
# Brak modelu dla Żędowice, pomijam predykcję.
# Brak modelu dla Konstantynów łódzki, pomijam predykcję.
# Brak modelu dla Kieźliny, pomijam predykcję.
# Brak modelu dla Lubartów, pomijam predykcję.
# Brak modelu dla Korsze, pomijam predykcję.
# Brak modelu dla Żary, pomijam predykcję.
# Brak modelu dla Głogów, pomijam predykcję.
# Brak modelu dla Blizne łaszczyńskiego, pomijam predykcję.
# Brak modelu dla Niepołomice, pomijam predykcję.
# Brak modelu dla Kamionki, pomijam predykcję.
# Brak modelu dla Bolesławiec, pomijam predykcję.
# Brak modelu dla Walim, pomijam predykcję.
# Brak modelu dla Kowale, pomijam predykcję.
# Brak modelu dla Koszalin, pomijam predykcję.
# Brak modelu dla Wągrowiec, pomijam predykcję.
# Brak modelu dla Kraśnik, pomijam predykcję.
# Brak modelu dla Złotów, pomijam predykcję.
# Brak modelu dla Krynica morska, pomijam predykcję.
# Brak modelu dla Żyrardów, pomijam predykcję.
# Brak modelu dla Łomża, pomijam predykcję.
# Brak modelu dla Wałcz, pomijam predykcję.
# Brak modelu dla Resko, pomijam predykcję.
# Brak modelu dla Mikołów, pomijam predykcję.
# Brak modelu dla Nowogard, pomijam predykcję.
# Brak modelu dla Mońki, pomijam predykcję.
# Brak modelu dla Brzeg dolny, pomijam predykcję.
# Brak modelu dla Przewłoki, pomijam predykcję.
# Brak modelu dla Chełm, pomijam predykcję.
# Brak modelu dla Świdnik, pomijam predykcję.
# Brak modelu dla Chełmek, pomijam predykcję.
# Brak modelu dla Mława, pomijam predykcję.
# Brak modelu dla Jaworzno, pomijam predykcję.
# Brak modelu dla Słupca, pomijam predykcję.
# Brak modelu dla Szklarska poręba, pomijam predykcję.
# Brak modelu dla Sianożęty, pomijam predykcję.
# Brak modelu dla Środa wielkopolska, pomijam predykcję.
# Brak modelu dla Białobrzegi, pomijam predykcję.
# Brak modelu dla Trzcianka, pomijam predykcję.
# Brak modelu dla Dębica, pomijam predykcję.
# Brak modelu dla Nowe oborzyska, pomijam predykcję.
# Brak modelu dla Straszyn, pomijam predykcję.
# Brak modelu dla Dziekanów nowy, pomijam predykcję.
# Brak modelu dla Brześć kujawski, pomijam predykcję.
# Brak modelu dla Rzepin, pomijam predykcję.
# Brak modelu dla Radwanice, pomijam predykcję.
# Brak modelu dla Trzcinica wołowska, pomijam predykcję.
# Brak modelu dla Zamość, pomijam predykcję.
# Brak modelu dla Lębork, pomijam predykcję.
# Brak modelu dla Grodzisk mazowiecki, pomijam predykcję.
# Brak modelu dla Bielawa, pomijam predykcję.
# Brak modelu dla Redzikowo, pomijam predykcję.
# Brak modelu dla Koziegłowy, pomijam predykcję.
# Brak modelu dla Drezdenko, pomijam predykcję.
# Brak modelu dla Łęczna, pomijam predykcję.
# Brak modelu dla Lipiany, pomijam predykcję.
# Brak modelu dla Rewal, pomijam predykcję.
# Brak modelu dla Zieleniewo, pomijam predykcję.
# Brak modelu dla Maksymilianowo, pomijam predykcję.
# Brak modelu dla Mierzyn, pomijam predykcję.
# Brak modelu dla Chojnów, pomijam predykcję.
# Brak modelu dla Chojniczki, pomijam predykcję.
# Brak modelu dla Pasłęk, pomijam predykcję.
# Brak modelu dla Spalice, pomijam predykcję.
# Brak modelu dla Marki, pomijam predykcję.
# Brak modelu dla Barczewo, pomijam predykcję.
# Brak modelu dla Dzierzążenko, pomijam predykcję.
# Brak modelu dla Ostrowiec świętokrzyski, pomijam predykcję.
# Brak modelu dla Płońsk, pomijam predykcję.
# Brak modelu dla Pszczyna, pomijam predykcję.
# Brak modelu dla Sanok, pomijam predykcję.
# Brak modelu dla Oświęcim, pomijam predykcję.
# Brak modelu dla Iwno, pomijam predykcję.
# Brak modelu dla Murzynowo, pomijam predykcję.
# Brak modelu dla Rabowice, pomijam predykcję.
# Brak modelu dla Brodnica, pomijam predykcję.
# Brak modelu dla Żabnica, pomijam predykcję.
# Brak modelu dla Kęty, pomijam predykcję.
# Brak modelu dla Nakło nad notecią, pomijam predykcję.
# Brak modelu dla Włodawa, pomijam predykcję.
# Brak modelu dla Września, pomijam predykcję.
# Brak modelu dla Wołomin, pomijam predykcję.
# Brak modelu dla Oleśnica, pomijam predykcję.
# Brak modelu dla Legionowo, pomijam predykcję.
# Brak modelu dla Zielonka, pomijam predykcję.
# Brak modelu dla Góra kalwaria, pomijam predykcję.
# Brak modelu dla Mielno, pomijam predykcję.
# Brak modelu dla Ciechocinek, pomijam predykcję.
# Brak modelu dla Wiączyń dolny, pomijam predykcję.
# Brak modelu dla Wodzisław śląski, pomijam predykcję.
# Brak modelu dla Derczewo, pomijam predykcję.
# Brak modelu dla Chojnice, pomijam predykcję.
# Brak modelu dla Dąbrówka, pomijam predykcję.
# Brak modelu dla Lipno, pomijam predykcję.
# Brak modelu dla Zwoleń, pomijam predykcję.
# Brak modelu dla Suchy las, pomijam predykcję.
# Brak modelu dla Wądzyn, pomijam predykcję.
# Brak modelu dla Mrągowo, pomijam predykcję.
# Brak modelu dla Wolsztyn, pomijam predykcję.
# Brak modelu dla Wałbrzych, pomijam predykcję.
# Brak modelu dla Grudziądz, pomijam predykcję.
# Brak modelu dla Zgierz, pomijam predykcję.
# Brak modelu dla Działdowo, pomijam predykcję.
# Brak modelu dla Staniszów, pomijam predykcję.
# Brak modelu dla Bytów, pomijam predykcję.
# Brak modelu dla Siechnice, pomijam predykcję.
# Brak modelu dla Nysa, pomijam predykcję.
# Brak modelu dla Reda, pomijam predykcję.
# Brak modelu dla Jastrowie, pomijam predykcję.
# Brak modelu dla Gryfice, pomijam predykcję.
# Brak modelu dla Przemyśl, pomijam predykcję.
# Brak modelu dla Świnoujście, pomijam predykcję.
# Brak modelu dla Staszów, pomijam predykcję.
# Brak modelu dla Lubawa, pomijam predykcję.
# Brak modelu dla Ostrołęka, pomijam predykcję.
# Brak modelu dla Mała kępa, pomijam predykcję.
# Brak modelu dla Mroków, pomijam predykcję.
# Brak modelu dla Brwinów, pomijam predykcję.
# Brak modelu dla Nowy dwór mazowiecki, pomijam predykcję.
# Brak modelu dla Opoczno, pomijam predykcję.
# Brak modelu dla Kruszwica, pomijam predykcję.
# Brak modelu dla Tarnowskie góry, pomijam predykcję.
# Brak modelu dla Bolków, pomijam predykcję.
# Brak modelu dla Skierniewice, pomijam predykcję.
# Brak modelu dla Przelewice, pomijam predykcję.
# Brak modelu dla Drawsko pomorskie, pomijam predykcję.
# Brak modelu dla Kartuzy, pomijam predykcję.
# Brak modelu dla Święta katarzyna, pomijam predykcję.
# Brak modelu dla Milanówek, pomijam predykcję.
# Brak modelu dla Słubice, pomijam predykcję.
# Brak modelu dla Przechlewo, pomijam predykcję.
# Brak modelu dla Grzybowo, pomijam predykcję.
# Brak modelu dla Włostowo, pomijam predykcję.
# Brak modelu dla Łobez, pomijam predykcję.
# Brak modelu dla Siewierz, pomijam predykcję.
# Brak modelu dla Chełmno, pomijam predykcję.
# Brak modelu dla Dolice, pomijam predykcję.
# Brak modelu dla Biała, pomijam predykcję.
# Brak modelu dla Cieszyn, pomijam predykcję.
# Brak modelu dla Międzyrzecz, pomijam predykcję.
# Brak modelu dla Krapkowice, pomijam predykcję.
# Brak modelu dla Radzionków, pomijam predykcję.
# Brak modelu dla Domanin, pomijam predykcję.
# Brak modelu dla Swarzędz, pomijam predykcję.
# Brak modelu dla Czeladź, pomijam predykcję.
# Brak modelu dla Kargowa, pomijam predykcję.
# Brak modelu dla Puck, pomijam predykcję.
# Brak modelu dla Jabłonna, pomijam predykcję.
# Brak modelu dla Radomierzyce, pomijam predykcję.
# Brak modelu dla Michałówek, pomijam predykcję.
# Brak modelu dla Włoszczowa, pomijam predykcję.
# Brak modelu dla Górowo iławeckie, pomijam predykcję.
# Brak modelu dla Pogorzelica, pomijam predykcję.
# Brak modelu dla Zawiercie, pomijam predykcję.
# Brak modelu dla Dziekanowice, pomijam predykcję.
# Brak modelu dla Porosły, pomijam predykcję.
# Brak modelu dla Gniechowice, pomijam predykcję.
# Brak modelu dla Wadowice, pomijam predykcję.
# Brak modelu dla Wola mrokowska, pomijam predykcję.
# Brak modelu dla Nadma, pomijam predykcję.
# Brak modelu dla Złotoryja, pomijam predykcję.
# Brak modelu dla Gromadka, pomijam predykcję.
# Brak modelu dla Turek, pomijam predykcję.
# Brak modelu dla Lubaczów, pomijam predykcję.
# Brak modelu dla Czarnochowice, pomijam predykcję.
# Brak modelu dla Poręba, pomijam predykcję.
# Brak modelu dla Stegna, pomijam predykcję.
# Brak modelu dla Dobre miasto, pomijam predykcję.
# Brak modelu dla Wysoka, pomijam predykcję.
# Brak modelu dla Człuchów, pomijam predykcję.
# Brak modelu dla Syców, pomijam predykcję.
# Brak modelu dla Ożarów mazowiecki, pomijam predykcję.
# Brak modelu dla Myślenice, pomijam predykcję.
# Brak modelu dla Ozorków, pomijam predykcję.
# Brak modelu dla Augustów, pomijam predykcję.
# Brak modelu dla Płock, pomijam predykcję.
# Brak modelu dla Raków, pomijam predykcję.
# Brak modelu dla Żytkiejmy, pomijam predykcję.
# Brak modelu dla Skrzydlów, pomijam predykcję.
# Brak modelu dla Wola krzysztoporska, pomijam predykcję.
# Brak modelu dla Tomaszów mazowiecki, pomijam predykcję.
# Brak modelu dla Międzywodzie, pomijam predykcję.
# Brak modelu dla Ignatki, pomijam predykcję.
# Brak modelu dla Pełczyce, pomijam predykcję.
# Brak modelu dla Damnica, pomijam predykcję.
# Brak modelu dla Nowy tomyśl, pomijam predykcję.
# Brak modelu dla Malawa, pomijam predykcję.
# Brak modelu dla Pogórze, pomijam predykcję.
# Brak modelu dla Radlin, pomijam predykcję.
# Brak modelu dla Wojtkówka, pomijam predykcję.
# Brak modelu dla Paczółtowice, pomijam predykcję.
# Brak modelu dla Biała podlaska, pomijam predykcję.
# Brak modelu dla Mikołajki, pomijam predykcję.
# Brak modelu dla Leśna, pomijam predykcję.
# Brak modelu dla Gryfino, pomijam predykcję.
# Brak modelu dla Skarpa, pomijam predykcję.
# Brak modelu dla Skopanie, pomijam predykcję.
# Brak modelu dla Górzno, pomijam predykcję.
# Brak modelu dla Żmigród, pomijam predykcję.
# Brak modelu dla Wojbórz, pomijam predykcję.
# Brak modelu dla Grajewo, pomijam predykcję.
# Brak modelu dla Oława, pomijam predykcję.
# Brak modelu dla Gozdowo, pomijam predykcję.
# Brak modelu dla Wilczyce, pomijam predykcję.
# Brak modelu dla Trzeboszowice, pomijam predykcję.
# Brak modelu dla Kolonia mrokowska, pomijam predykcję.
# Brak modelu dla Ostroszowice, pomijam predykcję.
# Brak modelu dla Kamień pomorski, pomijam predykcję.
# Brak modelu dla Władysławowo, pomijam predykcję.
# Brak modelu dla Krotoszyn, pomijam predykcję.
# Brak modelu dla Ostróda, pomijam predykcję.
# Brak modelu dla Małomice, pomijam predykcję.
# Brak modelu dla Kałuszyn, pomijam predykcję.
# Brak modelu dla Komorów, pomijam predykcję.
# Brak modelu dla Kostrzyn nad odrą, pomijam predykcję.
# Brak modelu dla Kuźnia raciborska, pomijam predykcję.
# Brak modelu dla Polkowice, pomijam predykcję.
# Brak modelu dla Kryniczno, pomijam predykcję.
# Brak modelu dla Kowary, pomijam predykcję.
# Brak modelu dla Kościelisko, pomijam predykcję.
# Brak modelu dla Zawada, pomijam predykcję.
# Brak modelu dla Stary węgliniec, pomijam predykcję.
# Brak modelu dla Wschowa, pomijam predykcję.
# Brak modelu dla Wolin, pomijam predykcję.
# Brak modelu dla Nadarzyn, pomijam predykcję.
# Brak modelu dla Mników, pomijam predykcję.
# Brak modelu dla Ryn, pomijam predykcję.
# Brak modelu dla Oborniki, pomijam predykcję.
# Brak modelu dla Rokietnica, pomijam predykcję.
# Brak modelu dla Krzeptów, pomijam predykcję.
# Brak modelu dla Kielanówka, pomijam predykcję.
# Brak modelu dla Karpacz, pomijam predykcję.
# Brak modelu dla Wisła, pomijam predykcję.
# Brak modelu dla Czarna woda, pomijam predykcję.
# Brak modelu dla Ropczyce, pomijam predykcję.
# Brak modelu dla Działyń, pomijam predykcję.
# Brak modelu dla Łeba, pomijam predykcję.
# Brak modelu dla Biały bór, pomijam predykcję.
# Brak modelu dla Gudowo, pomijam predykcję.
# Brak modelu dla Borne sulinowo, pomijam predykcję.
# Brak modelu dla Łańcut, pomijam predykcję.
# Brak modelu dla Wojcieszów, pomijam predykcję.
# Brak modelu dla Gorlice, pomijam predykcję.
# Brak modelu dla Głowno, pomijam predykcję.
# Brak modelu dla Halasy, pomijam predykcję.
# Brak modelu dla Barcin, pomijam predykcję.
# Brak modelu dla Łupowo, pomijam predykcję.
# Brak modelu dla Lubań, pomijam predykcję.
# Brak modelu dla Kamienna góra, pomijam predykcję.
# Brak modelu dla Niałek wielki, pomijam predykcję.
# Brak modelu dla Sygneczów, pomijam predykcję.
# Brak modelu dla Gowarzewo, pomijam predykcję.
# Brak modelu dla Olecko, pomijam predykcję.
# Brak modelu dla Pieszyce, pomijam predykcję.
# Brak modelu dla Kluczbork, pomijam predykcję.
# Brak modelu dla Radoszewo, pomijam predykcję.
# Brak modelu dla Mokronos górny, pomijam predykcję.
# Brak modelu dla Olsztynek, pomijam predykcję.
# Brak modelu dla Warzymice, pomijam predykcję.
# Brak modelu dla Dąbrowa tarnowska, pomijam predykcję.
# Brak modelu dla Kąty wrocławskie, pomijam predykcję.
# Brak modelu dla Wasilków, pomijam predykcję.
# Brak modelu dla Biała woda, pomijam predykcję.
# Brak modelu dla Hiszpania, pomijam predykcję.
# Brak modelu dla Żnin, pomijam predykcję.
# Brak modelu dla Knurów, pomijam predykcję.
# Brak modelu dla Białka tatrzańska, pomijam predykcję.
# Brak modelu dla Turka, pomijam predykcję.
# Brak modelu dla Lesko, pomijam predykcję.
# Brak modelu dla Sierakowice, pomijam predykcję.
# Brak modelu dla Srebrna, pomijam predykcję.
# Brak modelu dla Golczewo, pomijam predykcję.
# Brak modelu dla Świerzno, pomijam predykcję.
# Brak modelu dla Goleniów, pomijam predykcję.
# Brak modelu dla Węgry, pomijam predykcję.
# Brak modelu dla Buczkowice, pomijam predykcję.
# Brak modelu dla Dobroszyce, pomijam predykcję.
# Brak modelu dla Paprotnia, pomijam predykcję.
# Brak modelu dla Trzebnica, pomijam predykcję.
# Brak modelu dla Sztutowo, pomijam predykcję.
# Brak modelu dla Koronowo, pomijam predykcję.
# Brak modelu dla Jenin, pomijam predykcję.
# Brak modelu dla Jaroszowiec, pomijam predykcję.
# Brak modelu dla Gołdap, pomijam predykcję.
# Brak modelu dla Biłgoraj, pomijam predykcję.
# Brak modelu dla Krasnystaw, pomijam predykcję.
# Brak modelu dla Piława górna, pomijam predykcję.
# Brak modelu dla Szwecja, pomijam predykcję.
# Brak modelu dla Stary chwalim, pomijam predykcję.
# Brak modelu dla Stasiówka, pomijam predykcję.
# Brak modelu dla Bełżyce, pomijam predykcję.
# Brak modelu dla Cierpice, pomijam predykcję.
# Brak modelu dla Błaszki, pomijam predykcję.
# Brak modelu dla Węgierki, pomijam predykcję.
# Brak modelu dla Gostyń, pomijam predykcję.
# Brak modelu dla Sokółka, pomijam predykcję.
# Brak modelu dla Ostrów mazowiecka, pomijam predykcję.
# Brak modelu dla Kłobuck, pomijam predykcję.
# Brak modelu dla Smolec, pomijam predykcję.
# Brak modelu dla Piastów, pomijam predykcję.
# Brak modelu dla Konstantynów, pomijam predykcję.
# Brak modelu dla Raszyn, pomijam predykcję.
# Brak modelu dla Hel, pomijam predykcję.
# Brak modelu dla Laski, pomijam predykcję.
# Brak modelu dla Grochowiska szlacheckie, pomijam predykcję.
# Brak modelu dla Mogilany, pomijam predykcję.
# Brak modelu dla Skarszewy, pomijam predykcję.
# Brak modelu dla Nidzica, pomijam predykcję.
# Brak modelu dla Połaniec, pomijam predykcję.
# Brak modelu dla Glinno, pomijam predykcję.
# Brak modelu dla Bogdanowo, pomijam predykcję.
# Brak modelu dla Komorniki, pomijam predykcję.
# Brak modelu dla Wieluń, pomijam predykcję.
# Brak modelu dla Bierutów, pomijam predykcję.
# Brak modelu dla Jarosław, pomijam predykcję.
# Brak modelu dla Skórka, pomijam predykcję.
# Brak modelu dla Warka, pomijam predykcję.
# Brak modelu dla Jedwabno, pomijam predykcję.
# Brak modelu dla Jarocin, pomijam predykcję.
# Brak modelu dla Łysinin, pomijam predykcję.
# Brak modelu dla Sianów, pomijam predykcję.
# Brak modelu dla Maków mazowiecki, pomijam predykcję.
# Brak modelu dla Lucień, pomijam predykcję.
# Brak modelu dla Jasło, pomijam predykcję.
# Brak modelu dla Szczyrk, pomijam predykcję.
# Brak modelu dla Płoty, pomijam predykcję.
# Brak modelu dla Sierosław, pomijam predykcję.
# Brak modelu dla Niechorze, pomijam predykcję.
# Brak modelu dla Trzciniec, pomijam predykcję.
# Brak modelu dla Świebodzice, pomijam predykcję.
# Brak modelu dla Witkowo, pomijam predykcję.
# Brak modelu dla Szklarka radnicka, pomijam predykcję.
# Brak modelu dla Pyskowice, pomijam predykcję.
# Brak modelu dla Boguchwała, pomijam predykcję.
# Brak modelu dla Blachownia, pomijam predykcję.
# Brak modelu dla Tomaszowo, pomijam predykcję.
# Brak modelu dla Pakość, pomijam predykcję.
# Brak modelu dla Zgorzała, pomijam predykcję.
# Brak modelu dla Sępólno krajeńskie, pomijam predykcję.
# Brak modelu dla Starachowice, pomijam predykcję.
# Brak modelu dla Parzniew, pomijam predykcję.
# Brak modelu dla Okonek, pomijam predykcję.
# Brak modelu dla Ozimek, pomijam predykcję.
# Brak modelu dla Czarnowo, pomijam predykcję.
# Brak modelu dla Pułtusk, pomijam predykcję.
# Brak modelu dla Czarnków, pomijam predykcję.
# Brak modelu dla Rogoźno, pomijam predykcję.
# Brak modelu dla Nowy dwór-parcela, pomijam predykcję.
# Brak modelu dla Markotów duży, pomijam predykcję.
# Brak modelu dla Żywiec, pomijam predykcję.
# Brak modelu dla Radowice, pomijam predykcję.
# Brak modelu dla Lublewo gdańskie, pomijam predykcję.
# Brak modelu dla Choszczno, pomijam predykcję.
# Brak modelu dla Głuszyca, pomijam predykcję.
# Brak modelu dla Czarna białostocka, pomijam predykcję.
# Brak modelu dla Nasale, pomijam predykcję.
# Brak modelu dla Okmiany, pomijam predykcję.
# Brak modelu dla Nowa wieś, pomijam predykcję.
# Brak modelu dla Jabłkowo, pomijam predykcję.
# Brak modelu dla Olkusz, pomijam predykcję.
# Brak modelu dla Braniewo, pomijam predykcję.
# Brak modelu dla Luzino, pomijam predykcję.
# Brak modelu dla Stronie śląskie, pomijam predykcję.
# Brak modelu dla Krynica-zdrój, pomijam predykcję.
# Brak modelu dla Zbylitowska góra, pomijam predykcję.
# Brak modelu dla Aleksandrów, pomijam predykcję.
# Brak modelu dla Kębłowo, pomijam predykcję.
# Brak modelu dla Hrubieszów, pomijam predykcję.
# Brak modelu dla Mokra prawa, pomijam predykcję.
# Brak modelu dla Węgorzewo, pomijam predykcję.
# Brak modelu dla Andrychów, pomijam predykcję.
# Brak modelu dla Zacharzyce, pomijam predykcję.
# Brak modelu dla Piechowice, pomijam predykcję.
# Brak modelu dla Piecki, pomijam predykcję.
# Brak modelu dla Kożuchów, pomijam predykcję.
# Brak modelu dla Cedry wielkie, pomijam predykcję.
# Brak modelu dla Jaworze, pomijam predykcję.
# Brak modelu dla Adamowo, pomijam predykcję.
# Brak modelu dla Złotniki, pomijam predykcję.
# Brak modelu dla Dalabuszki, pomijam predykcję.
# Brak modelu dla Końskie, pomijam predykcję.
# Brak modelu dla Strzegom, pomijam predykcję.
# Brak modelu dla Mysiadło, pomijam predykcję.
# Brak modelu dla Hajnówka, pomijam predykcję.
# Brak modelu dla Lutynia, pomijam predykcję.
# Brak modelu dla Tarczyn, pomijam predykcję.
# Brak modelu dla Rawicz, pomijam predykcję.
# Brak modelu dla Chodzież, pomijam predykcję.
# Brak modelu dla Świecie, pomijam predykcję.
# Brak modelu dla Kostrzyn, pomijam predykcję.
# Brak modelu dla Nowe miasto nad wartą, pomijam predykcję.
# Brak modelu dla Miękinia, pomijam predykcję.
# Brak modelu dla Łapy, pomijam predykcję.
# Brak modelu dla Jedlina-zdrój, pomijam predykcję.
# Brak modelu dla Różana, pomijam predykcję.
# Brak modelu dla Szare, pomijam predykcję.
# Brak modelu dla Węgrów, pomijam predykcję.
# Brak modelu dla Stradzewo, pomijam predykcję.
# Brak modelu dla Środa śląska, pomijam predykcję.
# Brak modelu dla Kosów, pomijam predykcję.
# Brak modelu dla Adamówek, pomijam predykcję.
# Brak modelu dla Żołędowo, pomijam predykcję.
# Brak modelu dla Potulice, pomijam predykcję.
# Brak modelu dla Ścinawa, pomijam predykcję.
# Brak modelu dla Piasek, pomijam predykcję.
# Brak modelu dla Lubicz dolny, pomijam predykcję.
# Brak modelu dla Laskowice, pomijam predykcję.
# Brak modelu dla Kiączyn, pomijam predykcję.
# Brak modelu dla Jelcz-laskowice, pomijam predykcję.
# Brak modelu dla Żabiczyn, pomijam predykcję.
# Brak modelu dla Przasnysz, pomijam predykcję.
# Brak modelu dla Ustrzyki dolne, pomijam predykcję.
# Brak modelu dla Tuchola, pomijam predykcję.
# Brak modelu dla Lidzbark warmiński, pomijam predykcję.
# Brak modelu dla Pierwoszyno, pomijam predykcję.
# Brak modelu dla Sulechów, pomijam predykcję.
# Brak modelu dla Świelino, pomijam predykcję.
# Brak modelu dla Bieniewice, pomijam predykcję.
# Brak modelu dla Chocianów, pomijam predykcję.
# Brak modelu dla Kobierzyce, pomijam predykcję.
# Brak modelu dla Olszewka, pomijam predykcję.
# Brak modelu dla Zawadzkie, pomijam predykcję.
# Brak modelu dla Kurowice, pomijam predykcję.
# Brak modelu dla Lwówek śląski, pomijam predykcję.
# Brak modelu dla Babienica, pomijam predykcję.
# Brak modelu dla Szczytnica, pomijam predykcję.
# Brak modelu dla Granowo, pomijam predykcję.
# Brak modelu dla Szczytno, pomijam predykcję.
# Brak modelu dla Brzeźno, pomijam predykcję.
# Brak modelu dla Łowicz, pomijam predykcję.
# Brak modelu dla Grabowo, pomijam predykcję.
# Brak modelu dla Kończyce-kolonia, pomijam predykcję.
# Brak modelu dla Sierpc, pomijam predykcję.
# Brak modelu dla Zdzięsławice, pomijam predykcję.
# Brak modelu dla Mechelinki, pomijam predykcję.
# Brak modelu dla Dębogórze, pomijam predykcję.
# Brak modelu dla Prostki, pomijam predykcję.
# Brak modelu dla Łodygowice, pomijam predykcję.
# Brak modelu dla Łęczyca, pomijam predykcję.
# Brak modelu dla Wołczyn, pomijam predykcję.
# Brak modelu dla Gubin, pomijam predykcję.
# Brak modelu dla Oborniki śląskie, pomijam predykcję.
# Brak modelu dla Mogilno, pomijam predykcję.
# Brak modelu dla Chrzanów, pomijam predykcję.
# Brak modelu dla Jankowice, pomijam predykcję.
# Brak modelu dla Sokołów podlaski, pomijam predykcję.
# Brak modelu dla Ruda, pomijam predykcję.
# Brak modelu dla Zaczernie, pomijam predykcję.
# Brak modelu dla Baborów, pomijam predykcję.
# Brak modelu dla Lądek-zdrój, pomijam predykcję.
# Brak modelu dla Książnik, pomijam predykcję.
# Brak modelu dla Konstancin-jeziorna, pomijam predykcję.
# Brak modelu dla Bibice, pomijam predykcję.
# Brak modelu dla Struga, pomijam predykcję.
# Brak modelu dla Zator, pomijam predykcję.
# Brak modelu dla Kajetany, pomijam predykcję.
# Brak modelu dla Słupno, pomijam predykcję.
# Brak modelu dla Dobre, pomijam predykcję.
# Brak modelu dla Dubeczno, pomijam predykcję.
# Brak modelu dla Dębno, pomijam predykcję.
# Brak modelu dla Pyszczyn, pomijam predykcję.
# Brak modelu dla Chodecz, pomijam predykcję.
# Brak modelu dla Niemcz, pomijam predykcję.
# Brak modelu dla Siemiatycze, pomijam predykcję.
# Brak modelu dla Koźmin wielkopolski, pomijam predykcję.
# Brak modelu dla Kosakowo, pomijam predykcję.
# Brak modelu dla Purda, pomijam predykcję.
# Brak modelu dla Lubiń, pomijam predykcję.
# Brak modelu dla Krzeczyn wielki, pomijam predykcję.
# Brak modelu dla Gola, pomijam predykcję.
# Brak modelu dla Pniewy, pomijam predykcję.
# Brak modelu dla Gębice, pomijam predykcję.
# Brak modelu dla Bytom odrzański, pomijam predykcję.
# Brak modelu dla Nowe warpno, pomijam predykcję.
# Brak modelu dla Juszkowo, pomijam predykcję.
# Brak modelu dla Płochocin, pomijam predykcję.
# Brak modelu dla Chruściele, pomijam predykcję.
# Brak modelu dla Cisie, pomijam predykcję.
# Brak modelu dla Niegolewo, pomijam predykcję.
# Brak modelu dla Skwierzyna, pomijam predykcję.
# Brak modelu dla Biadacz, pomijam predykcję.
# Brak modelu dla Rudawa, pomijam predykcję.
# Brak modelu dla Tuszyn, pomijam predykcję.
# Brak modelu dla Dobrzany, pomijam predykcję.
# Brak modelu dla Marcinowice, pomijam predykcję.
# Brak modelu dla Michałowice, pomijam predykcję.
# Brak modelu dla Wronki, pomijam predykcję.
# Brak modelu dla Jesionowo, pomijam predykcję.
# Brak modelu dla Sulęcin, pomijam predykcję.
# Brak modelu dla Milówka, pomijam predykcję.
# Brak modelu dla Dywity, pomijam predykcję.
# Brak modelu dla Dziekanów leśny, pomijam predykcję.
# Brak modelu dla Wola, pomijam predykcję.
# Brak modelu dla Poniatowa, pomijam predykcję.
# Brak modelu dla Piechcin, pomijam predykcję.
# Brak modelu dla Łupawa, pomijam predykcję.
# Brak modelu dla Pomiechówek, pomijam predykcję.
# Brak modelu dla Węgliniec, pomijam predykcję.
# Brak modelu dla Nowa ruda, pomijam predykcję.
# Brak modelu dla Aleksandrów łódzki, pomijam predykcję.
# Brak modelu dla Prudnik, pomijam predykcję.
# Brak modelu dla Kościerzyna, pomijam predykcję.
# Brak modelu dla Szczawno-zdrój, pomijam predykcję.
# Brak modelu dla Krosno, pomijam predykcję.
# Brak modelu dla Ciechanowice, pomijam predykcję.
# Brak modelu dla Proszowice, pomijam predykcję.
# Brak modelu dla Goczałków, pomijam predykcję.
# Brak modelu dla Aleksandrów kujawski, pomijam predykcję.
# Brak modelu dla Żychlin, pomijam predykcję.
# Brak modelu dla Kurzętnik, pomijam predykcję.
# Brak modelu dla Błędowo, pomijam predykcję.
# Brak modelu dla Przyborki, pomijam predykcję.
# Brak modelu dla Krzeszowice, pomijam predykcję.
# Brak modelu dla Strzelin, pomijam predykcję.
# Brak modelu dla Zielonki-parcela, pomijam predykcję.
# Brak modelu dla Połchowo, pomijam predykcję.
# Brak modelu dla Bukowina, pomijam predykcję.
# Brak modelu dla Solec kujawski, pomijam predykcję.
# Brak modelu dla Gostynin, pomijam predykcję.
# Brak modelu dla Stara kamienica, pomijam predykcję.
# Brak modelu dla Kiełczów, pomijam predykcję.
# Brak modelu dla Łapy-szołajdy, pomijam predykcję.
# Brak modelu dla Stara wiśniewka, pomijam predykcję.
# Brak modelu dla Łaziska górne, pomijam predykcję.
# Brak modelu dla Jadwisin, pomijam predykcję.
# Brak modelu dla Jastrzębia góra, pomijam predykcję.
# Brak modelu dla Sowlany, pomijam predykcję.
# Brak modelu dla Barany, pomijam predykcję.
# Brak modelu dla Suchedniów, pomijam predykcję.
# Brak modelu dla Jantar, pomijam predykcję.
# Brak modelu dla Chałupki, pomijam predykcję.
# Brak modelu dla Wonieść, pomijam predykcję.
# Brak modelu dla Koszanowo, pomijam predykcję.
# Brak modelu dla Turza, pomijam predykcję.
# Brak modelu dla Czmoń, pomijam predykcję.
# Brak modelu dla Rajgród, pomijam predykcję.
# Brak modelu dla Białka, pomijam predykcję.
# Brak modelu dla Lwówek, pomijam predykcję.
# Brak modelu dla Trzebinia, pomijam predykcję.
# Brak modelu dla Mosina, pomijam predykcję.
# Brak modelu dla Miechów, pomijam predykcję.
# Brak modelu dla Jazgarzew, pomijam predykcję.
# Brak modelu dla Żuromin, pomijam predykcję.
# Brak modelu dla Jaworzyna śląska, pomijam predykcję.
# Brak modelu dla Zębowice, pomijam predykcję.
# Brak modelu dla Bystrzyca kłodzka, pomijam predykcję.
# Brak modelu dla Stanisławów pierwszy, pomijam predykcję.
# Brak modelu dla Orneta, pomijam predykcję.
# Brak modelu dla Niedalino, pomijam predykcję.
# Brak modelu dla Nowa dęba, pomijam predykcję.
# Brak modelu dla Konstantyna, pomijam predykcję.
# Brak modelu dla Trąbki wielkie, pomijam predykcję.
# Brak modelu dla Długołęka, pomijam predykcję.
# Brak modelu dla Czaplinek, pomijam predykcję.
# Brak modelu dla Łącznik, pomijam predykcję.
# Brak modelu dla Wójcin, pomijam predykcję.
# Brak modelu dla Gorzków, pomijam predykcję.
# Brak modelu dla Skąpe, pomijam predykcję.
# Brak modelu dla Rabka-zdrój, pomijam predykcję.
# Brak modelu dla Rudna mała, pomijam predykcję.
# Brak modelu dla Ustronie, pomijam predykcję.
# Brak modelu dla Czerwionka-leszczyny, pomijam predykcję.
# Brak modelu dla Tychnowy, pomijam predykcję.
# Brak modelu dla Rąbino, pomijam predykcję.
# Brak modelu dla Mokronos dolny, pomijam predykcję.
# Brak modelu dla Widawa, pomijam predykcję.
# Brak modelu dla Brzeszcze, pomijam predykcję.
# Brak modelu dla Budzyń, pomijam predykcję.
# Brak modelu dla Dubienka, pomijam predykcję.
# Brak modelu dla Łask, pomijam predykcję.
# Brak modelu dla Murów, pomijam predykcję.
# Brak modelu dla Kłodawa, pomijam predykcję.
# Brak modelu dla Potoczek, pomijam predykcję.
# Brak modelu dla Radymno, pomijam predykcję.
# Brak modelu dla Małkocin, pomijam predykcję.
# Brak modelu dla Kolno, pomijam predykcję.
# Brak modelu dla Kluki, pomijam predykcję.
# Brak modelu dla Kępno, pomijam predykcję.
# Brak modelu dla Mieszkowice, pomijam predykcję.
# Brak modelu dla Skarbimierz, pomijam predykcję.
# Brak modelu dla Ligota łabędzka, pomijam predykcję.
# Brak modelu dla Słotwina, pomijam predykcję.
# Brak modelu dla Kępice, pomijam predykcję.
# Brak modelu dla Bochnia, pomijam predykcję.
# Brak modelu dla Straduny, pomijam predykcję.
# Brak modelu dla Krośnice, pomijam predykcję.
# Brak modelu dla Pszów, pomijam predykcję.
# Brak modelu dla Wietlin trzeci, pomijam predykcję.
# Brak modelu dla Borawskie, pomijam predykcję.
# Brak modelu dla Dębnica kaszubska, pomijam predykcję.
# Brak modelu dla Lewin brzeski, pomijam predykcję.
# Brak modelu dla Nowe gulczewo, pomijam predykcję.
# Brak modelu dla Myszków, pomijam predykcję.
# Brak modelu dla Miłomłyn, pomijam predykcję.
# Brak modelu dla Myślibórz, pomijam predykcję.
# Brak modelu dla Limanowa, pomijam predykcję.
# Brak modelu dla Księginice wielkie, pomijam predykcję.
# Brak modelu dla Warmątowice, pomijam predykcję.
# Brak modelu dla Wydminy, pomijam predykcję.
# Brak modelu dla Wiśniowa góra, pomijam predykcję.
# Brak modelu dla Jerzmanice-zdrój, pomijam predykcję.
# Brak modelu dla Strzelce krajeńskie, pomijam predykcję.
# Brak modelu dla Janocin, pomijam predykcję.
# Brak modelu dla Szerokie, pomijam predykcję.
# Brak modelu dla Kietrz, pomijam predykcję.
# Brak modelu dla Paczków, pomijam predykcję.
# Brak modelu dla Dorohusk, pomijam predykcję.
# Brak modelu dla Przecław, pomijam predykcję.
# Brak modelu dla Unisław, pomijam predykcję.
# Brak modelu dla Łuczyce, pomijam predykcję.
# Brak modelu dla Nowe miasto nad pilicą, pomijam predykcję.
# Brak modelu dla Chwalimierz, pomijam predykcję.
# Brak modelu dla Zamysłowo, pomijam predykcję.
# Brak modelu dla Szymanów, pomijam predykcję.
# Brak modelu dla Występ, pomijam predykcję.
# Brak modelu dla Kalwaria zebrzydowska, pomijam predykcję.
# Brak modelu dla Rogowo, pomijam predykcję.
# Brak modelu dla Bogatynia, pomijam predykcję.
# Brak modelu dla Chmielnik, pomijam predykcję.
# Brak modelu dla Chotkowo, pomijam predykcję.
# Brak modelu dla Imielin, pomijam predykcję.
# Brak modelu dla Szczepanów, pomijam predykcję.
# Brak modelu dla Szczytna, pomijam predykcję.
# Brak modelu dla Gąsawa, pomijam predykcję.
# Brak modelu dla Tarnowo podgórne, pomijam predykcję.
# Brak modelu dla Różany, pomijam predykcję.
# Brak modelu dla Demlin, pomijam predykcję.
# Brak modelu dla Dopiewiec, pomijam predykcję.
# Brak modelu dla Nowa wola, pomijam predykcję.
# Brak modelu dla Opalenica, pomijam predykcję.
# Brak modelu dla Libertów, pomijam predykcję.
# Brak modelu dla Leżajsk, pomijam predykcję.
# Brak modelu dla Pastuchów, pomijam predykcję.
# Brak modelu dla Ślesin, pomijam predykcję.
# Brak modelu dla Bieruń, pomijam predykcję.
# Brak modelu dla Ujście, pomijam predykcję.
# Brak modelu dla Skalin, pomijam predykcję.
# Brak modelu dla Byczyna, pomijam predykcję.
# Brak modelu dla Perzanowo, pomijam predykcję.
# Brak modelu dla Przemków, pomijam predykcję.
# Brak modelu dla Kowanówko, pomijam predykcję.
# Brak modelu dla Rudno, pomijam predykcję.
# Brak modelu dla Krosno odrzańskie, pomijam predykcję.
# Brak modelu dla Wojkowice, pomijam predykcję.
# Brak modelu dla Domaszowice, pomijam predykcję.
# Brak modelu dla Zabór, pomijam predykcję.
# Brak modelu dla Nowa wieś wielka, pomijam predykcję.
# Brak modelu dla Mrozów, pomijam predykcję.
# Brak modelu dla Babimost, pomijam predykcję.
# Brak modelu dla Libiąż, pomijam predykcję.
# Brak modelu dla Siercza, pomijam predykcję.
# Brak modelu dla Krosino, pomijam predykcję.
# Brak modelu dla Tomaszów lubelski, pomijam predykcję.
# Brak modelu dla Nawojowa góra, pomijam predykcję.
# Brak modelu dla Ogorzelec, pomijam predykcję.
# Brak modelu dla Bienice, pomijam predykcję.
# Brak modelu dla Potęgowo, pomijam predykcję.
# Brak modelu dla Rąbień ab, pomijam predykcję.
# Brak modelu dla Święciechowa, pomijam predykcję.
# Brak modelu dla Jamielnik, pomijam predykcję.
# Brak modelu dla Brynek, pomijam predykcję.
# Brak modelu dla Uniejów, pomijam predykcję.
# Brak modelu dla Głowienka, pomijam predykcję.
# Brak modelu dla Praszka, pomijam predykcję.
# Brak modelu dla Łambinowice, pomijam predykcję.
# Brak modelu dla Łochów, pomijam predykcję.
# Brak modelu dla Żarnowska, pomijam predykcję.
# Brak modelu dla Kamień krajeński, pomijam predykcję.
# Brak modelu dla Jaroty, pomijam predykcję.
# Brak modelu dla Nowy targ, pomijam predykcję.
# Brak modelu dla Kluszkowce, pomijam predykcję.
# Brak modelu dla Lubsza, pomijam predykcję.
# Brak modelu dla Gryfów śląski, pomijam predykcję.
# Brak modelu dla Ząbkowice śląskie, pomijam predykcję.
# Brak modelu dla Górsk, pomijam predykcję.
# Brak modelu dla Zawidów, pomijam predykcję.
# Brak modelu dla Ujazd, pomijam predykcję.
# Brak modelu dla Pieniężno, pomijam predykcję.
# Brak modelu dla Wola batorska, pomijam predykcję.
# Brak modelu dla Lipa, pomijam predykcję.
# Brak modelu dla Bodaczów, pomijam predykcję.
# Brak modelu dla Radziejów, pomijam predykcję.
# Brak modelu dla Pietrzykowice, pomijam predykcję.
# Brak modelu dla Chotków, pomijam predykcję.
# Brak modelu dla Bystrzyca górna, pomijam predykcję.
# Brak modelu dla Przerzeczyn-zdrój, pomijam predykcję.
# Brak modelu dla Serock, pomijam predykcję.
# Brak modelu dla Tarnawatka, pomijam predykcję.
# Brak modelu dla Jędrzejów, pomijam predykcję.
# Brak modelu dla Przewóz, pomijam predykcję.
# Brak modelu dla Groblice, pomijam predykcję.
# Brak modelu dla Dawidy bankowe, pomijam predykcję.
# Brak modelu dla Brzozów, pomijam predykcję.
# Brak modelu dla Daszówka, pomijam predykcję.
# Brak modelu dla Kruszewnia, pomijam predykcję.
# Brak modelu dla Walendów, pomijam predykcję.
# Brak modelu dla Chociwel, pomijam predykcję.
# Brak modelu dla Śliwniki, pomijam predykcję.
# Brak modelu dla Bardo, pomijam predykcję.
# Brak modelu dla Ryjewo, pomijam predykcję.
# Brak modelu dla Skępe, pomijam predykcję.
# Brak modelu dla Suchań, pomijam predykcję.
# Brak modelu dla Kiełcz, pomijam predykcję.
# Brak modelu dla Franciszkowo, pomijam predykcję.
# Brak modelu dla Żulice, pomijam predykcję.
# Brak modelu dla Lubonieczek, pomijam predykcję.
# Brak modelu dla Czerwieńsk, pomijam predykcję.
# Brak modelu dla Lubsko, pomijam predykcję.
# Brak modelu dla Dąbie, pomijam predykcję.
# Brak modelu dla Sokołowice, pomijam predykcję.
# Brak modelu dla Elizówka, pomijam predykcję.
# Brak modelu dla Chojna, pomijam predykcję.
# Brak modelu dla Ziębice, pomijam predykcję.
# Brak modelu dla Jarużyn, pomijam predykcję.
# Brak modelu dla Staw, pomijam predykcję.
# Brak modelu dla Przedbórz, pomijam predykcję.
# Brak modelu dla Czersk, pomijam predykcję.
# Brak modelu dla Jaksonów, pomijam predykcję.
# Brak modelu dla Sieradz, pomijam predykcję.
# Brak modelu dla Dukla, pomijam predykcję.
# Brak modelu dla Górki, pomijam predykcję.
# Brak modelu dla Nowe miasteczko, pomijam predykcję.
# Brak modelu dla Netta-folwark, pomijam predykcję.
# Brak modelu dla Jastarnia, pomijam predykcję.
# Brak modelu dla Grodzisk wielkopolski, pomijam predykcję.
# Brak modelu dla Świerzawa, pomijam predykcję.
# Brak modelu dla Ośno lubuskie, pomijam predykcję.
# Brak modelu dla Koluszki, pomijam predykcję.
# Brak modelu dla Ostroróg, pomijam predykcję.
# Brak modelu dla Kajkowo, pomijam predykcję.
# Brak modelu dla Pawłowice, pomijam predykcję.
# Brak modelu dla Miszewko, pomijam predykcję.
# Brak modelu dla Zabłudów, pomijam predykcję.
# Brak modelu dla Lubiąż, pomijam predykcję.
# Brak modelu dla Wołów, pomijam predykcję.
# Brak modelu dla Sucha beskidzka, pomijam predykcję.
# Brak modelu dla Złocieniec, pomijam predykcję.
# Brak modelu dla Biesiekierz, pomijam predykcję.
# Brak modelu dla Warta, pomijam predykcję.
# Brak modelu dla Osiecznica, pomijam predykcję.
# Brak modelu dla Pawłów, pomijam predykcję.
# Brak modelu dla Chłapowo, pomijam predykcję.
# Brak modelu dla Gościejewice, pomijam predykcję.
# Brak modelu dla Rożental, pomijam predykcję.
# Brak modelu dla Cyprki, pomijam predykcję.
# Brak modelu dla Raczki, pomijam predykcję.
# Brak modelu dla Orzysz, pomijam predykcję.
# Brak modelu dla Mrocza, pomijam predykcję.
# Brak modelu dla Kobylnica, pomijam predykcję.
# Brak modelu dla Wiechlice, pomijam predykcję.
# Brak modelu dla Borowo, pomijam predykcję.
# Brak modelu dla Konopki, pomijam predykcję.
# Brak modelu dla Widok, pomijam predykcję.
# Brak modelu dla Licze, pomijam predykcję.
# Brak modelu dla Prabuty, pomijam predykcję.
# Brak modelu dla Głuchołazy, pomijam predykcję.
# Brak modelu dla Muszyna, pomijam predykcję.
# Brak modelu dla Wólka, pomijam predykcję.
# Brak modelu dla Nisko, pomijam predykcję.
# Brak modelu dla Górno, pomijam predykcję.
# Brak modelu dla Ceradz dolny, pomijam predykcję.
# Brak modelu dla Iłowa, pomijam predykcję.
# Brak modelu dla Pokrzywnica, pomijam predykcję.
# Brak modelu dla Radomierz, pomijam predykcję.
# Brak modelu dla Kunów, pomijam predykcję.
# Brak modelu dla Odrano-wola, pomijam predykcję.
# Brak modelu dla Młochów, pomijam predykcję.
# Brak modelu dla Kock, pomijam predykcję.
# Brak modelu dla Grębocin, pomijam predykcję.
# Brak modelu dla Siennica nadolna, pomijam predykcję.
# Brak modelu dla Głogów małopolski, pomijam predykcję.
# Brak modelu dla Zaścianki, pomijam predykcję.
# Brak modelu dla Krasne, pomijam predykcję.
# Brak modelu dla Pelplin, pomijam predykcję.
# Brak modelu dla Duszniki-zdrój, pomijam predykcję.
# Brak modelu dla Murowana goślina, pomijam predykcję.
# Brak modelu dla Modlnica, pomijam predykcję.
# Brak modelu dla Borkowo, pomijam predykcję.
# Brak modelu dla Sulejówek, pomijam predykcję.
# Brak modelu dla Lędzin, pomijam predykcję.
# Brak modelu dla Uherce mineralne, pomijam predykcję.
# Brak modelu dla Markowice, pomijam predykcję.
# Brak modelu dla Goręczyno, pomijam predykcję.
# Brak modelu dla Wilkowyja, pomijam predykcję.
# Brak modelu dla Piastoszyn, pomijam predykcję.
# Brak modelu dla Stary grabiąż, pomijam predykcję.
# Brak modelu dla Supraśl, pomijam predykcję.
# Brak modelu dla Kosewo, pomijam predykcję.
# Brak modelu dla Lubawka, pomijam predykcję.
# Brak modelu dla Komprachcice, pomijam predykcję.
# Brak modelu dla Radzanek, pomijam predykcję.
# Brak modelu dla Pszenno, pomijam predykcję.
# Brak modelu dla Rurzyca, pomijam predykcję.
# Brak modelu dla Żukowo, pomijam predykcję.
# Brak modelu dla Tupadły, pomijam predykcję.
# Brak modelu dla Pieńkowo, pomijam predykcję.
# Brak modelu dla Mosty, pomijam predykcję.
# Brak modelu dla Frombork, pomijam predykcję.
# Brak modelu dla Jora wielka, pomijam predykcję.
# Brak modelu dla Puczyce, pomijam predykcję.
# Brak modelu dla Nowe, pomijam predykcję.
# Brak modelu dla Tyczyn, pomijam predykcję.
# Brak modelu dla Skowarcz, pomijam predykcję.
# Brak modelu dla Roztoki, pomijam predykcję.
# Brak modelu dla Stary gołębin, pomijam predykcję.
# Brak modelu dla Tuczno, pomijam predykcję.
# Brak modelu dla Rogaczewo małe, pomijam predykcję.
# Brak modelu dla Nowa iwiczna, pomijam predykcję.
# Brak modelu dla Retków, pomijam predykcję.
# Brak modelu dla Koło, pomijam predykcję.
# Brak modelu dla Kudowa-zdrój, pomijam predykcję.
# Brak modelu dla Debrzno, pomijam predykcję.
# Brak modelu dla Chrzanów mały, pomijam predykcję.
# Brak modelu dla Szczebrzeszyn, pomijam predykcję.
# Brak modelu dla Pszczółki, pomijam predykcję.
# Brak modelu dla Czarne, pomijam predykcję.
# Brak modelu dla Podkowa leśna, pomijam predykcję.
# Brak modelu dla Krotoszyce, pomijam predykcję.
# Brak modelu dla Tokary, pomijam predykcję.
# ...
# Brak modelu dla Kaczory, pomijam predykcję.
# Brak modelu dla Czarnocin, pomijam predykcję.
# Brak modelu dla Korytów, pomijam predykcję.
# Brak modelu dla Przylesie dolne, pomijam predykcję.
# Brak modelu dla Dębnica, pomijam predykcję.
# Brak modelu dla Kadłub, pomijam predykcję.
# Brak modelu dla Jarkowice, pomijam predykcję.
# Brak modelu dla Wola zaleska, pomijam predykcję.
# Brak modelu dla Chocznia, pomijam predykcję.
# Brak modelu dla Łekno, pomijam predykcję.
# Brak modelu dla Krzydlina wielka, pomijam predykcję.
# Brak modelu dla Stary adamów, pomijam predykcję.
# Brak modelu dla Uzdowo, pomijam predykcję.
# Brak modelu dla Dębowa kłoda, pomijam predykcję.
# Brak modelu dla Czerwonków, pomijam predykcję.
# Brak modelu dla Wambierzyce, pomijam predykcję.
# Brak modelu dla Okrąg, pomijam predykcję.
# Brak modelu dla Witków, pomijam predykcję.
# Brak modelu dla Łojki, pomijam predykcję.
# Brak modelu dla Garbatka-letnisko, pomijam predykcję.
# Brak modelu dla Bębnów, pomijam predykcję.
# Brak modelu dla Mariopol, pomijam predykcję.
# Brak modelu dla Wola rasztowska, pomijam predykcję.
# Brak modelu dla Wilczyn, pomijam predykcję.
# Brak modelu dla Radowo wielkie, pomijam predykcję.
# Brak modelu dla Skrobów, pomijam predykcję.
# Brak modelu dla Stachowice, pomijam predykcję.
# Brak modelu dla Wilkaski, pomijam predykcję.
# Brak modelu dla Zawda, pomijam predykcję.
# Brak modelu dla Kuźnica czeszycka, pomijam predykcję.
# Brak modelu dla Gorysławice, pomijam predykcję.
# Brak modelu dla Krajowice, pomijam predykcję.
# Brak modelu dla Nowy jaworów, pomijam predykcję.
# Brak modelu dla Warta bolesławiecka, pomijam predykcję.
# Brak modelu dla Śliwnica, pomijam predykcję.
# Brak modelu dla Dybawka, pomijam predykcję.
# Brak modelu dla Zdbice, pomijam predykcję.
# Brak modelu dla Kamienica polska, pomijam predykcję.
# Brak modelu dla Dębsko, pomijam predykcję.
# Brak modelu dla Radwanów, pomijam predykcję.
# Brak modelu dla Barty, pomijam predykcję.
# Brak modelu dla Sokoły, pomijam predykcję.
# Brak modelu dla Głębock, pomijam predykcję.
# Brak modelu dla Potuliniec, pomijam predykcję.
# Brak modelu dla Rajki, pomijam predykcję.
# Brak modelu dla Dębołęka, pomijam predykcję.
# Brak modelu dla Nowa wieś kętrzyńska, pomijam predykcję.
# Brak modelu dla Nowosiółki, pomijam predykcję.
# Brak modelu dla Nieświń, pomijam predykcję.
# Brak modelu dla Pogórska wola, pomijam predykcję.
# Brak modelu dla Lewkowo stare, pomijam predykcję.
# Brak modelu dla Miłogostowice, pomijam predykcję.
# Brak modelu dla Marcinów, pomijam predykcję.
# Brak modelu dla Parowa, pomijam predykcję.
# Brak modelu dla Pogorzel, pomijam predykcję.
# Brak modelu dla Nowy żmigród, pomijam predykcję.
# Brak modelu dla Łaszczów, pomijam predykcję.
# Brak modelu dla Jabłów, pomijam predykcję.
# Brak modelu dla Trzygłów, pomijam predykcję.
# Brak modelu dla Krzekotowice, pomijam predykcję.
# Brak modelu dla Nieczajna górna, pomijam predykcję.
# Brak modelu dla Murzynowo kościelne, pomijam predykcję.
# Brak modelu dla Skoroszów, pomijam predykcję.
# Brak modelu dla Wielki las, pomijam predykcję.
# Brak modelu dla Dworczysko, pomijam predykcję.
# Brak modelu dla Smarków, pomijam predykcję.
# Brak modelu dla Żelazny most, pomijam predykcję.
# Brak modelu dla Nagórki, pomijam predykcję.
# Brak modelu dla Pełcznica, pomijam predykcję.
# Brak modelu dla Kociugi, pomijam predykcję.
# Brak modelu dla Starczówek, pomijam predykcję.
# Brak modelu dla Damno, pomijam predykcję.
# Brak modelu dla Konradowa, pomijam predykcję.
# Brak modelu dla Daleszyce, pomijam predykcję.
# Brak modelu dla Nowa wieś niemczańska, pomijam predykcję.
# Brak modelu dla Maciejów, pomijam predykcję.
# Brak modelu dla Czarna sędziszowska, pomijam predykcję.
# Brak modelu dla Bednary, pomijam predykcję.
# Brak modelu dla Modliszewo, pomijam predykcję.
# Brak modelu dla Płośnica, pomijam predykcję.
# Brak modelu dla Kierszek, pomijam predykcję.
# Brak modelu dla Białęgi, pomijam predykcję.
# Brak modelu dla Trzeszczany pierwsze, pomijam predykcję.
# Brak modelu dla Uhnin, pomijam predykcję.
# Brak modelu dla Starzykowo, pomijam predykcję.
# Brak modelu dla Nowy sumin, pomijam predykcję.
# Brak modelu dla Zieleniec, pomijam predykcję.
# Brak modelu dla Rybnica leśna, pomijam predykcję.
# Brak modelu dla Suszki, pomijam predykcję.
# Brak modelu dla Bielawa górna, pomijam predykcję.
# Brak modelu dla Nowe gizewo, pomijam predykcję.
# Brak modelu dla Włosań, pomijam predykcję.
# Brak modelu dla Brzeziniec, pomijam predykcję.
# Brak modelu dla Byszewy, pomijam predykcję.
# Brak modelu dla Łazy biegonickie, pomijam predykcję.
# Brak modelu dla Milice, pomijam predykcję.
# Brak modelu dla Solniczki, pomijam predykcję.
# Brak modelu dla Piątkowisko, pomijam predykcję.
# Brak modelu dla Domasławice, pomijam predykcję.
# Brak modelu dla Dąbrówki, pomijam predykcję.
# Brak modelu dla Trzebunia, pomijam predykcję.
# Brak modelu dla Chmielno, pomijam predykcję.
# Brak modelu dla Chełmce, pomijam predykcję.
# Brak modelu dla Glinice, pomijam predykcję.
# Brak modelu dla Librantowa, pomijam predykcję.
# Brak modelu dla Stare lubiejewo, pomijam predykcję.
# Brak modelu dla Murzynówko, pomijam predykcję.
# Brak modelu dla Pomyków, pomijam predykcję.
# Brak modelu dla Sulnówko, pomijam predykcję.
# Brak modelu dla Spławie, pomijam predykcję.
# Brak modelu dla Perły, pomijam predykcję.
# Brak modelu dla Emilia, pomijam predykcję.
# Brak modelu dla Łazy wielkie, pomijam predykcję.
# Brak modelu dla Silnowo, pomijam predykcję.
# Brak modelu dla Ulesie, pomijam predykcję.
# Brak modelu dla Żabi róg, pomijam predykcję.
# Brak modelu dla Miłobędzyn, pomijam predykcję.
# Brak modelu dla Słabomierz, pomijam predykcję.
# Brak modelu dla Tokarnia, pomijam predykcję.
# Brak modelu dla Murowaniec, pomijam predykcję.
# Brak modelu dla Masłowice, pomijam predykcję.
# Brak modelu dla Bilcza, pomijam predykcję.
# Brak modelu dla Trzeszkowice, pomijam predykcję.
# Brak modelu dla Miąskowo, pomijam predykcję.
# Brak modelu dla Iwierzyce, pomijam predykcję.
# Brak modelu dla Zyndranowa, pomijam predykcję.
# Brak modelu dla Florków, pomijam predykcję.
# Brak modelu dla Chludowo, pomijam predykcję.
# Brak modelu dla Prochy, pomijam predykcję.
# Brak modelu dla Bąkowo, pomijam predykcję.
# Brak modelu dla Wola osowińska, pomijam predykcję.
# Brak modelu dla Ościęcin, pomijam predykcję.
# Brak modelu dla Mierzynek, pomijam predykcję.
# Brak modelu dla Sebastianowo, pomijam predykcję.
# Brak modelu dla Baniewice, pomijam predykcję.
# Brak modelu dla Dobrowo, pomijam predykcję.
# Brak modelu dla Podrzecze, pomijam predykcję.
# Brak modelu dla Komorze przybysławskie, pomijam predykcję.
# Brak modelu dla Mierzęcin, pomijam predykcję.
# Brak modelu dla Małki, pomijam predykcję.
# Brak modelu dla Krzesimów, pomijam predykcję.
# Brak modelu dla Łupki, pomijam predykcję.
# Brak modelu dla Wrząca śląska, pomijam predykcję.
# Brak modelu dla Dąbie kujawskie, pomijam predykcję.
# Brak modelu dla Stara jabłona, pomijam predykcję.
# Brak modelu dla Błąkały, pomijam predykcję.
# Brak modelu dla Płonica, pomijam predykcję.
# Brak modelu dla Stary bartków, pomijam predykcję.
# Brak modelu dla Marynin, pomijam predykcję.
# Brak modelu dla Doręgowice, pomijam predykcję.
# Brak modelu dla Raciechowice, pomijam predykcję.
# Brak modelu dla Brzezinki, pomijam predykcję.
# Brak modelu dla Niechorz, pomijam predykcję.
# Brak modelu dla Turznice, pomijam predykcję.
# Brak modelu dla Adamów-wieś, pomijam predykcję.
# Brak modelu dla Scholastykowo, pomijam predykcję.
# Brak modelu dla Tyniec legnicki, pomijam predykcję.
# Brak modelu dla Przydwórz, pomijam predykcję.
# Brak modelu dla Nowa cerekwia, pomijam predykcję.
# Brak modelu dla Karwieńskie błoto pierwsze, pomijam predykcję.
# Brak modelu dla Sikorzyn, pomijam predykcję.
# Brak modelu dla Gorzany, pomijam predykcję.
# Brak modelu dla Przydroże małe, pomijam predykcję.
# Brak modelu dla Ursynów, pomijam predykcję.
# Brak modelu dla Łukawica, pomijam predykcję.
# Brak modelu dla Łoniów, pomijam predykcję.
# Brak modelu dla Kowalowa, pomijam predykcję.
# Brak modelu dla Szczepankowo, pomijam predykcję.
# Brak modelu dla Książnica, pomijam predykcję.
# Brak modelu dla Pielgrzymowice, pomijam predykcję.
# Brak modelu dla Różankowo, pomijam predykcję.
# Brak modelu dla Goździchowo, pomijam predykcję.
# Brak modelu dla Lutry, pomijam predykcję.
# Brak modelu dla Cyprzanów, pomijam predykcję.
# Brak modelu dla Radziwiłłówka, pomijam predykcję.
# Brak modelu dla Morsk, pomijam predykcję.
# Brak modelu dla Stanisław dolny, pomijam predykcję.
# Brak modelu dla Kozłowice, pomijam predykcję.
# Brak modelu dla Adamowo-zastawa, pomijam predykcję.
# Brak modelu dla Poklatki, pomijam predykcję.
# Brak modelu dla Dokudów drugi, pomijam predykcję.
# Brak modelu dla Kościuszków, pomijam predykcję.
# Brak modelu dla Garbce, pomijam predykcję.
# Brak modelu dla Kamienna stara, pomijam predykcję.
# Brak modelu dla Anieliny, pomijam predykcję.
# Brak modelu dla Naborów, pomijam predykcję.
# Brak modelu dla Magnuszewice, pomijam predykcję.
# Brak modelu dla Przyłubie, pomijam predykcję.
# Brak modelu dla Przążewo, pomijam predykcję.
# Brak modelu dla Krakowiany, pomijam predykcję.
# Brak modelu dla Łaznowska wola, pomijam predykcję.
# Brak modelu dla Byków, pomijam predykcję.
# Brak modelu dla Snopki, pomijam predykcję.
# Brak modelu dla Zdziechowa, pomijam predykcję.
# Brak modelu dla Skrzypnik, pomijam predykcję.
# Brak modelu dla Kady, pomijam predykcję.
# Brak modelu dla Zarzeczewo, pomijam predykcję.
# Brak modelu dla Zalipie, pomijam predykcję.
# Brak modelu dla Wierzba, pomijam predykcję.
# Brak modelu dla Bedoń-wieś, pomijam predykcję.
# Brak modelu dla Szczytkowice, pomijam predykcję.
# Brak modelu dla Lubkowo, pomijam predykcję.
# Brak modelu dla Huta janowska, pomijam predykcję.
# Brak modelu dla Ocieszyn, pomijam predykcję.
# Brak modelu dla Anielinek, pomijam predykcję.
# Brak modelu dla Porudzie, pomijam predykcję.
# Brak modelu dla Czatkowice, pomijam predykcję.
# Brak modelu dla Kościerzyn, pomijam predykcję.
# Brak modelu dla Ryboły, pomijam predykcję.
# Brak modelu dla Nadwiślanka, pomijam predykcję.
# Brak modelu dla Zamienie, pomijam predykcję.
# Brak modelu dla Smęcino, pomijam predykcję.
# Brak modelu dla Tucze, pomijam predykcję.
# Brak modelu dla Krajnik górny, pomijam predykcję.
# Brak modelu dla Golczowice, pomijam predykcję.
# Brak modelu dla Sumiak, pomijam predykcję.
# Brak modelu dla Zielonka stara, pomijam predykcję.
# Brak modelu dla Koźmice, pomijam predykcję.
# Brak modelu dla Stablewice, pomijam predykcję.
# Brak modelu dla Gródków, pomijam predykcję.
# Brak modelu dla Rumienica, pomijam predykcję.
# Brak modelu dla Kłudno, pomijam predykcję.
# Brak modelu dla Piduń, pomijam predykcję.
# Brak modelu dla Popielewko, pomijam predykcję.
# Brak modelu dla Lipia góra, pomijam predykcję.
# Brak modelu dla Obra, pomijam predykcję.
# Brak modelu dla Urbanowo, pomijam predykcję.
# Brak modelu dla Werdun, pomijam predykcję.
# Brak modelu dla Żelazów, pomijam predykcję.
# Brak modelu dla Kuranów, pomijam predykcję.
# Brak modelu dla Leszczyniec, pomijam predykcję.
# Brak modelu dla Karczyn, pomijam predykcję.
# Brak modelu dla Chinów, pomijam predykcję.
# Brak modelu dla Tolcz, pomijam predykcję.
# Brak modelu dla Opolnica, pomijam predykcję.
# Brak modelu dla Posadowice, pomijam predykcję.
# Brak modelu dla Kusin, pomijam predykcję.
# Brak modelu dla Żelechowo, pomijam predykcję.
# Brak modelu dla Płutowo, pomijam predykcję.
# Brak modelu dla Gójsk, pomijam predykcję.
# Brak modelu dla Kościernica, pomijam predykcję.
# Brak modelu dla Lewków, pomijam predykcję.
# Brak modelu dla Kanibród, pomijam predykcję.
# Brak modelu dla Stolno, pomijam predykcję.
# Brak modelu dla Tuchla, pomijam predykcję.
# Brak modelu dla Równia, pomijam predykcję.
# Brak modelu dla Niećkowo, pomijam predykcję.
# Brak modelu dla Raszowa, pomijam predykcję.
# Brak modelu dla Ocice, pomijam predykcję.
# Brak modelu dla Janopole, pomijam predykcję.
# Brak modelu dla Nienowice, pomijam predykcję.
# Brak modelu dla Sufczyn, pomijam predykcję.
# Brak modelu dla Gnatowo, pomijam predykcję.
# Brak modelu dla Warszawianka, pomijam predykcję.
# Brak modelu dla Tatynia, pomijam predykcję.
# Brak modelu dla Powidz, pomijam predykcję.
# Brak modelu dla Wytok, pomijam predykcję.
# Brak modelu dla Gołębiewek stary, pomijam predykcję.
# Brak modelu dla Mochała, pomijam predykcję.
# Brak modelu dla Pniewite, pomijam predykcję.
# Brak modelu dla Jeże, pomijam predykcję.
# Brak modelu dla Grabowska huta, pomijam predykcję.
# Brak modelu dla Donosy, pomijam predykcję.
# Brak modelu dla Polanka, pomijam predykcję.
# Brak modelu dla Szamoty, pomijam predykcję.
# Brak modelu dla Zastawie, pomijam predykcję.
# Brak modelu dla Bocheniec, pomijam predykcję.
# Brak modelu dla Stare kozłowice, pomijam predykcję.
# Brak modelu dla Głuszyn, pomijam predykcję.
# Brak modelu dla Kłódka, pomijam predykcję.
# Brak modelu dla Tropy sztumskie, pomijam predykcję.
# Brak modelu dla Mroczeń, pomijam predykcję.
# Brak modelu dla Kąp, pomijam predykcję.
# Brak modelu dla Wola błędowa, pomijam predykcję.
# Brak modelu dla Powroźnik, pomijam predykcję.
# Brak modelu dla Czostków, pomijam predykcję.
# Brak modelu dla Mieszewo, pomijam predykcję.
# Brak modelu dla Kozierów, pomijam predykcję.
# Brak modelu dla Surmaczówka, pomijam predykcję.
# Brak modelu dla Jeziórki, pomijam predykcję.
# Brak modelu dla Kopaszyce, pomijam predykcję.
# Brak modelu dla Płużnica wielka, pomijam predykcję.
# Brak modelu dla Wiszniów, pomijam predykcję.
# Brak modelu dla Sulin, pomijam predykcję.
# Brak modelu dla Trzciana, pomijam predykcję.
# Brak modelu dla Rogóźno, pomijam predykcję.
# Brak modelu dla Szemudzka huta, pomijam predykcję.
# Brak modelu dla Cieszkowo stare, pomijam predykcję.
# Brak modelu dla Obodowo, pomijam predykcję.
# Brak modelu dla Jarząbkowice, pomijam predykcję.
# Brak modelu dla Zosin, pomijam predykcję.
# Brak modelu dla Żmigródek, pomijam predykcję.
# Brak modelu dla Trzemosna, pomijam predykcję.
# Brak modelu dla Niedźwiednik, pomijam predykcję.
# Brak modelu dla Czyżew-siedliska, pomijam predykcję.
# Brak modelu dla Rudziczka, pomijam predykcję.
# Brak modelu dla Kaniów, pomijam predykcję.
# Brak modelu dla Roszkowice, pomijam predykcję.
# Brak modelu dla Mątawy, pomijam predykcję.
# Brak modelu dla Palczewo, pomijam predykcję.
# Brak modelu dla Mieszałki, pomijam predykcję.
# Brak modelu dla Lubstówek, pomijam predykcję.
# Brak modelu dla Krzaki czaplinkowskie, pomijam predykcję.
# Brak modelu dla Rudunki, pomijam predykcję.
# Brak modelu dla Kwiecewo, pomijam predykcję.
# Brak modelu dla Bulowice, pomijam predykcję.
# Brak modelu dla Szczukowskie górki, pomijam predykcję.
# Brak modelu dla Bąkówka, pomijam predykcję.
# Brak modelu dla Ligota książęca, pomijam predykcję.
# Brak modelu dla Karsinka, pomijam predykcję.
# Brak modelu dla Cypriany, pomijam predykcję.
# Brak modelu dla Potulin, pomijam predykcję.
# Brak modelu dla Brzozie, pomijam predykcję.
# Brak modelu dla Boreczek, pomijam predykcję.
# Brak modelu dla Więcław, pomijam predykcję.
# Brak modelu dla Dulsk, pomijam predykcję.
# Brak modelu dla Chlastawa, pomijam predykcję.
# Brak modelu dla Cekanowo, pomijam predykcję.
# Brak modelu dla Rawka, pomijam predykcję.
# Brak modelu dla Nowa góra, pomijam predykcję.
# Brak modelu dla Sąpolno, pomijam predykcję.
# Brak modelu dla Brynica, pomijam predykcję.
# Brak modelu dla Goryń, pomijam predykcję.
# Brak modelu dla Nowe objezierze, pomijam predykcję.
# Brak modelu dla Strączno, pomijam predykcję.
# Brak modelu dla Tłokinia wielka, pomijam predykcję.
# Brak modelu dla Kostrza, pomijam predykcję.
# Brak modelu dla Szczuka, pomijam predykcję.
# Brak modelu dla Gniewowo, pomijam predykcję.
# Brak modelu dla Malenin, pomijam predykcję.
# Brak modelu dla Orchowiec, pomijam predykcję.
# Brak modelu dla Haczów, pomijam predykcję.
# Brak modelu dla Szarejki, pomijam predykcję.
# Brak modelu dla Borysew, pomijam predykcję.
# Brak modelu dla Gajkowice, pomijam predykcję.
# Brak modelu dla Jaroszyn, pomijam predykcję.
# Brak modelu dla Przytyk, pomijam predykcję.
# Brak modelu dla Potkanna, pomijam predykcję.
# Brak modelu dla Gierczyce, pomijam predykcję.
# Brak modelu dla Frank, pomijam predykcję.
# Brak modelu dla Gnojnik, pomijam predykcję.
# Brak modelu dla Rakowo, pomijam predykcję.
# Brak modelu dla Przyczyna dolna, pomijam predykcję.
# Brak modelu dla Kopanica, pomijam predykcję.
# Brak modelu dla Berzyna, pomijam predykcję.
#
# Wykonano predykcje dla 42295 ogłoszeń.
