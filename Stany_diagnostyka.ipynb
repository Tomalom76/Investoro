# %%
# CELL 1: imports, config, required schema
import os, sys, csv, json, textwrap, math, gc
import pandas as pd
import numpy as np

# Robust CSV reading: auto-detect delimiter
def read_csv_auto(path, nrows=None):
    return pd.read_csv(path, sep=None, engine='python', nrows=nrows)

# Four labeled files
FILES = {
    'sf_after_renovation.csv': 'AFTER_RENOVATION',
    'sf_developer_state.csv' : 'DEVELOPER_STATE',
    'sf_for_renovation.csv'  : 'FOR_RENOVATION',
    'sf_good.csv'            : 'GOOD',
}

# Required schema per the training/inference pipeline
REQUIRED_TEXT = ['Description']
REQUIRED_NUM  = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors']
REQUIRED_CAT  = ['BuildingType', 'OfferFrom', 'TypeOfMarket']
REQUIRED_DT   = ['BuiltYear']  # used to derive 'year'
REQUIRED_ALL  = REQUIRED_TEXT + REQUIRED_NUM + REQUIRED_CAT + REQUIRED_DT

print("Required columns:", REQUIRED_ALL)
# Out:
# Required columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']

# %%
# CELL 2 (robust loader): load and normalize column names with resilient CSV parsing
import os, io, csv
import pandas as pd

try:
    import chardet
except ImportError:
    chardet = None

# Prefer semicolon first (the notebook writes CSV with sep=';'), then sniff/fallbacks
PREFERRED_SEPARATORS = [';', ',', '\t', '|']

def detect_encoding(path, sample_bytes=512_000):
    if chardet is None:
        # Common encodings for PL datasets
        for enc in ['utf-8-sig', 'utf-8', 'cp1250', 'latin1']:
            try:
                with open(path, 'rb') as f:
                    f.read(64)
                return enc
            except Exception:
                continue
        return 'utf-8'
    with open(path, 'rb') as f:
        raw = f.read(sample_bytes)
    res = chardet.detect(raw) or {}
    return (res.get('encoding') or 'utf-8')

def sniff_delimiter(path, encoding, sample_lines=500):
    from itertools import islice
    with open(path, 'r', encoding=encoding, errors='replace', newline='') as f:
        sample = ''.join(list(islice(f, sample_lines)))
    try:
        dialect = csv.Sniffer().sniff(sample, delimiters=',;\t|')
        return dialect.delimiter
    except Exception:
        counts = {sep: sample.count(sep) for sep in [',',';','\t','|']}
        return max(counts, key=counts.get)

def try_read(path, sep, encoding, quoting_mode=None, force_quote_none=False):
    kw = dict(sep=sep, engine='python', encoding=encoding, on_bad_lines='skip',
              quotechar='"', doublequote=True)
    if force_quote_none:
        kw.update(dict(quotechar='\x01', quoting=csv.QUOTE_NONE, escapechar='\\'))
    if quoting_mode is not None:
        kw.update(dict(quoting=quoting_mode))
    return pd.read_csv(path, **kw)

def read_csv_robust(path):
    enc_candidates = [detect_encoding(path)] + ['utf-8-sig','utf-8','cp1250','latin1']
    seen = set(); enc_candidates = [e for e in enc_candidates if not (e in seen or seen.add(e))]

    # 1) Prefer semicolon, then sniffed, then list
    sep_candidates = PREFERRED_SEPARATORS.copy()
    try:
        sniffed = sniff_delimiter(path, enc_candidates)
        if sniffed not in sep_candidates:
            sep_candidates.insert(1, sniffed)
    except Exception:
        pass

    last_err = None
    for enc in enc_candidates:
        for sep in sep_candidates:
            for mode in [None, csv.QUOTE_MINIMAL]:
                try:
                    return try_read(path, sep=sep, encoding=enc, quoting_mode=mode), (enc, sep, mode, False)
                except Exception as e:
                    last_err = e
            try:
                return try_read(path, sep=sep, encoding=enc, force_quote_none=True), (enc, sep, 'QUOTE_NONE+escape', True)
            except Exception as e:
                last_err = e
                continue
    raise last_err if last_err else RuntimeError('Unable to read CSV')

# Load all four files
dfs = {}
for path, label in FILES.items():
    if not os.path.exists(path):
        print(f"[MISSING] {path}")
        continue
    try:
        df, used = read_csv_robust(path)
        enc, sep, quoting_used, forced = used
        df.columns = [c.strip() for c in df.columns]
        dfs[path] = df
        print(f"[OK] {path}: shape={df.shape} | encoding={enc} | sep={repr(sep)} | quoting={quoting_used} | forced_quote_none={forced}")
        print("     columns(sample):", df.columns[:12].tolist())
    except Exception as e:
        print(f"[FAIL] {path}: {type(e).__name__}: {e}")

assert len(dfs) == len(FILES), "Some input files failed to load"
# Out:
# [OK] sf_after_renovation.csv: shape=(20384, 1) | encoding=utf-8-sig | sep=';' | quoting=QUOTE_NONE+escape | forced_quote_none=True
#      columns(sample): ['"5376217","NULL","22","Ochota | Mołdawska – mieszkanie z widokiem na panoramę Warszawy","Na ulicy Mołdawskiej, w sercu Ochoty, znajduje się mieszkanie z widokiem na panoramę Warszawy. To przestrzeń, w której codzienność łączy wygodę życia w spokojnym otoczeniu z szybkim dostępem do centrum. Kameralna atmosfera osiedla i dobrze rozwinięta infrastruktura sprawiają, że to miejsce spełnia oczekiwania zarówno rodzin, jak i osób aktywnie korzystających z uroków miasta. Wnętrze z potencjałem Na 49 m² rozplanowano funkcjonalnie trzy pokoje: jasny salon (17 m²) z dużym oknem i pięknym widokiem, sypialnię (12 m²), przytulny trzeci pokój (6,5 m²) – idealny na gabinet lub pokój dziecka, osobną widną kuchnię (5 m²) oraz łazienkę z WC (3 m²). Przemyślany układ uzupełnia przedpokój (5,5 m²) z miejscem na zabudowę. Mieszkanie jest po generalnym remoncie (lipiec 2021) – od tamtej pory nikt w nim nie mieszkał. Nowa instalacja elektryczna, gładzie, wysokiej klasy panele, elegancka ceramika. Drzwi antywłamaniowe dodają poczucia bezpieczeństwa, a całość została wykończona w spójnej, nowoczesnej kolorystyce. Do lokalu przynależy piwnica. Lokalizacja, która ułatwia życie To miejsce docenią zarówno rodziny, jak i studenci. W zasięgu kilku kroków są sklepy, piekarnia, bazarek, Biedronka, Rossmann i apteka. Kilka minut spacerem dzielić Cię będzie od zielonych terenów Fortów Korotyńskiego i Parku Kotańskiego – idealnych na poranny jogging czy popołudniowy spacer. Dojazd? 200 metrów od budynku znajdziesz przystanek autobusowy. W 5 minut dotrzesz na Warszawski Uniwersytet Medyczny, a w około 15 minut do metra Politechnika lub Racławicka. Atuty w skrócie widok na panoramę Warszawy 3 pokoje w praktycznym układzie świeżo po remoncie, nikt tu jeszcze nie mieszkał spokojna okolica, dużo zieleni bezpłatne miejsca parkingowe przy budynku pełna infrastruktura w zasięgu kilku kroków świetne połączenie z Centrum Bezpieczna forma własności Mieszkanie spółdzielczo-własnościowe z księgą wieczystą, uregulowany grunt – bez przeszkód do zakupu na kredyt. ? To propozycja dla młodej rodziny, pary, a także dla inwestora szukającego mieszkania pod wynajem (studenci Warszawskiego Uniwersytetu Medycznego to stali najemcy w tej lokalizacji). Kupujący nie podpisuje żadnych umów pośrednictwa, nie ma dla Państwa żadnej "prowizji" - proszę czuć się swobodnie na prezentacji mieszkania. Zadzwoń, aby dowiedzieć się więcej i umówić się na prezentację mieszkania! Zapraszam, Anna Kalicińska --- Przedstawiona informacja nie jest ofertą handlową w rozumieniu przepisów prawa, lecz ma charakter informacyjny. Niebanalna Brokerka Sp. z o.o. dokłada wszelkich starań, aby przedstawione treści były aktualne i rzetelne. Dane dotyczące ofert uzyskano na podstawie oświadczeń Sprzedających. Wszystkie zdjęcia oraz opis nieruchomości stanowią utwór chroniony prawem autorskim w rozumieniu przepisów ustawy o prawie autorskim i prawach pokrewnych (Dz.U. 1994 Nr 24 poz. 83 z późn. zm.) i pozostają własnością Niebanalna Brokerka Sp. z o.o.. Zabrania się ich kopiowania, rozpowszechniania, publikowania oraz wykorzystywania w jakiejkolwiek formie, zarówno w całości, jak i we fragmentach, bez pisemnej zgody właściciela praw autorskich. W przypadku stwierdzenia naruszenia powyższych praw, zostaną podjęte odpowiednie kroki prawne.","49","759000","NULL","NULL","NULL","15489.8","3","1974","Mieszkania","Blok","AFTER_RENOVATION","Agencja","9","NULL","Wtórny","Spółdzielcze własnościowe","2025-08-20 14:38:15","2025-08-20 14:38:15","NULL","NULL","2025-08-20 14:38:15","NULL","https://www.sprzedajemy.pl/ochota-moldawska-mieszkanie-z-widokiem-na-panorame-warszawy-warszawa-4-1b8e55-6fpbc4-nr72037742","535568535","20250820143828_2JdNPuY7.webp","20250820143829_3oUMV93L.webp,20250820143829_4JRrTGpp.webp,20250820143829_2lZU1odr.webp,20250820143829_6N6XKCYE.webp,20250820143829_3GNb7qQQ.webp,20250820143830_4mk0u4Qw.webp,20250820143830_2ZGebinD.webp","0","0","0","0","0","3","2","0","0","0","NULL","83814","N ...
# [OK] sf_developer_state.csv: shape=(19829, 1) | encoding=utf-8 | sep=';' | quoting=QUOTE_NONE+escape | forced_quote_none=True
#      columns(sample): ['"5376157","NULL","19","PSARSKIE - ul. Hebanowa 5/34 - 42,11 m2, II PIĘTRO","Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantujący bezpieczeństwo nabywcy lokalu. Po więcej informacji zapraszamy do biura firmy przy ul. Sikorskiego 41 w Śremie oraz zachęcamy do kontaktu telefonicznego. Pełna oferta naszej firmy znajduje się również na stronie internetowej nieruchomosci-enigma.pl Niniejsza oferta nie stanowi oferty w świetle przepisów KC. Zamieszczone plany lokalu, opisy i wizualizacje nie stanowią oferty w rozumieniu prawa i są publikowane w celach informacyjnych. Przedstawione materiały mają charakter poglądowy i nie mogą być traktowane jako projekty realizacyjne. Pomiarów pod zakup mebli, urządzeń i wyposażenia należy dokonać z natury, po zakończeniu budowy Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantuj
charakter informacyjny. Na sprzedaż mieszkanie 4-pokojowe o powierzchni 50,20 m² 6 piętro w 10-piętrowym bloku z 1980 roku Kraków, Czyżyny Ogłoszenie biura nieruchomości Właściciel postanowił powierzyć ofertę agencji nieruchomości. Oferta dodana dzisiaj Ta nieruchomość może być Twoja już od 3339 zł / mc Wkład własny: 131 800 zł (20%) Okres spłaty: 30 lat Oblicz zdolność kredytową Kraków Czyżyny Poland - lokalizacja przybliżona","50.2","659000","980721.33","NULL","NULL","13127.49","4","1980","Mieszkania","Blok","FOR_RENOVATION","Agencja","6","10","NULL","NULL","2025-08-20 14:34:45","2025-08-20 14:34:43","NULL","NULL","2025-08-20 14:34:43","NULL","https://www.adresowo.pl/o/mieszkanie-krakow-czyzyny-4-pokojowe-50-m2-b2i6g2","NULL","20250820143500_1sF1FCiq.webp","20250820143500_5hqTpq0f.webp,20250820143500_19w2g9Lt.webp,20250820143500_6GnxKB8F.webp,20250820143500_wzeroR2p.webp,20250820143501_18T1e1ng.webp,20250820143501_6jJRr0Fc.webp","4","0","0","0","0","5","2","0","0","0","NULL","94050","NULL","NULL","NULL","NULL","NULL","NULL","50-gPkdXgOVH3wdJTK_MCai_rC3KFy_RnfS0EWfIRU4=","14,0,0,337,3279,94050,0","Małopols ...
# [OK] sf_good.csv: shape=(19875, 1) | encoding=utf-8 | sep=';' | quoting=QUOTE_NONE+escape | forced_quote_none=True
#      columns(sample): ['"5376200","NULL","2","Na sprzedaż 3\\\'pokojowe mieszkanie, II piętro","Na sprzedaż 3\'pokojowe mieszkanie o powierzchni użytkowej 55,19 m2 przy ul. Zacisze w Kaliszu. Mieszkanie mieści się na II piętrze, w niskim czteropiętrowym bloku z cegły z 1976 roku. Układ mieszkania: trzy niezależne pokoje, osobna kuchnia, łazienka, wc, przedpokój. Z salonu wyjście na balkon z widokiem na Aulę Jerzego Rubińskiego. Do mieszkania przynależy piwnica w przyziemiu budynku. Za blokiem parking i plac zabaw dla lokatorów bloku. Mieszkanie spółdzielcze własnościowe. Wszystkie media miejskie. Czynsz administracyjny do spółdzielni ok. 600 zł (przy rozliczeniu mediów dla 1 osoby). Mieszkanie o bardzo funkcjonalnym układzie pomieszczeń - niezależność pokoi podnosi komfort użytkowania lokalu. Pomieszczenia słoneczne - ekspozycja okien po dwóch stronach mieszkania. Mieszkanie dostępne od ręki. Zachęcam do zapoznania się z tą wyjątkową ofertą. Cena mieszkania 328.000 zł do negocjacji Gorąco polecam! Dagmara501... pokaż Jednorazowa prowizja dla biura wg aktualnego cennika. Licencja 16070 Dagmara Jeżyk. Zapraszamy również na bezpłatną konsultację z Naszym Ekspertem finansowym. Opis ma charakter informacyjny i nie stanowi oferty w rozumieniu Kodeksu Cywilnego.","55.19","328000","NULL","NULL","NULL","5943.11","3","1976","Mieszkania","Blok","GOOD","Agencja","2","4","Wtórny","Spółdzielcze-własnościowe","2025-08-20 14:36:02","2025-08-20 14:36:02","NULL","NULL","2025-08-20 14:36:02","NULL","https://www.morizon.pl/oferta/sprzedaz-mieszkanie-kalisz-srodmiescie-zacisze-55m2-mzn2046146898","501684817","20250820143608_6tdmTknf.webp","20250820143609_4rc3z70E.webp,20250820143609_6dnuHDnz.webp","0","0","0","0","0","5","2","0","0","0","NULL","351374","NULL","NULL","NULL","NULL","NULL","NULL","jqWH3UzmKlk3acr1GorX1FcgSx7sGm5nUpo5FzVSNNM=","12,0,0,347,0,105716,351374","Kalisz, Śródmieście, Zacisze"']

# %%
# CELL 2a: raw preview of files + delimiter frequency
import os
from collections import Counter

CAND_SEPS = [',',';','\t','|','^','~']

def raw_head(path, encoding='utf-8', n=10):
    lines=[]
    with open(path, 'r', encoding=encoding, errors='replace', newline='') as f:
        for i, line in enumerate(f, 1):
            lines.append((i, line.rstrip('\n')))
            if i>=n: break
    return lines

def guess_encoding(path):
    try:
        import chardet
        with open(path,'rb') as f:
            data=f.read(512000)
        return (chardet.detect(data) or {}).get('encoding') or 'utf-8'
    except Exception:
        return 'utf-8'

def sep_stats(lines):
    stats=[]
    for s in CAND_SEPS:
        stats.append((s, sum(l.count(s) for _,l in lines)))
    return sorted(stats, key=lambda x: x[1], reverse=True)

for path in FILES.keys():
    if not os.path.exists(path):
        print(f"[MISSING] {path}")
        continue
    enc = guess_encoding(path)
    lines = raw_head(path, encoding=enc, n=10)
    print(f"\n=== {path} | encoding≈{enc} ===")
    for i, l in lines:
        print(f"{i:03d}: {l!r}")
    print("Separator counts (top):", sep_stats(lines)[:5])
# Out:
# === sf_after_renovation.csv | encoding≈Windows-1254 ===
# 001: '"5376217","NULL","22","Ochota | MoÅ‚dawska â€“ mieszkanie z widokiem na panoramÄ™ Warszawy","Na ulicy MoÅ‚dawskiej, w sercu Ochoty, znajduje siÄ™ mieszkanie z widokiem na panoramÄ™ Warszawy. To przestrzeÅ„, w ktÃ³rej codziennoÅ›Ä‡ Å‚Ä…czy wygodÄ™ Å¼ycia w spokojnym otoczeniu z szybkim dostÄ™pem do centrum. Kameralna atmosfera osiedla i dobrze rozwiniÄ™ta infrastruktura sprawiajÄ…, Å¼e to miejsce speÅ‚nia oczekiwania zarÃ³wno rodzin, jak i osÃ³b aktywnie korzystajÄ…cych z urokÃ³w miasta. WnÄ™trze z potencjaÅ‚em Na 49 mÂ² rozplanowano funkcjonalnie trzy pokoje: jasny salon (17 mÂ²) z duÅ¼ym oknem i piÄ™knym widokiem, sypialniÄ™ (12 mÂ²), przytulny trzeci pokÃ³j (6,5 mÂ²) â€“ idealny na gabinet lub pokÃ³j dziecka, osobnÄ… widnÄ… kuchniÄ™ (5 mÂ²) oraz Å‚azienkÄ™ z WC (3 mÂ²). PrzemyÅ›lany ukÅ‚ad uzupeÅ‚nia przedpokÃ³j (5,5 mÂ²) z miejscem na zabudowÄ™. Mieszkanie jest po generalnym remoncie (lipiec 2021) â€“ od tamtej pory nikt w nim nie mieszkaÅ‚. Nowa instalacja elektryczna, gÅ‚adzie, wysokiej klasy panele, elegancka ceramika. Drzwi antywÅ‚amaniowe dodajÄ… poczucia bezpieczeÅ„stwa, a caÅ‚oÅ›Ä
�a zainstalowana klimatyzacja. W cenie nieruchomoÅ›ci pozostajÄ… zabudowy staÅ‚e tj. zabudowa kuchni i AGD, szafy w zabudowie oraz stÃ³Å‚ kuchenny. Czynsz: 600 zÅ‚ latem i 700 zimÄ… przy 3 osobach. KotÅ‚ownia gazowa w budynku. Do mieszkania przynaleÅ¼y piwnica o powierzchni 4,6 m2. Zapraszam na prezentacjÄ™! KUP Z NAMI - KORZYSTNIE I BEZPIECZNIE! - 0% prowizji od KupujÄ…cego (dotyczy ofert oznaczonych znaczkiem KUP bez prowizji) i Å¼adnych dodatkowych lub ukrytych kosztÃ³w - gwarantujemy bezpieczny zakup i najlepszÄ… cenÄ™ - oferujemy skutecznÄ… i bezpÅ‚atnÄ… pomoc w uzyskaniu kredytu - zapewniamy fachowe doradztwo przy zakupie pod inwestycjÄ™","45.7","549000","NULL","NULL","NULL","12013.13","3","2007","Mieszkania","Blok","AFTER_RENOVATION","Agencja","3","3","WtÃ³rny","WÅ‚asnoÅ›Ä‡","2025-08-20 14:20:57","2025-08-20 14:20:56","NULL","NULL","2025-08-20 14:20:56","NULL","https://www.morizon.pl/oferta/sprzedaz-mieszkanie-pomorskie-gdanski-horsztynskiego-45m2-mzn2046146844","NULL","20250820142103_333hY5vF.webp","20250820142103_27UDZEC1.webp,20250820142104_1qnIFQFB.webp","4","0","0","0","0","6","3","0","0","0","NULL","537545","NULL","NULL","NULL","NULL","NULL","NULL","jtBEWwSCc0w0wu5vvDMRFRhr0WkApuPzxhJg57rv_OE=","11,214,0,13561,0,0,537545","GdaÅ„ski, Pruszcz GdaÅ„ski, HorsztyÅ„skiego"'
# Separator counts (top): [(',', 873), (';', 3), ('|', 1), ('\t', 0), ('^', 0)]
#
# === sf_developer_state.csv | encoding≈utf-8 ===
# 001: '"5376157","NULL","19","PSARSKIE - ul. Hebanowa 5/34 - 42,11 m2, II PIĘTRO","Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantujący bezpieczeństwo nabywcy lokalu. Po więcej informacji zapraszamy do biura firmy przy ul. Sikorskiego 41 w Śremie oraz zachęcamy do kontaktu telefonicznego. Pełna oferta naszej firmy znajduje się również na stronie internetowej nieruchomosci-enigma.pl Niniejsza oferta nie stanowi oferty w świetle przepisów KC. Zamieszczone plany lokalu, opisy i wizualizacje nie stanowią oferty w rozumieniu prawa i są publikowane w celach informacyjnych. Przedstawione materiały mają charakter poglądowy i nie mogą być traktowane jako projekty realizacyjne. Pomiarów pod zakup mebli, urządzeń i wyposażenia należy dokonać z natury, po zakończeniu budowy Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantujący bezpieczeństwo na ...
# 002: '"5376148","NULL","19","PSARSKIE - ul. Hebanowa 5/33 - 62,11 m2, II PIĘTRO","Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 33 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej aż 62,11 m2 w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, pokój 2, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantuj
. Zapraszam na prezentację nieruchomości. W razie zainteresowania prosimy o kontakt: , Powyższa oferta ma charakter informacyjny i nie stanowi oferty handlowej w rozumieniu art. 66 §1 Kodeksu Cywilnego. Podana ulica nieruchomości przy ogłoszeniu ma na celu wskazania przybliżonej lokalizacji z dużą dokładnością. Bezpłatnie pomagamy znaleźć najkorzystniejszą na rynku ofertę kredytową. Na życzenie w ramach prezentacji nieruchomości możliwość przeprowadzenia przez firmę budowlaną oceny stanu mieszkania i wycenę remontu. Na sprzedaż mieszkanie 2-pokojowe o powierzchni 31,06 m² 7 piętro w 10-piętrowym bloku z windą z 1973 roku Warszawa, Mokotów, ul. Stefana Pieńkowskiego Balkon Mieszkanie w bardzo dobrym stanie, okna plastikowe Odrębna własność z księgą wieczystą Ogłoszenie biura nieruchomości Właściciel postanowił powierzyć ofertę agencji nieruchomości. Oferta dodana dzisiaj Ta nieruchomość może być Twoja już od 2907 zł / mc Wkład własny: 114 000 zł (20%) Okres spłaty: 30 lat Oblicz zdolność kredytową Warszawa Mokotów, Stefana Pieńkowskiego Poland - lokalizacja przybliżona","31.06","570000","722875","NULL","NULL","18351.58","2","1973","Mieszkania","Blok","GOOD","Agencja","7","10","NULL","Odrębna własność z księgą wieczystą","2025-08-20 14:34:21","2025-08-20 14:34:19","NULL","NULL","2025-08-20 14:34:19","NULL","https://www.adresowo.pl/o/mieszkanie-warszawa-mokotow-ul-stefana-pienkowskiego-2-pokojowe-k1h4q4","NULL","20250820143446_3rBwrsy4.webp","20250820143446_2FFQsMjy.webp,20250820143446_1rrnYr0L.webp,20250820143446_2DJyBZjj.webp,20250820143446_2xlUJDmP.webp,20250820143447_1LLtz96a.webp,20250820143447_2p6ZReCI.webp,20250820143447_1IAq60AZ.webp","1","0","0","0","0","5","2","0","0","0","NULL","372689","NULL","NULL","NULL","NULL","NULL","NULL","50-gPkdXgOVH3wdJTK_MCUl0No0EG2AVE6RTeqEmbdY=","9,0,0,368,3283,80732,372689","Mazowieckie, Warszawa, Mokotów, Ul. Stefana Pieńkowskiego, Ul. Stefana Pieńkowskiego"'
# Separator counts (top): [(',', 884), ('|', 5), (';', 0), ('\t', 0), ('^', 0)]

# %%
# CELL 2b: auto-pick header line, re-read with inferred header and sep
import csv, re
import pandas as pd
from itertools import islice

def score_header_line(line, sep):
    # więcej tokenów alfanumerycznych i krótkie tokeny => bardziej jak nagłówki
    toks = [t.strip() for t in line.split(sep)]
    alnum = sum(bool(re.search(r'[A-Za-zĄąĆćĘęŁłŃńÓóŚśŹźŻż]', t)) for t in toks)
    uniq = len(set(toks))
    short = sum(len(t)<=30 for t in toks)
    return alnum*2 + uniq + short*0.5

def infer_sep_by_counts(line):
    counts = {s: line.count(s) for s in [',',';','\t','|','^','~']}
    return max(counts, key=counts.get)

def find_header(path, encoding, scan_lines=200):
    with open(path, 'r', encoding=encoding, errors='replace', newline='') as f:
        lines = list(islice(f, scan_lines))
    # infer sep from the densest line among first 5
    probe = ''.join(lines[:5])
    sep = infer_sep_by_counts(probe)
    best_i, best_score = 0, -1
    for i, ln in enumerate(lines[:50]):  # zwykle w nagłówku
        sc = score_header_line(ln.rstrip('\n'), sep)
        if sc>best_score:
            best_score, best_i = sc, i
    header_line = lines[best_i].rstrip('\n')
    header_tokens = [t.strip() for t in header_line.split(sep)]
    return sep, best_i, header_tokens

def read_with_header(path):
    enc = guess_encoding(path)
    sep, hdr_idx, names = find_header(path, enc)
    print(f"{path}: sep={repr(sep)} | header_line={hdr_idx+1} | columns_detected={names}")
    # read all, then drop rows up to header line and set names
    df_raw = pd.read_csv(path, sep=sep, engine='python', header=None, encoding=enc, on_bad_lines='skip')
    df = df_raw.iloc[hdr_idx+1:].reset_index(drop=True).copy()
    df.columns = [str(c).strip() for c in names]
    return df, {'encoding':enc, 'sep':sep, 'header_line':hdr_idx+1, 'columns':names}

dfs2 = {}
meta2 = {}
for path in FILES.keys():
    if os.path.exists(path):
        try:
            df, meta = read_with_header(path)
            dfs2[path] = df
            meta2[path] = meta
            print(f"[OK] {path}: shape={df.shape}")
            print("     columns(sample):", df.columns[:20].tolist())
        except Exception as e:
            print(f"[FAIL] {path}: {e}")

# If success, replace dfs by dfs2 for next steps
if dfs2 and len(dfs2)==len(FILES):
    dfs = dfs2
# Out:
# sf_after_renovation.csv: sep=',' | header_line=48 | columns_detected=['"5375146"', '"NULL"', '"11"', '"Mieszkanie', 'KrakÃ³w', 'PodgÃ³rze Duchackie', 'Wola Duchacka', '48 mÂ²"', '"Mieszkanie', 'KrakÃ³w', 'PodgÃ³rze Duchackie', 'Wola Duchacka', '48 mÂ² OgÅ‚oszeniodawca: Bracia Sadurscy NieruchomoÅ›ci Kontakt: Julia Tarkowska Informacje szczegÃ³Å‚owe Forma wÅ‚asnoÅ›ci: OdrÄ™bna wÅ‚asnoÅ›Ä‡ lokalu Typ kuchni: aneks kuchenny - poÅ‚Ä…czony z salonem Stan nieruchomoÅ›ci: wysoki standard Stolarka okienna: PCVDodatkowe koszty: 600 TytuÅ‚ ogÅ‚oszenia: 2-pok./wysok standard/2022/podwÃ³jny garaÅ¼/ Szpakowa Nr oferty ogÅ‚oszeniodawcy: BS1- MS-311082 Ulica: Szpakowa Powierzchnia balkonu: 6.00 mÂ² Powierzchnia uÅ¼ytkowa: 47.83 mÂ² PiÄ™tro: 8 Liczba piÄ™ter: 11 Pokoje: 2 Liczba Å‚azienek: 1 Liczba sypialni: 1 Czy Å‚azienka z WC: Razem Typ rynku: WtÃ³rny Budynek Rok budowy: 2022 MateriaÅ‚ budowlany: zrÃ³Å¼nicowany Udogodnieniabalkoninternetklimatyzacja | Sprzedam 2-pok. mieszkanie z 2022r. / meble wykonane na wymiar przez stolarza/ wysoki standard/ podwÃ³jne miejsce garaÅ¼owe JeÅ›li szukasz mieszkania nowoczesnego', 'gotowego do wejÅ›cia', 'to ta oferta moÅ¼e byÄ‡ wÅ‚aÅ›nie dla Ciebie! Tylko w naszym Biurze Do sprzedaÅ¼y oferujÄ™ 2-pok.mieszkanie o pow. 47', '83 m 2 wykoÅ„czone w wysokim standardzie
48 505 083 150 - Julia Tarkowska Prezentacja nieruchomoÅ›ci po podpisaniu umowy poÅ›rednictwa jest bezpÅ‚atna. :: DODATKOWE INFORMACJE | Rodzaj budynku: nowe budownictwo | DozÃ³r budynku: monitoring | GÅ‚oÅ›noÅ›Ä‡: ciche | Plac zabaw: TAK | Widok: na osiedle | Gaz: brak | Woda: tak - miejska | Dojazd: asfaltowa/kostka | Otoczenie: osiedle | Ogrzewanie: C. O. ...
# [FAIL] sf_after_renovation.csv: 'charmap' codec can't decode byte 0x81 in position 5717: character maps to <undefined>
# sf_developer_state.csv: sep=',' | header_line=22 | columns_detected=['"5375984"', '"NULL"', '"10"', '"Mieszk/pod wynajem/dla studenta/centrum/Przed.Świdnickie/super lokalizacja"', '"Oferta od dewelopera', 'bez prowizji od kupującego', 'bez PCC! To nowoczesna inwestycja klasy premium zlokalizowana w centrum Wrocławia. Idealna lokalizacja pod inwestycję', 'dwie minuty pieszo do Wrocławskiego Rynku', '7 minut pieszo do Dworca Głównego. Zastosowanie materiałów spełniających najwyższe standardy', 'wykorzystanie funkcjonalnych rozwiązań', 'plus niepowtarzalna lokalizacja zapewniają wielowymiarowy komfort życia w mieście. Ten prestiżowy apartamentowiec', 'powstaje w topowej lokalizacji', 'która doskonale realizuje koncepcję 15 minutowego miasta. W sąsiedztwie inwestycji odnajdziemy m.in. Operę Wrocławską', 'Teatr Lalek', 'Galerię Renoma oraz zieloną Promenadę Staromiejską. Łatwy dostęp do placówek edukacyjnych', 'komunikacji miejskiej', 'oraz sąsiedztwo terenów rekreacyjnych sprawiają', 'że wygoda i komfort w środku miasta są możliwe i przyjemne! Starannie przemyślany projekt doskonale komponuje się z charakterem centrum Wrocławia. W prostej formie łączy piękno nowoczesnej architektury z funkcjonalnością rozwiązań służących mieszkańcom', 'takich jak taras widokowy ze strefą rekreacji na dachu budynku', 'przestrzeń coworkingową dla osób pracujących zdalnie oraz rozwiązania typu smart home. Całość inwestycji zaplanowano jako miejsce niezwykle przyjazne rowerzystom. Proponowane mieszkanie ma 35', '96m2', 'znajduje się na parterze w 6 kondygnacyjnym apartamentowcu a jego główne cechy to: - salon z aneksem kuchennym 28', '02m2', 'z salonu wyjście na ogród o powierzchni 26', '44m2', 'w salonie istnieje możliwość wydzielenia sypialni - łazienka 4', '39m2', '- p.pokój 3', '69m2', 'Ponadto w standardzie premium', 'dla mieszkańców przygotowane są: • Zielony dach jako miejsce do rekreacji', '• Bogata i różnorodna zieleń', '• Strefa coworkingowa', '• 3 energooszczędne i cichobieżne windy', '• Bezpieczeństwo (wideodomofony', 'kontrola dostępu', 'ochrona', 'monitoring)', '• Części wspólne wykończone materiałami wysokiej jakości', '• Wypełnienia balustrad ze szkła bezpiecznego', '• Duże okna o podwyższonej izolacji akustycznej', '• Drewniana stolarka okienna', '• Mieszkania wyposażone w system smart home', '• Rolety elektryczne na parterze', '• Wysokość mieszkań 2', '86 m (parter) i 2', '69 m (pozostałe piętra)', '• Grzejniki kanałowe na 5. i 6. piętrze', '• Wyprowadzenie pod klimatyzację na 5. i 6. piętrze. W trosce o ekologię inwestor zadbał także o: • Duża ilość miejsc rowerowych', '• Budki dla ptaków', '• Panele fotowoltaiczne do zasilania części wspólnych', '• Odzysk deszczówki do podlewania zieleni na terenie osiedla', '• Infrastrukturę pod instalację ładowarek do samochodów elektrycznych. Mieszkanie gotowe z kluczami do odbioru! Zapraszam do kontaktu! Zapewniam - profesjonalną obsługę', 'gwarantowaną wieloletnim doświadczeniem w branży nieruchomości-możliwość bezpłatnej rezerwacji apartamentu - kompleksowe wsparcie na każdym etapie transakcji - gwarancję bezpiecznego zakupu - oszczędność czasu -pomoc w uzyskaniu kredytu na najlepszych warunkach - kompleksowe doradztwo Ania Kamuda - Doradca klienta 535... pokaż anna.kamuda@ Nr oferty: CZ-M.01.21/AK Zamieszczone na naszych stronach informacje nie stanowią oferty w rozumieniu Kodeksu Cywilnego', 'a dane w nich zawarte mają jedynie charakter informacyjny. OFERTA CENOWA AKTUALNA NA DZIEŃ 21.08.2025 I OBOWIĄZUJE DO DNIA 21.08.2025"', '"35.96"', '"699000"', '"NULL"', '"NULL"', '"NULL"', '"19438.26"', '"1"', '"2024"', '"Mieszkania"', '"Apartamentowiec"', '"DEVELOPER_STATE"', '"Agencja"', '"0"', '"6"', '"Pierwotny"', '"Własność"', '"2025-08-20 14:10:11"', '"2025-08-20 14:10:09"', '"NULL"', '"NULL"', '"2025-08-20 14:10:09"', '"NULL"', '"https://nieruchomosci.gratka.pl/nieruchomosci/mieszkanie-wroclaw-stare-miasto/ob/43543913"', '"535422188"', '"20250820141022_4o3PDSmE.webp"', '"20250820141023_4Tfu3ZJn ...
# [FAIL] sf_developer_state.csv: Length mismatch: Expected axis has 52 elements, new values have 111 elements
# sf_for_renovation.csv: sep=',' | header_line=14 | columns_detected=['"5375593"', '"NULL"', '"38"', '"Mieszkanie 3 pokojowe"', '"Oferta aktualna - moÅ¼liwoÅ›Ä‡ umÃ³wienia bezpiecznej prezentacji. Zapraszamy! Na sprzedaÅ¼ przestronne', 'funkcjonalne i umeblowane mieszkanie poÅ‚oÅ¼one przy ul. Idzikowskiego w Toruniu â€“ w spokojnej i zielonej okolicy', 'tuÅ¼ obok Parku TysiÄ…clecia. To idealna propozycja dla rodzin', 'par', 'jak i osÃ³b ceniÄ…cych sobie bliskoÅ›Ä‡ natury przy jednoczesnym dostÄ™pie do peÅ‚nej infrastruktury miejskiej. LOKALIZACJA: To spokojne', 'zielone osiedle Å‚Ä…czy w sobie zalety miejskiego Å¼ycia z bliskoÅ›ciÄ… natury. W sÄ…siedztwie znajdujÄ… siÄ™ liczne sklepy', 'punkty usÅ‚ugowe', 'szkoÅ‚y oraz przystanki komunikacji miejskiej', 'co zapewnia wygodÄ™ codziennego funkcjonowania. Dodatkowo', 'bliskoÅ›Ä‡ parku oraz terenÃ³w rekreacyjnych sprzyja aktywnemu wypoczynkowi na Å›wieÅ¼ym powietrzu. W najbliÅ¼szej okolicy znaj
and functional apartment located at Idzikowskiego Street in ToruÅ„ - in a quiet and green area', 'right next to the TysiÄ…clecia Park. This is an ideal proposition for families', 'couples and people who value proximity to nature while having access to full urban infrastructure. LOCATION: This quiet', 'green estate combines the advantages of city life with proximity to nature. In the vicinity there are numerous shops', 'service points', 'schools and public transport stops', 'which ensures the convenience of everyday functioning. Additionally', 'the proximity of the park and recreational areas is conducive to active outdoor recreation. In the immediate vicinity there is a mini Aqua Park at Hallera Street. An apartment located in this location is an excellent choice for both families and people who value comfort and peace', 'without giving up ...
# [FAIL] sf_for_renovation.csv: 'charmap' codec can't decode byte 0x81 in position 2251: character maps to <undefined>
# sf_good.csv: sep=',' | header_line=14 | columns_detected=['"5376101"', '"NULL"', '"4"', '"3-pokojowe mieszkanie na sprzedaż"', '"Mokotów', 'uznawany za jedno z głównych centrów biznesowych Warszawy', 'wyróżnia się doskonale rozwiniętą infrastrukturą handlową', 'gastronomiczną i edukacyjną', 'a także licznymi terenami zielonymi. Dzięki swojej wszechstronności', 'dzielnica ta idealnie odpowiada na potrzeby rodzin z dziećmi', 'singli', 'studentów i inwestorów. Zapraszam do zapoznania się z wyjątkową ofertą 3 - pokojowego mieszkania o powierzchni 72 m2', 'położonego na 3 piętrze w siedmiopiętrowym', 'nowoczesnym budynku z 2018r. Nieruchomość znajduje się na warszawskim Mokotowie', 'przy ul. Śródziemnomorskiej', 'w kameralnej inwestycji „Nowe Południe”. To doskonały wybór dla pary', 'rodziny lub inwestora', 'poszukujących przestronnego', 'wygodnego miejsca w świetnie skomunikowanej okolicy. OPIS NIERUCHOMOŚCI : Mieszkanie jest c iche', 'przestronne', 'posiada dwustronną ekspozycję oraz przemyślany układ', 'który maksymalizuje komfort codziennego życia. Salon', 'kuchnia i loggia zlokalizowane od strony ul. Alei Wilanowskiej są skierowane na stronę Południową', 'natomiast sypialnie usytuowane są na stronę Północną. Wszystkie zabudowy meblowe zostały wykonane przez stolarza', 'co nadaje przestrzeni unikatowy charakter. Nieruchomość oferuje dużo miejsca do przechowywania dzięki licznym szafom i praktycznym rozwiązaniom. Budynek jest całodobowo monitorowany z własną ochroną zapewniając bezpieczeństwo pod każdym względem. Do dyspozycji jest także klimatyzacja', 'która dba o idealną temperaturę przez cały rok. • Przestronny salon z aneksem kuchennym (30', '18 m2): Stanowi serce mieszkania i został wyposażony w wygodną', 'dużą sofę', 'idealną do relaksu', 'duży telewizor z szafką RTV oraz stół z krzesłami. Aneks kuchenny oferuje wiele miejsca do przechowywania i został zaprojektowany z myślą o funkcjonalności. Na wyposażeniu znajdują się: lodówko-zamrażarka', 'płyta indukcyjna', 'piekarnik', 'okap oraz zmywarka. Kuchnia zachwyca jasnością', 'przestronnością i ergonomicznym układem. • Stylowa sypialnia (13', '17 m2): To przytulne miejsce do odpoczynku. Znajdziemy tu komfortowe', 'szerokie łóżko gwarantujące spokojny sen i pełen relaks', 'dużą szafę do przechowywania oraz telewizor. • Pokój (11', '27 m2): Sprawdzi się idealnie jako pokój dla dziecka lub gabinet do pracy. Aktualnie znajdziemy w nim dużą szafę', 'piętrowe łóżko oraz biurko . • Łazienka pełna komfortu (5', '7 m2): Nowoczesna łazienka wyposażona w przestronną wannę z funkcją prysznica', 'lustro', 'toaletę', 'umywalkę z dużą szafką oraz pralkę. Dodatkową wygodę zapewnia duża zabudowa meblowa', 'w której znajdziemy sporo miejsca do przechowywania. • WC (1', '46 m2): Znajdziemy tu toaletę', 'zabudowę meblową', 'lustro oraz umywalkę z szafką', 'łączące funkcjonalność z estetyką. • Praktyczny hol (10', '19 m2): Wchodząc do mieszkania', 'witają nas funkcjonalne rozwiązania', 'duża narożna szafa', 'które zapewnia przestrzeń do przechowywania i wygodę użytkowania. Znajdziemy tu także lustro oraz domofon. • Loggia (3', '4 m2): To idealne miejsce na poranną kawę', 'odpoczynek po pracy lub chwilę relaksu. LOKALIZACJA: Nieruchomość mieści się na estetycznie zaprojektowanym osiedlu', 'położonym w spokojnej okolicy. W bezpośrednim sąsiedztwie dostępne są liczne sklepy', 'punkty usługowe', 'restauracje', 'żłobki oraz szkoły. Miłośnicy natury mogą wybrać się na spacer do pobliskiego Parku Dolinka Służewiecka. Nieruchomość charakteryzuje się doskonałą komunikacją z pozostałymi częściami Warszawy. Zaledwie 2 minuty spacerem dzielą nas od przystanku autobusowego „Karczocha 02”', 'a w około 10 minut dotrzemy pieszo do przystanku tramwajowego „Nałęczowska 05”. Dojazd do Stacji Metra', '', 'Wilanowska zajmie nam tylko 7 min. komunikacją. Dodatkowym atutem lokalizacji jest planowana Stacja Metra w odległości ok. 1200 m od inwestycji . OKOLICA : Żłobek - 900 m Restauracja - 500 m Sklep spożywczy - 50 m ...
# [FAIL] sf_good.csv: Length mismatch: Expected axis has 52 elements, new values have 141 elements

# %%
# CELL 3: schema normalization (auto-rename) and validation
import re, difflib
import pandas as pd

# Expected schema from the notebook pipeline
REQUIRED_TEXT = ['Description']
REQUIRED_NUM  = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors']
REQUIRED_CAT  = ['BuildingType', 'OfferFrom', 'TypeOfMarket']
REQUIRED_DT   = ['BuiltYear']
REQUIRED_ALL  = REQUIRED_TEXT + REQUIRED_NUM + REQUIRED_CAT + REQUIRED_DT

# Synonyms dictionary (lowercased, whitespace/underscore-insensitive match)
COLUMN_SYNONYMS = {
    'Description': ['description','opis','opis_oferty','opisoferty','desc','full_description','opis_pelny','tytul_opisu','title_description'],
    'Area': ['area','powierzchnia','metraz','metraż','pow','m2','sqm','surface','powierzchnia_m2'],
    'Price': ['price','cena','kwota','amount','price_pln','cena_pln','wartosc','wartość'],
    'NumberOfRooms': ['numberofrooms','rooms','liczbapokoi','pokoje','pokoi','iloscpokoi','rooms_count','roomsnumber','roomsno'],
    'Floor': ['floor','piętro','pietro','poziom','floor_no','floornumber'],
    'Floors': ['floors','liczbapieter','liczba_pieter','kondygnacje','kondygnacji','pieter','pietra_total','total_floors','floors_total'],
    'BuildingType': ['buildingtype','typbudynku','rodzajbudynku','typ_budynku','type_building','building_type'],
    'OfferFrom': ['offerfrom','ofertaod','zrodlo','źródło','source','sprzedajacy','sprzedający','agency','offer_from'],
    'TypeOfMarket': ['typeofmarket','rynek','market','typ_rynku','market_type'],
    'BuiltYear': ['builtyear','rokbudowy','rok_budowy','year_built','rok','data_budowy','rok_powstania']
}

def normalize_token(s: str) -> str:
    return re.sub(r'[^a-z0-9]+','', str(s).strip().lower())

def build_normal_index(cols):
    idx = {}
    for c in cols:
        idx[normalize_token(c)] = c
    return idx

def auto_map_columns(df: pd.DataFrame):
    original_cols = list(df.columns)
    norm_index = build_normal_index(original_cols)
    rename_map = {}
    report = []

    for target in REQUIRED_ALL:
        # 1) exact normalized name
        key = normalize_token(target)
        if key in norm_index:
            rename_map[norm_index[key]] = target
            report.append((target, norm_index[key], 'exact'))
            continue
        # 2) synonyms
        matched = False
        for syn in COLUMN_SYNONYMS.get(target, []):
            syn_key = normalize_token(syn)
            if syn_key in norm_index:
                rename_map[norm_index[syn_key]] = target
                report.append((target, norm_index[syn_key], 'synonym'))
                matched = True
                break
        if matched:
            continue
        # 3) fuzzy close match among available columns
        candidates = difflib.get_close_matches(target.lower(), [c.lower() for c in original_cols], n=1, cutoff=0.88)
        if candidates:
            # pick the first candidate that is not already mapped
            cand = candidates
            # find original case column
            orig = next(c for c in original_cols if c.lower()==cand)
            if orig not in rename_map:
                rename_map[orig] = target
                report.append((target, orig, 'fuzzy'))
                continue
        # 4) leave as missing for now
        report.append((target, None, 'missing'))

    # Apply rename only for mapped items
    df2 = df.rename(columns=rename_map)
    return df2, report

# Apply auto mapping to each loaded DataFrame in dfs
mapping_reports = {}
for path, df in list(dfs.items()):
    df_mapped, rep = auto_map_columns(df)
    dfs[path] = df_mapped
    mapping_reports[path] = rep
    # Print mapping summary
    print(f"\n[{path}] column mapping summary:")
    for target, source, how in rep:
        print(f" - {target:<16} <- {source if source is not None else 'MISSING'} [{how}]")
    # Show unmapped required
    unmapped = [t for t,s,how in rep if s is None]
    if unmapped:
        print("Unmapped required columns:", unmapped)

# Re-run schema validation after mapping
problems = []
for path, df in dfs.items():
    cols = set(df.columns)
    missing = [c for c in REQUIRED_ALL if c not in cols]
    extra   = [c for c in cols if c not in REQUIRED_ALL]
    print(f"\n[{path}] post-mapping schema:")
    print(" - missing:", missing)
    print(" - extra  :", extra[:20], "(+ more)" if len(extra) > 20 else "")
    if missing:
        problems.append((path, "missing_columns", missing))

assert not problems, f"Schema issues after auto-mapping: {problems}"
# Out:
# [sf_after_renovation.csv] column mapping summary:
#  - Description      <- MISSING [missing]
#  - Area             <- MISSING [missing]
#  - Price            <- MISSING [missing]
#  - NumberOfRooms    <- MISSING [missing]
#  - Floor            <- MISSING [missing]
#  - Floors           <- MISSING [missing]
#  - BuildingType     <- MISSING [missing]
#  - OfferFrom        <- MISSING [missing]
#  - TypeOfMarket     <- MISSING [missing]
#  - BuiltYear        <- MISSING [missing]
# Unmapped required columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#
# [sf_developer_state.csv] column mapping summary:
#  - Description      <- MISSING [missing]
#  - Area             <- MISSING [missing]
#  - Price            <- MISSING [missing]
#  - NumberOfRooms    <- MISSING [missing]
#  - Floor            <- MISSING [missing]
#  - Floors           <- MISSING [missing]
#  - BuildingType     <- MISSING [missing]
#  - OfferFrom        <- MISSING [missing]
#  - TypeOfMarket     <- MISSING [missing]
#  - BuiltYear        <- MISSING [missing]
# Unmapped required columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#
# [sf_for_renovation.csv] column mapping summary:
#  - Description      <- MISSING [missing]
#  - Area             <- MISSING [missing]
#  - Price            <- MISSING [missing]
#  - NumberOfRooms    <- MISSING [missing]
#  - Floor            <- MISSING [missing]
#  - Floors           <- MISSING [missing]
#  - BuildingType     <- MISSING [missing]
#  - OfferFrom        <- MISSING [missing]
#  - TypeOfMarket     <- MISSING [missing]
#  - BuiltYear        <- MISSING [missing]
# Unmapped required columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#
# [sf_good.csv] column mapping summary:
#  - Description      <- MISSING [missing]
#  - Area             <- MISSING [missing]
#  - Price            <- MISSING [missing]
#  - NumberOfRooms    <- MISSING [missing]
#  - Floor            <- MISSING [missing]
#  - Floors           <- MISSING [missing]
#  - BuildingType     <- MISSING [missing]
#  - OfferFrom        <- MISSING [missing]
#  - TypeOfMarket     <- MISSING [missing]
#  - BuiltYear        <- MISSING [missing]
# Unmapped required columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#
# [sf_after_renovation.csv] post-mapping schema:
#  - missing: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#  - extra  : ['"5376217","NULL","22","Ochota | Mołdawska – mieszkanie z widokiem na panoramę Warszawy","Na ulicy Mołdawskiej, w sercu Ochoty, znajduje się mieszkanie z widokiem na panoramę Warszawy. To przestrzeń, w której codzienność łączy wygodę życia w spokojnym otoczeniu z szybkim dostępem do centrum. Kameralna atmosfera osiedla i dobrze rozwinięta infrastruktura sprawiają, że to miejsce spełnia oczekiwania zarówno rodzin, jak i osób aktywnie korzystających z uroków miasta. Wnętrze z potencjałem Na 49 m² rozplanowano funkcjonalnie trzy pokoje: jasny salon (17 m²) z dużym oknem i pięknym widokiem, sypialnię (12 m²), przytulny trzeci pokój (6,5 m²) – idealny na gabinet lub pokój dziecka, osobną widną kuchnię (5 m²) oraz łazienkę z WC (3 m²). Przemyślany układ uzupełnia przedpokój (5,5 m²) z miejscem na zabudowę. Mieszkanie jest po generalnym remoncie (lipiec 2021) – od tamtej pory nikt w nim nie mieszkał. Nowa instalacja elektryczna, gładzie, wysokiej klasy panele, elegancka ceramika. Drzwi antywłamaniowe dodają poczucia bezpieczeństwa, a całość została wykończona w spójnej, nowoczesnej kolorystyce. Do lokalu przynależy piwnica. Lokalizacja, która ułatwia życie To miejsce docenią zarówno rodziny, jak i studenci. W zasięgu kilku kroków są sklepy, piekarnia, bazarek, Biedronka, Rossmann i apteka. Kilka minut spacerem dzielić Cię będzie od zielonych terenów Fortów Korotyńskiego i Parku Kotańskiego – idealnych na poranny jogging czy popołudniowy spacer. Dojazd? 200 metrów od budynku znajdziesz przystanek autobusowy. W 5 minut dotrzesz na Warszawski Uniwersytet Medyczny, a w około 15 minut do metra Politechnika lub Racławicka. Atuty w skrócie widok na panoramę Warszawy 3 pokoje w praktycznym układzie świeżo po remoncie, nikt tu jeszcze nie mieszkał spokojna okolica, dużo zieleni bezpłatne miejsca parkingowe przy budynku pełna infrastruktura w zasięgu kilku kroków świetne połączenie z Centrum Bezpieczna forma własności Mieszkanie spółdzielczo-własnościowe z księgą wieczystą, uregulowany grunt – bez przeszkód do zakupu na kredyt. ? To propozycja dla młodej rodziny, pary, a także dla inwestora szukającego mieszkania pod wynajem (studenci Warszawskiego Uniwersytetu Medycznego to stali najemcy w tej lokalizacji). Kupujący nie podpisuje żadnych umów pośrednictwa, nie ma dla Państwa żadnej "prowizji" - proszę czuć się swobodnie na prezentacji mieszkania. Zadzwoń, aby dowiedzieć się więcej i umówić się na prezentację mieszkania! Zapraszam, Anna Kalicińska --- Przedstawiona informacja nie jest ofertą handlową w rozumieniu przepisów prawa, lecz ma charakter informacyjny. Niebanalna Brokerka Sp. z o.o. dokłada wszelkich starań, aby przedstawione treści były aktualne i rzetelne. Dane dotyczące ofert uzyskano na podstawie oświadczeń Sprzedających. Wszystkie zdjęcia oraz opis nieruchomości stanowią utwór chroniony prawem autorskim w rozumieniu przepisów ustawy o prawie autorskim i prawach pokrewnych (Dz.U. 1994 Nr 24 poz. 83 z późn. zm.) i pozostają własnością Niebanalna Brokerka Sp. z o.o.. Zabrania się ich kopiowania, rozpowszechniania, publikowania oraz wykorzystywania w jakiejkolwiek formie, zarówno w całości, jak i we fragmentach, bez pisemnej zgody właściciela praw autorskich. W przypadku stwierdzenia naruszenia powyższych praw, zostaną podjęte odpowiednie kroki prawne.","49","759000","NULL","NULL","NULL","15489.8","3","1974","Mieszkania","Blok","AFTER_RENOVATION","Agencja","9","NULL","Wtórny","Spółdzielcze własnościowe","2025-08-20 14:38:15","2025-08-20 14:38:15","NULL","NULL","2025-08-20 14:38:15","NULL","https://www.sprzedajemy.pl/ochota-moldawska-mieszkanie-z-widokiem-na-panorame-warszawy-warszawa-4-1b8e55-6fpbc4-nr72037742","535568535","20250820143828_2JdNPuY7.webp","20250820143829_3oUMV93L.webp,20250820143829_4JRrTGpp.webp,20250820143829_2lZU1odr.webp,20250820143829_6N6XKCYE.webp,20250820143829_3GNb7qQQ.webp,20250820143830_4mk0u4Qw.webp,20250820143830_2ZGebinD.webp","0","0","0","0","0","3","2","0","0","0","NULL","83814","NULL","NULL ...
#
# [sf_developer_state.csv] post-mapping schema:
#  - missing: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#  - extra  : ['"5376157","NULL","19","PSARSKIE - ul. Hebanowa 5/34 - 42,11 m2, II PIĘTRO","Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantujący bezpieczeństwo nabywcy lokalu. Po więcej informacji zapraszamy do biura firmy przy ul. Sikorskiego 41 w Śremie oraz zachęcamy do kontaktu telefonicznego. Pełna oferta naszej firmy znajduje się również na stronie internetowej nieruchomosci-enigma.pl Niniejsza oferta nie stanowi oferty w świetle przepisów KC. Zamieszczone plany lokalu, opisy i wizualizacje nie stanowią oferty w rozumieniu prawa i są publikowane w celach informacyjnych. Przedstawione materiały mają charakter poglądowy i nie mogą być traktowane jako projekty realizacyjne. Pomiarów pod zakup mebli, urządzeń i wyposażenia należy dokonać z natury, po zakończeniu budowy Spółka ENIGMA Nieruchomości rozpoczęła budowę kolejnego budynku wielkorodzinnego na terenie nowopowstającego osiedla w Psarskim, przy ul. Hebanowej 5. Budujemy nowoczesny, 3 kondygnacyjny budynek mieszkalny (parter i dwa piętra), w którym znajdować się będą 44 mieszkania, 7 garaży oraz 18 schowków. Piękna architektura budynku nawiązuje do istniejących już nieruchomości przy ul. Hebanowej 4, 6, 8 i 10. Duży wybór mieszkań w kilku wariantach metrażowych sprawia, że każdy znajdzie coś dla siebie. Do mieszkań zlokalizowanych na parterze przynależne będą ogródki, a do lokali na piętrach balkony. Przed budynkiem zlokalizowane będą miejsca postojowe, chodniki, droga wewnętrzna utwardzona z kostki betonowej. Zgodnie z planem inwestycja powinna zakończyć się w grudniu 2026 r., kolejno niezbędne formalności związane z oddaniem budynku do użytkowania, a wydanie kluczy Nabywcom planowane jest na maj 2027 r. Przedstawiamy Państwu szczegółową ofertę dotyczącą funkcjonalnego lokalu nr 34 zlokalizowanego na II piętrze wskazanej nieruchomości. Jest to lokal o powierzchni użytkowej 42,11 m2, w skład którego wchodzą: salon z aneksem kuchennym, pokój 1, łazienka i korytarz. Do lokalu przynależy balkon, a także miejsce postojowe. Układ pomieszczeń w lokalu prezentuje załączona grafika. Mieszkanie oddane będzie do użytkowania w standardzie deweloperskim, który szczegółowo opisuje prospekt informacyjny sporządzony dla tego lokalu. Podana cena jest ceną brutto i zawiera podatek VAT, w cenę lokalu wliczony jest również koszt miejsca postojowego w kwocie 12 000 zł brutto. Transakcja oparta jest o rachunek powierniczy gwarantujący bezpiecze ...
#
# [sf_for_renovation.csv] post-mapping schema:
#  - missing: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#  - extra  : ['"5376182","NULL","4","4-pokojowe mieszkanie na sprzedaż","Atuty nieruchomości | 50m² | 2 Pokoje | Oddzielna, jasna kuchnia | Ustawny Projekt Wnętrza | Wysokie piętro - spokój i widok | Winda | 400m do przystanku tramwajowego | Piwnica | Mieszkanie Mam przyjemność przedstawić Państwu przestronne, funkcjonalne mieszkanie o powierzchni 50m², znajdujące się w sercu Nowej Huty - na Osiedlu 2 Pułku Lotniczego, w sąsiedztwie ul. Orlińskiego. Lokal mieści się na 6. piętrze z 10 i składa się z dwóch niezależnych pokoi, osobnej kuchni z oknem, łazienki z toaletą oraz przedpokoju z miejscem na przechowywanie. Mieszkanie w stanie do remontu lub odświeżenia - daje więc szerokie możliwości aranżacyjne według własnych upodobań. Duże okna zapewniają bardzo dobre doświetlenie pomieszczeń, a ekspozycja i wysokość piętra gwarantują ciszę i przyjemny widok. Do lokalu przynależy piwnica, idealna na przechowywanie rzeczy sezonowych. Budynek Blok z 1980 roku, zadbany, wyposażony w windę i administrowany przez sprawną wspólnotę mieszkaniową. Budynek znajduje się w dobrze utrzymanym otoczeniu z dużą ilością zieleni i przestrzeni między budynkami. Lokalizacja To jedno z najbardziej pożądanych i rozwijających się miejsc w Nowej Hucie. W zasięgu spaceru znajdziemy przystanki tramwajowe i autobusowe, sklepy, punkty usługowe oraz szkoły i przedszkola. Blisko do osiedla Avia, ul. Orlińskiego oraz nowych inwestycji mieszkaniowych i biurowych. Szybki dojazd do centrum Krakowa oraz Nowego Kleparza dzięki rozwiniętej sieci komunikacyjnej. To idealne miejsce do życia lub inwestycji. Podsumowanie Funkcjonalne mieszkanie w doskonałej lokalizacji - świetnie skomunikowane, otoczone pełną infrastrukturą i zielenią. Duży potencjał aranżacyjny sprawia, że nieruchomość będzie doskonałym wyborem zarówno do zamieszkania, jak i jako lokata kapitału. Zapraszam na prezentację i do zakupu! TEKTON PROPERTY TO NAJLEPSZE BIURO NIERUCHOMOŚCI W POLSCE WG KONKURSU LIDER NIERUCHOMOŚCI OTODOM 2020. Znajdź nas w swoim mieście: Gdańsk, ul. Chmielna 10 - Warszawa, Plac Dąbrowskiego 1/311 - Wrocław, ul. Kasztanowa 3A/118 - Kraków, ul. Józefitów 7/4 - Poznań, ul. Wojskowa 6/D6 - Łódź, ul. Zachodnia 70 pok. 223. Podejmując współpracę z przedstawicielami Tekton Property zyskujesz: - oszczędność czasu - weryfikację dokumentów od strony formalno-prawnej - wsparcie agenta na każdym etapie transakcji - pomoc przy uzyskaniu kredytu hipotecznego w kilkunastu bankach - wgląd do umów przed zawarciem aktu notarialnego u sprawdzonych Notariuszy - własne analizy makroekonomiczne i raporty z prowadzonych działań - dostęp do cen transakcyjnych z okolicy Skontaktuj się z opiekunem oferty, a on poprowadzi Cię przez wszystkie etapy transakcji. Zapraszamy do współpracy! Niniejsze ogłoszenie nie stanowi oferty handlowej w rozumieniu przepisów art. 66 k.c., a przedstawione dane mają charakter informacyjny. Na sprzedaż mieszkanie 4-pokojowe o powierzchni 50,20 m² 6 piętro w 10-piętrowym bloku z 1980 roku Kraków, Czyżyny Ogłoszenie biura nieruchomości Właściciel postanowił powierzyć ofertę agencji nieruchomości. Oferta dodana dzisiaj Ta nieruchomość może być Twoja już od 3339 zł / mc Wkład własny: 131 800 zł (20%) Okres spłaty: 30 lat Oblicz zdolność kredytową Kraków Czyżyny Poland - lokalizacja przybliżona","50.2","659000","980721.33","NULL","NULL","13127.49","4","1980","Mieszkania","Blok","FOR_RENOVATION","Agencja","6","10","NULL","NULL","2025-08-20 14:34:45","2025-08-20 14:34:43","NULL","NULL","2025-08-20 14:34:43","NULL","https://www.adresowo.pl/o/mieszkanie-krakow-czyzyny-4-pokojowe-50-m2-b2i6g2","NULL","20250820143500_1sF1FCiq.webp","20250820143500_5hqTpq0f.webp,20250820143500_19w2g9Lt.webp,20250820143500_6GnxKB8F.webp,20250820143500_wzeroR2p.webp,20250820143501_18T1e1ng.webp,20250820143501_6jJRr0Fc.webp","4","0","0","0","0","5","2","0","0","0","NULL","94050","NULL","NULL","NULL","NULL","NULL","NULL","50-gPkdXgOVH3wdJTK_MCai_rC3KFy_RnfS0EWfIRU4=","14,0,0,337,3279,94050,0","Małopolskie, Krakó ...
#
# [sf_good.csv] post-mapping schema:
#  - missing: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
#  - extra  : ['"5376200","NULL","2","Na sprzedaż 3\\\'pokojowe mieszkanie, II piętro","Na sprzedaż 3\'pokojowe mieszkanie o powierzchni użytkowej 55,19 m2 przy ul. Zacisze w Kaliszu. Mieszkanie mieści się na II piętrze, w niskim czteropiętrowym bloku z cegły z 1976 roku. Układ mieszkania: trzy niezależne pokoje, osobna kuchnia, łazienka, wc, przedpokój. Z salonu wyjście na balkon z widokiem na Aulę Jerzego Rubińskiego. Do mieszkania przynależy piwnica w przyziemiu budynku. Za blokiem parking i plac zabaw dla lokatorów bloku. Mieszkanie spółdzielcze własnościowe. Wszystkie media miejskie. Czynsz administracyjny do spółdzielni ok. 600 zł (przy rozliczeniu mediów dla 1 osoby). Mieszkanie o bardzo funkcjonalnym układzie pomieszczeń - niezależność pokoi podnosi komfort użytkowania lokalu. Pomieszczenia słoneczne - ekspozycja okien po dwóch stronach mieszkania. Mieszkanie dostępne od ręki. Zachęcam do zapoznania się z tą wyjątkową ofertą. Cena mieszkania 328.000 zł do negocjacji Gorąco polecam! Dagmara501... pokaż Jednorazowa prowizja dla biura wg aktualnego cennika. Licencja 16070 Dagmara Jeżyk. Zapraszamy również na bezpłatną konsultację z Naszym Ekspertem finansowym. Opis ma charakter informacyjny i nie stanowi oferty w rozumieniu Kodeksu Cywilnego.","55.19","328000","NULL","NULL","NULL","5943.11","3","1976","Mieszkania","Blok","GOOD","Agencja","2","4","Wtórny","Spółdzielcze-własnościowe","2025-08-20 14:36:02","2025-08-20 14:36:02","NULL","NULL","2025-08-20 14:36:02","NULL","https://www.morizon.pl/oferta/sprzedaz-mieszkanie-kalisz-srodmiescie-zacisze-55m2-mzn2046146898","501684817","20250820143608_6tdmTknf.webp","20250820143609_4rc3z70E.webp,20250820143609_6dnuHDnz.webp","0","0","0","0","0","5","2","0","0","0","NULL","351374","NULL","NULL","NULL","NULL","NULL","NULL","jqWH3UzmKlk3acr1GorX1FcgSx7sGm5nUpo5FzVSNNM=","12,0,0,347,0,105716,351374","Kalisz, Śródmieście, Zacisze"']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 104
#     101     if missing:
#     102         problems.append((path, "missing_columns", missing))
# --> 104 assert not problems, f"Schema issues after auto-mapping: {problems}"
#
# AssertionError: Schema issues after auto-mapping: [('sf_after_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_developer_state.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_for_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_good.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear'])]

# %%
# CELL 3b (optional): headerless CSV fallback per file with all-missing required columns
from copy import deepcopy

def headerless_fallback(path, df):
    # Heuristic: if po auto-mapping z komórki 3 mamy brak wszystkich REQUIRED_ALL,
    # spróbujmy ponownie wczytać plik z header=None i użyć pierwszego wiersza jako nagłówków.
    required_missing_all = all(c not in df.columns for c in REQUIRED_ALL)
    if not required_missing_all:
        return df, False

    print(f"[{path}] Trying header=None fallback ...")
    enc = 'utf-8-sig'
    try:
        # Użyj tych samych parametrów separacji, które wypisała komórka 2 (jeśli logowano),
        # w razie braku – spróbuj ';' i ',' po kolei.
        for sep in ['; ',',']:
            try:
                df0 = pd.read_csv(path, sep=sep, engine='python', header=None, on_bad_lines='skip', encoding=enc)
                # Pierwszy wiersz jako nagłówek
                new_cols = df0.iloc.astype(str).tolist()
                df1 = df0.iloc[1:].copy()
                df1.columns = [c.strip() for c in new_cols]
                df1, _ = auto_map_columns(df1)
                return df1, True
            except Exception:
                continue
    except Exception as e:
        print(f"[{path}] header=None fallback failed: {e}")
    return df, False

# Apply fallback only if absolutely necessary
reloaded = {}
for path, df in list(dfs.items()):
    df2, changed = headerless_fallback(path, df)
    dfs[path] = df2
    reloaded[path] = changed
    if changed:
        print(f"[{path}] Headerless fallback applied and columns remapped.")

# Final schema check
problems = []
for path, df in dfs.items():
    missing = [c for c in REQUIRED_ALL if c not in df.columns]
    print(f"[{path}] final missing columns:", missing)
    if missing:
        problems.append((path, "missing_columns", missing))
assert not problems, f"Schema issues remain after fallback: {problems}"
# Out:
# [sf_after_renovation.csv] Trying header=None fallback ...
# [sf_developer_state.csv] Trying header=None fallback ...
# [sf_for_renovation.csv] Trying header=None fallback ...
# [sf_good.csv] Trying header=None fallback ...
# [sf_after_renovation.csv] final missing columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_developer_state.csv] final missing columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_for_renovation.csv] final missing columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_good.csv] final missing columns: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 47
#      45     if missing:
#      46         problems.append((path, "missing_columns", missing))
# ---> 47 assert not problems, f"Schema issues remain after fallback: {problems}"
#
# AssertionError: Schema issues remain after fallback: [('sf_after_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_developer_state.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_for_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_good.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear'])]

# %%
# CELL 3c: mapping suggestions + manual mapping hook
import difflib

REQUIRED_TEXT = ['Description']
REQUIRED_NUM  = ['Area','Price','NumberOfRooms','Floor','Floors']
REQUIRED_CAT  = ['BuildingType','OfferFrom','TypeOfMarket']
REQUIRED_DT   = ['BuiltYear']
REQUIRED_ALL  = REQUIRED_TEXT + REQUIRED_NUM + REQUIRED_CAT + REQUIRED_DT

for path, df in dfs.items():
    cols = list(df.columns)
    print(f"\n[{path}] mapping suggestions:")
    for target in REQUIRED_ALL:
        cands = difflib.get_close_matches(target.lower(), [c.lower() for c in cols], n=5, cutoff=0.6)
        # odzyskaj oryginalną wielkość liter
        cands_orig = []
        for c in cands:
            cands_orig.append(next(cc for cc in cols if cc.lower()==c))
        print(f" - {target:<16}: {cands_orig}")

# Manual mapping to fill if needed: {'existing_col_name':'ExpectedName'}
manual_map = {
    # 'opis':'Description',
    # 'powierzchnia':'Area',
    # 'cena':'Price',
    # 'pokoje':'NumberOfRooms',
    # 'pietro':'Floor',
    # 'liczba_pieter':'Floors',
    # 'typ_budynku':'BuildingType',
    # 'zrodlo':'OfferFrom',
    # 'rynek':'TypeOfMarket',
    # 'rok_budowy':'BuiltYear',
}

for path in list(dfs.keys()):
    if manual_map:
        dfs[path] = dfs[path].rename(columns=manual_map)

# Validate after manual map
problems = []
for path, df in dfs.items():
    missing = [c for c in REQUIRED_ALL if c not in df.columns]
    print(f"[{path}] missing after manual map:", missing)
    if missing:
        problems.append((path, 'missing_columns', missing))
assert not problems, f"Still missing required columns. Please extend manual_map. Details: {problems}"
# Out:
# [sf_after_renovation.csv] mapping suggestions:
#  - Description     : []
#  - Area            : []
#  - Price           : []
#  - NumberOfRooms   : []
#  - Floor           : []
#  - Floors          : []
#  - BuildingType    : []
#  - OfferFrom       : []
#  - TypeOfMarket    : []
#  - BuiltYear       : []
#
# [sf_developer_state.csv] mapping suggestions:
#  - Description     : []
#  - Area            : []
#  - Price           : []
#  - NumberOfRooms   : []
#  - Floor           : []
#  - Floors          : []
#  - BuildingType    : []
#  - OfferFrom       : []
#  - TypeOfMarket    : []
#  - BuiltYear       : []
#
# [sf_for_renovation.csv] mapping suggestions:
#  - Description     : []
#  - Area            : []
#  - Price           : []
#  - NumberOfRooms   : []
#  - Floor           : []
#  - Floors          : []
#  - BuildingType    : []
#  - OfferFrom       : []
#  - TypeOfMarket    : []
#  - BuiltYear       : []
#
# [sf_good.csv] mapping suggestions:
#  - Description     : []
#  - Area            : []
#  - Price           : []
#  - NumberOfRooms   : []
#  - Floor           : []
#  - Floors          : []
#  - BuildingType    : []
#  - OfferFrom       : []
#  - TypeOfMarket    : []
#  - BuiltYear       : []
# [sf_after_renovation.csv] missing after manual map: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_developer_state.csv] missing after manual map: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_for_renovation.csv] missing after manual map: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# [sf_good.csv] missing after manual map: ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 46
#      44     if missing:
#      45         problems.append((path, 'missing_columns', missing))
# ---> 46 assert not problems, f"Still missing required columns. Please extend manual_map. Details: {problems}"
#
# AssertionError: Still missing required columns. Please extend manual_map. Details: [('sf_after_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_developer_state.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_for_renovation.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear']), ('sf_good.csv', 'missing_columns', ['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear'])]

# %%
# CELL 3d (optional): expand JSON if files contain JSON records
import json
from pandas import json_normalize

def try_expand_json(df):
    expanded = None
    for col in df.columns:
        sample = df[col].dropna().astype(str).head(50).tolist()
        # heur: jeśli większość niepustych wierszy zaczyna się znakiem { lub [, mamy JSON
        if sample and sum(s.strip().startswith(('{','[')) for s in sample) >= max(5, int(0.6*len(sample))):
            try:
                objs = []
                for s in df[col].fillna('').astype(str):
                    s = s.strip()
                    if not s:
                        objs.append({})
                        continue
                    try:
                        objs.append(json.loads(s))
                    except Exception:
                        objs.append({})
                exp = json_normalize(objs)
                # Dołącz prefiks kolumny źródłowej, żeby uniknąć konfliktów
                exp.columns = [f"{col}.{c}" for c in exp.columns]
                other = df.drop(columns=[col])
                expanded = pd.concat([other.reset_index(drop=True), exp.reset_index(drop=True)], axis=1)
                return expanded
            except Exception:
                continue
    return expanded

changed = False
for path in list(dfs.keys()):
    df = dfs[path]
    if df.shape[1] <= 3:  # podejrzanie mało kolumn jak na CSV tabelaryczne
        df2 = try_expand_json(df)
        if df2 is not None and df2.shape[1] > df.shape[1]:
            dfs[path] = df2
            changed = True
            print(f"[{path}] Expanded JSON-like column(s): new shape={df2.shape}")

if changed:
    # Po rozwinięciu uruchom ponownie CELL 3c, aby zmapować kolumny.
    print("Run CELL 3c again to map expanded columns to required schema.")

# %%
# CELL 4: missingness and text/date sanity
for path, df in dfs.items():
    print(f"\n[{path}] Missingness and sanity")
    sub = df[REQUIRED_ALL].copy()

    # Missingness
    miss_pct = sub.isna().mean().sort_values(ascending=False) * 100
    print("Missing % (top 15):")
    print(miss_pct.head(15).round(2))

    # Description emptiness
    desc = sub['Description'].fillna('')
    empty_ratio = (desc.str.strip() == '').mean() * 100
    print(f"Empty Description: {empty_ratio:.2f}%")

    # BuiltYear parse success
    by = pd.to_datetime(sub['BuiltYear'], errors='coerce')
    parse_ok = by.notna().mean() * 100
    year_min, year_max = by.dt.year.min(), by.dt.year.max()
    print(f"BuiltYear parse OK: {parse_ok:.2f}% | year_range=({year_min}, {year_max})")
# Out:
# [sf_after_renovation.csv] Missingness and sanity
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 for path, df in dfs.items():
#       3     print(f"\n[{path}] Missingness and sanity")
# ----> 4     sub = df[REQUIRED_ALL].copy()
#       6     # Missingness
#       7     miss_pct = sub.isna().mean().sort_values(ascending=False) * 100
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Description', 'Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors',\n       'BuildingType', 'OfferFrom', 'TypeOfMarket', 'BuiltYear'],\n      dtype='object')] are in the [columns]"

# %%
# CELL 5: numeric distributions and plausible ranges
RANGES = {
    'Area': (5, 1000),            # m^2
    'Price': (1000, 1e9),         # PLN-like
    'NumberOfRooms': (0, 50),
    'Floor': (-3, 200),
    'Floors': (1, 200),
}
for path, df in dfs.items():
    print(f"\n[{path}] Numeric stats and range checks")
    num = df[REQUIRED_NUM].apply(pd.to_numeric, errors='coerce')
    print(num.describe(percentiles=[.01,.05,.5,.95,.99]).T)

    for col, (lo, hi) in RANGES.items():
        bad = num[col].notna() & ((num[col] < lo) | (num[col] > hi))
        print(f"Out-of-range {col}: {bad.sum()} rows | expected [{lo},{hi}]")
# Out:
# [sf_after_renovation.csv] Numeric stats and range checks
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 11
#       9 for path, df in dfs.items():
#      10     print(f"\n[{path}] Numeric stats and range checks")
# ---> 11     num = df[REQUIRED_NUM].apply(pd.to_numeric, errors='coerce')
#      12     print(num.describe(percentiles=[.01,.05,.5,.95,.99]).T)
#      14     for col, (lo, hi) in RANGES.items():
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors'], dtype='object')] are in the [columns]"

# %%
# CELL 6: categorical levels overview
for path, df in dfs.items():
    print(f"\n[{path}] Categorical levels")
    for col in REQUIRED_CAT:
        vc = df[col].astype(str).fillna('NA').str.strip().value_counts(dropna=False)
        print(f"- {col}: unique={vc.shape}")
        print(vc.head(20))
# Out:
# [sf_after_renovation.csv] Categorical levels
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BuildingType'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       3 print(f"\n[{path}] Categorical levels")
#       4 for col in REQUIRED_CAT:
# ----> 5     vc = df[col].astype(str).fillna('NA').str.strip().value_counts(dropna=False)
#       6     print(f"- {col}: unique={vc.shape}")
#       7     print(vc.head(20))
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'BuildingType'

# %%
# CELL 7: text diagnostics
for path, df in dfs.items():
    print(f"\n[{path}] Text length diagnostics")
    desc = df['Description'].fillna('').astype(str)
    chars = desc.str.len()
    words = desc.str.split().map(len)
    print("Chars len: mean={:.1f}, p50={:.0f}, p90={:.0f}, p99={:.0f}".format(
        chars.mean(), chars.median(), chars.quantile(.9), chars.quantile(.99)))
    print("Words len: mean={:.1f}, p50={:.0f}, p90={:.0f}, p99={:.0f}".format(
        words.mean(), words.median(), words.quantile(.9), words.quantile(.99)))
    short = (words < 3).mean() * 100
    print(f"Very short (<3 words): {short:.2f}%")
# Out:
# [sf_after_renovation.csv] Text length diagnostics
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       2 for path, df in dfs.items():
#       3     print(f"\n[{path}] Text length diagnostics")
# ----> 4     desc = df['Description'].fillna('').astype(str)
#       5     chars = desc.str.len()
#       6     words = desc.str.split().map(len)
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Description'

# %%
# CELL 8: merge labeled datasets
merged = []
for path, target in FILES.items():
    df = dfs[path].copy()
    df['State'] = target  # target labels aligned with notebook classes
    merged.append(df)
full = pd.concat(merged, ignore_index=True)
print("Merged shape:", full.shape)
print("Class counts:\n", full['State'].value_counts())
# Out:
# Merged shape: (79351, 5)
# Class counts:
#  State
# AFTER_RENOVATION    20384
# GOOD                19875
# DEVELOPER_STATE     19829
# FOR_RENOVATION      19263
# Name: count, dtype: int64

# %%
# CELL 9: category harmonization across files
for col in REQUIRED_CAT:
    levels_per_file = {p: set(dfs[p][col].dropna().astype(str).str.strip().unique()) for p in dfs}
    union = set().union(*levels_per_file.values())
    print(f"\n{col}: union={len(union)}")
    only_in = {}
    for p, lv in levels_per_file.items():
        only = lv - set().union(*(levels_per_file[q] for q in levels_per_file if q != p))
        only_in[p] = only
    for p, only in only_in.items():
        if only:
            print(f" - only in {p}: {sorted(list(only))[:20]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BuildingType'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 3
#       1 # CELL 9: category harmonization across files
#       2 for col in REQUIRED_CAT:
# ----> 3     levels_per_file = {p: set(dfs[p][col].dropna().astype(str).str.strip().unique()) for p in dfs}
#       4     union = set().union(*levels_per_file.values())
#       5     print(f"\n{col}: union={len(union)}")
#
# Cell In[17], line 3, in <dictcomp>(.0)
#       1 # CELL 9: category harmonization across files
#       2 for col in REQUIRED_CAT:
# ----> 3     levels_per_file = {p: set(dfs[p][col].dropna().astype(str).str.strip().unique()) for p in dfs}
#       4     union = set().union(*levels_per_file.values())
#       5     print(f"\n{col}: union={len(union)}")
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'BuildingType'

# %%
# CELL 10: duplicates check
if 'SaleId' in full.columns:
    dup_id = full.duplicated(subset=['SaleId'], keep=False).sum()
    print(f"Duplicates by SaleId: {dup_id}")

keys = [c for c in ['Description','Price','Area'] if c in full.columns]
if keys:
    dup_keys = full.duplicated(subset=keys, keep=False).sum()
    print(f"Duplicates by {keys}: {dup_keys}")

# %%
# CELL 11: enforce dtypes and build 'year'
for col in REQUIRED_NUM:
    full[col] = pd.to_numeric(full[col], errors='coerce')
for col in REQUIRED_CAT:
    full[col] = full[col].astype(str).str.strip()

built_dt = pd.to_datetime(full['BuiltYear'], errors='coerce')
ok = built_dt.notna().mean() * 100
full['year'] = built_dt.dt.year
med = full['year'].median()
full['year'] = full['year'].fillna(med)
print(f"BuiltYear parse OK: {ok:.2f}% | filled NA in 'year' with median {med}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
#       1 # CELL 11: enforce dtypes and build 'year'
#       2 for col in REQUIRED_NUM:
# ----> 3     full[col] = pd.to_numeric(full[col], errors='coerce')
#       4 for col in REQUIRED_CAT:
#       5     full[col] = full[col].astype(str).str.strip()
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Area'

# %%
# CELL 12: dry-run preprocessing identical to notebook training
from sklearn.preprocessing import StandardScaler
num_features_train = ['Area','Price','NumberOfRooms','Floor','Floors','year']
cat_features_train = ['BuildingType','OfferFrom','TypeOfMarket']

scaler = StandardScaler()
X_num = scaler.fit_transform(full[num_features_train])

X_cat = pd.get_dummies(full[cat_features_train], dummy_na=False)
encoded_categorical_columns = X_cat.columns.tolist()

X_tabular = np.concatenate([X_num, X_cat.values], axis=1)
print("Tabular shapes -> num:", X_num.shape, "cat:", X_cat.shape, "concat:", X_tabular.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 7
#       4 cat_features_train = ['BuildingType','OfferFrom','TypeOfMarket']
#       6 scaler = StandardScaler()
# ----> 7 X_num = scaler.fit_transform(full[num_features_train])
#       9 X_cat = pd.get_dummies(full[cat_features_train], dummy_na=False)
#      10 encoded_categorical_columns = X_cat.columns.tolist()
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'year'], dtype='object')] are in the [columns]"

# %%
# CELL 13: tokenizer dry-run (as in notebook)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_words, max_len = 10000, 200
tok = Tokenizer(num_words=max_words, oov_token="<UNK>")
tok.fit_on_texts(full['Description'].fillna('').astype(str))

# Coverage estimate
total_tokens = sum(tok.word_counts.values())
top_words = [w for w,i in tok.word_index.items() if i <= max_words]
top_tokens = sum(tok.word_counts[w] for w in top_words if w in tok.word_counts)
coverage = 100.0 * top_tokens / max(1, total_tokens)
print(f"Vocab size={len(tok.word_index)} | coverage@{max_words}={coverage:.2f}%")

seqs = tok.texts_to_sequences(full['Description'].fillna('').astype(str))
lens = pd.Series([len(s) for s in seqs])
print("Seq len -> mean={:.1f}, p50={:.0f}, p90={:.0f}, p99={:.0f}, max={:.0f}".format(
    lens.mean(), lens.quantile(.5), lens.quantile(.9), lens.quantile(.99), lens.max()))
X_text = pad_sequences(seqs, maxlen=max_len)
print("Padded X_text shape:", X_text.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 7
#       5 max_words, max_len = 10000, 200
#       6 tok = Tokenizer(num_words=max_words, oov_token="<UNK>")
# ----> 7 tok.fit_on_texts(full['Description'].fillna('').astype(str))
#       9 # Coverage estimate
#      10 total_tokens = sum(tok.word_counts.values())
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Description'

# %%
# CELL 14: readiness summary checks
checks = {
    "schema_ok": all(c in full.columns for c in REQUIRED_ALL + ['year']),
    "text_non_empty_%": (full['Description'].fillna('').str.strip() != '').mean() * 100,
    "built_year_parse_ok_%": pd.to_datetime(full['BuiltYear'], errors='coerce').notna().mean() * 100,
    "all_num_finite_%": np.isfinite(full[['Area','Price','NumberOfRooms','Floor','Floors','year']].astype(float).values).mean() * 100,
    "cat_cardinality": {c: int(full[c].nunique()) for c in ['BuildingType','OfferFrom','TypeOfMarket']},
    "class_counts": full['State'].value_counts().to_dict(),
    "tabular_shape": tuple(X_tabular.shape),
    "text_shape": tuple(X_text.shape),
}
print(json.dumps(checks, ensure_ascii=False, indent=2))
