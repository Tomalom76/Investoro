# %% [markdown]
# # Wersja v11: Model Hierarchiczny z 3 Głowicami i Post-processingiem
#
# ## Część 1: Przygotowanie Danych i Inżynieria Cech
# Ta część jest odpowiedzialna za wczytanie, oczyszczenie i przetworzenie danych w celu przygotowania ich do treningu modelu. Zapiszemy również wszystkie niezbędne artefakty (mapy, transformatory) na dysku.

# %%
import pandas as pd
import numpy as np
import os
import joblib
import gc
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy.sparse

# Definicja stałych globalnych
ARTIFACTS_DIR = 'artifacts_v11'
PROCESSED_DATA_DIR = 'processed_data_v11'
MAX_TEXT_FEATURES = 20000
RANDOM_STATE = 42

# Tworzenie katalogów, jeśli nie istnieją
os.makedirs(ARTIFACTS_DIR, exist_ok=True)
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

print(f"Katalogi '{ARTIFACTS_DIR}' i '{PROCESSED_DATA_DIR}' są gotowe.")
# Out:
# Katalogi 'artifacts_v11' i 'processed_data_v11' są gotowe.

# %%
def load_location_data(location_path='lokalizacja.csv'):
    print(f"Wczytywanie pliku: {location_path}")
    df_loc = pd.read_csv(
        location_path,
        na_values=['\\N', 'NULL'],
        sep=',',
        header=None,
        names=['id', 'parent_id', 'name', 'type', 'full_name']
    )
    return df_loc

def load_offers_data(offers_path='saleflats_2024_2025.csv'):
    print(f"Wczytywanie pliku: {offers_path}")
    column_names = ['title', 'description', 'area', 'price', 'locationPath']
    try:
        first_row = pd.read_csv(offers_path, header=None, sep=',', nrows=1, on_bad_lines='skip')
        last_col_index = first_row.shape[1] - 1
        usecols = [3, 4, 5, 6, last_col_index]
        df_offers = pd.read_csv(offers_path, header=None, sep=',', usecols=usecols, on_bad_lines='skip')
        df_offers.columns = column_names
    except Exception as e:
        print(f"Wystąpił błąd: {e}")
        df_offers = pd.DataFrame(columns=column_names)
    return df_offers

df_loc = load_location_data()
df_offers = load_offers_data()

# Stworzenie i zapisanie map
id_to_name = dict(zip(df_loc['id'], df_loc['name']))
joblib.dump(id_to_name, os.path.join(ARTIFACTS_DIR, 'id_to_name.joblib'))
hierarchy_map = dict(zip(df_loc['id'], df_loc['parent_id']))
joblib.dump(hierarchy_map, os.path.join(ARTIFACTS_DIR, 'hierarchy_map.joblib'))
print("Mapy 'id_to_name' i 'hierarchy_map' zostały stworzone i zapisane.")
# Out:
# Wczytywanie pliku: lokalizacja.csv
# Wczytywanie pliku: saleflats_2024_2025.csv
# Mapy 'id_to_name' i 'hierarchy_map' zostały stworzone i zapisane.

# %% [markdown]
# ## Inżynieria Cech i Definicja Zmiennej Celu (REKOMENDACJA #1)
#
# **Zmiana:** Zamiast jednej zmiennej `target_district_id`, tworzymy teraz **trzy oddzielne zmienne docelowe**: `target_district_id`, `target_subdistrict_id` oraz `target_street_id`. Dzięki temu model będzie uczył się przewidywać każdy poziom hierarchii osobno.

# %%
# Cechy Numeryczne
df_offers['area'] = pd.to_numeric(df_offers['area'], errors='coerce')
df_offers['price'] = pd.to_numeric(df_offers['price'], errors='coerce')
df_offers.dropna(subset=['area', 'price'], inplace=True)
df_offers = df_offers[df_offers['area'] > 0]
df_offers['price_per_meter'] = df_offers['price'] / df_offers['area']

# NOWA DEFINICJA CELÓW: Dzielnica, Pod-dzielnica, Ulica
path_cols = ['woj_id', 'pow_id', 'gmi_id', 'city_id', 'district_id', 'subdistrict_id', 'street_id']
path_df = df_offers['locationPath'].str.split(',', expand=True)
path_df = path_df.iloc[:, :len(path_cols)] # Zabezpieczenie przed zbyt krótkimi ścieżkami
path_df.columns = path_cols[:path_df.shape[1]]
path_df = path_df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
df_offers = pd.concat([df_offers.reset_index(drop=True), path_df.reset_index(drop=True)], axis=1)

# Finalne czyszczenie i tworzenie df_processed
df_offers.dropna(subset=['city_id'], inplace=True)
df_offers = df_offers[df_offers['city_id'] != 0]

df_processed = df_offers[[
    'title', 'description', 'area', 'price', 'price_per_meter', 'city_id', 
    'district_id', 'subdistrict_id', 'street_id'
]].copy()

df_processed.rename(columns={
    'district_id': 'target_district_id',
    'subdistrict_id': 'target_subdistrict_id',
    'street_id': 'target_street_id'
}, inplace=True)

df_processed['text_features'] = df_processed['title'].fillna('') + " " + df_processed['description'].fillna('')
df_processed.drop(columns=['title', 'description'], inplace=True)
df_processed.dropna(inplace=True)

print("\n--- Nagłówek finalnego df_processed ---\n")
print(df_processed.head())
# Out:
# --- Nagłówek finalnego df_processed ---
#
#     area     price  price_per_meter  city_id  target_district_id  \
# 0  73.00  766500.0     10500.000000      352                   0
# 1  64.80  540000.0      8333.333333      352                   0
# 2  51.00  540000.0     10588.235294      352                   0
# 3  67.62  544000.0      8044.957113      352                   0
# 4  48.00  459000.0      9562.500000      352                   0
#
#    target_subdistrict_id  target_street_id  \
# 0                 103786                 0
# 1                  99764                 0
# 2                  74375                 0
# 3                  74375            517513
# 4                  95559                 0
#
#                                        text_features
# 0  Mieszkanie trzypokojowe na sprzedaż Mieszkanie...
# 1  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2  Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki ...
# 3  Mieszkanie trzypokojowe na sprzedaż ***Oferta ...
# 4  3 Pokoje- 48M2-Osiedle Dziesięciny Przedstawia...

# %%
# Sprawdzenie liczności klas dla stratyfikacji
city_counts = df_processed['city_id'].value_counts()
valid_cities = city_counts[city_counts > 1].index
df_filtered = df_processed[df_processed['city_id'].isin(valid_cities)].copy()

# Podział na zbiory (X i y)
target_columns = ['target_district_id', 'target_subdistrict_id', 'target_street_id']
X = df_filtered.drop(columns=target_columns)
y = df_filtered[target_columns]

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=X['city_id']
)
print(f"Podział danych: {len(X_train)} próbek treningowych, {len(X_val)} próbek walidacyjnych.")

# Przetwarzanie Cech Numerycznych
numeric_features = ['area', 'price', 'price_per_meter']
imputer = SimpleImputer(strategy='median'); scaler = StandardScaler()
X_train_num = scaler.fit_transform(imputer.fit_transform(X_train[numeric_features]))
X_val_num = scaler.transform(imputer.transform(X_val[numeric_features]))
joblib.dump(imputer, os.path.join(ARTIFACTS_DIR, 'imputer.joblib'))
joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, 'scaler.joblib'))

# Przetwarzanie Cech Tekstowych
vectorizer = TfidfVectorizer(max_features=MAX_TEXT_FEATURES, ngram_range=(1, 2))
X_train_text = vectorizer.fit_transform(X_train['text_features'])
X_val_text = vectorizer.transform(X_val['text_features'])
joblib.dump(vectorizer, os.path.join(ARTIFACTS_DIR, 'vectorizer.joblib'))

# Przygotowanie pozostałych cech
X_train_city = X_train['city_id'].values
X_val_city = X_val['city_id'].values

# Przygotowanie ODDZIELNYCH celów dla każdej głowicy
y_district_train = y_train['target_district_id'].values; y_district_val = y_val['target_district_id'].values
y_subdistrict_train = y_train['target_subdistrict_id'].values; y_subdistrict_val = y_val['target_subdistrict_id'].values
y_street_train = y_train['target_street_id'].values; y_street_val = y_val['target_street_id'].values

print("Transformatory dopasowane i zapisane.")
# Out:
# Podział danych: 887572 próbek treningowych, 221893 próbek walidacyjnych.
# Transformatory dopasowane i zapisane.

# %%
# Zapisanie wszystkich przetworzonych danych
scipy.sparse.save_npz(os.path.join(PROCESSED_DATA_DIR, 'X_train_text.npz'), X_train_text)
scipy.sparse.save_npz(os.path.join(PROCESSED_DATA_DIR, 'X_val_text.npz'), X_val_text)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_train_num.npy'), X_train_num)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_val_num.npy'), X_val_num)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_train_city.npy'), X_train_city)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_val_city.npy'), X_val_city)

# Zapis nowych, potrójnych zmiennych docelowych
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_district_train.npy'), y_district_train)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_subdistrict_train.npy'), y_subdistrict_train)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_street_train.npy'), y_street_train)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_district_val.npy'), y_district_val)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_subdistrict_val.npy'), y_subdistrict_val)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_street_val.npy'), y_street_val)

print("Wszystkie przetworzone zbiory danych zostały zapisane.")

# Zwolnienie pamięci
del df_loc, df_offers, df_processed, X, y, X_train, X_val, y_train, y_val, df_filtered
del X_train_text, X_val_text, X_train_num, X_val_num, X_train_city, X_val_city
gc.collect()

print("\n" + "="*80)
print("CZĘŚĆ 1 ZAKOŃCZONA POWODZENIEM. ZRESTARTUJ KERNEL.")
print("="*80)
# Out:
# Wszystkie przetworzone zbiory danych zostały zapisane.
#
# ================================================================================
# CZĘŚĆ 1 ZAKOŃCZONA POWODZENIEM. ZRESTARTUJ KERNEL.
# ================================================================================

# %% [markdown]
# # Część 2: Budowa, Trening i Inferencia Modelu

# %%
import pandas as pd
import numpy as np
import joblib
import os
import gc
import scipy.sparse
import tensorflow as tf
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Dropout, Embedding, Flatten, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import register_keras_serializable

# Ponowna definicja stałych
ARTIFACTS_DIR = 'artifacts_v11'
PROCESSED_DATA_DIR = 'processed_data_v11'
RANDOM_STATE = 42
MAX_TEXT_FEATURES = 20000
MODEL_PATH = os.path.join(ARTIFACTS_DIR, 'best_location_model_v11.keras')

# %%
# Wczytanie artefaktów
print("Wczytywanie artefaktów...")
hierarchy_map = joblib.load(os.path.join(ARTIFACTS_DIR, 'hierarchy_map.joblib'))
id_to_name = joblib.load(os.path.join(ARTIFACTS_DIR, 'id_to_name.joblib'))

# Wczytanie przetworzonych danych
print("Wczytywanie przetworzonych danych...")
X_train_text = scipy.sparse.load_npz(os.path.join(PROCESSED_DATA_DIR, 'X_train_text.npz'))
X_val_text = scipy.sparse.load_npz(os.path.join(PROCESSED_DATA_DIR, 'X_val_text.npz'))
X_train_num = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_train_num.npy'))
X_val_num = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_val_num.npy'))
X_train_city = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_train_city.npy'))
X_val_city = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_val_city.npy'))
y_district_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_district_train.npy'))
y_subdistrict_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_subdistrict_train.npy'))
y_street_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_street_train.npy'))
y_district_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_district_val.npy'))
y_subdistrict_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_subdistrict_val.npy'))
y_street_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_street_val.npy'))
print("Dane wczytane.")
# Out:
# Wczytywanie artefaktów...
# Wczytywanie przetworzonych danych...
# Dane wczytane.

# %% [markdown]
# ## Hierarchiczna Funkcja Straty (REKOMENDACJA #3)
#
# **Zmiana:** Pozostawiamy tylko jedną, poprawną definicję klasy `HierarchicalLoss`. Naprawiono również błąd w metodzie `call` i zapewniono poprawną serializację (konwersja kluczy na `int` w `__init__`).

# %%
@register_keras_serializable()
class HierarchicalLoss(tf.keras.losses.Loss):
    def __init__(self, id_to_parent_map, penalty_config, **kwargs):
        super().__init__(**kwargs)
        self.id_to_parent_map = id_to_parent_map
        self.penalty_config = penalty_config
        self.base_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction='none')
        self.penalty_wrong_parent = penalty_config.get('wrong_parent', 1.5)
        
        # Poprawka: Konwersja kluczy na int, aby uniknąć błędu podczas wczytywania modelu
        keys = [int(k) for k in id_to_parent_map.keys()]
        values = [int(v) if pd.notna(v) else 0 for v in id_to_parent_map.values()]
        self.parent_table = tf.lookup.StaticHashTable(
            tf.lookup.KeyValueTensorInitializer(keys, values, key_dtype=tf.int64, value_dtype=tf.int64), 0
        )

    def call(self, y_true, y_pred):
        y_true_tensor = tf.cast(y_true, dtype=tf.int64)
        y_pred_ids = tf.cast(tf.argmax(y_pred, axis=-1), dtype=tf.int64)
        base_loss = self.base_loss_fn(y_true_tensor, y_pred)
        
        # Ignorujemy straty dla etykiety 'Brak' (ID=0)
        mask = tf.not_equal(y_true_tensor, 0)
        
        true_parents = self.parent_table.lookup(y_true_tensor)
        pred_parents = self.parent_table.lookup(y_pred_ids)
        
        # Kara jest stosowana tylko tam, gdzie etykieta nie jest 'Brak'
        is_correct = tf.equal(y_true_tensor, y_pred_ids)
        is_parent_correct = tf.equal(true_parents, pred_parents)
        
        penalties = tf.where(is_correct, 1.0, self.penalty_wrong_parent) # Kara za złą predykcję
        penalties = tf.where(is_parent_correct, 1.0, penalties) # Jeśli rodzic jest ok, nie ma kary - to można zmienić
        
        penalized_loss = base_loss * penalties
        masked_loss = tf.where(mask, penalized_loss, 0.0)

        return tf.reduce_sum(masked_loss) / tf.reduce_sum(tf.cast(mask, tf.float32))

    def get_config(self):
        base_config = super().get_config()
        config = {"id_to_parent_map": self.id_to_parent_map, "penalty_config": self.penalty_config}
        return {**base_config, **config}

print("Hierarchiczna funkcja straty zdefiniowana i gotowa do użycia.")
# Out:
# Hierarchiczna funkcja straty zdefiniowana i gotowa do użycia.

# %% [markdown]
# ## Definicja Architektury Modelu (3 Głowice)
#
# **Zmiana:** Budujemy model Keras z trzema oddzielnymi wyjściami: `district_output`, `subdistrict_output` i `street_output`. Pozwoli to na jednoczesne przewidywanie wszystkich poziomów lokalizacji.

# %%
def create_mapper(y_train, y_val):
    """Tworzy mapowanie z oryginalnych ID na ciągłe indeksy."""
    unique_ids = np.unique(np.concatenate([y_train, y_val]))
    mapper = {val: i for i, val in enumerate(unique_ids)}
    return mapper

def map_labels(y, mapper):
    """Mapuje etykiety używając stworzonego mapowania."""
    return np.array([mapper.get(val, 0) for val in y])

# Mapowanie dla każdej głowicy
district_map = create_mapper(y_district_train, y_district_val)
subdistrict_map = create_mapper(y_subdistrict_train, y_subdistrict_val)
street_map = create_mapper(y_street_train, y_street_val)
city_map = create_mapper(X_train_city, X_val_city)

y_district_train_mapped = map_labels(y_district_train, district_map)
y_district_val_mapped = map_labels(y_district_val, district_map)
y_subdistrict_train_mapped = map_labels(y_subdistrict_train, subdistrict_map)
y_subdistrict_val_mapped = map_labels(y_subdistrict_val, subdistrict_map)
y_street_train_mapped = map_labels(y_street_train, street_map)
y_street_val_mapped = map_labels(y_street_val, street_map)
X_train_city_mapped = map_labels(X_train_city, city_map)
X_val_city_mapped = map_labels(X_val_city, city_map)

joblib.dump(city_map, os.path.join(ARTIFACTS_DIR, 'city_map.joblib'))

# Definicja parametrów
NUM_DISTRICTS = len(district_map)
NUM_SUBDISTRICTS = len(subdistrict_map)
NUM_STREETS = len(street_map)
NUM_CITIES = len(city_map)
NUM_FEATURES = X_train_num.shape[1]

# Definicja modelu
input_text = Input(shape=(MAX_TEXT_FEATURES,), name='text_input', sparse=True)
input_num = Input(shape=(NUM_FEATURES,), name='num_input')
input_city = Input(shape=(1,), name='city_input')

# Wspólna część modelu (ciało)
text_branch = Dense(128, activation='relu')(input_text); text_branch = Dropout(0.3)(text_branch)
num_branch = Dense(64, activation='relu')(input_num); num_branch = Dense(32, activation='relu')(num_branch)
city_branch = Embedding(input_dim=NUM_CITIES, output_dim=50, name='city_embedding')(input_city); city_branch = Flatten()(city_branch)
combined = Concatenate()([text_branch, num_branch, city_branch])
z = Dense(512, activation='relu')(combined); z = Dropout(0.5)(z)
z = Dense(256, activation='relu')(z); z = Dropout(0.5)(z)

# Trzy oddzielne głowice wyjściowe
output_district = Dense(NUM_DISTRICTS, activation='softmax', name='district_output')(z)
output_subdistrict = Dense(NUM_SUBDISTRICTS, activation='softmax', name='subdistrict_output')(z)
output_street = Dense(NUM_STREETS, activation='softmax', name='street_output')(z)

model = Model(inputs=[input_text, input_num, input_city], outputs=[output_district, output_subdistrict, output_street])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)       │ (None, 20000)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ num_input (InputLayer)        │ (None, 3)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_input (InputLayer)       │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │       2,560,128 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64)                │             256 │ num_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_embedding (Embedding)    │ (None, 1, 50)             │         276,800 │ city_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 32)                │           2,080 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 50)                │               0 │ city_embedding[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 210)               │               0 │ dropout[0][0],             │
# │                               │                           │                 │ dense_2[0][0],             │
# │                               │                           │                 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 512)               │         108,032 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 512)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 256)               │         131,328 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 256)               │               0 │ dense_4[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ district_output (Dense)       │ (None, 38)                │           9,766 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ subdistrict_output (Dense)    │ (None, 2167)              │         556,919 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ street_output (Dense)         │ (None, 33604)             │       8,636,228 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 12,281,537 (46.85 MB)
#  Trainable params: 12,281,537 (46.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Instancje funkcji straty dla każdej głowicy
penalty_config = {'wrong_parent': 1.5}
district_loss = 'sparse_categorical_crossentropy' # Dzielnica nie ma rodzica w naszym kontekście
subdistrict_loss = HierarchicalLoss(hierarchy_map, penalty_config, name='subdistrict_loss')
street_loss = HierarchicalLoss(hierarchy_map, penalty_config, name='street_loss')

# Kompilacja modelu
model.compile(
    optimizer='adam',
    loss={
        'district_output': district_loss,
        'subdistrict_output': subdistrict_loss,
        'street_output': street_loss
    },
    loss_weights={'district_output': 1.0, 'subdistrict_output': 1.2, 'street_output': 1.5},
    metrics={'district_output': 'accuracy', 'subdistrict_output': 'accuracy', 'street_output': 'accuracy'}
)

# Callbacks
model_checkpoint = ModelCheckpoint(MODEL_PATH, monitor='val_loss', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

# Przygotowanie słowników danych
X_train_dict = {'text_input': X_train_text, 'num_input': X_train_num, 'city_input': X_train_city_mapped}
X_val_dict = {'text_input': X_val_text, 'num_input': X_val_num, 'city_input': X_val_city_mapped}
y_train_dict = {
    'district_output': y_district_train_mapped,
    'subdistrict_output': y_subdistrict_train_mapped,
    'street_output': y_street_train_mapped
}
y_val_dict = {
    'district_output': y_district_val_mapped,
    'subdistrict_output': y_subdistrict_val_mapped,
    'street_output': y_street_val_mapped
}

# Trening
history = model.fit(
    X_train_dict, y_train_dict,
    validation_data=(X_val_dict, y_val_dict),
    epochs=20, batch_size=128,
    callbacks=[model_checkpoint, early_stopping]
)
# Out:
# Epoch 1/20
# 6934/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - district_output_accuracy: 0.7367 - district_output_loss: 0.8553 - loss: 26.5172 - street_output_accuracy: 0.0147 - street_output_loss: 12.3722 - subdistrict_output_accuracy: 0.0875 - subdistrict_output_loss: 5.9197
# Epoch 1: val_loss improved from inf to 17.70551, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 579s 83ms/step - district_output_accuracy: 0.7367 - district_output_loss: 0.8553 - loss: 26.5162 - street_output_accuracy: 0.0147 - street_output_loss: 12.3718 - subdistrict_output_accuracy: 0.0875 - subdistrict_output_loss: 5.9194 - val_district_output_accuracy: 0.8431 - val_district_output_loss: 0.4699 - val_loss: 17.7055 - val_street_output_accuracy: 0.0606 - val_street_output_loss: 8.7091 - val_subdistrict_output_accuracy: 0.1879 - val_subdistrict_output_loss: 3.4770
# Epoch 2/20
# 6934/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - district_output_accuracy: 0.8291 - district_output_loss: 0.5057 - loss: 17.8815 - street_output_accuracy: 0.0485 - street_output_loss: 8.7500 - subdistrict_output_accuracy: 0.1801 - subdistrict_output_loss: 3.5423
# Epoch 2: val_loss improved from 17.70551 to 15.10416, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 617s 89ms/step - district_output_accuracy: 0.8291 - district_output_loss: 0.5057 - loss: 17.8814 - street_output_accuracy: 0.0485 - street_output_loss: 8.7499 - subdistrict_output_accuracy: 0.1801 - subdistrict_output_loss: 3.5423 - val_district_output_accuracy: 0.8785 - val_district_output_loss: 0.3701 - val_loss: 15.1042 - val_street_output_accuracy: 0.0773 - val_street_output_loss: 7.4831 - val_subdistrict_output_accuracy: 0.2204 - val_subdistrict_output_loss: 2.9246
# Epoch 3/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - district_output_accuracy: 0.8597 - district_output_loss: 0.4244 - loss: 15.4422 - street_output_accuracy: 0.0619 - street_output_loss: 7.5721 - subdistrict_output_accuracy: 0.2071 - subdistrict_output_loss: 3.0497
# Epoch 3: val_loss improved from 15.10416 to 13.78940, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 635s 92ms/step - district_output_accuracy: 0.8597 - district_output_loss: 0.4244 - loss: 15.4422 - street_output_accuracy: 0.0619 - street_output_loss: 7.5721 - subdistrict_output_accuracy: 0.2071 - subdistrict_output_loss: 3.0496 - val_district_output_accuracy: 0.8924 - val_district_output_loss: 0.3259 - val_loss: 13.7894 - val_street_output_accuracy: 0.0871 - val_street_output_loss: 6.8739 - val_subdistrict_output_accuracy: 0.2372 - val_subdistrict_output_loss: 2.6273
# Epoch 4/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - district_output_accuracy: 0.8736 - district_output_loss: 0.3887 - loss: 14.1868 - street_output_accuracy: 0.0687 - street_output_loss: 6.9536 - subdistrict_output_accuracy: 0.2223 - subdistrict_output_loss: 2.8064
# Epoch 4: val_loss improved from 13.78940 to 13.13059, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 680s 98ms/step - district_output_accuracy: 0.8736 - district_output_loss: 0.3887 - loss: 14.1867 - street_output_accuracy: 0.0687 - street_output_loss: 6.9536 - subdistrict_output_accuracy: 0.2223 - subdistrict_output_loss: 2.8064 - val_district_output_accuracy: 0.9002 - val_district_output_loss: 0.3060 - val_loss: 13.1306 - val_street_output_accuracy: 0.0913 - val_street_output_loss: 6.5505 - val_subdistrict_output_accuracy: 0.2480 - val_subdistrict_output_loss: 2.4991
# Epoch 5/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - district_output_accuracy: 0.8827 - district_output_loss: 0.3648 - loss: 13.4709 - street_output_accuracy: 0.0744 - street_output_loss: 6.6029 - subdistrict_output_accuracy: 0.2311 - subdistrict_output_loss: 2.6681
# Epoch 5: val_loss improved from 13.13059 to 12.70117, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 709s 102ms/step - district_output_accuracy: 0.8827 - district_output_loss: 0.3648 - loss: 13.4709 - street_output_accuracy: 0.0744 - street_output_loss: 6.6029 - subdistrict_output_accuracy: 0.2311 - subdistrict_output_loss: 2.6681 - val_district_output_accuracy: 0.9072 - val_district_output_loss: 0.2886 - val_loss: 12.7012 - val_street_output_accuracy: 0.0951 - val_street_output_loss: 6.3557 - val_subdistrict_output_accuracy: 0.2550 - val_subdistrict_output_loss: 2.3993
# Epoch 6/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - district_output_accuracy: 0.8883 - district_output_loss: 0.3517 - loss: 12.9944 - street_output_accuracy: 0.0767 - street_output_loss: 6.3708 - subdistrict_output_accuracy: 0.2383 - subdistrict_output_loss: 2.5720
# Epoch 6: val_loss improved from 12.70117 to 12.44386, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 749s 108ms/step - district_output_accuracy: 0.8883 - district_output_loss: 0.3517 - loss: 12.9944 - street_output_accuracy: 0.0767 - street_output_loss: 6.3708 - subdistrict_output_accuracy: 0.2383 - subdistrict_output_loss: 2.5720 - val_district_output_accuracy: 0.9076 - val_district_output_loss: 0.2860 - val_loss: 12.4439 - val_street_output_accuracy: 0.0977 - val_street_output_loss: 6.2328 - val_subdistrict_output_accuracy: 0.2595 - val_subdistrict_output_loss: 2.3406
# Epoch 7/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - district_output_accuracy: 0.8922 - district_output_loss: 0.3432 - loss: 12.6818 - street_output_accuracy: 0.0791 - street_output_loss: 6.2167 - subdistrict_output_accuracy: 0.2422 - subdistrict_output_loss: 2.5113
# Epoch 7: val_loss improved from 12.44386 to 12.20729, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 782s 113ms/step - district_output_accuracy: 0.8922 - district_output_loss: 0.3432 - loss: 12.6818 - street_output_accuracy: 0.0791 - street_output_loss: 6.2167 - subdistrict_output_accuracy: 0.2422 - subdistrict_output_loss: 2.5113 - val_district_output_accuracy: 0.9110 - val_district_output_loss: 0.2752 - val_loss: 12.2073 - val_street_output_accuracy: 0.0995 - val_street_output_loss: 6.1227 - val_subdistrict_output_accuracy: 0.2637 - val_subdistrict_output_loss: 2.2901
# Epoch 8/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - district_output_accuracy: 0.8951 - district_output_loss: 0.3349 - loss: 12.4184 - street_output_accuracy: 0.0807 - street_output_loss: 6.0940 - subdistrict_output_accuracy: 0.2468 - subdistrict_output_loss: 2.4520
# Epoch 8: val_loss improved from 12.20729 to 12.10068, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 820s 118ms/step - district_output_accuracy: 0.8951 - district_output_loss: 0.3349 - loss: 12.4184 - street_output_accuracy: 0.0807 - street_output_loss: 6.0940 - subdistrict_output_accuracy: 0.2468 - subdistrict_output_loss: 2.4520 - val_district_output_accuracy: 0.9127 - val_district_output_loss: 0.2689 - val_loss: 12.1007 - val_street_output_accuracy: 0.1000 - val_street_output_loss: 6.0731 - val_subdistrict_output_accuracy: 0.2650 - val_subdistrict_output_loss: 2.2684
# Epoch 9/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - district_output_accuracy: 0.8965 - district_output_loss: 0.3313 - loss: 12.2199 - street_output_accuracy: 0.0832 - street_output_loss: 5.9908 - subdistrict_output_accuracy: 0.2488 - subdistrict_output_loss: 2.4187
# Epoch 9: val_loss improved from 12.10068 to 11.97429, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 873s 126ms/step - district_output_accuracy: 0.8965 - district_output_loss: 0.3313 - loss: 12.2199 - street_output_accuracy: 0.0832 - street_output_loss: 5.9908 - subdistrict_output_accuracy: 0.2488 - subdistrict_output_loss: 2.4187 - val_district_output_accuracy: 0.9138 - val_district_output_loss: 0.2656 - val_loss: 11.9743 - val_street_output_accuracy: 0.1014 - val_street_output_loss: 6.0232 - val_subdistrict_output_accuracy: 0.2677 - val_subdistrict_output_loss: 2.2283
# Epoch 10/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - district_output_accuracy: 0.8983 - district_output_loss: 0.3273 - loss: 12.0590 - street_output_accuracy: 0.0840 - street_output_loss: 5.9069 - subdistrict_output_accuracy: 0.2506 - subdistrict_output_loss: 2.3928
# Epoch 10: val_loss improved from 11.97429 to 11.87147, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 920s 133ms/step - district_output_accuracy: 0.8983 - district_output_loss: 0.3273 - loss: 12.0590 - street_output_accuracy: 0.0840 - street_output_loss: 5.9069 - subdistrict_output_accuracy: 0.2506 - subdistrict_output_loss: 2.3928 - val_district_output_accuracy: 0.9159 - val_district_output_loss: 0.2615 - val_loss: 11.8715 - val_street_output_accuracy: 0.1026 - val_street_output_loss: 5.9839 - val_subdistrict_output_accuracy: 0.2704 - val_subdistrict_output_loss: 2.1953
# Epoch 11/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - district_output_accuracy: 0.8999 - district_output_loss: 0.3236 - loss: 11.9199 - street_output_accuracy: 0.0853 - street_output_loss: 5.8379 - subdistrict_output_accuracy: 0.2520 - subdistrict_output_loss: 2.3662
# Epoch 11: val_loss improved from 11.87147 to 11.86433, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 983s 142ms/step - district_output_accuracy: 0.8999 - district_output_loss: 0.3236 - loss: 11.9199 - street_output_accuracy: 0.0853 - street_output_loss: 5.8379 - subdistrict_output_accuracy: 0.2520 - subdistrict_output_loss: 2.3662 - val_district_output_accuracy: 0.9154 - val_district_output_loss: 0.2638 - val_loss: 11.8643 - val_street_output_accuracy: 0.1025 - val_street_output_loss: 5.9798 - val_subdistrict_output_accuracy: 0.2710 - val_subdistrict_output_loss: 2.1925
# Epoch 12/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - district_output_accuracy: 0.9000 - district_output_loss: 0.3234 - loss: 11.8333 - street_output_accuracy: 0.0854 - street_output_loss: 5.7925 - subdistrict_output_accuracy: 0.2540 - subdistrict_output_loss: 2.3509
# Epoch 12: val_loss improved from 11.86433 to 11.78867, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1063s 153ms/step - district_output_accuracy: 0.9000 - district_output_loss: 0.3234 - loss: 11.8333 - street_output_accuracy: 0.0854 - street_output_loss: 5.7925 - subdistrict_output_accuracy: 0.2540 - subdistrict_output_loss: 2.3509 - val_district_output_accuracy: 0.9178 - val_district_output_loss: 0.2571 - val_loss: 11.7887 - val_street_output_accuracy: 0.1042 - val_street_output_loss: 5.9479 - val_subdistrict_output_accuracy: 0.2727 - val_subdistrict_output_loss: 2.1749
# Epoch 13/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - district_output_accuracy: 0.9002 - district_output_loss: 0.3243 - loss: 11.7467 - street_output_accuracy: 0.0863 - street_output_loss: 5.7495 - subdistrict_output_accuracy: 0.2561 - subdistrict_output_loss: 2.3318
# Epoch 13: val_loss improved from 11.78867 to 11.76465, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1132s 163ms/step - district_output_accuracy: 0.9002 - district_output_loss: 0.3243 - loss: 11.7467 - street_output_accuracy: 0.0863 - street_output_loss: 5.7495 - subdistrict_output_accuracy: 0.2561 - subdistrict_output_loss: 2.3318 - val_district_output_accuracy: 0.9176 - val_district_output_loss: 0.2561 - val_loss: 11.7646 - val_street_output_accuracy: 0.1039 - val_street_output_loss: 5.9380 - val_subdistrict_output_accuracy: 0.2730 - val_subdistrict_output_loss: 2.1681
# Epoch 14/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - district_output_accuracy: 0.9017 - district_output_loss: 0.3221 - loss: 11.7092 - street_output_accuracy: 0.0873 - street_output_loss: 5.7358 - subdistrict_output_accuracy: 0.2563 - subdistrict_output_loss: 2.3195
# Epoch 14: val_loss improved from 11.76465 to 11.74172, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1199s 173ms/step - district_output_accuracy: 0.9017 - district_output_loss: 0.3221 - loss: 11.7092 - street_output_accuracy: 0.0873 - street_output_loss: 5.7358 - subdistrict_output_accuracy: 0.2563 - subdistrict_output_loss: 2.3195 - val_district_output_accuracy: 0.9174 - val_district_output_loss: 0.2607 - val_loss: 11.7417 - val_street_output_accuracy: 0.1046 - val_street_output_loss: 5.9242 - val_subdistrict_output_accuracy: 0.2736 - val_subdistrict_output_loss: 2.1624
# Epoch 15/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - district_output_accuracy: 0.9019 - district_output_loss: 0.3191 - loss: 11.6143 - street_output_accuracy: 0.0874 - street_output_loss: 5.6922 - subdistrict_output_accuracy: 0.2583 - subdistrict_output_loss: 2.2974
# Epoch 15: val_loss improved from 11.74172 to 11.73563, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1239s 179ms/step - district_output_accuracy: 0.9019 - district_output_loss: 0.3191 - loss: 11.6143 - street_output_accuracy: 0.0874 - street_output_loss: 5.6922 - subdistrict_output_accuracy: 0.2583 - subdistrict_output_loss: 2.2974 - val_district_output_accuracy: 0.9184 - val_district_output_loss: 0.2571 - val_loss: 11.7356 - val_street_output_accuracy: 0.1046 - val_street_output_loss: 5.9327 - val_subdistrict_output_accuracy: 0.2754 - val_subdistrict_output_loss: 2.1497
# Epoch 16/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - district_output_accuracy: 0.9029 - district_output_loss: 0.3197 - loss: 11.5989 - street_output_accuracy: 0.0875 - street_output_loss: 5.6803 - subdistrict_output_accuracy: 0.2580 - subdistrict_output_loss: 2.2989
# Epoch 16: val_loss did not improve from 11.73563
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1277s 184ms/step - district_output_accuracy: 0.9029 - district_output_loss: 0.3197 - loss: 11.5989 - street_output_accuracy: 0.0875 - street_output_loss: 5.6804 - subdistrict_output_accuracy: 0.2580 - subdistrict_output_loss: 2.2989 - val_district_output_accuracy: 0.9182 - val_district_output_loss: 0.2588 - val_loss: 11.7528 - val_street_output_accuracy: 0.1056 - val_street_output_loss: 5.9371 - val_subdistrict_output_accuracy: 0.2741 - val_subdistrict_output_loss: 2.1571
# Epoch 17/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - district_output_accuracy: 0.9022 - district_output_loss: 0.3201 - loss: 11.5530 - street_output_accuracy: 0.0884 - street_output_loss: 5.6629 - subdistrict_output_accuracy: 0.2597 - subdistrict_output_loss: 2.2822
# Epoch 17: val_loss improved from 11.73563 to 11.72466, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1364s 197ms/step - district_output_accuracy: 0.9022 - district_output_loss: 0.3201 - loss: 11.5530 - street_output_accuracy: 0.0884 - street_output_loss: 5.6629 - subdistrict_output_accuracy: 0.2597 - subdistrict_output_loss: 2.2822 - val_district_output_accuracy: 0.9187 - val_district_output_loss: 0.2581 - val_loss: 11.7247 - val_street_output_accuracy: 0.1050 - val_street_output_loss: 5.9215 - val_subdistrict_output_accuracy: 0.2749 - val_subdistrict_output_loss: 2.1537
# Epoch 18/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - district_output_accuracy: 0.9026 - district_output_loss: 0.3203 - loss: 11.5367 - street_output_accuracy: 0.0887 - street_output_loss: 5.6521 - subdistrict_output_accuracy: 0.2599 - subdistrict_output_loss: 2.2819
# Epoch 18: val_loss improved from 11.72466 to 11.70909, saving model to artifacts_v11\best_location_model_v11.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1421s 205ms/step - district_output_accuracy: 0.9026 - district_output_loss: 0.3203 - loss: 11.5367 - street_output_accuracy: 0.0887 - street_output_loss: 5.6521 - subdistrict_output_accuracy: 0.2599 - subdistrict_output_loss: 2.2819 - val_district_output_accuracy: 0.9192 - val_district_output_loss: 0.2550 - val_loss: 11.7091 - val_street_output_accuracy: 0.1053 - val_street_output_loss: 5.9314 - val_subdistrict_output_accuracy: 0.2757 - val_subdistrict_output_loss: 2.1310
# Epoch 19/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - district_output_accuracy: 0.9038 - district_output_loss: 0.3189 - loss: 11.5043 - street_output_accuracy: 0.0886 - street_output_loss: 5.6323 - subdistrict_output_accuracy: 0.2603 - subdistrict_output_loss: 2.2808
# Epoch 19: val_loss did not improve from 11.70909
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1500s 216ms/step - district_output_accuracy: 0.9038 - district_output_loss: 0.3189 - loss: 11.5043 - street_output_accuracy: 0.0886 - street_output_loss: 5.6323 - subdistrict_output_accuracy: 0.2603 - subdistrict_output_loss: 2.2808 - val_district_output_accuracy: 0.9188 - val_district_output_loss: 0.2572 - val_loss: 11.7283 - val_street_output_accuracy: 0.1060 - val_street_output_loss: 5.9390 - val_subdistrict_output_accuracy: 0.2758 - val_subdistrict_output_loss: 2.1356
# Epoch 20/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - district_output_accuracy: 0.9030 - district_output_loss: 0.3211 - loss: 11.5136 - street_output_accuracy: 0.0889 - street_output_loss: 5.6422 - subdistrict_output_accuracy: 0.2605 - subdistrict_output_loss: 2.2743
# Epoch 20: val_loss did not improve from 11.70909
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1543s 223ms/step - district_output_accuracy: 0.9030 - district_output_loss: 0.3211 - loss: 11.5136 - street_output_accuracy: 0.0889 - street_output_loss: 5.6422 - subdistrict_output_accuracy: 0.2605 - subdistrict_output_loss: 2.2743 - val_district_output_accuracy: 0.9193 - val_district_output_loss: 0.2563 - val_loss: 11.7311 - val_street_output_accuracy: 0.1063 - val_street_output_loss: 5.9491 - val_subdistrict_output_accuracy: 0.2773 - val_subdistrict_output_loss: 2.1261
# Restoring model weights from the end of the best epoch: 18.

# %% [markdown]
# ## Predykcja z Post-processingiem i Rozszerzona Ewaluacja (REKOMENDACJA #2 i #4)
#
# **Zmiana:** Ta komórka implementuje kluczową logikę biznesową:
# 1.  **Post-processing:** Weryfikujemy, czy przewidziane lokalizacje są ze sobą spójne hierarchicznie. Jeśli nie, unieważniamy niższe poziomy (np. błędna ulica dla danej pod-dzielnicy).
# 2.  **Rozszerzona Ewaluacja:** Obliczamy dokładność dla każdego poziomu (dzielnica, pod-dzielnica, ulica) oddzielnie, a także łączną dokładność, aby lepiej zrozumieć wyniki.

# %%
print(f"Wczytywanie najlepszego modelu z: {MODEL_PATH}")
best_model = tf.keras.models.load_model(
    MODEL_PATH, 
    custom_objects={'HierarchicalLoss': HierarchicalLoss}
)
print("Model wczytany pomyślnie.")

# Wczytujemy mapy odwrotne
inv_district_map = {v: k for k, v in district_map.items()}
inv_subdistrict_map = {v: k for k, v in subdistrict_map.items()}
inv_street_map = {v: k for k, v in street_map.items()}

num_samples = 1000
indices = np.random.choice(range(len(y_district_val)), num_samples, replace=False)

results_data = []

print(f"Przeprowadzanie predykcji z post-processingiem na {num_samples} próbkach...")
for i in indices:
    # Przygotowanie wejścia
    original_city_id = X_val_city[i]
    mapped_city_id = city_map.get(original_city_id, 0)
    dense_vector_sample = X_val_text[i].toarray()
    input_sample = {
        'text_input': dense_vector_sample,
        'num_input': np.expand_dims(X_val_num[i], axis=0),
        'city_input': np.expand_dims(mapped_city_id, axis=0)
    }
    
    # Surowa predykcja modelu
    pred_district_probs, pred_subdistrict_probs, pred_street_probs = best_model.predict(input_sample, verbose=0)
    
    # Odmapowanie indeksów na oryginalne ID
    pred_district_id = inv_district_map.get(np.argmax(pred_district_probs[0]), 0)
    pred_subdistrict_id = inv_subdistrict_map.get(np.argmax(pred_subdistrict_probs[0]), 0)
    pred_street_id = inv_street_map.get(np.argmax(pred_street_probs[0]), 0)
    
    # --- POST-PROCESSING HIERARCHICZNY ---
    # Krok 1: Weryfikacja pod-dzielnicy względem dzielnicy
    if pred_subdistrict_id != 0:
        parent_of_subdistrict = hierarchy_map.get(pred_subdistrict_id, -1)
        if parent_of_subdistrict != pred_district_id:
            pred_subdistrict_id = 0 # Unieważnij pod-dzielnicę
            pred_street_id = 0      # Unieważnij też ulicę
            
    # Krok 2: Weryfikacja ulicy względem pod-dzielnicy (jeśli pod-dzielnica jest poprawna)
    if pred_street_id != 0:
        parent_of_street = hierarchy_map.get(pred_street_id, -1)
        if parent_of_street != pred_subdistrict_id:
            pred_street_id = 0 # Unieważnij tylko ulicę
    
    # Pobranie prawdziwych ID
    true_district_id = y_district_val[i]
    true_subdistrict_id = y_subdistrict_val[i]
    true_street_id = y_street_val[i]
    
    results_data.append({
        'True_District': true_district_id, 'Pred_District': pred_district_id,
        'True_SubDistrict': true_subdistrict_id, 'Pred_SubDistrict': pred_subdistrict_id,
        'True_Street': true_street_id, 'Pred_Street': pred_street_id
    })

df_results = pd.DataFrame(results_data)

# --- ROZSZERZONA EWALUACJA ---
df_results['Correct_District'] = (df_results['True_District'] == df_results['Pred_District'])
# Poprawna pod-dzielnica = (ID się zgadzają) LUB (oba są 'Brak', czyli 0)
df_results['Correct_SubDistrict'] = (df_results['True_SubDistrict'] == df_results['Pred_SubDistrict'])
df_results['Correct_Street'] = (df_results['True_Street'] == df_results['Pred_Street'])

# Ogólna poprawność - wszystkie poziomy muszą się zgadzać
df_results['Correct_Overall'] = df_results['Correct_District'] & df_results['Correct_SubDistrict'] & df_results['Correct_Street']

acc_district = df_results['Correct_District'].mean()
acc_subdistrict = df_results['Correct_SubDistrict'].mean()
acc_street = df_results['Correct_Street'].mean()
acc_overall = df_results['Correct_Overall'].mean()

print("\n--- Wyniki Ewaluacji ---")
print(f"Dokładność dla Dzielnic: {acc_district:.2%}")
print(f"Dokładność dla Pod-dzielnic: {acc_subdistrict:.2%}")
print(f"Dokładność dla Ulic: {acc_street:.2%}")
print(f"\nDokładność CAŁKOWITA (wszystkie poziomy poprawne): {acc_overall:.2%}")

# Wizualizacja
def highlight_correct(s):
    return ['background-color: #d4edda' if s.Correct_Overall else 'background-color: #f8d7da'] * len(s)

for col in ['True_District', 'Pred_District', 'True_SubDistrict', 'Pred_SubDistrict', 'True_Street', 'Pred_Street']:
    df_results[f'{col}_Name'] = df_results[col].apply(lambda x: id_to_name.get(x, 'Brak'))
    
styled_results = df_results.sample(min(20, len(df_results)), random_state=RANDOM_STATE).style.apply(highlight_correct, axis=1)
print("\n--- Losowe wyniki predykcji (Zielony = Poprawna, Czerwony = Błędna) ---")
display(styled_results)
# Out:
# Wczytywanie najlepszego modelu z: artifacts_v11\best_location_model_v11.keras
# Model wczytany pomyślnie.
# Przeprowadzanie predykcji z post-processingiem na 1000 próbkach...
#
# --- Wyniki Ewaluacji ---
# Dokładność dla Dzielnic: 91.40%
# Dokładność dla Pod-dzielnic: 59.10%
# Dokładność dla Ulic: 56.60%
#
# Dokładność CAŁKOWITA (wszystkie poziomy poprawne): 38.80%
#
# --- Losowe wyniki predykcji (Zielony = Poprawna, Czerwony = Błędna) ---
# <style type="text/css">
# #T_2b2d4_row0_col0, #T_2b2d4_row0_col1, #T_2b2d4_row0_col2, #T_2b2d4_row0_col3, #T_2b2d4_row0_col4, #T_2b2d4_row0_col5, #T_2b2d4_row0_col6, #T_2b2d4_row0_col7, #T_2b2d4_row0_col8, #T_2b2d4_row0_col9, #T_2b2d4_row0_col10, #T_2b2d4_row0_col11, #T_2b2d4_row0_col12, #T_2b2d4_row0_col13, #T_2b2d4_row0_col14, #T_2b2d4_row0_col15, #T_2b2d4_row1_col0, #T_2b2d4_row1_col1, #T_2b2d4_row1_col2, #T_2b2d4_row1_col3, #T_2b2d4_row1_col4, #T_2b2d4_row1_col5, #T_2b2d4_row1_col6, #T_2b2d4_row1_col7, #T_2b2d4_row1_col8, #T_2b2d4_row1_col9, #T_2b2d4_row1_col10, #T_2b2d4_row1_col11, #T_2b2d4_row1_col12, #T_2b2d4_row1_col13, #T_2b2d4_row1_col14, #T_2b2d4_row1_col15, #T_2b2d4_row3_col0, #T_2b2d4_row3_col1, #T_2b2d4_row3_col2, #T_2b2d4_row3_col3, #T_2b2d4_row3_col4, #T_2b2d4_row3_col5, #T_2b2d4_row3_col6, #T_2b2d4_row3_col7, #T_2b2d4_row3_col8, #T_2b2d4_row3_col9, #T_2b2d4_row3_col10, #T_2b2d4_row3_col11, #T_2b2d4_row3_col12, #T_2b2d4_row3_col13, #T_2b2d4_row3_col14, #T_2b2d4_row3_col15, #T_2b2d4_row4_col0, #T_2b2d4_row4_col1, #T_2b2d4_row4_col2, #T_2b2d4_row4_col3, #T_2b2d4_row4_col4, #T_2b2d4_row4_col5, #T_2b2d4_row4_col6, #T_2b2d4_row4_col7, #T_2b2d4_row4_col8, #T_2b2d4_row4_col9, #T_2b2d4_row4_col10, #T_2b2d4_row4_col11, #T_2b2d4_row4_col12, #T_2b2d4_row4_col13, #T_2b2d4_row4_col14, #T_2b2d4_row4_col15, #T_2b2d4_row6_col0, #T_2b2d4_row6_col1, #T_2b2d4_row6_col2, #T_2b2d4_row6_col3, #T_2b2d4_row6_col4, #T_2b2d4_row6_col5, #T_2b2d4_row6_col6, #T_2b2d4_row6_col7, #T_2b2d4_row6_col8, #T_2b2d4_row6_col9, #T_2b2d4_row6_col10, #T_2b2d4_row6_col11, #T_2b2d4_row6_col12, #T_2b2d4_row6_col13, #T_2b2d4_row6_col14, #T_2b2d4_row6_col15, #T_2b2d4_row10_col0, #T_2b2d4_row10_col1, #T_2b2d4_row10_col2, #T_2b2d4_row10_col3, #T_2b2d4_row10_col4, #T_2b2d4_row10_col5, #T_2b2d4_row10_col6, #T_2b2d4_row10_col7, #T_2b2d4_row10_col8, #T_2b2d4_row10_col9, #T_2b2d4_row10_col10, #T_2b2d4_row10_col11, #T_2b2d4_row10_col12, #T_2b2d4_row10_col13, #T_2b2d4_row10_col14, #T_2b2d4_row10_col15, #T_2b2d4_row11_col0, #T_2b2d4_row11_col1, #T_2b2d4_row11_col2, #T_2b2d4_row11_col3, #T_2b2d4_row11_col4, #T_2b2d4_row11_col5, #T_2b2d4_row11_col6, #T_2b2d4_row11_col7, #T_2b2d4_row11_col8, #T_2b2d4_row11_col9, #T_2b2d4_row11_col10, #T_2b2d4_row11_col11, #T_2b2d4_row11_col12, #T_2b2d4_row11_col13, #T_2b2d4_row11_col14, #T_2b2d4_row11_col15, #T_2b2d4_row12_col0, #T_2b2d4_row12_col1, #T_2b2d4_row12_col2, #T_2b2d4_row12_col3, #T_2b2d4_row12_col4, #T_2b2d4_row12_col5, #T_2b2d4_row12_col6, #T_2b2d4_row12_col7, #T_2b2d4_row12_col8, #T_2b2d4_row12_col9, #T_2b2d4_row12_col10, #T_2b2d4_row12_col11, #T_2b2d4_row12_col12, #T_2b2d4_row12_col13, #T_2b2d4_row12_col14, #T_2b2d4_row12_col15, #T_2b2d4_row14_col0, #T_2b2d4_row14_col1, #T_2b2d4_row14_col2, #T_2b2d4_row14_col3, #T_2b2d4_row14_col4, #T_2b2d4_row14_col5, #T_2b2d4_row14_col6, #T_2b2d4_row14_col7, #T_2b2d4_row14_col8, #T_2b2d4_row14_col9, #T_2b2d4_row14_col10, #T_2b2d4_row14_col11, #T_2b2d4_row14_col12, #T_2b2d4_row14_col13, #T_2b2d4_row14_col14, #T_2b2d4_row14_col15 {
#   background-color: #d4edda;
# }
# #T_2b2d4_row2_col0, #T_2b2d4_row2_col1, #T_2b2d4_row2_col2, #T_2b2d4_row2_col3, #T_2b2d4_row2_col4, #T_2b2d4_row2_col5, #T_2b2d4_row2_col6, #T_2b2d4_row2_col7, #T_2b2d4_row2_col8, #T_2b2d4_row2_col9, #T_2b2d4_row2_col10, #T_2b2d4_row2_col11, #T_2b2d4_row2_col12, #T_2b2d4_row2_col13, #T_2b2d4_row2_col14, #T_2b2d4_row2_col15, #T_2b2d4_row5_col0, #T_2b2d4_row5_col1, #T_2b2d4_row5_col2, #T_2b2d4_row5_col3, #T_2b2d4_row5_col4, #T_2b2d4_row5_col5, #T_2b2d4_row5_col6, #T_2b2d4_row5_col7, #T_2b2d4_row5_col8, #T_2b2d4_row5_col9, #T_2b2d4_row5_col10, #T_2b2d4_row5_col11, #T_2b2d4_row5_col12, #T_2b2d4_row5_col13, #T_2b2d4_row5_col14, #T_2b2d4_row5_col15, #T_2b2d4_row7_col0, #T_2b2d4_row7_col1, #T_2b2d4_row7_col2, #T_2b2d4_row7_col3, #T_2b2d4_row7_col4, #T_2b2d4_row7_col5, #T_2b2d4_row7_col6, #T_2b2d4_row7_col7, #T_2b2d4_row7_col8, #T_2b2d4_row7_col9, #T_2b2d4_row7_col10, #T_2b2d4_row7_col11, #T_2b2d4_row7_col12, #T_2b2d4_row7_col13, #T_2b2d4_row7_col14, #T_2b2d4_row7_col15, #T_2b2d4_row8_col0, #T_2b2d4_row8_col1, #T_2b2d4_row8_col2, #T_2b2d4_row8_col3, #T_2b2d4_row8_col4, #T_2b2d4_row8_col5, #T_2b2d4_row8_col6, #T_2b2d4_row8_col7, #T_2b2d4_row8_col8, #T_2b2d4_row8_col9, #T_2b2d4_row8_col10, #T_2b2d4_row8_col11, #T_2b2d4_row8_col12, #T_2b2d4_row8_col13, #T_2b2d4_row8_col14, #T_2b2d4_row8_col15, #T_2b2d4_row9_col0, #T_2b2d4_row9_col1, #T_2b2d4_row9_col2, #T_2b2d4_row9_col3, #T_2b2d4_row9_col4, #T_2b2d4_row9_col5, #T_2b2d4_row9_col6, #T_2b2d4_row9_col7, #T_2b2d4_row9_col8, #T_2b2d4_row9_col9, #T_2b2d4_row9_col10, #T_2b2d4_row9_col11, #T_2b2d4_row9_col12, #T_2b2d4_row9_col13, #T_2b2d4_row9_col14, #T_2b2d4_row9_col15, #T_2b2d4_row13_col0, #T_2b2d4_row13_col1, #T_2b2d4_row13_col2, #T_2b2d4_row13_col3, #T_2b2d4_row13_col4, #T_2b2d4_row13_col5, #T_2b2d4_row13_col6, #T_2b2d4_row13_col7, #T_2b2d4_row13_col8, #T_2b2d4_row13_col9, #T_2b2d4_row13_col10, #T_2b2d4_row13_col11, #T_2b2d4_row13_col12, #T_2b2d4_row13_col13, #T_2b2d4_row13_col14, #T_2b2d4_row13_col15, #T_2b2d4_row15_col0, #T_2b2d4_row15_col1, #T_2b2d4_row15_col2, #T_2b2d4_row15_col3, #T_2b2d4_row15_col4, #T_2b2d4_row15_col5, #T_2b2d4_row15_col6, #T_2b2d4_row15_col7, #T_2b2d4_row15_col8, #T_2b2d4_row15_col9, #T_2b2d4_row15_col10, #T_2b2d4_row15_col11, #T_2b2d4_row15_col12, #T_2b2d4_row15_col13, #T_2b2d4_row15_col14, #T_2b2d4_row15_col15, #T_2b2d4_row16_col0, #T_2b2d4_row16_col1, #T_2b2d4_row16_col2, #T_2b2d4_row16_col3, #T_2b2d4_row16_col4, #T_2b2d4_row16_col5, #T_2b2d4_row16_col6, #T_2b2d4_row16_col7, #T_2b2d4_row16_col8, #T_2b2d4_row16_col9, #T_2b2d4_row16_col10, #T_2b2d4_row16_col11, #T_2b2d4_row16_col12, #T_2b2d4_row16_col13, #T_2b2d4_row16_col14, #T_2b2d4_row16_col15, #T_2b2d4_row17_col0, #T_2b2d4_row17_col1, #T_2b2d4_row17_col2, #T_2b2d4_row17_col3, #T_2b2d4_row17_col4, #T_2b2d4_row17_col5, #T_2b2d4_row17_col6, #T_2b2d4_row17_col7, #T_2b2d4_row17_col8, #T_2b2d4_row17_col9, #T_2b2d4_row17_col10, #T_2b2d4_row17_col11, #T_2b2d4_row17_col12, #T_2b2d4_row17_col13, #T_2b2d4_row17_col14, #T_2b2d4_row17_col15, #T_2b2d4_row18_col0, #T_2b2d4_row18_col1, #T_2b2d4_row18_col2, #T_2b2d4_row18_col3, #T_2b2d4_row18_col4, #T_2b2d4_row18_col5, #T_2b2d4_row18_col6, #T_2b2d4_row18_col7, #T_2b2d4_row18_col8, #T_2b2d4_row18_col9, #T_2b2d4_row18_col10, #T_2b2d4_row18_col11, #T_2b2d4_row18_col12, #T_2b2d4_row18_col13, #T_2b2d4_row18_col14, #T_2b2d4_row18_col15, #T_2b2d4_row19_col0, #T_2b2d4_row19_col1, #T_2b2d4_row19_col2, #T_2b2d4_row19_col3, #T_2b2d4_row19_col4, #T_2b2d4_row19_col5, #T_2b2d4_row19_col6, #T_2b2d4_row19_col7, #T_2b2d4_row19_col8, #T_2b2d4_row19_col9, #T_2b2d4_row19_col10, #T_2b2d4_row19_col11, #T_2b2d4_row19_col12, #T_2b2d4_row19_col13, #T_2b2d4_row19_col14, #T_2b2d4_row19_col15 {
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_2b2d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b2d4_level0_col0" class="col_heading level0 col0" >True_District</th>
#       <th id="T_2b2d4_level0_col1" class="col_heading level0 col1" >Pred_District</th>
#       <th id="T_2b2d4_level0_col2" class="col_heading level0 col2" >True_SubDistrict</th>
#       <th id="T_2b2d4_level0_col3" class="col_heading level0 col3" >Pred_SubDistrict</th>
#       <th id="T_2b2d4_level0_col4" class="col_heading level0 col4" >True_Street</th>
#       <th id="T_2b2d4_level0_col5" class="col_heading level0 col5" >Pred_Street</th>
#       <th id="T_2b2d4_level0_col6" class="col_heading level0 col6" >Correct_District</th>
#       <th id="T_2b2d4_level0_col7" class="col_heading level0 col7" >Correct_SubDistrict</th>
#       <th id="T_2b2d4_level0_col8" class="col_heading level0 col8" >Correct_Street</th>
#       <th id="T_2b2d4_level0_col9" class="col_heading level0 col9" >Correct_Overall</th>
#       <th id="T_2b2d4_level0_col10" class="col_heading level0 col10" >True_District_Name</th>
#       <th id="T_2b2d4_level0_col11" class="col_heading level0 col11" >Pred_District_Name</th>
#       <th id="T_2b2d4_level0_col12" class="col_heading level0 col12
