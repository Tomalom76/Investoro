# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.impute import SimpleImputer
import joblib
import os
import re
from IPython.display import display
from tqdm.notebook import tqdm
import gc

# %%
print("Krok 0: Konfiguracja środowiska")

ARTIFACTS_DIR = "Artifacts_Polska"
os.makedirs(ARTIFACTS_DIR, exist_ok=True)

LOC_FILE = 'lokalizacja.csv'
DATA_FILE_1 = 'saleflats_2024_dateAdded_polska.csv'
DATA_FILE_2 = 'saleflats_2024_newestDate_polska.csv'
OUTPUT_FILE = 'Location_Polska_Final_Tuned.csv'

MAX_TEXT_FEATURES = 5000
# Out:
# Krok 0: Konfiguracja środowiska

# %%
print("--- START: Budowa finalnego zbioru danych ---")

# --- Krok 1: Wczytanie pliku lokalizacja.csv ---
print("Wczytywanie i przygotowywanie pliku lokalizacja.csv...")
try:
    df_lokalizacja = pd.read_csv(
        'lokalizacja.csv', sep=',', header=None,
        names=['Id', 'ParentId', 'Name', 'AdditionalName', 'FullName'], dtype=str
    )
    df_lokalizacja['Id'] = pd.to_numeric(df_lokalizacja['Id'], errors='coerce')
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].replace('\\N', pd.NA)
    df_lokalizacja['ParentId'] = pd.to_numeric(df_lokalizacja['ParentId'], errors='coerce')
    df_lokalizacja.dropna(subset=['Id'], inplace=True)
    df_lokalizacja['Id'] = df_lokalizacja['Id'].astype(int)
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].astype('Int64')
    
    id_to_name = df_lokalizacja.set_index('Id')['Name'].to_dict()
    id_to_parent = df_lokalizacja.set_index('Id')['ParentId'].to_dict()
    city_to_districts = df_lokalizacja[df_lokalizacja['AdditionalName'].str.contains('Dzielnica|Osiedle', na=False)].groupby('ParentId')['Id'].apply(list).to_dict()
    district_to_streets = df_lokalizacja[df_lokalizacja['AdditionalName'] == 'Ulica'].groupby('ParentId')['Id'].apply(list).to_dict()
    print(f"Plik lokalizacja.csv wczytany.")
except FileNotFoundError:
    print("BŁĄD KRYTYCZNY: Nie znaleziono pliku lokalizacja.csv")
    exit()

# --- Krok 2: Ekstrakcja danych z plików ofert ---
try:
    first_row = pd.read_csv(DATA_FILE_1, sep=',', header=None, nrows=1, on_bad_lines='skip', encoding='utf-8')
    last_col_index = first_row.shape[1] - 1
    print(f"Automatycznie wykryto, że ostatnia kolumna ma indeks: {last_col_index}")
except:
    last_col_index = 52
    print(f"Nie udało się wykryć ostatniej kolumny, używam wartości awaryjnej: {last_col_index}")

COLS_TO_EXTRACT = {
    3: 'Title', 4: 'Description', 5: 'Area', 6: 'Price',
    9: 'NumberOfRooms', 16: 'BuiltYear',
    last_col_index: 'locationPath'
}

all_offers_df = []
for filepath in [DATA_FILE_1, DATA_FILE_2]:
    print(f"\nEkstrakcja danych z pliku: {filepath}...")
    try:
        df_chunk = pd.read_csv(
            filepath, sep=',', header=None, on_bad_lines='skip',
            usecols=list(COLS_TO_EXTRACT.keys()), low_memory=False, dtype=str, encoding='utf-8'
        )
        df_chunk.rename(columns=COLS_TO_EXTRACT, inplace=True)
        all_offers_df.append(df_chunk)
        print(f"Udało się wyekstrahować {len(df_chunk)} wierszy.")
    except Exception as e:
        print(f"Błąd podczas ekstrakcji z {filepath}: {e}")

if not all_offers_df:
    print("BŁĄD KRYTYCZNY: Nie udało się wczytać żadnych danych z plików ofert.")
    exit()

df = pd.concat(all_offers_df, ignore_index=True)
df.dropna(subset=['locationPath'], inplace=True)
df.drop_duplicates(subset=['Title', 'Description', 'locationPath'], keep='first', inplace=True)
df_original = df.copy()
print(f"\nPołączono i uzyskano {len(df)} unikalnych ofert.")

# --- Krok 3: Parsowanie ścieżki i tworzenie kolumn docelowych ---
print("Parsowanie ścieżek i tworzenie kolumn docelowych...")
path_cols = ['Wojewodztwo_ID', 'Powiat_ID', 'Gmina_ID', 'Miasto_ID', 'Dzielnica_ID', 'PodDzielnica_ID', 'Ulica_ID']
split_paths = df['locationPath'].str.split(',')
path_df = pd.DataFrame(split_paths.tolist(), index=df.index)
if path_df.shape[1] > 7: path_df = path_df.iloc[:, :7]
while path_df.shape[1] < 7: path_df[path_df.shape[1]] = None
path_df.columns = path_cols
path_df = path_df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
df = pd.concat([df.reset_index(drop=True), path_df.reset_index(drop=True)], axis=1)

df['target_district_id'] = np.where(df['PodDzielnica_ID'] != 0, df['PodDzielnica_ID'], df['Dzielnica_ID'])
df['target_city_id'] = df['Miasto_ID']
df['target_street_id'] = df['Ulica_ID']

df = df[df['target_city_id'] != 0].copy()
df.reset_index(drop=True, inplace=True)

if len(df) == 0:
    print("BŁĄD KRYTYCZNY: Po filtrowaniu nie pozostały żadne wiersze z określonym miastem.")
else:
    print(f"Liczba ogłoszeń z określonym miastem do treningu: {len(df)}")
# Out:
# --- START: Budowa finalnego zbioru danych ---
# Wczytywanie i przygotowywanie pliku lokalizacja.csv...
# Plik lokalizacja.csv wczytany.
# Automatycznie wykryto, że ostatnia kolumna ma indeks: 52
#
# Ekstrakcja danych z pliku: saleflats_2024_dateAdded_polska.csv...
# Udało się wyekstrahować 793664 wierszy.
#
# Ekstrakcja danych z pliku: saleflats_2024_newestDate_polska.csv...
# Udało się wyekstrahować 755679 wierszy.
#
# Połączono i uzyskano 773591 unikalnych ofert.
# Parsowanie ścieżek i tworzenie kolumn docelowych...
# Liczba ogłoszeń z określonym miastem do treningu: 709104

# %%
print("\nKrok 2: Inżynieria Cech (v1.3 - Finalna, Niezawodna)")
from sklearn.impute import SimpleImputer

# --- Przetwarzanie cech numerycznych ---
# ZMIANA: Używamy TYLKO 'Area' i 'Price', ponieważ inne indeksy są nieprawidłowe
num_features_final = ['Area', 'Price']
print(f"Używane cechy numeryczne: {num_features_final}")

for col in num_features_final:
    df[col] = pd.to_numeric(df[col], errors='coerce')

imputer = SimpleImputer(strategy='median')
df[num_features_final] = imputer.fit_transform(df[num_features_final])

scaler = StandardScaler()
X_num = scaler.fit_transform(df[num_features_final])
joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, 'scaler_final.joblib'))

# --- Przetwarzanie cech tekstowych (z zachowaniem liczb) ---
df['text_features'] = df['Title'].fillna('') + ' ' + df['Description'].fillna('')

def clean_text_with_digits(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['text_features'] = df['text_features'].apply(clean_text_with_digits)

vectorizer = TfidfVectorizer(max_features=MAX_TEXT_FEATURES, ngram_range=(1, 1))

print("Rozpoczynam wektoryzację tekstu...")
X_text = vectorizer.fit_transform(df['text_features'])
joblib.dump(vectorizer, os.path.join(ARTIFACTS_DIR, 'vectorizer_final.joblib'))

print(f"Przygotowano cechy: {X_text.shape[1]} tekstowych i {X_num.shape[1]} numerycznych.")
# Out:
# Krok 2: Inżynieria Cech (v1.3 - Finalna, Niezawodna)
# Używane cechy numeryczne: ['Area', 'Price']
# Rozpoczynam wektoryzację tekstu...
# Przygotowano cechy: 5000 tekstowych i 2 numerycznych.

# %%
print("\nKrok 3: Przygotowanie Celów (Target Variables) jako indeksy")

city_ids = sorted(df['target_city_id'].unique())
district_ids = sorted(df['target_district_id'].unique())
street_ids = sorted(df['target_street_id'].unique())

if 0 not in district_ids: district_ids.insert(0,0)
if 0 not in street_ids: street_ids.insert(0,0)

city_id_map = {id: i for i, id in enumerate(city_ids)}
district_id_map = {id: i for i, id in enumerate(district_ids)}
street_id_map = {id: i for i, id in enumerate(street_ids)}

joblib.dump(city_id_map, os.path.join(ARTIFACTS_DIR, 'city_id_map.joblib'))
joblib.dump(district_id_map, os.path.join(ARTIFACTS_DIR, 'district_id_map.joblib'))
joblib.dump(street_id_map, os.path.join(ARTIFACTS_DIR, 'street_id_map.joblib'))

inv_city_id_map = {i: id for id, i in city_id_map.items()}
inv_district_id_map = {i: id for id, i in district_id_map.items()}
inv_street_id_map = {i: id for id, i in street_id_map.items()}
joblib.dump(inv_city_id_map, os.path.join(ARTIFACTS_DIR, 'inv_city_id_map.joblib'))
joblib.dump(inv_district_id_map, os.path.join(ARTIFACTS_DIR, 'inv_district_id_map.joblib'))
joblib.dump(inv_street_id_map, os.path.join(ARTIFACTS_DIR, 'inv_street_id_map.joblib'))

y_city = df['target_city_id'].map(city_id_map).values
y_district = df['target_district_id'].map(district_id_map).values
y_street = df['target_street_id'].map(street_id_map).values

if np.isnan(y_city).any() or np.isnan(y_district).any() or np.isnan(y_street).any():
    print("BŁĄD: Wystąpiły wartości NaN po mapowaniu ID na indeksy.")
    exit()

print(f"Przygotowano zmienne docelowe. Liczba unikalnych klas:\nMiasta: {len(city_ids)}\nDzielnice: {len(district_ids)}\nUlice: {len(street_ids)}")
# Out:
# Krok 3: Przygotowanie Celów (Target Variables) jako indeksy
# Przygotowano zmienne docelowe. Liczba unikalnych klas:
# Miasta: 6933
# Dzielnice: 1940
# Ulice: 28177

# %%
print("\nKrok 4: Podział na Zbiory Danych")
X_text_train, X_text_val, X_num_train, X_num_val, y_city_train, y_city_val, y_district_train, y_district_val, y_street_train, y_street_val = train_test_split(
    X_text, X_num, y_city, y_district, y_street, test_size=0.2, random_state=42
)
print(f"Rozmiar zbioru treningowego: {X_text_train.shape[0]}\nRozmiar zbioru walidacyjnego: {X_text_val.shape[0]}")
# Out:
# Krok 4: Podział na Zbiory Danych
# Rozmiar zbioru treningowego: 567283
# Rozmiar zbioru walidacyjnego: 141821

# %%
print("\nKrok 5: Budowa i Kompilacja Modelu (v1.3 - Pełne Cechy + Dedykowana Głowa)")

# Wejścia
input_text = Input(shape=(MAX_TEXT_FEATURES,), name='text_input', sparse=True) 
# ZMIANA: Kształt wejścia numerycznego wraca do (None, 2)
input_num = Input(shape=(X_num_train.shape[1],), name='num_input') 

# --- Wspólna baza modelu ---
x1 = Dense(128, activation='relu')(input_text)
x1 = Dropout(0.4)(x1)

x2 = Dense(64, activation='relu')(input_num)
x2 = Dense(32, activation='relu')(x2)

combined = Concatenate()([x1, x2])
z_base = Dense(256, activation='relu')(combined)
z_base = Dropout(0.5)(z_base)

# --- Głowy dla Miasta i Dzielnicy ---
output_city = Dense(len(city_ids), activation='softmax', name='city_output')(z_base)
output_district = Dense(len(district_ids), activation='softmax', name='district_output')(z_base)

# --- Dedykowana, głębsza ścieżka tylko dla Ulicy ---
z_street = Dense(256, activation='relu')(z_base)
z_street = Dropout(0.4)(z_street)
output_street = Dense(len(street_ids), activation='softmax', name='street_output')(z_street)

model_final = Model(
    inputs=[input_text, input_num],
    outputs=[output_city, output_district, output_street]
)

# --- Kompilacja z wagami strat ---
optimizer_final = tf.keras.optimizers.Adam(learning_rate=0.0005)

model_final.compile(
    optimizer=optimizer_final,
    loss={
        'city_output': 'sparse_categorical_crossentropy',
        'district_output': 'sparse_categorical_crossentropy',
        'street_output': 'sparse_categorical_crossentropy'
    },
    loss_weights={
        'city_output': 1.0, 
        'district_output': 1.2,
        'street_output': 1.5
    },
    metrics={
        'city_output': 'accuracy',
        'district_output': 'accuracy',
        'street_output': 'accuracy'
    }
)

model_final.summary()
# Out:
# Krok 5: Budowa i Kompilacja Modelu (v1.3 - Pełne Cechy + Dedykowana Głowa)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)       │ (None, 5000)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ num_input (InputLayer)        │ (None, 2)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │         640,128 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64)                │             192 │ num_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 32)                │           2,080 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 160)               │               0 │ dropout[0][0],             │
# │                               │                           │                 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │          41,216 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 256)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 256)               │          65,792 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 256)               │               0 │ dense_4[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_output (Dense)           │ (None, 6933)              │       1,781,781 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ district_output (Dense)       │ (None, 1940)              │         498,580 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ street_output (Dense)         │ (None, 28177)             │       7,241,489 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 10,271,258 (39.18 MB)
#  Trainable params: 10,271,258 (39.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\nKrok 6: Trening Modelu (Finalny Tuning)")

X_train_list = [X_text_train, X_num_train]
y_train_dict = {'city_output': y_city_train, 'district_output': y_district_train, 'street_output': y_street_train}
X_val_list = [X_text_val, X_num_val]
y_val_dict = {'city_output': y_city_val, 'district_output': y_district_val, 'street_output': y_street_val}

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-5, verbose=1)

history_final = model_final.fit(
    X_train_list,
    y_train_dict,
    validation_data=(X_val_list, y_val_dict),
    epochs=25,
    batch_size=256,
    callbacks=[early_stopping, reduce_lr]
)

model_final.save(os.path.join(ARTIFACTS_DIR, 'location_prediction_model_final.h5'))
print("Finalny, tuningowany model został wytrenowany i zapisany.")
# Out:
# Krok 6: Trening Modelu (Finalny Tuning)
# Epoch 1/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 176s 78ms/step - city_output_accuracy: 0.1867 - city_output_loss: 4.8239 - district_output_accuracy: 0.4897 - district_output_loss: 3.9461 - loss: 16.0818 - street_output_accuracy: 0.6611 - street_output_loss: 4.3484 - val_city_output_accuracy: 0.5212 - val_city_output_loss: 2.9321 - val_district_output_accuracy: 0.5149 - val_district_output_loss: 2.6522 - val_loss: 11.5278 - val_street_output_accuracy: 0.6713 - val_street_output_loss: 3.6087 - learning_rate: 5.0000e-04
# Epoch 2/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 156s 70ms/step - city_output_accuracy: 0.5276 - city_output_loss: 2.8503 - district_output_accuracy: 0.5113 - district_output_loss: 2.6403 - loss: 11.1699 - street_output_accuracy: 0.6701 - street_output_loss: 3.4341 - val_city_output_accuracy: 0.6145 - val_city_output_loss: 2.3466 - val_district_output_accuracy: 0.5393 - val_district_output_loss: 2.2263 - val_loss: 10.0150 - val_street_output_accuracy: 0.6713 - val_street_output_loss: 3.3313 - learning_rate: 5.0000e-04
# Epoch 3/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 160s 72ms/step - city_output_accuracy: 0.5982 - city_output_loss: 2.3967 - district_output_accuracy: 0.5302 - district_output_loss: 2.2770 - loss: 9.8620 - street_output_accuracy: 0.6708 - street_output_loss: 3.1553 - val_city_output_accuracy: 0.6443 - val_city_output_loss: 2.1156 - val_district_output_accuracy: 0.5662 - val_district_output_loss: 1.9478 - val_loss: 8.9231 - val_street_output_accuracy: 0.6713 - val_street_output_loss: 2.9801 - learning_rate: 5.0000e-04
# Epoch 4/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 165s 74ms/step - city_output_accuracy: 0.6253 - city_output_loss: 2.1849 - district_output_accuracy: 0.5500 - district_output_loss: 2.0421 - loss: 9.0838 - street_output_accuracy: 0.6692 - street_output_loss: 2.9655 - val_city_output_accuracy: 0.6611 - val_city_output_loss: 1.9927 - val_district_output_accuracy: 0.5884 - val_district_output_loss: 1.7813 - val_loss: 8.3244 - val_street_output_accuracy: 0.6720 - val_street_output_loss: 2.7961 - learning_rate: 5.0000e-04
# Epoch 5/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 169s 76ms/step - city_output_accuracy: 0.6400 - city_output_loss: 2.0644 - district_output_accuracy: 0.5661 - district_output_loss: 1.8958 - loss: 8.5395 - street_output_accuracy: 0.6703 - street_output_loss: 2.8001 - val_city_output_accuracy: 0.6728 - val_city_output_loss: 1.9088 - val_district_output_accuracy: 0.6010 - val_district_output_loss: 1.6758 - val_loss: 7.9335 - val_street_output_accuracy: 0.6731 - val_street_output_loss: 2.6758 - learning_rate: 5.0000e-04
# Epoch 6/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 180s 81ms/step - city_output_accuracy: 0.6503 - city_output_loss: 1.9749 - district_output_accuracy: 0.5754 - district_output_loss: 1.8062 - loss: 8.1489 - street_output_accuracy: 0.6702 - street_output_loss: 2.6710 - val_city_output_accuracy: 0.6811 - val_city_output_loss: 1.8509 - val_district_output_accuracy: 0.6124 - val_district_output_loss: 1.6059 - val_loss: 7.6570 - val_street_output_accuracy: 0.6744 - val_street_output_loss: 2.5860 - learning_rate: 5.0000e-04
# Epoch 7/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 180s 81ms/step - city_output_accuracy: 0.6572 - city_output_loss: 1.9161 - district_output_accuracy: 0.5834 - district_output_loss: 1.7402 - loss: 7.8611 - street_output_accuracy: 0.6700 - street_output_loss: 2.5712 - val_city_output_accuracy: 0.6873 - val_city_output_loss: 1.8091 - val_district_output_accuracy: 0.6202 - val_district_output_loss: 1.5637 - val_loss: 7.4504 - val_street_output_accuracy: 0.6764 - val_street_output_loss: 2.5099 - learning_rate: 5.0000e-04
# Epoch 8/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 190s 86ms/step - city_output_accuracy: 0.6637 - city_output_loss: 1.8607 - district_output_accuracy: 0.5895 - district_output_loss: 1.6911 - loss: 7.6326 - street_output_accuracy: 0.6690 - street_output_loss: 2.4950 - val_city_output_accuracy: 0.6930 - val_city_output_loss: 1.7759 - val_district_output_accuracy: 0.6255 - val_district_output_loss: 1.5290 - val_loss: 7.2943 - val_street_output_accuracy: 0.6780 - val_street_output_loss: 2.4557 - learning_rate: 5.0000e-04
# Epoch 9/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 195s 88ms/step - city_output_accuracy: 0.6671 - city_output_loss: 1.8311 - district_output_accuracy: 0.5956 - district_output_loss: 1.6492 - loss: 7.4570 - street_output_accuracy: 0.6706 - street_output_loss: 2.4313 - val_city_output_accuracy: 0.6981 - val_city_output_loss: 1.7511 - val_district_output_accuracy: 0.6307 - val_district_output_loss: 1.5057 - val_loss: 7.1788 - val_street_output_accuracy: 0.6797 - val_street_output_loss: 2.4139 - learning_rate: 5.0000e-04
# Epoch 10/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 202s 91ms/step - city_output_accuracy: 0.6711 - city_output_loss: 1.7978 - district_output_accuracy: 0.5977 - district_output_loss: 1.6231 - loss: 7.3139 - street_output_accuracy: 0.6707 - street_output_loss: 2.3790 - val_city_output_accuracy: 0.6998 - val_city_output_loss: 1.7294 - val_district_output_accuracy: 0.6324 - val_district_output_loss: 1.4834 - val_loss: 7.0742 - val_street_output_accuracy: 0.6812 - val_street_output_loss: 2.3765 - learning_rate: 5.0000e-04
# Epoch 11/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 205s 92ms/step - city_output_accuracy: 0.6746 - city_output_loss: 1.7703 - district_output_accuracy: 0.6020 - district_output_loss: 1.5998 - loss: 7.1894 - street_output_accuracy: 0.6718 - street_output_loss: 2.3329 - val_city_output_accuracy: 0.7029 - val_city_output_loss: 1.7078 - val_district_output_accuracy: 0.6368 - val_district_output_loss: 1.4634 - val_loss: 6.9959 - val_street_output_accuracy: 0.6833 - val_street_output_loss: 2.3546 - learning_rate: 5.0000e-04
# Epoch 12/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 203s 92ms/step - city_output_accuracy: 0.6770 - city_output_loss: 1.7465 - district_output_accuracy: 0.6070 - district_output_loss: 1.5703 - loss: 7.0775 - street_output_accuracy: 0.6724 - street_output_loss: 2.2978 - val_city_output_accuracy: 0.7065 - val_city_output_loss: 1.6928 - val_district_output_accuracy: 0.6386 - val_district_output_loss: 1.4460 - val_loss: 6.9288 - val_street_output_accuracy: 0.6844 - val_street_output_loss: 2.3338 - learning_rate: 5.0000e-04
# Epoch 13/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 209s 94ms/step - city_output_accuracy: 0.6794 - city_output_loss: 1.7275 - district_output_accuracy: 0.6077 - district_output_loss: 1.5543 - loss: 6.9895 - street_output_accuracy: 0.6733 - street_output_loss: 2.2645 - val_city_output_accuracy: 0.7087 - val_city_output_loss: 1.6793 - val_district_output_accuracy: 0.6421 - val_district_output_loss: 1.4306 - val_loss: 6.8757 - val_street_output_accuracy: 0.6851 - val_street_output_loss: 2.3198 - learning_rate: 5.0000e-04
# Epoch 14/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 223s 101ms/step - city_output_accuracy: 0.6827 - city_output_loss: 1.7084 - district_output_accuracy: 0.6116 - district_output_loss: 1.5365 - loss: 6.8987 - street_output_accuracy: 0.6748 - street_output_loss: 2.2310 - val_city_output_accuracy: 0.7104 - val_city_output_loss: 1.6690 - val_district_output_accuracy: 0.6438 - val_district_output_loss: 1.4266 - val_loss: 6.8260 - val_street_output_accuracy: 0.6870 - val_street_output_loss: 2.2967 - learning_rate: 5.0000e-04
# Epoch 15/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 234s 106ms/step - city_output_accuracy: 0.6831 - city_output_loss: 1.6962 - district_output_accuracy: 0.6128 - district_output_loss: 1.5267 - loss: 6.8513 - street_output_accuracy: 0.6732 - street_output_loss: 2.2154 - val_city_output_accuracy: 0.7123 - val_city_output_loss: 1.6548 - val_district_output_accuracy: 0.6460 - val_district_output_loss: 1.4165 - val_loss: 6.7710 - val_street_output_accuracy: 0.6872 - val_street_output_loss: 2.2776 - learning_rate: 5.0000e-04
# Epoch 16/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 239s 108ms/step - city_output_accuracy: 0.6865 - city_output_loss: 1.6729 - district_output_accuracy: 0.6125 - district_output_loss: 1.5155 - loss: 6.7748 - street_output_accuracy: 0.6748 - street_output_loss: 2.1889 - val_city_output_accuracy: 0.7139 - val_city_output_loss: 1.6462 - val_district_output_accuracy: 0.6481 - val_district_output_loss: 1.4038 - val_loss: 6.7349 - val_street_output_accuracy: 0.6893 - val_street_output_loss: 2.2694 - learning_rate: 5.0000e-04
# Epoch 17/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 234s 106ms/step - city_output_accuracy: 0.6870 - city_output_loss: 1.6630 - district_output_accuracy: 0.6165 - district_output_loss: 1.5014 - loss: 6.7260 - street_output_accuracy: 0.6750 - street_output_loss: 2.1742 - val_city_output_accuracy: 0.7159 - val_city_output_loss: 1.6428 - val_district_output_accuracy: 0.6468 - val_district_output_loss: 1.4026 - val_loss: 6.7146 - val_street_output_accuracy: 0.6907 - val_street_output_loss: 2.2591 - learning_rate: 5.0000e-04
# Epoch 18/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 250s 113ms/step - city_output_accuracy: 0.6885 - city_output_loss: 1.6546 - district_output_accuracy: 0.6176 - district_output_loss: 1.4956 - loss: 6.6751 - street_output_accuracy: 0.6763 - street_output_loss: 2.1505 - val_city_output_accuracy: 0.7168 - val_city_output_loss: 1.6334 - val_district_output_accuracy: 0.6498 - val_district_output_loss: 1.3943 - val_loss: 6.6716 - val_street_output_accuracy: 0.6911 - val_street_output_loss: 2.2434 - learning_rate: 5.0000e-04
# Epoch 19/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 240s 108ms/step - city_output_accuracy: 0.6905 - city_output_loss: 1.6417 - district_output_accuracy: 0.6191 - district_output_loss: 1.4825 - loss: 6.6230 - street_output_accuracy: 0.6755 - street_output_loss: 2.1349 - val_city_output_accuracy: 0.7182 - val_city_output_loss: 1.6260 - val_district_output_accuracy: 0.6514 - val_district_output_loss: 1.3895 - val_loss: 6.6424 - val_street_output_accuracy: 0.6911 - val_street_output_loss: 2.2327 - learning_rate: 5.0000e-04
# Epoch 20/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 241s 109ms/step - city_output_accuracy: 0.6908 - city_output_loss: 1.6289 - district_output_accuracy: 0.6212 - district_output_loss: 1.4700 - loss: 6.5600 - street_output_accuracy: 0.6780 - street_output_loss: 2.1114 - val_city_output_accuracy: 0.7197 - val_city_output_loss: 1.6177 - val_district_output_accuracy: 0.6519 - val_district_output_loss: 1.3831 - val_loss: 6.6221 - val_street_output_accuracy: 0.6929 - val_street_output_loss: 2.2297 - learning_rate: 5.0000e-04
# Epoch 21/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 244s 110ms/step - city_output_accuracy: 0.6919 - city_output_loss: 1.6236 - district_output_accuracy: 0.6208 - district_output_loss: 1.4687 - loss: 6.5473 - street_output_accuracy: 0.6769 - street_output_loss: 2.1075 - val_city_output_accuracy: 0.7208 - val_city_output_loss: 1.6134 - val_district_output_accuracy: 0.6522 - val_district_output_loss: 1.3775 - val_loss: 6.6032 - val_street_output_accuracy: 0.6930 - val_street_output_loss: 2.2245 - learning_rate: 5.0000e-04
# Epoch 22/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 241s 109ms/step - city_output_accuracy: 0.6929 - city_output_loss: 1.6129 - district_output_accuracy: 0.6228 - district_output_loss: 1.4615 - loss: 6.5196 - street_output_accuracy: 0.6762 - street_output_loss: 2.1020 - val_city_output_accuracy: 0.7219 - val_city_output_loss: 1.6073 - val_district_output_accuracy: 0.6540 - val_district_output_loss: 1.3713 - val_loss: 6.5823 - val_street_output_accuracy: 0.6935 - val_street_output_loss: 2.2196 - learning_rate: 5.0000e-04
# Epoch 23/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 250s 113ms/step - city_output_accuracy: 0.6946 - city_output_loss: 1.6036 - district_output_accuracy: 0.6222 - district_output_loss: 1.4547 - loss: 6.4773 - street_output_accuracy: 0.6773 - street_output_loss: 2.0854 - val_city_output_accuracy: 0.7224 - val_city_output_loss: 1.6099 - val_district_output_accuracy: 0.6533 - val_district_output_loss: 1.3679 - val_loss: 6.5694 - val_street_output_accuracy: 0.6936 - val_street_output_loss: 2.2120 - learning_rate: 5.0000e-04
# Epoch 24/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 255s 115ms/step - city_output_accuracy: 0.6946 - city_output_loss: 1.6017 - district_output_accuracy: 0.6247 - district_output_loss: 1.4498 - loss: 6.4440 - street_output_accuracy: 0.6787 - street_output_loss: 2.0683 - val_city_output_accuracy: 0.7232 - val_city_output_loss: 1.6057 - val_district_output_accuracy: 0.6561 - val_district_output_loss: 1.3654 - val_loss: 6.5551 - val_street_output_accuracy: 0.6942 - val_street_output_loss: 2.2072 - learning_rate: 5.0000e-04
# Epoch 25/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 256s 116ms/step - city_output_accuracy: 0.6969 - city_output_loss: 1.5919 - district_output_accuracy: 0.6260 - district_output_loss: 1.4373 - loss: 6.4005 - street_output_accuracy: 0.6791 - street_output_loss: 2.0559 - val_city_output_accuracy: 0.7241 - val_city_output_loss: 1.5981 - val_district_output_accuracy: 0.6563 - val_district_output_loss: 1.3586 - val_loss: 6.5293 - val_street_output_accuracy: 0.6947 - val_street_output_loss: 2.2006 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Finalny, tuningowany model został wytrenowany i zapisany.

# %%
import gc
from tqdm.notebook import tqdm

print("\nKrok 7: Predykcja i Zastosowanie Logiki Hierarchicznej (Ręczna Pętla)")

n_samples = df.shape[0]
chunk_size = 50000

predicted_city_ids = []
predicted_district_ids = []
predicted_street_ids = []

print(f"Rozpoczynam predykcję na {n_samples} próbkach w kawałkach po {chunk_size}...")

for i in tqdm(range(0, n_samples, chunk_size)):
    chunk_text = X_text[i:i + chunk_size]
    chunk_num = X_num[i:i + chunk_size]
    chunk_list = [chunk_text, chunk_num]
    
    pred_city_chunk, pred_district_chunk, pred_street_chunk = model_final.predict(chunk_list, batch_size=512, verbose=0)
    
    for j in range(pred_city_chunk.shape[0]):
        city_pred_index = np.argmax(pred_city_chunk[j])
        city_id = inv_city_id_map.get(city_pred_index, 0)
        
        valid_districts_for_city = city_to_districts.get(city_id, [])
        # POPRAWKA: Używamy `pred_district_chunk`
        district_pred_index = np.argmax(pred_district_chunk[j]) 
        if valid_districts_for_city:
            district_mask = np.zeros_like(pred_district_chunk[j])
            valid_indices = [district_id_map.get(d_id) for d_id in valid_districts_for_city if district_id_map.get(d_id) is not None]
            if valid_indices:
                district_mask[valid_indices] = 1
                if np.sum(district_mask) > 0:
                    district_pred_index = np.argmax(pred_district_chunk[j] * district_mask)
        
        district_id = inv_district_id_map.get(district_pred_index, 0)
        
        valid_streets_for_district = district_to_streets.get(district_id, [])
        # POPRAWKA: Używamy `pred_street_chunk`
        street_pred_index = np.argmax(pred_street_chunk[j]) 
        if valid_streets_for_district:
            street_mask = np.zeros_like(pred_street_chunk[j])
            valid_indices = [street_id_map.get(s_id) for s_id in valid_streets_for_district if street_id_map.get(s_id) is not None]
            if valid_indices:
                street_mask[valid_indices] = 1
                if np.sum(street_mask) > 0:
                    street_pred_index = np.argmax(pred_street_chunk[j] * street_mask)

        street_id = inv_street_id_map.get(street_pred_index, 0)
        
        predicted_city_ids.append(city_id)
        predicted_district_ids.append(district_id)
        predicted_street_ids.append(street_id)
        
    del pred_city_chunk, pred_district_chunk, pred_street_chunk
    gc.collect()

df['predicted_city_id'] = predicted_city_ids
df['predicted_district_id'] = predicted_district_ids
df['predicted_street_id'] = predicted_street_ids

print("Zakończono predykcję z logiką hierarchiczną.")
# Out:
# Krok 7: Predykcja i Zastosowanie Logiki Hierarchicznej (Ręczna Pętla)
# Rozpoczynam predykcję na 709104 próbkach w kawałkach po 50000...
#   0%|          | 0/15 [00:00<?, ?it/s]
# Zakończono predykcję z logiką hierarchiczną.

# %%
print("\nKrok 8: Generowanie i Zapis Wyników")

def create_loc_string(row):
    city = id_to_name.get(row['predicted_city_id'], "?")
    district = id_to_name.get(row['predicted_district_id'], "?")
    street = id_to_name.get(row['predicted_street_id'], "?")
    
    if row['predicted_district_id'] == 0: district = '?'
    if row['predicted_street_id'] == 0: street = '?'
        
    return f"{city} > {district} > {street}"

df['Predict_Loc'] = df.apply(create_loc_string, axis=1)

# Używamy df_original, które zapisaliśmy w komórce 3
df_to_merge = df[['Title', 'Description', 'locationPath', 'Predict_Loc']].copy()
df_final = pd.merge(df_original, df_to_merge, on=['Title', 'Description', 'locationPath'], how='left')
df_final.drop_duplicates(subset=['Title', 'Description', 'locationPath'], inplace=True)
df_final['Predict_Loc'].fillna('Brak predykcji', inplace=True)

df_final.to_csv(OUTPUT_FILE, index=False, sep=';', encoding='utf-8-sig')
print(f"Wyniki zostały zapisane do pliku: {OUTPUT_FILE}")
# Out:
# Krok 8: Generowanie i Zapis Wyników
# Wyniki zostały zapisane do pliku: Location_Polska_Final_Tuned.csv

# %%
print("\nPrzykładowe 20 wierszy z wynikami:")

predicted_df = df_final[df_final['Predict_Loc'] != 'Brak predykcji']
if len(predicted_df) > 20:
    sample = predicted_df.sample(20)
else:
    sample = predicted_df.head(20)

display_cols = ['Title', 'locationPath', 'Predict_Loc']
sample_display = sample[display_cols]

def highlight_col(s):
    return ['background-color: #ffff99' if c == 'Predict_Loc' else '' for c in s.index]

styled_sample = sample_display.style.apply(highlight_col, axis=1)
display(styled_sample)
# Out:
# Przykładowe 20 wierszy z wynikami:
# <style type="text/css">
# #T_1a750_row0_col2, #T_1a750_row1_col2, #T_1a750_row2_col2, #T_1a750_row3_col2, #T_1a750_row4_col2, #T_1a750_row5_col2, #T_1a750_row6_col2, #T_1a750_row7_col2, #T_1a750_row8_col2, #T_1a750_row9_col2, #T_1a750_row10_col2, #T_1a750_row11_col2, #T_1a750_row12_col2, #T_1a750_row13_col2, #T_1a750_row14_col2, #T_1a750_row15_col2, #T_1a750_row16_col2, #T_1a750_row17_col2, #T_1a750_row18_col2, #T_1a750_row19_col2 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_1a750">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a750_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_1a750_level0_col1" class="col_heading level0 col1" >locationPath</th>
#       <th id="T_1a750_level0_col2" class="col_heading level0 col2" >Predict_Loc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a750_level0_row0" class="row_heading level0 row0" >27378</th>
#       <td id="T_1a750_row0_col0" class="data row0 col0" >Mieszkanie, Bydgoszcz, Kapuściska, 68 m²</td>
#       <td id="T_1a750_row0_col1" class="data row0 col1" >10,0,0,374,0,0,0</td>
#       <td id="T_1a750_row0_col2" class="data row0 col2" >Bydgoszcz > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row1" class="row_heading level0 row1" >38361</th>
#       <td id="T_1a750_row1_col0" class="data row1 col0" >Sprzedam mieszkanie 56, 81m2</td>
#       <td id="T_1a750_row1_col1" class="data row1 col1" >8,206,0,3909,0,0,0</td>
#       <td id="T_1a750_row1_col2" class="data row1 col2" >Konin > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row2" class="row_heading level0 row2" >399018</th>
#       <td id="T_1a750_row2_col0" class="data row2 col0" >Seaport live in Gdynia Twoje nowe mieszkanie</td>
#       <td id="T_1a750_row2_col1" class="data row2 col1" >11,0,0,388,0,104414,455720</td>
#       <td id="T_1a750_row2_col2" class="data row2 col2" >Gdynia > Grabówek > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row3" class="row_heading level0 row3" >557015</th>
#       <td id="T_1a750_row3_col0" class="data row3 col0" >Mieszkanie, Wrocław, Fabryczna, 50 m²</td>
#       <td id="T_1a750_row3_col1" class="data row3 col1" >16,0,0,366,3270,72674,0</td>
#       <td id="T_1a750_row3_col2" class="data row3 col2" >Wrocław > Fabryczna > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row4" class="row_heading level0 row4" >160103</th>
#       <td id="T_1a750_row4_col0" class="data row4 col0" >3 pokojowe mieszkanie blisko toru Służewiec</td>
#       <td id="T_1a750_row4_col1" class="data row4 col1" >9,0,0,368,3284,91625,0</td>
#       <td id="T_1a750_row4_col2" class="data row4 col2" >Warszawa > Ursynów > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row5" class="row_heading level0 row5" >572280</th>
#       <td id="T_1a750_row5_col0" class="data row5 col0" >Mieszkanie, Poznań, Naramowice, 73 m²</td>
#       <td id="T_1a750_row5_col1" class="data row5 col1" >12,0,0,370,3261,81795,0</td>
#       <td id="T_1a750_row5_col2" class="data row5 col2" >Poznań > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row6" class="row_heading level0 row6" >197903</th>
#       <td id="T_1a750_row6_col0" class="data row6 col0" >Mieszkanie, Wrocław, Fabryczna, 80 m²</td>
#       <td id="T_1a750_row6_col1" class="data row6 col1" >16,0,0,366,0,0,0</td>
#       <td id="T_1a750_row6_col2" class="data row6 col2" >Wrocław > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row7" class="row_heading level0 row7" >708702</th>
#       <td id="T_1a750_row7_col0" class="data row7 col0" >Penthouse Z Windą Przy Parku Słowackiego - Chopina</td>
#       <td id="T_1a750_row7_col1" class="data row7 col1" >2,0,0,333,0,0,297485</td>
#       <td id="T_1a750_row7_col2" class="data row7 col2" >Bielsko-biała > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row8" class="row_heading level0 row8" >275684</th>
#       <td id="T_1a750_row8_col0" class="data row8 col0" >Mieszkanie 2 pokoje, 34,25 m2, Sady</td>
#       <td id="T_1a750_row8_col1" class="data row8 col1" >1,0,0,381,0,0,0</td>
#       <td id="T_1a750_row8_col2" class="data row8 col2" >Kielce > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row9" class="row_heading level0 row9" >771369</th>
#       <td id="T_1a750_row9_col0" class="data row9 col0" >Mieszkanie Warszawa</td>
#       <td id="T_1a750_row9_col1" class="data row9 col1" >9,0,0,368,3283,80732,0</td>
#       <td id="T_1a750_row9_col2" class="data row9 col2" >Warszawa > Mokotów > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row10" class="row_heading level0 row10" >595824</th>
#       <td id="T_1a750_row10_col0" class="data row10 col0" >66m ul.DĄBROWSKIEGO, mieszkanie 3-pokojowe</td>
#       <td id="T_1a750_row10_col1" class="data row10 col1" >13,0,0,361,0,0,284645</td>
#       <td id="T_1a750_row10_col2" class="data row10 col2" >Rzeszów > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row11" class="row_heading level0 row11" >639153</th>
#       <td id="T_1a750_row11_col0" class="data row11 col0" >Vonder UpTown | apartament 3-pok. | 51</td>
#       <td id="T_1a750_row11_col1" class="data row11 col1" >9,0,0,368,3285,100689,550032</td>
#       <td id="T_1a750_row11_col2" class="data row11 col2" >Warszawa > Śródmieście > Stanisława dubois</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row12" class="row_heading level0 row12" >250255</th>
#       <td id="T_1a750_row12_col0" class="data row12 col0" >2-pokojowe mieszkanie na sprzedaż</td>
#       <td id="T_1a750_row12_col1" class="data row12 col1" >14,248,0,20719,0,0,401102</td>
#       <td id="T_1a750_row12_col2" class="data row12 col2" >Tarnów > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row13" class="row_heading level0 row13" >499333</th>
#       <td id="T_1a750_row13_col0" class="data row13 col0" >Mieszkanie, ul. Rakowicka</td>
#       <td id="T_1a750_row13_col1" class="data row13 col1" >14,0,0,337,3255,86616,461113</td>
#       <td id="T_1a750_row13_col2" class="data row13 col2" >Kraków > Stare miasto > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row14" class="row_heading level0 row14" >326011</th>
#       <td id="T_1a750_row14_col0" class="data row14 col0" >Dwupokojowe mieszkanie w Żarowie do remontu</td>
#       <td id="T_1a750_row14_col1" class="data row14 col1" >16,39,0,21397,0,0,0</td>
#       <td id="T_1a750_row14_col2" class="data row14 col2" >Świdnica > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row15" class="row_heading level0 row15" >244027</th>
#       <td id="T_1a750_row15_col0" class="data row15 col0" >Mieszkanie trzypokojowe na sprzedaż</td>
#       <td id="T_1a750_row15_col1" class="data row15 col1" >9,0,0,368,3283,85722,474887</td>
#       <td id="T_1a750_row15_col2" class="data row15 col2" >Warszawa > Mokotów > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row16" class="row_heading level0 row16" >31292</th>
#       <td id="T_1a750_row16_col0" class="data row16 col0" >Apartament W Kamienica - Centrum Warszawy</td>
#       <td id="T_1a750_row16_col1" class="data row16 col1" >9,0,0,368,3285,0,0</td>
#       <td id="T_1a750_row16_col2" class="data row16 col2" >Warszawa > Śródmieście > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row17" class="row_heading level0 row17" >429397</th>
#       <td id="T_1a750_row17_col0" class="data row17 col0" >Mieszkanie, Wrocław, Krzyki, Klecina, 72 m²</td>
#       <td id="T_1a750_row17_col1" class="data row17 col1" >16,0,0,366,3272,85628,0</td>
#       <td id="T_1a750_row17_col2" class="data row17 col2" >Wrocław > Krzyki > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row18" class="row_heading level0 row18" >23500</th>
#       <td id="T_1a750_row18_col0" class="data row18 col0" >3 pok nowe mieszkanie. PROMOCJE!</td>
#       <td id="T_1a750_row18_col1" class="data row18 col1" >10,0,0,374,0,0,0</td>
#       <td id="T_1a750_row18_col2" class="data row18 col2" >Bydgoszcz > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_1a750_level0_row19" class="row_heading level0 row19" >485419</th>
#       <td id="T_1a750_row19_col0" class="d
