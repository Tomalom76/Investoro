# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
import os
import re
from IPython.display import display

# %%
print("Krok 0: Konfiguracja środowiska")

# Tworzenie katalogów na artefakty i wyniki
ARTIFACTS_DIR = "Artifacts_Polska"
os.makedirs(ARTIFACTS_DIR, exist_ok=True)

# Nazwy plików
LOC_FILE = 'lokalizacja.csv'
DATA_FILE_1 = 'saleflats_2024_dateAdded_polska.csv'
DATA_FILE_2 = 'saleflats_2024_newestDate_polska.csv'
OUTPUT_FILE = 'Location_Polska.csv'

# Hiperparametry
MAX_TEXT_FEATURES = 20000
# Out:
# Krok 0: Konfiguracja środowiska

# %%
print("--- START: Budowa finalnego zbioru danych ---")

# --- Krok 1: Wczytanie i przygotowanie pliku lokalizacja.csv ---
print("Wczytywanie i przygotowywanie pliku lokalizacja.csv...")
try:
    df_lokalizacja_raw = pd.read_csv(
        'lokalizacja.csv', sep=',', header=None,
        names=['Id', 'ParentId', 'Name', 'AdditionalName', 'FullName'], dtype=str
    )
    df_lokalizacja = df_lokalizacja_raw.copy()
    df_lokalizacja['Id'] = pd.to_numeric(df_lokalizacja['Id'], errors='coerce')
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].replace('\\N', pd.NA)
    df_lokalizacja['ParentId'] = pd.to_numeric(df_lokalizacja['ParentId'], errors='coerce')
    df_lokalizacja.dropna(subset=['Id'], inplace=True)
    df_lokalizacja['Id'] = df_lokalizacja['Id'].astype(int)
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].astype('Int64')
    
    location_dict = df_lokalizacja.set_index('Id').to_dict('index')
    id_to_name = df_lokalizacja.set_index('Id')['Name'].to_dict()
    id_to_parent = df_lokalizacja.set_index('Id')['ParentId'].to_dict()
    
    # Tworzenie struktur do walidacji hierarchii
    miasta_ids = df_lokalizacja[df_lokalizacja['AdditionalName'].str.contains('Miasto', na=False)]['Id'].tolist()
    dzielnice_ids = df_lokalizacja[df_lokalizacja['AdditionalName'].str.contains('Dzielnica|Osiedle', na=False)]['Id'].tolist()
    city_to_districts = df_lokalizacja[df_lokalizacja['Id'].isin(dzielnice_ids)].groupby('ParentId')['Id'].apply(list).to_dict()
    district_to_streets = df_lokalizacja[df_lokalizacja['AdditionalName'] == 'Ulica'].groupby('ParentId')['Id'].apply(list).to_dict()
    
    print(f"Plik lokalizacja.csv wczytany. Mamy {len(location_dict)} unikalnych lokalizacji.")
except FileNotFoundError:
    print("BŁĄD KRYTYCZNY: Nie znaleziono pliku lokalizacja.csv")
    exit()

# --- Krok 2: Ekstrakcja danych z plików ofert za pomocą 'usecols' ---
# UWAGA: Indeksy kolumn mogą wymagać weryfikacji. Na podstawie przykładów i błędów,
# zakładamy, że plik ma więcej kolumn, a `locationPath` jest na końcu.
# Próbujemy znaleźć ostatnią kolumnę, ale jeśli to zawiedzie, użyjemy stałej.
try:
    # Szybki odczyt pierwszego wiersza, żeby znaleźć ostatnią kolumnę
    first_row = pd.read_csv('saleflats_2024_dateAdded_polska.csv', sep=',', header=None, nrows=1, on_bad_lines='skip')
    last_col_index = first_row.shape[1] - 1
    print(f"Automatycznie wykryto, że ostatnia kolumna ma indeks: {last_col_index}")
except:
    last_col_index = 64 # Wartość awaryjna
    print(f"Nie udało się wykryć ostatniej kolumny, używam wartości awaryjnej: {last_col_index}")

COLS_TO_EXTRACT = {
    3: 'Title', 4: 'Description', 5: 'Area', 6: 'Price',
    9: 'NumberOfRooms', 14: 'Floor', 15: 'Floors', 16: 'BuiltYear',
    last_col_index: 'locationPath' # Używamy wykrytego indeksu
}

all_offers_df = []
FILES = ['saleflats_2024_dateAdded_polska.csv', 'saleflats_2024_newestDate_polska.csv']
for filepath in FILES:
    print(f"\nEkstrakcja danych z pliku: {filepath}...")
    try:
        df_chunk = pd.read_csv(
            filepath, sep=',', header=None, on_bad_lines='skip',
            usecols=list(COLS_TO_EXTRACT.keys()), low_memory=False, dtype=str, encoding='utf-8'
        )
        df_chunk.rename(columns=COLS_TO_EXTRACT, inplace=True)
        all_offers_df.append(df_chunk)
        print(f"Udało się wyekstrahować {len(df_chunk)} wierszy.")
    except Exception as e:
        print(f"Błąd podczas ekstrakcji z {filepath}: {e}")

if not all_offers_df:
    print("BŁĄD KRYTYCZNY: Nie udało się wczytać żadnych danych z plików ofert.")
    exit()

df = pd.concat(all_offers_df, ignore_index=True)
df.dropna(subset=['locationPath'], inplace=True)
df.drop_duplicates(subset=['Title', 'Description', 'locationPath'], keep='first', inplace=True)
print(f"\nPołączono i uzyskano {len(df)} unikalnych ofert.")


# --- Krok 3: Parsowanie ścieżki i tworzenie kolumn docelowych ---
print("Parsowanie ścieżek i tworzenie kolumn docelowych...")
path_cols = ['Wojewodztwo_ID', 'Powiat_ID', 'Gmina_ID', 'Miasto_ID', 'Dzielnica_ID', 'PodDzielnica_ID', 'Ulica_ID']
split_paths = df['locationPath'].str.split(',')
path_df = pd.DataFrame(split_paths.tolist(), index=df.index)
if path_df.shape[1] > 7: path_df = path_df.iloc[:, :7]
while path_df.shape[1] < 7: path_df[path_df.shape[1]] = None
path_df.columns = path_cols
path_df = path_df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
df = pd.concat([df.reset_index(drop=True), path_df.reset_index(drop=True)], axis=1)

df['target_district_id'] = np.where(df['PodDzielnica_ID'] != 0, df['PodDzielnica_ID'], df['Dzielnica_ID'])
df['target_city_id'] = df['Miasto_ID']
df['target_street_id'] = df['Ulica_ID']

# Filtrujemy, wymagając tylko, aby miasto było określone
df = df[df['target_city_id'] != 0].copy()
df.reset_index(drop=True, inplace=True)

if len(df) == 0:
    print("BŁĄD KRYTYCZNY: Po filtrowaniu nie pozostały żadne wiersze z określonym miastem.")
else:
    print(f"Liczba ogłoszeń z określonym miastem do treningu: {len(df)}")
# Out:
# --- START: Budowa finalnego zbioru danych ---
# Wczytywanie i przygotowywanie pliku lokalizacja.csv...
# Plik lokalizacja.csv wczytany. Mamy 398832 unikalnych lokalizacji.
# Automatycznie wykryto, że ostatnia kolumna ma indeks: 52
#
# Ekstrakcja danych z pliku: saleflats_2024_dateAdded_polska.csv...
# Udało się wyekstrahować 793664 wierszy.
#
# Ekstrakcja danych z pliku: saleflats_2024_newestDate_polska.csv...
# Udało się wyekstrahować 755679 wierszy.
#
# Połączono i uzyskano 773591 unikalnych ofert.
# Parsowanie ścieżek i tworzenie kolumn docelowych...
# Liczba ogłoszeń z określonym miastem do treningu: 709104

# %%
print("\nKrok 2: Inżynieria Cech (Tuningowana i Niezawodna)")
from sklearn.impute import SimpleImputer

# --- Przetwarzanie cech numerycznych ---
# ZMIANA: Używamy tylko 'Area' i 'Price', co do których mamy pewność
num_features_base = ['Area', 'Price']
for col in num_features_base:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# NOWA CECHA: Cena za metr kwadratowy
df['Price_per_sqm'] = df['Price'] / df['Area']
df['Price_per_sqm'].replace([np.inf, -np.inf], np.nan, inplace=True)

# Lista wszystkich cech numerycznych, które będziemy przetwarzać
num_features_final = ['Area', 'Price', 'Price_per_sqm']

# Uzupełnianie brakujących wartości (teraz tylko dla tych 3 kolumn)
imputer = SimpleImputer(strategy='median')
df[num_features_final] = imputer.fit_transform(df[num_features_final])

# Skalowanie
scaler = StandardScaler()
X_num = scaler.fit_transform(df[num_features_final])
joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, 'scaler_tuned.joblib'))

# --- Przetwarzanie cech tekstowych (z ulepszonym czyszczeniem) ---
df['text_features'] = df['Title'].fillna('') + ' ' + df['Description'].fillna('')

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['text_features'] = df['text_features'].apply(clean_text)

MAX_TEXT_FEATURES_REDUCED = 5000
vectorizer = TfidfVectorizer(max_features=MAX_TEXT_FEATURES_REDUCED, ngram_range=(1, 1))

print("Rozpoczynam wektoryzację tekstu (ulepszone czyszczenie)...")
X_text = vectorizer.fit_transform(df['text_features'])
joblib.dump(vectorizer, os.path.join(ARTIFACTS_DIR, 'vectorizer_tuned.joblib'))

MAX_TEXT_FEATURES = MAX_TEXT_FEATURES_REDUCED

print(f"Przygotowano cechy: {X_text.shape[1]} tekstowych (TF-IDF) i {X_num.shape[1]} numerycznych.")
print(f"Kształt macierzy X_num: {X_num.shape}")
# Out:
# Krok 2: Inżynieria Cech (Tuningowana i Niezawodna)
# Rozpoczynam wektoryzację tekstu (ulepszone czyszczenie)...
# Przygotowano cechy: 5000 tekstowych (TF-IDF) i 3 numerycznych.
# Kształt macierzy X_num: (709104, 3)

# %%
print("\nKrok 3: Przygotowanie Celów (Target Variables) jako indeksy")

# Mapowanie ID na indeksy 0..N-1 (tak jak wcześniej)
city_ids = sorted(df['target_city_id'].unique())
district_ids = sorted(df['target_district_id'].unique())
street_ids = sorted(df['target_street_id'].unique())

if 0 not in district_ids: district_ids.insert(0,0)
if 0 not in street_ids: street_ids.insert(0,0)

city_id_map = {id: i for i, id in enumerate(city_ids)}
district_id_map = {id: i for i, id in enumerate(district_ids)}
street_id_map = {id: i for i, id in enumerate(street_ids)}

# Zapisanie mapowań
joblib.dump(city_id_map, os.path.join(ARTIFACTS_DIR, 'city_id_map.joblib'))
joblib.dump(district_id_map, os.path.join(ARTIFACTS_DIR, 'district_id_map.joblib'))
joblib.dump(street_id_map, os.path.join(ARTIFACTS_DIR, 'street_id_map.joblib'))

inv_city_id_map = {i: id for id, i in city_id_map.items()}
inv_district_id_map = {i: id for id, i in district_id_map.items()}
inv_street_id_map = {i: id for id, i in street_id_map.items()}
joblib.dump(inv_city_id_map, os.path.join(ARTIFACTS_DIR, 'inv_city_id_map.joblib'))
joblib.dump(inv_district_id_map, os.path.join(ARTIFACTS_DIR, 'inv_district_id_map.joblib'))
joblib.dump(inv_street_id_map, os.path.join(ARTIFACTS_DIR, 'inv_street_id_map.joblib'))

# KLUCZOWA ZMIANA: y to teraz wektory z indeksami, a nie macierze one-hot
y_city = df['target_city_id'].map(city_id_map).values
y_district = df['target_district_id'].map(district_id_map).values
y_street = df['target_street_id'].map(street_id_map).values

print(f"Przygotowano zmienne docelowe jako wektory indeksów. Liczba unikalnych klas:")
print(f"Miasta: {len(city_ids)}")
print(f"Dzielnice: {len(district_ids)}")
print(f"Ulice: {len(street_ids)}")
# Out:
# Krok 3: Przygotowanie Celów (Target Variables) jako indeksy
# Przygotowano zmienne docelowe jako wektory indeksów. Liczba unikalnych klas:
# Miasta: 6933
# Dzielnice: 1940
# Ulice: 28177

# %%
# Podział na zbiór treningowy i walidacyjny
# Ten kod teraz zadziała, bo nie operuje na gigantycznych macierzach y
X_text_train, X_text_val, X_num_train, X_num_val, y_city_train, y_city_val, y_district_train, y_district_val, y_street_train, y_street_val = train_test_split(
    X_text, X_num, y_city, y_district, y_street, test_size=0.2, random_state=42
)

print(f"Rozmiar zbioru treningowego: {X_text_train.shape[0]}")
print(f"Rozmiar zbioru walidacyjnego: {X_text_val.shape[0]}")
# Out:
# Rozmiar zbioru treningowego: 567283
# Rozmiar zbioru walidacyjnego: 141821

# %%
print("\nKrok 4: Budowa i Kompilacja Modelu (Ulepszona Architektura)")

# Wejścia
input_text = Input(shape=(MAX_TEXT_FEATURES,), name='text_input', sparse=True) 
# ZMIANA: Kształt wejścia numerycznego jest teraz (None, 3)
input_num = Input(shape=(X_num_train.shape[1],), name='num_input') 

# Ścieżka tekstowa
x1 = Dense(128, activation='relu')(input_text)
x1 = Dropout(0.4)(x1)

# Ścieżka numeryczna (głębsza)
x2 = Dense(64, activation='relu')(input_num)
x2 = Dense(32, activation='relu')(x2) # Dodatkowa warstwa
x2 = Dropout(0.3)(x2)

# Połączenie i dalsze przetwarzanie (głębsze)
combined = Concatenate()([x1, x2])
z = Dense(512, activation='relu')(combined)
z = Dropout(0.5)(z)
z = Dense(256, activation='relu')(z)
z = Dropout(0.4)(z)

# Głowy wyjściowe (bez zmian)
output_city = Dense(len(city_ids), activation='softmax', name='city_output')(z)
output_district = Dense(len(district_ids), activation='softmax', name='district_output')(z)
output_street = Dense(len(street_ids), activation='softmax', name='street_output')(z)

# Finalny model
model_tuned = Model(inputs=[input_text, input_num], outputs=[output_city, output_district, output_street])

# Kompilacja (z niższym learning_rate)
optimizer_tuned = tf.keras.optimizers.Adam(learning_rate=0.0005)

model_tuned.compile(
    optimizer=optimizer_tuned,
    loss={
        'city_output': 'sparse_categorical_crossentropy',
        'district_output': 'sparse_categorical_crossentropy',
        'street_output': 'sparse_categorical_crossentropy'
    },
    metrics={
        'city_output': 'accuracy',
        'district_output': 'accuracy',
        'street_output': 'accuracy'
    }
)

model_tuned.summary()
# Out:
# Krok 4: Budowa i Kompilacja Modelu (Ulepszona Architektura)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ num_input (InputLayer)        │ (None, 3)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ text_input (InputLayer)       │ (None, 5000)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64)                │             256 │ num_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │         640,128 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 32)                │           2,080 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 32)                │               0 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 160)               │               0 │ dropout[0][0],             │
# │                               │                           │                 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 512)               │          82,432 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 512)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 256)               │         131,328 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 256)               │               0 │ dense_4[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_output (Dense)           │ (None, 6933)              │       1,781,781 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ district_output (Dense)       │ (None, 1940)              │         498,580 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ street_output (Dense)         │ (None, 28177)             │       7,241,489 │ dropout_3[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 10,378,074 (39.59 MB)
#  Trainable params: 10,378,074 (39.59 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\nKrok 5: Trening Modelu (Tuningowany)")

# Przygotowanie danych do treningu
X_train_list = [X_text_train, X_num_train]
y_train_dict = {'city_output': y_city_train, 'district_output': y_district_train, 'street_output': y_street_train}
X_val_list = [X_text_val, X_num_val]
y_val_dict = {'city_output': y_city_val, 'district_output': y_district_val, 'street_output': y_street_val}

# Definicja callbacków
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# Trening nowego, tuningowanego modelu
history_tuned = model_tuned.fit(
    X_train_list,
    y_train_dict,
    validation_data=(X_val_list, y_val_dict),
    epochs=25,
    batch_size=256,
    callbacks=[early_stopping, reduce_lr]
)

# Zapis nowego, tuningowanego modelu
model_tuned.save(os.path.join(ARTIFACTS_DIR, 'location_prediction_model_tuned.h5'))
print("Tuningowany model został wytrenowany i zapisany.")
# Out:
# Krok 5: Trening Modelu (Tuningowany)
# Epoch 1/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 168s 75ms/step - city_output_accuracy: 0.1847 - city_output_loss: 4.6840 - district_output_accuracy: 0.4920 - district_output_loss: 3.8683 - loss: 12.7686 - street_output_accuracy: 0.6620 - street_output_loss: 4.2163 - val_city_output_accuracy: 0.5341 - val_city_output_loss: 2.8096 - val_district_output_accuracy: 0.5125 - val_district_output_loss: 2.5418 - val_loss: 8.5918 - val_street_output_accuracy: 0.6713 - val_street_output_loss: 3.2403 - learning_rate: 5.0000e-04
# Epoch 2/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 161s 73ms/step - city_output_accuracy: 0.5385 - city_output_loss: 2.7483 - district_output_accuracy: 0.5111 - district_output_loss: 2.5357 - loss: 8.4988 - street_output_accuracy: 0.6702 - street_output_loss: 3.2147 - val_city_output_accuracy: 0.6193 - val_city_output_loss: 2.2975 - val_district_output_accuracy: 0.5407 - val_district_output_loss: 2.1312 - val_loss: 7.3704 - val_street_output_accuracy: 0.6714 - val_street_output_loss: 2.9417 - learning_rate: 5.0000e-04
# Epoch 3/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 168s 76ms/step - city_output_accuracy: 0.6001 - city_output_loss: 2.3515 - district_output_accuracy: 0.5296 - district_output_loss: 2.2015 - loss: 7.4777 - street_output_accuracy: 0.6695 - street_output_loss: 2.9247 - val_city_output_accuracy: 0.6469 - val_city_output_loss: 2.0935 - val_district_output_accuracy: 0.5648 - val_district_output_loss: 1.9296 - val_loss: 6.7898 - val_street_output_accuracy: 0.6720 - val_street_output_loss: 2.7668 - learning_rate: 5.0000e-04
# Epoch 4/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 169s 76ms/step - city_output_accuracy: 0.6266 - city_output_loss: 2.1561 - district_output_accuracy: 0.5463 - district_output_loss: 2.0225 - loss: 6.8966 - street_output_accuracy: 0.6699 - street_output_loss: 2.7180 - val_city_output_accuracy: 0.6613 - val_city_output_loss: 1.9708 - val_district_output_accuracy: 0.5809 - val_district_output_loss: 1.8041 - val_loss: 6.4228 - val_street_output_accuracy: 0.6740 - val_street_output_loss: 2.6479 - learning_rate: 5.0000e-04
# Epoch 5/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━
25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 243s 110ms/step - city_output_accuracy: 0.6944 - city_output_loss: 1.6010 - district_output_accuracy: 0.6199 - district_output_loss: 1.4712 - loss: 4.9732 - street_output_accuracy: 0.6834 - street_output_loss: 1.9009 - val_city_output_accuracy: 0.7207 - val_city_output_loss: 1.5952 - val_district_output_accuracy: 0.6513 - val_district_output_loss: 1.3903 - val_loss: 5.1712 - val_street_output_accuracy: 0.6983 - val_street_output_loss: 2.1858 - learning_rate: 5.0000e-04
# Epoch 24/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 245s 111ms/step - city_output_accuracy: 0.6950 - city_output_loss: 1.5971 - district_output_accuracy: 0.6216 - district_output_loss: 1.4630 - loss: 4.9526 - street_output_accuracy: 0.6828 - street_output_loss: 1.8925 - val_city_output_accuracy: 0.7215 - val_city_output_loss: 1.5929 - val_district_output_accuracy: 0.6516 - val_district_output_loss: 1.3843 - val_loss: 5.1595 - val_street_output_accuracy: 0.6993 - val_street_output_loss: 2.1823 - learning_rate: 5.0000e-04
# Epoch 25/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 255s 115ms/step - city_output_accuracy: 0.6961 - city_output_loss: 1.5862 - district_output_accuracy: 0.6226 - district_output_loss: 1.4606 - loss: 4.9279 - street_output_accuracy: 0.6830 - street_output_loss: 1.8811 - val_city_output_accuracy: 0.7222 - val_city_output_loss: 1.5882 - val_district_output_accuracy: 0.6537 - val_district_output_loss: 1.3812 - val_loss: 5.1498 - val_street_output_accuracy: 0.7004 - val_street_output_loss: 2.1804 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Tuningowany model został wytrenowany i zapisany.

# %%
import gc
from tqdm.notebook import tqdm

print("\nKrok 6: Predykcja i Zastosowanie Logiki Hierarchicznej (w Pętli, model Tuned)")

# Używamy tej samej ramki danych 'df', która była użyta do treningu
n_samples = df.shape[0]
chunk_size = 100000

# Listy do przechowywania wyników
all_pred_city = []
all_pred_district = []
all_pred_street = []

print(f"Rozpoczynam predykcję na {n_samples} próbkach w kawałkach po {chunk_size}...")

for i in tqdm(range(0, n_samples, chunk_size)):
    print(f"  Przetwarzanie od {i} do {i + chunk_size}...")
    
    chunk_text = X_text[i:i + chunk_size]
    chunk_num = X_num[i:i + chunk_size]
    chunk_list = [chunk_text, chunk_num]
    
    # ZMIANA: Używamy poprawnej nazwy modelu: 'model_tuned'
    pred_city_chunk, pred_district_chunk, pred_street_chunk = model_tuned.predict(chunk_list, batch_size=512, verbose=0)
    
    all_pred_city.append(pred_city_chunk)
    all_pred_district.append(pred_district_chunk)
    all_pred_street.append(pred_street_chunk)
    
    del pred_city_chunk, pred_district_chunk, pred_street_chunk
    gc.collect()

print("Łączenie wyników predykcji...")
pred_city_proba = np.vstack(all_pred_city)
pred_district_proba = np.vstack(all_pred_district)
pred_street_proba = np.vstack(all_pred_street)

print("Dekodowanie predykcji z logiką hierarchiczną...")
predicted_city_ids = []
predicted_district_ids = []
predicted_street_ids = []

for i in range(len(df)):
    city_pred_index = np.argmax(pred_city_proba[i])
    city_id = inv_city_id_map.get(city_pred_index, 0)
    
    valid_districts_for_city = city_to_districts.get(city_id, [])
    district_pred_index = np.argmax(pred_district_proba[i]) 
    if valid_districts_for_city:
        district_mask = np.zeros_like(pred_district_proba[i])
        valid_indices = [district_id_map.get(d_id) for d_id in valid_districts_for_city if district_id_map.get(d_id) is not None]
        if valid_indices:
            district_mask[valid_indices] = 1
            if np.sum(district_mask) > 0:
                district_pred_index = np.argmax(pred_district_proba[i] * district_mask)
    
    district_id = inv_district_id_map.get(district_pred_index, 0)
    
    valid_streets_for_district = district_to_streets.get(district_id, [])
    street_pred_index = np.argmax(pred_street_proba[i]) 
    if valid_streets_for_district:
        street_mask = np.zeros_like(pred_street_proba[i])
        valid_indices = [street_id_map.get(s_id) for s_id in valid_streets_for_district if street_id_map.get(s_id) is not None]
        if valid_indices:
            street_mask[valid_indices] = 1
            if np.sum(street_mask) > 0:
                street_pred_index = np.argmax(pred_street_proba[i] * street_mask)

    street_id = inv_street_id_map.get(street_pred_index, 0)
    
    predicted_city_ids.append(city_id)
    predicted_district_ids.append(district_id)
    predicted_street_ids.append(street_id)

df['predicted_city_id'] = predicted_city_ids
df['predicted_district_id'] = predicted_district_ids
df['predicted_street_id'] = predicted_street_ids

print("Zakończono predykcję z logiką hierarchiczną.")
# Out:
# Krok 6: Predykcja i Zastosowanie Logiki Hierarchicznej (w Pętli, model Tuned)
# Rozpoczynam predykcję na 709104 próbkach w kawałkach po 100000...
#   0%|          | 0/8 [00:00<?, ?it/s]
#   Przetwarzanie od 0 do 100000...
#   Przetwarzanie od 100000 do 200000...
#   Przetwarzanie od 200000 do 300000...
#   Przetwarzanie od 300000 do 400000...
#   Przetwarzanie od 400000 do 500000...
#   Przetwarzanie od 500000 do 600000...
#   Przetwarzanie od 600000 do 700000...
#   Przetwarzanie od 700000 do 800000...
# Łączenie wyników predykcji...
# Dekodowanie predykcji z logiką hierarchiczną...
# Zakończono predykcję z logiką hierarchiczną.

# %%
print("Odtwarzam ramkę danych 'df_original'...")

# Ponownie wczytujemy dane w ten sam sposób, co w komórce 3,
# aby mieć pewność, że df_original ma identyczną strukturę jak df przed filtrowaniem.

# Szybki odczyt pierwszego wiersza, żeby znaleźć ostatnią kolumnę
try:
    first_row = pd.read_csv('saleflats_2024_dateAdded_polska.csv', sep=',', header=None, nrows=1, on_bad_lines='skip')
    last_col_index = first_row.shape[1] - 1
except:
    last_col_index = 64 # Wartość awaryjna

COLS_TO_EXTRACT = {
    3: 'Title', 4: 'Description', 5: 'Area', 6: 'Price',
    9: 'NumberOfRooms', 14: 'Floor', 15: 'Floors', 16: 'BuiltYear',
    last_col_index: 'locationPath'
}

all_offers_df_orig = []
FILES = ['saleflats_2024_dateAdded_polska.csv', 'saleflats_2024_newestDate_polska.csv']
for filepath in FILES:
    try:
        df_chunk = pd.read_csv(
            filepath, sep=',', header=None, on_bad_lines='skip',
            usecols=list(COLS_TO_EXTRACT.keys()), low_memory=False, dtype=str, encoding='utf-8'
        )
        df_chunk.rename(columns=COLS_TO_EXTRACT, inplace=True)
        all_offers_df_orig.append(df_chunk)
    except Exception:
        pass # Ignorujemy błędy, bo już raz wczytaliśmy

df_original = pd.concat(all_offers_df_orig, ignore_index=True)
df_original.drop_duplicates(subset=['Title', 'Description', 'locationPath'], keep='first', inplace=True)

print("'df_original' został pomyślnie odtworzony.")
# Out:
# Odtwarzam ramkę danych 'df_original'...
# 'df_original' został pomyślnie odtworzony.

# %%
print("\nKrok 7: Generowanie i Zapis Wyników")

def create_loc_string(row):
    city = id_to_name.get(row['predicted_city_id'], "?")
    district = id_to_name.get(row['predicted_district_id'], "?")
    street = id_to_name.get(row['predicted_street_id'], "?")
    
    # Zwracamy "?" dla nieokreślonych (ID=0)
    if row['predicted_district_id'] == 0: district = '?'
    if row['predicted_street_id'] == 0: street = '?'
        
    return f"{city} > {district} > {street}"

df['Predict_Loc'] = df.apply(create_loc_string, axis=1)

# Przygotowujemy do scalenia z oryginalnym DF
df_to_merge = df[['Title', 'Description', 'Predict_Loc']].copy()
# Tworzymy unikalny klucz do merge'owania, żeby uniknąć problemów
df_to_merge['merge_key'] = df_to_merge['Title'].fillna('') + df_to_merge['Description'].fillna('')
df_original['merge_key'] = df_original['Title'].fillna('') + df_original['Description'].fillna('')

# Scalenie
df_final = pd.merge(df_original, df_to_merge[['merge_key', 'Predict_Loc']], on='merge_key', how='left')
df_final.drop(columns=['merge_key'], inplace=True, errors='ignore')
df_final.drop_duplicates(subset=['Title', 'Description'], inplace=True)
df_final['Predict_Loc'].fillna('Brak predykcji', inplace=True)

# Zapis do pliku CSV
OUTPUT_FILE = 'Location_Polska.csv'
df_final.to_csv(OUTPUT_FILE, index=False, sep=';', encoding='utf-8-sig')
print(f"Wyniki zostały zapisane do pliku: {OUTPUT_FILE}")
# Out:
# Krok 7: Generowanie i Zapis Wyników
# Wyniki zostały zapisane do pliku: Location_Polska.csv

# %%
print("\nPrzykładowe 20 wierszy z wynikami:")

predicted_df = df_final[df_final['Predict_Loc'] != 'Brak predykcji']
if len(predicted_df) > 20:
    sample = predicted_df.sample(20)
else:
    sample = predicted_df.head(20)

display_cols = ['Title', 'locationPath', 'Predict_Loc']
sample_display = sample[display_cols]

def highlight_col(s):
    return ['background-color: #ffff99' if c == 'Predict_Loc' else '' for c in s.index]

styled_sample = sample_display.style.apply(highlight_col, axis=1)

display(styled_sample)
# Out:
# Przykładowe 20 wierszy z wynikami:
# <style type="text/css">
# #T_01f31_row0_col2, #T_01f31_row1_col2, #T_01f31_row2_col2, #T_01f31_row3_col2, #T_01f31_row4_col2, #T_01f31_row5_col2, #T_01f31_row6_col2, #T_01f31_row7_col2, #T_01f31_row8_col2, #T_01f31_row9_col2, #T_01f31_row10_col2, #T_01f31_row11_col2, #T_01f31_row12_col2, #T_01f31_row13_col2, #T_01f31_row14_col2, #T_01f31_row15_col2, #T_01f31_row16_col2, #T_01f31_row17_col2, #T_01f31_row18_col2, #T_01f31_row19_col2 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_01f31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f31_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_01f31_level0_col1" class="col_heading level0 col1" >locationPath</th>
#       <th id="T_01f31_level0_col2" class="col_heading level0 col2" >Predict_Loc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f31_level0_row0" class="row_heading level0 row0" >168729</th>
#       <td id="T_01f31_row0_col0" class="data row0 col0" >Mieszkanie pow.105,65m², Szczecin Centrum</td>
#       <td id="T_01f31_row0_col1" class="data row0 col1" >5,0,0,396,0,105741,488335</td>
#       <td id="T_01f31_row0_col2" class="data row0 col2" >Szczecin > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row1" class="row_heading level0 row1" >494498</th>
#       <td id="T_01f31_row1_col0" class="data row1 col0" >2 pokoje, widna kuchnia, ul. Lecha</td>
#       <td id="T_01f31_row1_col1" class="data row1 col1" >1,0,0,381,0,69683,369644</td>
#       <td id="T_01f31_row1_col2" class="data row1 col2" >Kielce > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row2" class="row_heading level0 row2" >41890</th>
#       <td id="T_01f31_row2_col0" class="data row2 col0" >Mieszkanie, Łódź, Górna, 45 m²</td>
#       <td id="T_01f31_row2_col1" class="data row2 col1" >15,0,0,378,0,0,0</td>
#       <td id="T_01f31_row2_col2" class="data row2 col2" >Łódź > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row3" class="row_heading level0 row3" >448208</th>
#       <td id="T_01f31_row3_col0" class="data row3 col0" >Nowoczesne mieszkanie 2 pokoje, loggia</td>
#       <td id="T_01f31_row3_col1" class="data row3 col1" >15,0,0,378,3265,65196,0</td>
#       <td id="T_01f31_row3_col2" class="data row3 col2" >Łódź > Polesie > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row4" class="row_heading level0 row4" >421258</th>
#       <td id="T_01f31_row4_col0" class="data row4 col0" >M na Krauthofera z miejscem post. Łazarz</td>
#       <td id="T_01f31_row4_col1" class="data row4 col1" >12,0,0,370,3260,67828,458351</td>
#       <td id="T_01f31_row4_col2" class="data row4 col2" >Wrocław > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row5" class="row_heading level0 row5" >286868</th>
#       <td id="T_01f31_row5_col0" class="data row5 col0" >Mieszkanie dwupokojowe, parter</td>
#       <td id="T_01f31_row5_col1" class="data row5 col1" >12,297,0,24662,0,0,0</td>
#       <td id="T_01f31_row5_col2" class="data row5 col2" >Szczecin > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row6" class="row_heading level0 row6" >430255</th>
#       <td id="T_01f31_row6_col0" class="data row6 col0" >Mieszkanie, Wrocław, Krzyki, 43 m²</td>
#       <td id="T_01f31_row6_col1" class="data row6 col1" >16,0,0,366,3272,84583,0</td>
#       <td id="T_01f31_row6_col2" class="data row6 col2" >Wrocław > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row7" class="row_heading level0 row7" >765871</th>
#       <td id="T_01f31_row7_col0" class="data row7 col0" >Mieszkanie czteropokojowe na sprzedaż</td>
#       <td id="T_01f31_row7_col1" class="data row7 col1" >10,0,0,375,0,73447,295099</td>
#       <td id="T_01f31_row7_col2" class="data row7 col2" >Toruń > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row8" class="row_heading level0 row8" >652889</th>
#       <td id="T_01f31_row8_col0" class="data row8 col0" >Styl lekki, nieprzytłaczający. Wszystko nowe.</td>
#       <td id="T_01f31_row8_col1" class="data row8 col1" >14,0,0,337,3275,105539,454562</td>
#       <td id="T_01f31_row8_col2" class="data row8 col2" >Kraków > Podgórze > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row9" class="row_heading level0 row9" >423353</th>
#       <td id="T_01f31_row9_col0" class="data row9 col0" >Mieszkanie Kraków</td>
#       <td id="T_01f31_row9_col1" class="data row9 col1" >14,0,0,337,3275,66071,354582</td>
#       <td id="T_01f31_row9_col2" class="data row9 col2" >Kraków > Wola duchacka > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row10" class="row_heading level0 row10" >801438</th>
#       <td id="T_01f31_row10_col0" class="data row10 col0" >Nowe mieszkanie Powstańców Śląskich, ul. Sudecka 94</td>
#       <td id="T_01f31_row10_col1" class="data row10 col1" >16,0,0,366,3272,104555,493160</td>
#       <td id="T_01f31_row10_col2" class="data row10 col2" >Wrocław > Krzyki > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row11" class="row_heading level0 row11" >522478</th>
#       <td id="T_01f31_row11_col0" class="data row11 col0" >Mieszkanie, Kraków, Krowodrza, 67 m²</td>
#       <td id="T_01f31_row11_col1" class="data row11 col1" >14,0,0,337,3257,100392,0</td>
#       <td id="T_01f31_row11_col2" class="data row11 col2" >Kraków > Krowodrza > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row12" class="row_heading level0 row12" >91472</th>
#       <td id="T_01f31_row12_col0" class="data row12 col0" >Do wprowadzenia | 36m2 | Jeżyce ul. Zwierzyniecka</td>
#       <td id="T_01f31_row12_col1" class="data row12 col1" >12,0,0,370,3252,76294,0</td>
#       <td id="T_01f31_row12_col2" class="data row12 col2" >Poznań > Jeżyce > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row13" class="row_heading level0 row13" >32801</th>
#       <td id="T_01f31_row13_col0" class="data row13 col0" >Mieszkanie, Warszawa, Targówek, 32 m²</td>
#       <td id="T_01f31_row13_col1" class="data row13 col1" >9,0,0,368,0,0,0</td>
#       <td id="T_01f31_row13_col2" class="data row13 col2" >Warszawa > Targówek > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row14" class="row_heading level0 row14" >264570</th>
#       <td id="T_01f31_row14_col0" class="data row14 col0" >Sprzedam mieszkanie 82 m²</td>
#       <td id="T_01f31_row14_col1" class="data row14 col1" >1,42,0,22821,0,0,0</td>
#       <td id="T_01f31_row14_col2" class="data row14 col2" >Chotyniec > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row15" class="row_heading level0 row15" >104233</th>
#       <td id="T_01f31_row15_col0" class="data row15 col0" >Mieszkanie Białystok, ul. Bema</td>
#       <td id="T_01f31_row15_col1" class="data row15 col1" >3,0,0,352,0,72927,324587</td>
#       <td id="T_01f31_row15_col2" class="data row15 col2" >Białystok > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row16" class="row_heading level0 row16" >53662</th>
#       <td id="T_01f31_row16_col0" class="data row16 col0" >Mieszkanie, Gdynia, Cisowa, 33 m²</td>
#       <td id="T_01f31_row16_col1" class="data row16 col1" >11,0,0,388,0,0,0</td>
#       <td id="T_01f31_row16_col2" class="data row16 col2" >Gdynia > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row17" class="row_heading level0 row17" >379692</th>
#       <td id="T_01f31_row17_col0" class="data row17 col0" >3-pokojowe mieszkanie na sprzedaż</td>
#       <td id="T_01f31_row17_col1" class="data row17 col1" >8,142,0,30009,0,0,384672</td>
#       <td id="T_01f31_row17_col2" class="data row17 col2" >Pabianice > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row18" class="row_heading level0 row18" >665048</th>
#       <td id="T_01f31_row18_col0" class="data row18 col0" >3M| Wysoki standard wykończenia| Ogród 140 m2| HIT</td>
#       <td id="T_01f31_row18_col1" class="data row18 col1" >16,0,0,366,3273,88749,0</td>
#       <td id="T_01f31_row18_col2" class="data row18 col2" >Wrocław > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_01f31_level0_row19" class="row_heading level0 row19" >619050</th>
#       <td id="T_01f31_row19_col0" class="data row19 col0" >Komfortowe mi
