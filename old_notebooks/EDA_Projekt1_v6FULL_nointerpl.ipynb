# %% [markdown]
# # PROJEKT MODELU REGRESYJNEGO PRZEWIDYWANIA CEN MIESZKAŃ NA PODSTAWIE #

# %% [markdown]
# # ALGORYTMU LGBM #

# %% [markdown]
#   ## KWIECIEŃ 2025 ##

# %%
import pandas as pd
import mlflow
from pycaret.datasets import get_data
from pycaret.regression import setup, pull, compare_models, plot_model, load_model
import pymysql
from sqlalchemy import create_engine
import numpy as np
from scipy.stats import skewnorm
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import parallel_backend

# %%
# tą komórkę uruchom jeżeli bazie bierzesz np. z DBeaver
# username = 'root'
# password = '1234'
# host = '127.0.0.1'
# port = 3306  
# database = 'projekt1'
# engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')

# df = pd.read_sql("SELECT * FROM saleflats", con=engine)

# engine.dispose()

# %%
MLFLOW_EXPERIMENT_NAME = 'Investoro_Ceny'
MLFLOW_TAGS = {'data': 'Investoro_ceny', 'library': 'pycaret'}

mlflow.set_tracking_uri("http://localhost:5000")

# %%
# tę komórkę uruchom jeśli czerpiesz dane z pliku .csv
df = pd.read_csv('sale_2024_0.csv', sep=',')

# %%
df
# Out:
#           SaleId  OriginalId  PortalId  \
# 0             88         NaN        14
# 1             99         NaN        19
# 2            115         NaN         3
# 3            140         NaN        14
# 4            145         NaN         3
# ...          ...         ...       ...
# 1133882  4418401         NaN         2
# 1133883  4418402         NaN         2
# 1133884  4418404         NaN         2
# 1133885  4418405         NaN         2
# 1133886  4418406         NaN         2
#
#                                                      Title  \
# 0                      Mieszkanie trzypokojowe na sprzedaż
# 1        Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2            Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                      Mieszkanie trzypokojowe na sprzedaż
# 4                       3 Pokoje- 48M2-Osiedle Dziesięciny
# ...                                                    ...
# 1133882  Mieszkanie na sprzedaż - 59 m² - 3 pokoje Grod...
# 1133883  Mieszkanie na sprzedaż - 41 m² - 2 pokoje Grod...
# 1133884  Mieszkanie na sprzedaż - 49 m² - 3 pokoje Grod...
# 1133885  Mieszkanie na sprzedaż - 49 m² - 3 pokoje Grod...
# 1133886  Mieszkanie na sprzedaż - 39 m² - 2 pokoje Grod...
#
#                                                Description   Area     Price  \
# 0        Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1        Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2        SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3        ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4        Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
# ...                                                    ...    ...       ...
# 1133882  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  59.99       NaN
# 1133883  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  41.23       NaN
# 1133884  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  49.09       NaN
# 1133885  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  49.48       NaN
# 1133886  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  39.36       NaN
#
#          OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0               NaN                       NaN            NaN  ...      NaN
# 1               NaN                       NaN            NaN  ...      NaN
# 2               NaN                       NaN            NaN  ...      NaN
# 3               NaN                       NaN            NaN  ...      NaN
# 4               NaN                       NaN            NaN  ...      NaN
# ...             ...                       ...            ...  ...      ...
# 1133882         NaN                       NaN            NaN  ...      NaN
# 1133883         NaN                       NaN            NaN  ...      NaN
# 1133884         NaN                       NaN            NaN  ...      NaN
# 1133885         NaN                       NaN            NaN  ...      NaN
# 1133886         NaN                       NaN            NaN  ...      NaN
#
#                                                   Location  VoivodeshipNumber  \
# 0                             Podlaskie, Białystok, Bojary               20.0
# 1                           Podlaskie, Białystok, Antoniuk               20.0
# 2                           Podlaskie, Białystok, Bagnówka               20.0
# 3        Podlaskie, Białystok, Ul. Józefa Karola Puchal...               20.0
# 4                    Podlaskie, Białystok, Ul. Dziesięciny               20.0
# ...                                                    ...                ...
# 1133882  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133883  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133884  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133885  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133886  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
#
#         CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0               61.0             1.0        1.0     922490.0              NaN
# 1               61.0             1.0        1.0     922426.0              NaN
# 2               61.0             1.0        1.0     922461.0              NaN
# 3               61.0             1.0        1.0     922410.0              NaN
# 4               61.0             1.0        1.0     922410.0              NaN
# ...              ...             ...        ...          ...              ...
# 1133882          5.0             4.0        5.0       2594.0              NaN
# 1133883          5.0             4.0        5.0       2594.0              NaN
# 1133884          5.0             4.0        5.0       2594.0              NaN
# 1133885          5.0             4.0        5.0       2594.0              NaN
# 1133886          5.0             4.0        5.0       2594.0              NaN
#
#          StreetNumber                                   EncryptedId
# 0                 NaN                      02TgImo1wm-Ra4zUQxoPBw==
# 1                 NaN                      D-NUdVbtN3_kIW7ExgXkvA==
# 2                 NaN                      lmBSU1XiXLSLOq1yKSe2kA==
# 3             43141.0                      HWachf5gb6Vq-sFYH4YWnA==
# 4              4656.0                      AWsmt4ZY0X7lNv-6fSCn9Q==
# ...               ...                                           ...
# 1133882       24885.0  Ogpi4Jwj8KWDyT0rM_vFYftiMRU9ErLfA6XOKdBw9jY=
# 1133883       24885.0  Ogpi4Jwj8KWDyT0rM_vFYa7D8z7yjun2jGP_aZIReN8=
# 1133884       24885.0  Ogpi4Jwj8KWDyT0rM_vFYf9eM73_U8S05NBjfLiez6E=
# 1133885       24885.0  Ogpi4Jwj8KWDyT0rM_vFYRXVZdKE7iJxxFPu0Bq0ikc=
# 1133886       24885.0  Ogpi4Jwj8KWDyT0rM_vFYVxslNBbpBprsR-39HjnMC8=
#
# [1133887 rows x 51 columns]

# %%
df.head(10)
# Out:
#    SaleId  OriginalId  PortalId  \
# 0      88         NaN        14
# 1      99         NaN        19
# 2     115         NaN         3
# 3     140         NaN        14
# 4     145         NaN         3
# 5     159         NaN         3
# 6     165         NaN         3
# 7     173         NaN         3
# 8     179         NaN         3
# 9     189         NaN         4
#
#                                                Title  \
# 0                Mieszkanie trzypokojowe na sprzedaż
# 1  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2      Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                Mieszkanie trzypokojowe na sprzedaż
# 4                 3 Pokoje- 48M2-Osiedle Dziesięciny
# 5                       Mieszkanie, 87 m², Białystok
# 6               Przytulne mieszkanie blisko centrum!
# 7  **Jasne, 2 Pokojowe Mieszkanie, Widok Na Miasto**
# 8  *Bezpośrednio*PIĘKNY APARTAMENT w Centrum Lipo...
# 9                  2-pokojowe mieszkanie na sprzedaż
#
#                                          Description   Area     Price  \
# 0  Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1  Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2  SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3  ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4  Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
# 5  Przestronne, jasne mieszkanie na zamkniętym os...  87.00  779000.0
# 6  Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.10  359000.0
# 7  Mieszkanie o powierzchni 35,7 m2 Ul. Jarzębino...  35.70  380000.0
# 8  ***REZERWACJA ***WYJĄTKOWA PROPOZYCJA DLA WYMA...  39.40  559000.0
# 9  Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.20  354000.0
#
#    OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0         NaN                       NaN            NaN  ...      NaN
# 1         NaN                       NaN            NaN  ...      NaN
# 2         NaN                       NaN            NaN  ...      NaN
# 3         NaN                       NaN            NaN  ...      NaN
# 4         NaN                       NaN            NaN  ...      NaN
# 5         NaN                       NaN            NaN  ...      NaN
# 6         NaN                       NaN            NaN  ...      NaN
# 7         NaN                       NaN            NaN  ...      NaN
# 8         NaN                       NaN            NaN  ...      NaN
# 9         NaN                       NaN            NaN  ...      NaN
#
#                                             Location  VoivodeshipNumber  \
# 0                       Podlaskie, Białystok, Bojary               20.0
# 1                     Podlaskie, Białystok, Antoniuk               20.0
# 2                     Podlaskie, Białystok, Bagnówka               20.0
# 3  Podlaskie, Białystok, Ul. Józefa Karola Puchal...               20.0
# 4              Podlaskie, Białystok, Ul. Dziesięciny               20.0
# 5        Podlaskie, Białystok, Ul. Adama Mickiewicza               20.0
# 6                       Podlaskie, Białystok, Bojary               20.0
# 7                               Podlaskie, Białystok               20.0
# 8        Podlaskie, Białystok, Ul. Adama Mickiewicza               20.0
# 9                   Podlaskie, Białystok, Ul. Piasta               20.0
#
#   CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0         61.0             1.0        1.0     922490.0              NaN
# 1         61.0             1.0        1.0     922426.0              NaN
# 2         61.0             1.0        1.0     922461.0              NaN
# 3         61.0             1.0        1.0     922410.0              NaN
# 4         61.0             1.0        1.0     922410.0              NaN
# 5         61.0             1.0        1.0     922410.0              NaN
# 6         61.0             1.0        1.0     922490.0              NaN
# 7         61.0             1.0        1.0     922410.0              NaN
# 8         61.0             1.0        1.0     922410.0              NaN
# 9         61.0             1.0        1.0     922410.0              NaN
#
#    StreetNumber               EncryptedId
# 0           NaN  02TgImo1wm-Ra4zUQxoPBw==
# 1           NaN  D-NUdVbtN3_kIW7ExgXkvA==
# 2           NaN  lmBSU1XiXLSLOq1yKSe2kA==
# 3       43141.0  HWachf5gb6Vq-sFYH4YWnA==
# 4        4656.0  AWsmt4ZY0X7lNv-6fSCn9Q==
# 5       12740.0  SEPz6jrRB1vuWWYOn99h7g==
# 6       16041.0  Gt5-LUpJNg-wBgBd8-hxGQ==
# 7        7290.0  a5iP5JQyibefTTLgBRU8oA==
# 8       12740.0  C_F7Bxl4hKQ2a2votBqs-g==
# 9       16041.0  XylelQthYlIn_7k8orxBfQ==
#
# [10 rows x 51 columns]

# %%
df.sample(10)
# Out:
#           SaleId  OriginalId  PortalId  \
# 1068890  4300145         NaN         3
# 190803   1389176         NaN        18
# 1034843  4231734         NaN        38
# 1123561  4403078         NaN        19
# 907355   3913459         NaN         3
# 1047467  4256851         NaN         4
# 153345   1085583         NaN         3
# 936657   3991028         NaN         3
# 780468   3576637         NaN        18
# 216331   1572695         NaN         3
#
#                                                      Title  \
# 1068890                       Ruczaj 2 pokojowe ul. Piltza
# 190803   2-pokojowe mieszkanie do wykończenia w supercenie
# 1034843                              Mieszkanie 2 pokojowe
# 1123561                             Mieszkanie w kamienicy
# 907355                             Miękinia / bez prowizji
# 1047467                  3-pokojowe mieszkanie na sprzedaż
# 153345   GARAŻ za 0PLN oferta na DNI otwarte 26+27.4_tr...
# 936657         2 pokoje + KOmórka + PARKING_zobacz na żywo
# 780468   Mieszkanie 3-pokojowe o pow. 46m2, parter, osi...
# 216331    M-4 centrum*po generalnym remoncie* klimatyzacja
#
#                                                Description   Area     Price  \
# 1068890  Na sprzedaż oferuję dwupokojowe mieszkanie o p...  45.66  725994.0
# 190803   Opiekun oferty Magdalena Masłowska tel. 602101...  37.75  522600.0
# 1034843  Oferta aktualna - możliwość umówienia bezpiecz...  41.00  585724.0
# 1123561  Oferta sprzedaży wyjątkowego mieszkania w kami...  96.10  620000.0
# 907355   | Wszystkie mieszkania w budynkach wielorodzin...  58.00  482000.0
# 1047467  Sprzedam rozkładowe mieszkanie 3-pokojowe w ce...  48.00  385000.0
# 153345   DRZWI OTWARTE 25-27.04 w g. 9-18 - zarezerwuj ...  39.27  478160.0
# 936657   Zakup bezpośrednio od dewelopera – brak prowiz...  37.00  415000.0
# 780468   Na SPRZEDAŻ 3 - POKOJOWE MIESZKANIE, pow. 46 m...  45.94  349000.0
# 216331   *Oferta skierowana dla klientów szukających mi...  56.00  355000.0
#
#          OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 1068890    794760.0                 961666.67            NaN  ...      NaN
# 190803          NaN                       NaN            NaN  ...      NaN
# 1034843         NaN                       NaN            NaN  ...      NaN
# 1123561         NaN                       NaN            NaN  ...      NaN
# 907355          NaN                       NaN            NaN  ...      NaN
# 1047467    355000.0                 448797.90            NaN  ...      NaN
# 153345          NaN                       NaN            NaN  ...      NaN
# 936657     499000.0                1130753.33       396100.0  ...      NaN
# 780468          NaN                       NaN            NaN  ...      NaN
# 216331          NaN                       NaN            NaN  ...      NaN
#
#                                                   Location  VoivodeshipNumber  \
# 1068890  Małopolskie, Kraków, Kraków-podgórze, Kobierzy...               12.0
# 190803   Dolnośląskie, Wrocław, Wrocław-krzyki, Ul. Gazowa                2.0
# 1034843             Kujawsko-pomorskie, Bydgoszcz, Centrum                4.0
# 1123561                      Dolnośląskie, Jaworski, Jawor                2.0
# 907355                     Dolnośląskie, Średzki, Miękinia                2.0
# 1047467                           Łódzkie, Łowicki, Łowicz               10.0
# 153345   Wielkopolskie, Poznań, Poznań-nowe Miasto, Rataje               30.0
# 936657                                   Pomorskie, Gdańsk               22.0
# 780468                         Wielkopolskie, Pilski, Piła               30.0
# 216331                                       Śląskie, Żory               24.0
#
#         CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 1068890         61.0             4.0        9.0     951066.0              NaN
# 190803          64.0             3.0        9.0     986544.0              NaN
# 1034843         61.0             1.0        1.0    1067611.0              NaN
# 1123561          5.0             1.0        1.0     954120.0              NaN
# 907355          18.0             3.0        4.0          NaN              NaN
# 1047467          5.0             1.0        1.0     977031.0              NaN
# 153345          64.0             4.0        9.0     970081.0              NaN
# 936657          61.0             NaN        NaN          NaN              NaN
# 780468          19.0             1.0        1.0     966530.0              NaN
# 216331          79.0             1.0        1.0     945746.0              NaN
#
#          StreetNumber                                   EncryptedId
# 1068890       33381.0  98wID5JhDHcGQKizQYpUL2OX94vBVnrWznFwIq8TfgE=
# 190803         5403.0  wrRGOed4jrzHIdHLWxbSNGjzzGldvCsejqBZGAbYChc=
# 1034843           NaN  Ez0fqOp00V4QUZ8AvXPFfFS1vaJF4VCGA1NSnEfSywA=
# 1123561           NaN  qVd4JAXOCEokaiXQkKrMB6XA85RWXE2DCF5KBh3a4Js=
# 907355            NaN  mVvkNxyNTrY4LV8cqYwlvwAQzbPZDnsbuGvFGXpz1mg=
# 1047467           NaN  qNvpnwql2JMbwqzViT4s-NPMqpHF6X1wDc4eEYzDo2s=
# 153345            NaN  bP45mmWcL6tje9UN0PY0Xsc0fBXCdCR2219soBArV2g=
# 936657            NaN  RrAP9O0O2Jfa6BD9SUlYHo_bCM8lJ876moazm9h2OAo=
# 780468            NaN  kX_ZYmp6Ui7g0uvwd7awRVsBl2chVeLJOWFXdp_Irxg=
# 216331            NaN  ON3hWexmvVURa0ExjPgKZZ3inEDRqPi2MpqZO5i4jCY=
#
# [10 rows x 51 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of           SaleId  OriginalId  PortalId  \
# 0             88         NaN        14
# 1             99         NaN        19
# 2            115         NaN         3
# 3            140         NaN        14
# 4            145         NaN         3
# ...          ...         ...       ...
# 1133882  4418401         NaN         2
# 1133883  4418402         NaN         2
# 1133884  4418404         NaN         2
# 1133885  4418405         NaN         2
# 1133886  4418406         NaN         2
#
#                                                      Title  \
# 0                      Mieszkanie trzypokojowe na sprzedaż
# 1        Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2            Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                      Mieszkanie trzypokojowe na sprzedaż
# 4                       3 Pokoje- 48M2-Osiedle Dziesięciny
# ...                                                    ...
# 1133882  Mieszkanie na sprzedaż - 59 m² - 3 pokoje Grod...
# 1133883  Mieszkanie na sprzedaż - 41 m² - 2 pokoje Grod...
# 1133884  Mieszkanie na sprzedaż - 49 m² - 3 pokoje Grod...
# 1133885  Mieszkanie na sprzedaż - 49 m² - 3 pokoje Grod...
# 1133886  Mieszkanie na sprzedaż - 39 m² - 2 pokoje Grod...
#
#                                                Description   Area     Price  \
# 0        Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1        Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2        SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3        ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4        Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
# ...                                                    ...    ...       ...
# 1133882  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  59.99       NaN
# 1133883  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  41.23       NaN
# 1133884  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  49.09       NaN
# 1133885  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  49.48       NaN
# 1133886  Poznaj naszą inwestycję NA WSPÓLNEJ zlokalizow...  39.36       NaN
#
#          OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0               NaN                       NaN            NaN  ...      NaN
# 1               NaN                       NaN            NaN  ...      NaN
# 2               NaN                       NaN            NaN  ...      NaN
# 3               NaN                       NaN            NaN  ...      NaN
# 4               NaN                       NaN            NaN  ...      NaN
# ...             ...                       ...            ...  ...      ...
# 1133882         NaN                       NaN            NaN  ...      NaN
# 1133883         NaN                       NaN            NaN  ...      NaN
# 1133884         NaN                       NaN            NaN  ...      NaN
# 1133885         NaN                       NaN            NaN  ...      NaN
# 1133886         NaN                       NaN            NaN  ...      NaN
#
#                                                   Location  VoivodeshipNumber  \
# 0                             Podlaskie, Białystok, Bojary               20.0
# 1                           Podlaskie, Białystok, Antoniuk               20.0
# 2                           Podlaskie, Białystok, Bagnówka               20.0
# 3        Podlaskie, Białystok, Ul. Józefa Karola Puchal...               20.0
# 4                    Podlaskie, Białystok, Ul. Dziesięciny               20.0
# ...                                                    ...                ...
# 1133882  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133883  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133884  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133885  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
# 1133886  Mazowieckie, Grodziski, Grodzisk Mazowiecki, W...               14.0
#
#         CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0               61.0             1.0        1.0     922490.0              NaN
# 1               61.0             1.0        1.0     922426.0              NaN
# 2               61.0             1.0        1.0     922461.0              NaN
# 3               61.0             1.0        1.0     922410.0              NaN
# 4               61.0             1.0        1.0     922410.0              NaN
# ...              ...             ...        ...          ...              ...
# 1133882          5.0             4.0        5.0       2594.0              NaN
# 1133883          5.0             4.0        5.0       2594.0              NaN
# 1133884          5.0             4.0        5.0       2594.0              NaN
# 1133885          5.0             4.0        5.0       2594.0              NaN
# 1133886          5.0             4.0        5.0       2594.0              NaN
#
#          StreetNumber                                   EncryptedId
# 0                 NaN                      02TgImo1wm-Ra4zUQxoPBw==
# 1                 NaN                      D-NUdVbtN3_kIW7ExgXkvA==
# 2                 NaN                      lmBSU1XiXLSLOq1yKSe2kA==
# 3             43141.0                      HWachf5gb6Vq-sFYH4YWnA==
# 4              4656.0                      AWsmt4ZY0X7lNv-6fSCn9Q==
# ...               ...                                           ...
# 1133882       24885.0  Ogpi4Jwj8KWDyT0rM_vFYftiMRU9ErLfA6XOKdBw9jY=
# 1133883       24885.0  Ogpi4Jwj8KWDyT0rM_vFYa7D8z7yjun2jGP_aZIReN8=
# 1133884       24885.0  Ogpi4Jwj8KWDyT0rM_vFYf9eM73_U8S05NBjfLiez6E=
# 1133885       24885.0  Ogpi4Jwj8KWDyT0rM_vFYRXVZdKE7iJxxFPu0Bq0ikc=
# 1133886       24885.0  Ogpi4Jwj8KWDyT0rM_vFYVxslNBbpBprsR-39HjnMC8=
#
# [1133887 rows x 51 columns]>

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SaleId, OriginalId, PortalId, Title, Description, Area, Price, OfferPrice, RealPriceAfterRenovation, OriginalPrice, PricePerSquareMeter, NumberOfRooms, BuiltYear, Type, BuildingType, BuildingCondition, OfferFrom, Floor, Floors, TypeOfMarket, OwnerType, DateAddedToDatabase, DateAdded, DateLastModification, DateLastRaises, NewestDate, AvailableFrom, Link, Phone, MainImage, OtherImages, NumberOfDuplicates, NumberOfRaises, NumberOfModifications, IsDuplicatePriceLower, IsDuplicatePrivateOwner, Score, ScorePrecision, CommunityScore, NumberOfCommunityComments, NumberOfCommunityOpinions, Archive, Location, VoivodeshipNumber, CountyNumber, CommunityNumber, KindNumber, RegionNumber, SubRegionNumber, StreetNumber, EncryptedId]
# Index: []
#
# [0 rows x 51 columns]

# %%
df.nunique()
# Out:
# SaleId                       1133887
# OriginalId                         0
# PortalId                          35
# Title                         635825
# Description                   982079
# Area                           14360
# Price                         131353
# OfferPrice                     23232
# RealPriceAfterRenovation       29481
# OriginalPrice                  17584
# PricePerSquareMeter           306308
# NumberOfRooms                     90
# BuiltYear                        281
# Type                               2
# BuildingType                       4
# BuildingCondition                  4
# OfferFrom                          2
# Floor                             62
# Floors                            77
# TypeOfMarket                       2
# OwnerType                         96
# DateAddedToDatabase          1082247
# DateAdded                    1066927
# DateLastModification          242626
# DateLastRaises                292764
# NewestDate                   1070077
# AvailableFrom                      0
# Link                         1133749
# Phone                         172229
# MainImage                    1090896
# OtherImages                   764110
# NumberOfDuplicates                95
# NumberOfRaises                   186
# NumberOfModifications             59
# IsDuplicatePriceLower              2
# IsDuplicatePrivateOwner            2
# Score                              7
# ScorePrecision                     9
# CommunityScore                     7
# NumberOfCommunityComments          3
# NumberOfCommunityOpinions          3
# Archive                            0
# Location                       55868
# VoivodeshipNumber                 16
# CountyNumber                      57
# CommunityNumber                   19
# KindNumber                         7
# RegionNumber                   11337
# SubRegionNumber                    0
# StreetNumber                   11950
# EncryptedId                  1133683
# dtype: int64

# %%
correlation_matrix = df[['Area', 'Price', 'BuiltYear', 'Floor', 'Floors', 'CommunityScore', 'CountyNumber', 'CommunityNumber',
                               'RegionNumber','KindNumber']].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Price')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Price')

# %%
df.isnull()
# Out:
#          SaleId  OriginalId  PortalId  Title  Description   Area  Price  \
# 0         False        True     False  False        False  False  False
# 1         False        True     False  False        False  False  False
# 2         False        True     False  False        False  False  False
# 3         False        True     False  False        False  False  False
# 4         False        True     False  False        False  False  False
# ...         ...         ...       ...    ...          ...    ...    ...
# 1133882   False        True     False  False        False  False   True
# 1133883   False        True     False  False        False  False   True
# 1133884   False        True     False  False        False  False   True
# 1133885   False        True     False  False        False  False   True
# 1133886   False        True     False  False        False  False   True
#
#          OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0              True                      True           True  ...     True
# 1              True                      True           True  ...     True
# 2              True                      True           True  ...     True
# 3              True                      True           True  ...     True
# 4              True                      True           True  ...     True
# ...             ...                       ...            ...  ...      ...
# 1133882        True                      True           True  ...     True
# 1133883        True                      True           True  ...     True
# 1133884        True                      True           True  ...     True
# 1133885        True                      True           True  ...     True
# 1133886        True                      True           True  ...     True
#
#          Location  VoivodeshipNumber  CountyNumber  CommunityNumber  \
# 0           False              False         False            False
# 1           False              False         False            False
# 2           False              False         False            False
# 3           False              False         False            False
# 4           False              False         False            False
# ...           ...                ...           ...              ...
# 1133882     False              False         False            False
# 1133883     False              False         False            False
# 1133884     False              False         False            False
# 1133885     False              False         False            False
# 1133886     False              False         False            False
#
#          KindNumber  RegionNumber  SubRegionNumber  StreetNumber  EncryptedId
# 0             False         False             True          True        False
# 1             False         False             True          True        False
# 2             False         False             True          True        False
# 3             False         False             True         False        False
# 4             False         False             True         False        False
# ...             ...           ...              ...           ...          ...
# 1133882       False         False             True         False        False
# 1133883       False         False             True         False        False
# 1133884       False         False             True         False        False
# 1133885       False         False             True         False        False
# 1133886       False         False             True         False        False
#
# [1133887 rows x 51 columns]

# %%
df.isnull().sum()
# Out:
# SaleId                             0
# OriginalId                   1133887
# PortalId                           0
# Title                              0
# Description                     8664
# Area                            3393
# Price                          53424
# OfferPrice                   1050699
# RealPriceAfterRenovation     1050699
# OriginalPrice                1023184
# PricePerSquareMeter            57801
# NumberOfRooms                  14847
# BuiltYear                     382478
# Type                               0
# BuildingType                  206452
# BuildingCondition            1055766
# OfferFrom                       5031
# Floor                          58979
# Floors                        505193
# TypeOfMarket                   33527
# OwnerType                     545555
# DateAddedToDatabase                0
# DateAdded                          0
# DateLastModification          886552
# DateLastRaises                835087
# NewestDate                         0
# AvailableFrom                1133887
# Link                               0
# Phone                         217080
# MainImage                      21436
# OtherImages                   369735
# NumberOfDuplicates                 0
# NumberOfRaises                     0
# NumberOfModifications              0
# IsDuplicatePriceLower              0
# IsDuplicatePrivateOwner            0
# Score                              0
# ScorePrecision                     0
# CommunityScore                204274
# NumberOfCommunityComments     204274
# NumberOfCommunityOpinions     204275
# Archive                      1133887
# Location                         542
# VoivodeshipNumber               1139
# CountyNumber                    1139
# CommunityNumber               124733
# KindNumber                    124733
# RegionNumber                  207676
# SubRegionNumber              1133887
# StreetNumber                  645758
# EncryptedId                      204
# dtype: int64

# %%
df_beznull_price = df.dropna(subset=['Area'])

# %%
df_beznull_price.isnull().sum()
# Out:
# SaleId                             0
# OriginalId                   1130494
# PortalId                           0
# Title                              0
# Description                     7348
# Area                               0
# Price                          53291
# OfferPrice                   1047306
# RealPriceAfterRenovation     1047306
# OriginalPrice                1019890
# PricePerSquareMeter            54408
# NumberOfRooms                  12124
# BuiltYear                     379203
# Type                               0
# BuildingType                  204053
# BuildingCondition            1052403
# OfferFrom                       4742
# Floor                          56314
# Floors                        501959
# TypeOfMarket                   32011
# OwnerType                     542422
# DateAddedToDatabase                0
# DateAdded                          0
# DateLastModification          883586
# DateLastRaises                832330
# NewestDate                         0
# AvailableFrom                1130494
# Link                               0
# Phone                         215032
# MainImage                      21186
# OtherImages                   367952
# NumberOfDuplicates                 0
# NumberOfRaises                     0
# NumberOfModifications              0
# IsDuplicatePriceLower              0
# IsDuplicatePrivateOwner            0
# Score                              0
# ScorePrecision                     0
# CommunityScore                203979
# NumberOfCommunityComments     203979
# NumberOfCommunityOpinions     203980
# Archive                      1130494
# Location                         536
# VoivodeshipNumber               1126
# CountyNumber                    1126
# CommunityNumber               123785
# KindNumber                    123785
# RegionNumber                  206434
# SubRegionNumber              1130494
# StreetNumber                  642869
# EncryptedId                      204
# dtype: int64

# %%
# df_beznull_price2 = df_beznull_price.sort_values('Area').interpolate()

# %%
df_beznull_price.head(20)
# Out:
#     SaleId  OriginalId  PortalId  \
# 0       88         NaN        14
# 1       99         NaN        19
# 2      115         NaN         3
# 3      140         NaN        14
# 4      145         NaN         3
# 5      159         NaN         3
# 6      165         NaN         3
# 7      173         NaN         3
# 8      179         NaN         3
# 9      189         NaN         4
# 10     208         NaN         3
# 11     210         NaN        19
# 12     217         NaN         4
# 13     224         NaN         3
# 14     230         NaN         3
# 15     233         NaN         3
# 16     240         NaN        11
# 17     253         NaN        11
# 18     265         NaN        14
# 19     282         NaN         3
#
#                                                 Title  \
# 0                 Mieszkanie trzypokojowe na sprzedaż
# 1   Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2       Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                 Mieszkanie trzypokojowe na sprzedaż
# 4                  3 Pokoje- 48M2-Osiedle Dziesięciny
# 5                        Mieszkanie, 87 m², Białystok
# 6                Przytulne mieszkanie blisko centrum!
# 7   **Jasne, 2 Pokojowe Mieszkanie, Widok Na Miasto**
# 8   *Bezpośrednio*PIĘKNY APARTAMENT w Centrum Lipo...
# 9                   2-pokojowe mieszkanie na sprzedaż
# 10     Komfortowe M5, 116m2, Dwupoziomowe Mieszkanie.
# 11            Mieszkanie dwupoziomowe, ul. Zwycięstwa
# 12                  2-pokojowe mieszkanie na sprzedaż
# 13  Piękne m4 po generalnym remoncie na bema 2łazienk
# 14            Kawalerka Lipowa II Piętro BEZPOŚREDNIO
# 15    Piękne, nowe m. 45, 41m2 na 5 piętrze, Czarna 2
# 16               Mieszkanie, Białystok, Zawady, 75 m²
# 17               Mieszkanie, Białystok, Zawady, 77 m²
# 18                Mieszkanie trzypokojowe na sprzedaż
# 19      3 pok.*2018 r.*Bojary! Garaż! Komórka 8, 5m2!
#
#                                           Description    Area     Price  \
# 0   Mieszkanie o powierzchni 73m2 znajduje się na ...   73.00  766500.0
# 1   Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...   64.80  540000.0
# 2   SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...   51.00  540000.0
# 3   ***Oferta bez prowizji biura i podatku PCC!***...   67.62  544000.0
# 4   Przedstawiamy na sprzedaż 3 pokojowe mieszkani...   48.00  459000.0
# 5   Przestronne, jasne mieszkanie na zamkniętym os...   87.00  779000.0
# 6   Na sprzedaż 2 pokojowe mieszkanie położone na ...   34.10  359000.0
# 7   Mieszkanie o powierzchni 35,7 m2 Ul. Jarzębino...   35.70  380000.0
# 8   ***REZERWACJA ***WYJĄTKOWA PROPOZYCJA DLA WYMA...   39.40  559000.0
# 9   Na sprzedaż 2 pokojowe mieszkanie położone na ...   34.20  354000.0
# 10  Komfortowe, dwupoziomowe mieszkanie. Mamy przy...  116.00  820000.0
# 11  Mieszkanie jest zlokalizowane na osiedlu Młody...   64.50  606000.0
# 12  Bezpośrednio. Proszę pośredników o niekontakto...   43.00  529000.0
# 13  Piękne M4 po Generalnym Remoncie na Bema, 2 Ła...   70.00  659995.0
# 14  Mieszkanie sprzedawane bezpośrednio, wszystkim...   24.10  310000.0
# 15  ZDECYDOWANIE sprzedam nowe mieszkanie, ul. Cza...   45.50  575000.0
# 16  Mieszkanie, Białystok, Zawady, 75 m² Ogłoszeni...   75.05  577000.0
# 17  Mieszkanie, Białystok, Zawady, 77 m² Ogłoszeni...   77.26  592000.0
# 18  ***Oferta bez prowizji biura i podatku PCC!***...   69.60  572000.0
# 19  Polecamy Państwu ofertę trzypokojowego mieszka...   65.61  649000.0
#
#     OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0          NaN                       NaN            NaN  ...      NaN
# 1          NaN                       NaN            NaN  ...      NaN
# 2          NaN                       NaN            NaN  ...      NaN
# 3          NaN                       NaN            NaN  ...      NaN
# 4          NaN                       NaN            NaN  ...      NaN
# 5          NaN                       NaN            NaN  ...      NaN
# 6          NaN                       NaN            NaN  ...      NaN
# 7          NaN                       NaN            NaN  ...      NaN
# 8          NaN                       NaN            NaN  ...      NaN
# 9          NaN                       NaN            NaN  ...      NaN
# 10         NaN                       NaN            NaN  ...      NaN
# 11         NaN                       NaN            NaN  ...      NaN
# 12         NaN                       NaN            NaN  ...      NaN
# 13         NaN                       NaN            NaN  ...      NaN
# 14         NaN                       NaN            NaN  ...      NaN
# 15         NaN                       NaN       583000.0  ...      NaN
# 16         NaN                       NaN            NaN  ...      NaN
# 17         NaN                       NaN            NaN  ...      NaN
# 18         NaN                       NaN            NaN  ...      NaN
# 19         NaN                       NaN            NaN  ...      NaN
#
#                                              Location  VoivodeshipNumber  \
# 0                        Podlaskie, Białystok, Bojary               20.0
# 1                      Podlaskie, Białystok, Antoniuk               20.0
# 2                      Podlaskie, Białystok, Bagnówka               20.0
# 3   Podlaskie, Białystok, Ul. Józefa Karola Puchal...               20.0
# 4               Podlaskie, Białystok, Ul. Dziesięciny               20.0
# 5         Podlaskie, Białystok, Ul. Adama Mickiewicza               20.0
# 6                        Podlaskie, Białystok, Bojary               20.0
# 7                                Podlaskie, Białystok               20.0
# 8         Podlaskie, Białystok, Ul. Adama Mickiewicza               20.0
# 9                    Podlaskie, Białystok, Ul. Piasta               20.0
# 10                               Podlaskie, Białystok               20.0
# 11                     Podlaskie, Białystok, Antoniuk               20.0
# 12                Podlaskie, Białystok, Ul. Niemeńska               20.0
# 13         Podlaskie, Białystok, Ul. Gen. Józefa Bema               20.0
# 14                               Podlaskie, Białystok               20.0
# 15                               Podlaskie, Białystok               20.0
# 16                               Podlaskie, Białystok               20.0
# 17                               Podlaskie, Białystok               20.0
# 18                Podlaskie, Białystok, Ul. Kaktusowa               20.0
# 19                       Podlaskie, Białystok, Bojary               20.0
#
#    CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0          61.0             1.0        1.0     922490.0              NaN
# 1          61.0             1.0        1.0     922426.0              NaN
# 2          61.0             1.0        1.0     922461.0              NaN
# 3          61.0             1.0        1.0     922410.0              NaN
# 4          61.0             1.0        1.0     922410.0              NaN
# 5          61.0             1.0        1.0     922410.0              NaN
# 6          61.0             1.0        1.0     922490.0              NaN
# 7          61.0             1.0        1.0     922410.0              NaN
# 8          61.0             1.0        1.0     922410.0              NaN
# 9          61.0             1.0        1.0     922410.0              NaN
# 10         61.0             1.0        1.0     922410.0              NaN
# 11         61.0             1.0        1.0     922426.0              NaN
# 12         61.0             1.0        1.0     922410.0              NaN
# 13         61.0             1.0        1.0     922410.0              NaN
# 14         61.0             1.0        1.0     922410.0              NaN
# 15         61.0             1.0        1.0     922410.0              NaN
# 16         61.0             1.0        1.0     922410.0              NaN
# 17         61.0             1.0        1.0     922410.0              NaN
# 18         61.0             1.0        1.0     922410.0              NaN
# 19         61.0             1.0        1.0     922490.0              NaN
#
#     StreetNumber               EncryptedId
# 0            NaN  02TgImo1wm-Ra4zUQxoPBw==
# 1            NaN  D-NUdVbtN3_kIW7ExgXkvA==
# 2            NaN  lmBSU1XiXLSLOq1yKSe2kA==
# 3        43141.0  HWachf5gb6Vq-sFYH4YWnA==
# 4         4656.0  AWsmt4ZY0X7lNv-6fSCn9Q==
# 5        12740.0  SEPz6jrRB1vuWWYOn99h7g==
# 6        16041.0  Gt5-LUpJNg-wBgBd8-hxGQ==
# 7         7290.0  a5iP5JQyibefTTLgBRU8oA==
# 8        12740.0  C_F7Bxl4hKQ2a2votBqs-g==
# 9        16041.0  XylelQthYlIn_7k8orxBfQ==
# 10           NaN  PjyloplKnBm33SnJsmgnjA==
# 11       26326.0  iVpV9JFYX6RLvvEECFa6eg==
# 12       14180.0  m7rdVkLLwxAKoo3BcU6K8w==
# 13        1014.0  4a6UDYZ59kIpJ4Q2eKK1xQ==
# 14           NaN  D8EQlMOyJUi_9dKg3y3_Qw==
# 15           NaN  tyIjGaY-6XL8a--LyHKTSA==
# 16       11237.0  2njUzWQ7v2jcON4oLd5M4Q==
# 17       11237.0  _VMLJaw-VJy6iRWofLt8sA==
# 18        7782.0  aVxGz4sH1hQJqxsJ43fI7Q==
# 19           NaN  oTJWkSL77PbdNjqlN2ywMg==
#
# [20 rows x 51 columns]

# %%
Q1 = df_beznull_price["Price"].quantile(0.25)
Q3 = df_beznull_price["Price"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_price_p = df_beznull_price[~((df_beznull_price["Price"] < lower_bound) | (df_beznull_price["Price"] > upper_bound))]

# %%
Q1 = df_price_p["PricePerSquareMeter"].quantile(0.25)
Q3 = df_price_p["PricePerSquareMeter"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_price_a = df_price_p[~((df_price_p["PricePerSquareMeter"] < lower_bound) | (df_price_p["PricePerSquareMeter"] > upper_bound))]

# %%
Q1 = df_price_a["Area"].quantile(0.25)
Q3 = df_price_a["Area"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_price1 = df_price_a[~((df_price_a["Area"] < lower_bound) | (df_price_a["Area"] > upper_bound))]

# %%
df_price1['BuiltYear'] = pd.to_datetime(df_price1['BuiltYear'], format='%Y', errors='coerce')

# %%
df_price1.head(20)
# Out:
#     SaleId  OriginalId  PortalId  \
# 0       88         NaN        14
# 1       99         NaN        19
# 2      115         NaN         3
# 3      140         NaN        14
# 4      145         NaN         3
# 5      159         NaN         3
# 6      165         NaN         3
# 7      173         NaN         3
# 8      179         NaN         3
# 9      189         NaN         4
# 11     210         NaN        19
# 12     217         NaN         4
# 13     224         NaN         3
# 14     230         NaN         3
# 15     233         NaN         3
# 16     240         NaN        11
# 17     253         NaN        11
# 18     265         NaN        14
# 19     282         NaN         3
# 20     287         NaN        22
#
#                                                 Title  \
# 0                 Mieszkanie trzypokojowe na sprzedaż
# 1   Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2       Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                 Mieszkanie trzypokojowe na sprzedaż
# 4                  3 Pokoje- 48M2-Osiedle Dziesięciny
# 5                        Mieszkanie, 87 m², Białystok
# 6                Przytulne mieszkanie blisko centrum!
# 7   **Jasne, 2 Pokojowe Mieszkanie, Widok Na Miasto**
# 8   *Bezpośrednio*PIĘKNY APARTAMENT w Centrum Lipo...
# 9                   2-pokojowe mieszkanie na sprzedaż
# 11            Mieszkanie dwupoziomowe, ul. Zwycięstwa
# 12                  2-pokojowe mieszkanie na sprzedaż
# 13  Piękne m4 po generalnym remoncie na bema 2łazienk
# 14            Kawalerka Lipowa II Piętro BEZPOŚREDNIO
# 15    Piękne, nowe m. 45, 41m2 na 5 piętrze, Czarna 2
# 16               Mieszkanie, Białystok, Zawady, 75 m²
# 17               Mieszkanie, Białystok, Zawady, 77 m²
# 18                Mieszkanie trzypokojowe na sprzedaż
# 19      3 pok.*2018 r.*Bojary! Garaż! Komórka 8, 5m2!
# 20                  Sprzedam Mieszkanie cztery pokoje
#
#                                           Description   Area     Price  \
# 0   Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1   Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2   SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3   ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4   Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
# 5   Przestronne, jasne mieszkanie na zamkniętym os...  87.00  779000.0
# 6   Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.10  359000.0
# 7   Mieszkanie o powierzchni 35,7 m2 Ul. Jarzębino...  35.70  380000.0
# 8   ***REZERWACJA ***WYJĄTKOWA PROPOZYCJA DLA WYMA...  39.40  559000.0
# 9   Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.20  354000.0
# 11  Mieszkanie jest zlokalizowane na osiedlu Młody...  64.50  606000.0
# 12  Bezpośrednio. Proszę pośredników o niekontakto...  43.00  529000.0
# 13  Piękne M4 po Generalnym Remoncie na Bema, 2 Ła...  70.00  659995.0
# 14  Mieszkanie sprzedawane bezpośrednio, wszystkim...  24.10  310000.0
# 15  ZDECYDOWANIE sprzedam nowe mieszkanie, ul. Cza...  45.50  575000.0
# 16  Mieszkanie, Białystok, Zawady, 75 m² Ogłoszeni...  75.05  577000.0
# 17  Mieszkanie, Białystok, Zawady, 77 m² Ogłoszeni...  77.26  592000.0
# 18  ***Oferta bez prowizji biura i podatku PCC!***...  69.60  572000.0
# 19  Polecamy Państwu ofertę trzypokojowego mieszka...  65.61  649000.0
# 20  Sprzedam 4 pokojowe mieszkanie o powierzchni u...  63.00    8800.0
#
#     OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0          NaN                       NaN            NaN  ...      NaN
# 1          NaN                       NaN            NaN  ...      NaN
# 2          NaN                       NaN            NaN  ...      NaN
# 3          NaN                       NaN            NaN  ...      NaN
# 4          NaN                       NaN            NaN  ...      NaN
# 5          NaN                       NaN            NaN  ...      NaN
# 6          NaN                       NaN            NaN  ...      NaN
# 7          NaN                       NaN            NaN  ...      NaN
# 8          NaN                       NaN            NaN  ...      NaN
# 9          NaN                       NaN            NaN  ...      NaN
# 11         NaN                       NaN            NaN  ...      NaN
# 12         NaN                       NaN            NaN  ...      NaN
# 13         NaN                       NaN            NaN  ...      NaN
# 14         NaN                       NaN            NaN  ...      NaN
# 15         NaN                       NaN       583000.0  ...      NaN
# 16         NaN                       NaN            NaN  ...      NaN
# 17         NaN                       NaN            NaN  ...      NaN
# 18         NaN                       NaN            NaN  ...      NaN
# 19         NaN                       NaN            NaN  ...      NaN
# 20         NaN                       NaN            NaN  ...      NaN
#
#                                              Location VoivodeshipNumber  \
# 0                        Podlaskie, Białystok, Bojary              20.0
# 1                      Podlaskie, Białystok, Antoniuk              20.0
# 2                      Podlaskie, Białystok, Bagnówka              20.0
# 3   Podlaskie, Białystok, Ul. Józefa Karola Puchal...              20.0
# 4               Podlaskie, Białystok, Ul. Dziesięciny              20.0
# 5         Podlaskie, Białystok, Ul. Adama Mickiewicza              20.0
# 6                        Podlaskie, Białystok, Bojary              20.0
# 7                                Podlaskie, Białystok              20.0
# 8         Podlaskie, Białystok, Ul. Adama Mickiewicza              20.0
# 9                    Podlaskie, Białystok, Ul. Piasta              20.0
# 11                     Podlaskie, Białystok, Antoniuk              20.0
# 12                Podlaskie, Białystok, Ul. Niemeńska              20.0
# 13         Podlaskie, Białystok, Ul. Gen. Józefa Bema              20.0
# 14                               Podlaskie, Białystok              20.0
# 15                               Podlaskie, Białystok              20.0
# 16                               Podlaskie, Białystok              20.0
# 17                               Podlaskie, Białystok              20.0
# 18                Podlaskie, Białystok, Ul. Kaktusowa              20.0
# 19                       Podlaskie, Białystok, Bojary              20.0
# 20                               Podlaskie, Białystok              20.0
#
#    CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0          61.0             1.0        1.0     922490.0              NaN
# 1          61.0             1.0        1.0     922426.0              NaN
# 2          61.0             1.0        1.0     922461.0              NaN
# 3          61.0             1.0        1.0     922410.0              NaN
# 4          61.0             1.0        1.0     922410.0              NaN
# 5          61.0             1.0        1.0     922410.0              NaN
# 6          61.0             1.0        1.0     922490.0              NaN
# 7          61.0             1.0        1.0     922410.0              NaN
# 8          61.0             1.0        1.0     922410.0              NaN
# 9          61.0             1.0        1.0     922410.0              NaN
# 11         61.0             1.0        1.0     922426.0              NaN
# 12         61.0             1.0        1.0     922410.0              NaN
# 13         61.0             1.0        1.0     922410.0              NaN
# 14         61.0             1.0        1.0     922410.0              NaN
# 15         61.0             1.0        1.0     922410.0              NaN
# 16         61.0             1.0        1.0     922410.0              NaN
# 17         61.0             1.0        1.0     922410.0              NaN
# 18         61.0             1.0        1.0     922410.0              NaN
# 19         61.0             1.0        1.0     922490.0              NaN
# 20         61.0             1.0        1.0     922410.0              NaN
#
#     StreetNumber               EncryptedId
# 0            NaN  02TgImo1wm-Ra4zUQxoPBw==
# 1            NaN  D-NUdVbtN3_kIW7ExgXkvA==
# 2            NaN  lmBSU1XiXLSLOq1yKSe2kA==
# 3        43141.0  HWachf5gb6Vq-sFYH4YWnA==
# 4         4656.0  AWsmt4ZY0X7lNv-6fSCn9Q==
# 5        12740.0  SEPz6jrRB1vuWWYOn99h7g==
# 6        16041.0  Gt5-LUpJNg-wBgBd8-hxGQ==
# 7         7290.0  a5iP5JQyibefTTLgBRU8oA==
# 8        12740.0  C_F7Bxl4hKQ2a2votBqs-g==
# 9        16041.0  XylelQthYlIn_7k8orxBfQ==
# 11       26326.0  iVpV9JFYX6RLvvEECFa6eg==
# 12       14180.0  m7rdVkLLwxAKoo3BcU6K8w==
# 13        1014.0  4a6UDYZ59kIpJ4Q2eKK1xQ==
# 14           NaN  D8EQlMOyJUi_9dKg3y3_Qw==
# 15           NaN  tyIjGaY-6XL8a--LyHKTSA==
# 16       11237.0  2njUzWQ7v2jcON4oLd5M4Q==
# 17       11237.0  _VMLJaw-VJy6iRWofLt8sA==
# 18        7782.0  aVxGz4sH1hQJqxsJ43fI7Q==
# 19           NaN  oTJWkSL77PbdNjqlN2ywMg==
# 20           NaN  RPgHa0CrjslXjbGyRPXbTg==
#
# [20 rows x 51 columns]

# %%
df_price1.describe().T
# Out:
#                                count                           mean  \
# SaleId                     1019895.0                 2785334.786497
# OriginalId                       0.0                            NaN
# PortalId                   1019895.0                      10.468412
# Area                       1019895.0                      51.235749
# Price                       968696.0                  534743.792921
# OfferPrice                   76990.0                  569634.010829
# RealPriceAfterRenovation     76990.0                  940407.259452
# OriginalPrice               101360.0                14239892.054544
# PricePerSquareMeter         967666.0                   10724.361855
# NumberOfRooms              1009140.0                    7482.849491
# BuiltYear                     664448  2000-02-23 19:47:08.168945920
# Floor                       970572.0                       2.409566
# Floors                      563030.0                       4.815402
# AvailableFrom                    0.0                            NaN
# NumberOfDuplicates         1019895.0                       1.174147
# NumberOfRaises             1019895.0                       1.065549
# NumberOfModifications      1019895.0                        0.35337
# IsDuplicatePriceLower      1019895.0                       0.010093
# IsDuplicatePrivateOwner    1019895.0                       0.029484
# Score                      1019895.0                        2.33553
# ScorePrecision             1019895.0                       3.272895
# CommunityScore              835793.0                       0.000182
# NumberOfCommunityComments   835793.0                       0.000028
# NumberOfCommunityOpinions   835792.0                       0.000066
# Archive                          0.0                            NaN
# VoivodeshipNumber          1018930.0                      16.056326
# CountyNumber               1018930.0                      49.527484
# CommunityNumber             905213.0                       3.402314
# KindNumber                  905213.0                        4.39846
# RegionNumber                834290.0                  914828.607978
# SubRegionNumber                  0.0                            NaN
# StreetNumber                437416.0                   17946.491265
#
#                                            min                  25%  \
# SaleId                                    88.0            2032076.0
# OriginalId                                 NaN                  NaN
# PortalId                                   1.0                  3.0
# Area                                      6.87                 40.0
# Price                                      0.0             355000.0
# OfferPrice                             54000.0             397434.0
# RealPriceAfterRenovation               85000.0          503635.2475
# OriginalPrice                              1.0             355000.0
# PricePerSquareMeter                        0.0               7500.0
# NumberOfRooms                              1.0                  2.0
# BuiltYear                  1700-01-01 00:00:00  1980-01-01 00:00:00
# Floor                                      0.0                  1.0
# Floors                                     0.0                  3.0
# AvailableFrom                              NaN                  NaN
# NumberOfDuplicates                         0.0                  0.0
# NumberOfRaises                             0.0                  0.0
# NumberOfModifications                      0.0                  0.0
# IsDuplicatePriceLower                      0.0                  0.0
# IsDuplicatePrivateOwner                    0.0                  0.0
# Score                                      0.0                  0.0
# ScorePrecision                             0.0                  0.0
# CommunityScore                             0.0                  0.0
# NumberOfCommunityComments                  0.0                  0.0
# NumberOfCommunityOpinions                  0.0                  0.0
# Archive                                    NaN                  NaN
# VoivodeshipNumber                          2.0                 10.0
# CountyNumber                               1.0                 23.0
# CommunityNumber                            1.0                  1.0
# KindNumber                                 1.0                  1.0
# RegionNumber                              17.0             933016.0
# SubRegionNumber                            NaN                  NaN
# StreetNumber                               4.0               8259.0
#
#                                            50%                  75%  \
# SaleId                               3026910.0            3765616.5
# OriginalId                                 NaN                  NaN
# PortalId                                  10.0                 17.0
# Area                                     49.86                 61.0
# Price                                 499000.0           680681.125
# OfferPrice                            535000.0             699000.0
# RealPriceAfterRenovation             676333.33            904333.33
# OriginalPrice                         499000.0             684000.0
# PricePerSquareMeter                  10170.695           13573.5675
# NumberOfRooms                              2.0                  3.0
# BuiltYear                  2016-01-01 00:00:00  2024-01-01 00:00:00
# Floor                                      2.0                  3.0
# Floors                                     4.0                  5.0
# AvailableFrom                              NaN                  NaN
# NumberOfDuplicates                         0.0                  1.0
# NumberOfRaises                             0.0                  1.0
# NumberOfModifications                      0.0                  0.0
# IsDuplicatePriceLower                      0.0                  0.0
# IsDuplicatePrivateOwner                    0.0                  0.0
# Score                                      2.0                  4.0
# ScorePrecision                             5.0                  5.0
# CommunityScore                             0.0                  0.0
# NumberOfCommunityComments                  0.0                  0.0
# NumberOfCommunityOpinions                  0.0                  0.0
# Archive                                    NaN                  NaN
# VoivodeshipNumber                         14.0                 24.0
# CountyNumber                              61.0                 64.0
# CommunityNumber                            2.0                  4.0
# KindNumber                                 2.0                  9.0
# RegionNumber                          950960.0             974133.0
# SubRegionNumber                            NaN                  NaN
# StreetNumber                           15996.0              23682.0
#
#                                            max                std
# SaleId                               4418406.0     1216312.819628
# OriginalId                                 NaN                NaN
# PortalId                                  44.0           8.734634
# Area                                     96.17          15.155208
# Price                                1319000.0       241685.26195
# OfferPrice                           3300000.0      231145.324617
# RealPriceAfterRenovation           334234237.0     6197016.106829
# OriginalPrice                   857460922000.0  3163320460.728683
# PricePerSquareMeter                   23030.71        4338.931513
# NumberOfRooms                      792501237.0     2196237.851599
# BuiltYear                  2204-01-01 00:00:00                NaN
# Floor                                   2023.0           4.230665
# Floors                                  2025.0           8.508566
# AvailableFrom                              NaN                NaN
# NumberOfDuplicates                       181.0           2.477746
# NumberOfRaises                           272.0           4.367729
# NumberOfModifications                    106.0           0.965152
# IsDuplicatePriceLower                      1.0           0.099957
# IsDuplicatePrivateOwner                    1.0            0.16916
# Score                                      6.0           2.078293
# ScorePrecision                            10.0           2.450562
# CommunityScore                             5.0           0.026976
# NumberOfCommunityComments                  2.0           0.005469
# NumberOfCommunityOpinions                  2.0           0.008258
# Archive                                    NaN                NaN
# VoivodeshipNumber                         32.0           9.347861
# CountyNumber                              79.0          23.403116
# CommunityNumber                           19.0           3.463388
# KindNumber                                 9.0           3.576788
# RegionNumber                         1067871.0      168358.109373
# SubRegionNumber                            NaN                NaN
# StreetNumber                           60786.0       13080.018153

# %%
df_price1["Price"].value_counts(normalize=True)
# Out:
# Price
# 599000.0    0.009037
# 499000.0    0.008885
# 399000.0    0.008473
# 699000.0    0.007991
# 299000.0    0.006834
#               ...
# 629788.0    0.000001
# 626801.0    0.000001
# 848928.0    0.000001
# 849517.0    0.000001
# 374029.0    0.000001
# Name: proportion, Length: 117663, dtype: float64

# %%
#df_price2 = df_price1.sort_values('Price').interpolate()

# %%
df_price1.nunique()
# Out:
# SaleId                       1019895
# OriginalId                         0
# PortalId                          35
# Title                         573126
# Description                   882354
# Area                            8171
# Price                         117663
# OfferPrice                     21409
# RealPriceAfterRenovation       26948
# OriginalPrice                  15696
# PricePerSquareMeter           268912
# NumberOfRooms                     72
# BuiltYear                        222
# Type                               2
# BuildingType                       4
# BuildingCondition                  4
# OfferFrom                          2
# Floor                             49
# Floors                            64
# TypeOfMarket                       2
# OwnerType                         90
# DateAddedToDatabase           976917
# DateAdded                     964655
# DateLastModification          218341
# DateLastRaises                261071
# NewestDate                    967284
# AvailableFrom                      0
# Link                         1019766
# Phone                         160652
# MainImage                     981751
# OtherImages                   687955
# NumberOfDuplicates                93
# NumberOfRaises                   179
# NumberOfModifications             58
# IsDuplicatePriceLower              2
# IsDuplicatePrivateOwner            2
# Score                              7
# ScorePrecision                     9
# CommunityScore                     7
# NumberOfCommunityComments          3
# NumberOfCommunityOpinions          3
# Archive                            0
# Location                       52416
# VoivodeshipNumber                 16
# CountyNumber                      57
# CommunityNumber                   19
# KindNumber                         7
# RegionNumber                   10685
# SubRegionNumber                    0
# StreetNumber                   11422
# EncryptedId                  1019710
# dtype: int64

# %%
df_price1.head(10)
# Out:
#    SaleId  OriginalId  PortalId  \
# 0      88         NaN        14
# 1      99         NaN        19
# 2     115         NaN         3
# 3     140         NaN        14
# 4     145         NaN         3
# 5     159         NaN         3
# 6     165         NaN         3
# 7     173         NaN         3
# 8     179         NaN         3
# 9     189         NaN         4
#
#                                                Title  \
# 0                Mieszkanie trzypokojowe na sprzedaż
# 1  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2      Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                Mieszkanie trzypokojowe na sprzedaż
# 4                 3 Pokoje- 48M2-Osiedle Dziesięciny
# 5                       Mieszkanie, 87 m², Białystok
# 6               Przytulne mieszkanie blisko centrum!
# 7  **Jasne, 2 Pokojowe Mieszkanie, Widok Na Miasto**
# 8  *Bezpośrednio*PIĘKNY APARTAMENT w Centrum Lipo...
# 9                  2-pokojowe mieszkanie na sprzedaż
#
#                                          Description   Area     Price  \
# 0  Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1  Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2  SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3  ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4  Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
# 5  Przestronne, jasne mieszkanie na zamkniętym os...  87.00  779000.0
# 6  Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.10  359000.0
# 7  Mieszkanie o powierzchni 35,7 m2 Ul. Jarzębino...  35.70  380000.0
# 8  ***REZERWACJA ***WYJĄTKOWA PROPOZYCJA DLA WYMA...  39.40  559000.0
# 9  Na sprzedaż 2 pokojowe mieszkanie położone na ...  34.20  354000.0
#
#    OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0         NaN                       NaN            NaN  ...      NaN
# 1         NaN                       NaN            NaN  ...      NaN
# 2         NaN                       NaN            NaN  ...      NaN
# 3         NaN                       NaN            NaN  ...      NaN
# 4         NaN                       NaN            NaN  ...      NaN
# 5         NaN                       NaN            NaN  ...      NaN
# 6         NaN                       NaN            NaN  ...      NaN
# 7         NaN                       NaN            NaN  ...      NaN
# 8         NaN                       NaN            NaN  ...      NaN
# 9         NaN                       NaN            NaN  ...      NaN
#
#                                             Location VoivodeshipNumber  \
# 0                       Podlaskie, Białystok, Bojary              20.0
# 1                     Podlaskie, Białystok, Antoniuk              20.0
# 2                     Podlaskie, Białystok, Bagnówka              20.0
# 3  Podlaskie, Białystok, Ul. Józefa Karola Puchal...              20.0
# 4              Podlaskie, Białystok, Ul. Dziesięciny              20.0
# 5        Podlaskie, Białystok, Ul. Adama Mickiewicza              20.0
# 6                       Podlaskie, Białystok, Bojary              20.0
# 7                               Podlaskie, Białystok              20.0
# 8        Podlaskie, Białystok, Ul. Adama Mickiewicza              20.0
# 9                   Podlaskie, Białystok, Ul. Piasta              20.0
#
#   CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0         61.0             1.0        1.0     922490.0              NaN
# 1         61.0             1.0        1.0     922426.0              NaN
# 2         61.0             1.0        1.0     922461.0              NaN
# 3         61.0             1.0        1.0     922410.0              NaN
# 4         61.0             1.0        1.0     922410.0              NaN
# 5         61.0             1.0        1.0     922410.0              NaN
# 6         61.0             1.0        1.0     922490.0              NaN
# 7         61.0             1.0        1.0     922410.0              NaN
# 8         61.0             1.0        1.0     922410.0              NaN
# 9         61.0             1.0        1.0     922410.0              NaN
#
#    StreetNumber               EncryptedId
# 0           NaN  02TgImo1wm-Ra4zUQxoPBw==
# 1           NaN  D-NUdVbtN3_kIW7ExgXkvA==
# 2           NaN  lmBSU1XiXLSLOq1yKSe2kA==
# 3       43141.0  HWachf5gb6Vq-sFYH4YWnA==
# 4        4656.0  AWsmt4ZY0X7lNv-6fSCn9Q==
# 5       12740.0  SEPz6jrRB1vuWWYOn99h7g==
# 6       16041.0  Gt5-LUpJNg-wBgBd8-hxGQ==
# 7        7290.0  a5iP5JQyibefTTLgBRU8oA==
# 8       12740.0  C_F7Bxl4hKQ2a2votBqs-g==
# 9       16041.0  XylelQthYlIn_7k8orxBfQ==
#
# [10 rows x 51 columns]

# %%
unique_btype=df_price1['BuildingType'].unique()

unique_btype
# Out:
# array(['Blok', nan, 'Apartamentowiec', 'Kamienica', 'Pozostałe'],
#       dtype=object)

# %%
print(df_price1['Price'].nunique())
# Out:
# 117663

# %%
print(df_price1['Price'].value_counts())
# Out:
# Price
# 599000.0    8754
# 499000.0    8607
# 399000.0    8208
# 699000.0    7741
# 299000.0    6620
#             ...
# 629788.0       1
# 626801.0       1
# 848928.0       1
# 849517.0       1
# 374029.0       1
# Name: count, Length: 117663, dtype: int64

# %%
df_price1.isnull().sum()
# Out:
# SaleId                             0
# OriginalId                   1019895
# PortalId                           0
# Title                              0
# Description                     6232
# Area                               0
# Price                          51199
# OfferPrice                    942905
# RealPriceAfterRenovation      942905
# OriginalPrice                 918535
# PricePerSquareMeter            52229
# NumberOfRooms                  10755
# BuiltYear                     355447
# Type                               0
# BuildingType                  185268
# BuildingCondition             948805
# OfferFrom                       4574
# Floor                          49323
# Floors                        456865
# TypeOfMarket                   29083
# OwnerType                     489606
# DateAddedToDatabase                0
# DateAdded                          0
# DateLastModification          797740
# DateLastRaises                754002
# NewestDate                         0
# AvailableFrom                1019895
# Link                               0
# Phone                         197498
# MainImage                      18731
# OtherImages                   331899
# NumberOfDuplicates                 0
# NumberOfRaises                     0
# NumberOfModifications              0
# IsDuplicatePriceLower              0
# IsDuplicatePrivateOwner            0
# Score                              0
# ScorePrecision                     0
# CommunityScore                184102
# NumberOfCommunityComments     184102
# NumberOfCommunityOpinions     184103
# Archive                      1019895
# Location                         455
# VoivodeshipNumber                965
# CountyNumber                     965
# CommunityNumber               114682
# KindNumber                    114682
# RegionNumber                  185605
# SubRegionNumber              1019895
# StreetNumber                  582479
# EncryptedId                      185
# dtype: int64

# %%
df_price2 = df_price1.dropna(subset=['Price'])

# %%
df_price2.isnull().sum()
# Out:
# SaleId                            0
# OriginalId                   968696
# PortalId                          0
# Title                             0
# Description                    6033
# Area                              0
# Price                             0
# OfferPrice                   891706
# RealPriceAfterRenovation     891706
# OriginalPrice                867336
# PricePerSquareMeter            1087
# NumberOfRooms                 10648
# BuiltYear                    339100
# Type                              0
# BuildingType                 153500
# BuildingCondition            904569
# OfferFrom                       789
# Floor                         48234
# Floors                       436534
# TypeOfMarket                  27802
# OwnerType                    466260
# DateAddedToDatabase               0
# DateAdded                         0
# DateLastModification         747906
# DateLastRaises               717920
# NewestDate                        0
# AvailableFrom                968696
# Link                              0
# Phone                        191773
# MainImage                     18016
# OtherImages                  317028
# NumberOfDuplicates                0
# NumberOfRaises                    0
# NumberOfModifications             0
# IsDuplicatePriceLower             0
# IsDuplicatePrivateOwner           0
# Score                             0
# ScorePrecision                    0
# CommunityScore               175557
# NumberOfCommunityComments    175557
# NumberOfCommunityOpinions    175558
# Archive                      968696
# Location                        403
# VoivodeshipNumber               894
# CountyNumber                    894
# CommunityNumber              113299
# KindNumber                   113299
# RegionNumber                 183298
# SubRegionNumber              968696
# StreetNumber                 571970
# EncryptedId                     170
# dtype: int64

# %% [markdown]
# # Sprawdzenie braków - procentowo.

# %%
df_price2.isna().sum() / len(df) * 100
# Out:
# SaleId                        0.000000
# OriginalId                   85.431441
# PortalId                      0.000000
# Title                         0.000000
# Description                   0.532064
# Area                          0.000000
# Price                         0.000000
# OfferPrice                   78.641522
# RealPriceAfterRenovation     78.641522
# OriginalPrice                76.492278
# PricePerSquareMeter           0.095865
# NumberOfRooms                 0.939071
# BuiltYear                    29.905978
# Type                          0.000000
# BuildingType                 13.537504
# BuildingCondition            79.775939
# OfferFrom                     0.069584
# Floor                         4.253863
# Floors                       38.498898
# TypeOfMarket                  2.451920
# OwnerType                    41.120500
# DateAddedToDatabase           0.000000
# DateAdded                     0.000000
# DateLastModification         65.959483
# DateLastRaises               63.314951
# NewestDate                    0.000000
# AvailableFrom                85.431441
# Link                          0.000000
# Phone                        16.912885
# MainImage                     1.588871
# OtherImages                  27.959400
# NumberOfDuplicates            0.000000
# NumberOfRaises                0.000000
# NumberOfModifications         0.000000
# IsDuplicatePriceLower         0.000000
# IsDuplicatePrivateOwner       0.000000
# Score                         0.000000
# ScorePrecision                0.000000
# CommunityScore               15.482760
# NumberOfCommunityComments    15.482760
# NumberOfCommunityOpinions    15.482848
# Archive                      85.431441
# Location                      0.035541
# VoivodeshipNumber             0.078844
# CountyNumber                  0.078844
# CommunityNumber               9.992089
# KindNumber                    9.992089
# RegionNumber                 16.165456
# SubRegionNumber              85.431441
# StreetNumber                 50.443298
# EncryptedId                   0.014993
# dtype: float64

# %%
# parametr thresh pozwala określić minimalną liczbę nie-NaN wartości, które muszą być w wierszu/kolumnie
display(df_price2.head())
df_price2.dropna(thresh=(0.4*len(df_price2)),axis=1).head()
# Out:
#    SaleId  OriginalId  PortalId  \
# 0      88         NaN        14
# 1      99         NaN        19
# 2     115         NaN         3
# 3     140         NaN        14
# 4     145         NaN         3
#
#                                                Title  \
# 0                Mieszkanie trzypokojowe na sprzedaż
# 1  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2      Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                Mieszkanie trzypokojowe na sprzedaż
# 4                 3 Pokoje- 48M2-Osiedle Dziesięciny
#
#                                          Description   Area     Price  \
# 0  Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1  Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2  SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3  ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4  Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
#
#    OfferPrice  RealPriceAfterRenovation  OriginalPrice  ...  Archive  \
# 0         NaN                       NaN            NaN  ...      NaN
# 1         NaN                       NaN            NaN  ...      NaN
# 2         NaN                       NaN            NaN  ...      NaN
# 3         NaN                       NaN            NaN  ...      NaN
# 4         NaN                       NaN            NaN  ...      NaN
#
#                                             Location VoivodeshipNumber  \
# 0                       Podlaskie, Białystok, Bojary              20.0
# 1                     Podlaskie, Białystok, Antoniuk              20.0
# 2                     Podlaskie, Białystok, Bagnówka              20.0
# 3  Podlaskie, Białystok, Ul. Józefa Karola Puchal...              20.0
# 4              Podlaskie, Białystok, Ul. Dziesięciny              20.0
#
#   CountyNumber CommunityNumber KindNumber RegionNumber  SubRegionNumber  \
# 0         61.0             1.0        1.0     922490.0              NaN
# 1         61.0             1.0        1.0     922426.0              NaN
# 2         61.0             1.0        1.0     922461.0              NaN
# 3         61.0             1.0        1.0     922410.0              NaN
# 4         61.0             1.0        1.0     922410.0              NaN
#
#    StreetNumber               EncryptedId
# 0           NaN  02TgImo1wm-Ra4zUQxoPBw==
# 1           NaN  D-NUdVbtN3_kIW7ExgXkvA==
# 2           NaN  lmBSU1XiXLSLOq1yKSe2kA==
# 3       43141.0  HWachf5gb6Vq-sFYH4YWnA==
# 4        4656.0  AWsmt4ZY0X7lNv-6fSCn9Q==
#
# [5 rows x 51 columns]
#    SaleId  PortalId                                              Title  \
# 0      88        14                Mieszkanie trzypokojowe na sprzedaż
# 1      99        19  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2     115         3      Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3     140        14                Mieszkanie trzypokojowe na sprzedaż
# 4     145         3                 3 Pokoje- 48M2-Osiedle Dziesięciny
#
#                                          Description   Area     Price  \
# 0  Mieszkanie o powierzchni 73m2 znajduje się na ...  73.00  766500.0
# 1  Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...  64.80  540000.0
# 2  SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...  51.00  540000.0
# 3  ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000.0
# 4  Przedstawiamy na sprzedaż 3 pokojowe mieszkani...  48.00  459000.0
#
#    PricePerSquareMeter  NumberOfRooms  BuiltYear        Type  ...  \
# 0             10500.00            3.0 2005-01-01  Mieszkania  ...
# 1              8333.33            3.0        NaT  Mieszkania  ...
# 2             10588.00            3.0 2013-01-01  Mieszkania  ...
# 3              8044.96            3.0 2023-01-01  Mieszkania  ...
# 4              9563.00            3.0        NaT  Mieszkania  ...
#
#   NumberOfCommunityComments NumberOfCommunityOpinions  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#                                             Location  VoivodeshipNumber  \
# 0                       Podlaskie, Białystok, Bojary               20.0
# 1                     Podlaskie, Białystok, Antoniuk               20.0
# 2                     Podlaskie, Białystok, Bagnówka               20.0
# 3  Podlaskie, Białystok, Ul. Józefa Karola Puchal...               20.0
# 4              Podlaskie, Białystok, Ul. Dziesięciny               20.0
#
#   CountyNumber CommunityNumber KindNumber RegionNumber StreetNumber  \
# 0         61.0             1.0        1.0     922490.0          NaN
# 1         61.0             1.0        1.0     922426.0          NaN
# 2         61.0             1.0        1.0     922461.0          NaN
# 3         61.0             1.0        1.0     922410.0      43141.0
# 4         61.0             1.0        1.0     922410.0       4656.0
#
#                 EncryptedId
# 0  02TgImo1wm-Ra4zUQxoPBw==
# 1  D-NUdVbtN3_kIW7ExgXkvA==
# 2  lmBSU1XiXLSLOq1yKSe2kA==
# 3  HWachf5gb6Vq-sFYH4YWnA==
# 4  AWsmt4ZY0X7lNv-6fSCn9Q==
#
# [5 rows x 41 columns]

# %%
df_price2.isnull().sum()
# Out:
# SaleId                            0
# OriginalId                   968696
# PortalId                          0
# Title                             0
# Description                    6033
# Area                              0
# Price                             0
# OfferPrice                   891706
# RealPriceAfterRenovation     891706
# OriginalPrice                867336
# PricePerSquareMeter            1087
# NumberOfRooms                 10648
# BuiltYear                    339100
# Type                              0
# BuildingType                 153500
# BuildingCondition            904569
# OfferFrom                       789
# Floor                         48234
# Floors                       436534
# TypeOfMarket                  27802
# OwnerType                    466260
# DateAddedToDatabase               0
# DateAdded                         0
# DateLastModification         747906
# DateLastRaises               717920
# NewestDate                        0
# AvailableFrom                968696
# Link                              0
# Phone                        191773
# MainImage                     18016
# OtherImages                  317028
# NumberOfDuplicates                0
# NumberOfRaises                    0
# NumberOfModifications             0
# IsDuplicatePriceLower             0
# IsDuplicatePrivateOwner           0
# Score                             0
# ScorePrecision                    0
# CommunityScore               175557
# NumberOfCommunityComments    175557
# NumberOfCommunityOpinions    175558
# Archive                      968696
# Location                        403
# VoivodeshipNumber               894
# CountyNumber                    894
# CommunityNumber              113299
# KindNumber                   113299
# RegionNumber                 183298
# SubRegionNumber              968696
# StreetNumber                 571970
# EncryptedId                     170
# dtype: int64

# %%
df_price2.plot.scatter(x='Area', y='Price');

# %%
df_price2.plot.scatter(x='BuiltYear', y='Price');

# %%
correlation_matrix = df_price2[['Area', 'Price', 'BuiltYear', 'Floor', 'Floors', 'CommunityScore', 'CountyNumber', 'CommunityNumber',
                               'RegionNumber','KindNumber']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Price')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Price')

# %%
sale_ids = df_price2['SaleId'].reset_index(drop=True)

# %%
train_df = df_price2.sample(frac=0.9, random_state=42)
holdout_df = df_price2.drop(train_df.index)

# %%
df_price2['VoivodeshipNumber'] = df_price2['VoivodeshipNumber'].astype(str)
df_price2['CountyNumber'] = df_price2['CountyNumber'].astype(str)
df_price2['CommunityNumber'] = df_price2['CommunityNumber'].astype(str)
df_price2['KindNumber'] = df_price2['KindNumber'].astype(str)
df_price2['RegionNumber'] = df_price2['RegionNumber'].astype(str)
if 'StreetNumber' in df_price2.columns:
    df_price2['StreetNumber'] = df_price2['StreetNumber'].astype(str)

# %%
categorical_features_initial = [
    'BuildingType', 'BuildingCondition', 'TypeOfMarket', 'OwnerType', 'Type', 'OfferFrom',
    'VoivodeshipNumber', 'CountyNumber', 'CommunityNumber', 'KindNumber',
    'RegionNumber',
    'Location' # Dodajemy Location do kategorycznych
]
numeric_features_initial = [
    'Area', 'NumberOfRooms', 'Floor', 'Floors', 'CommunityScore'
]
date_features_initial = ['BuiltYear']

# Filtruj cechy, które faktycznie istnieją w df_price3
categorical_features_to_use = [col for col in categorical_features_initial if col in df_price2.columns]
numeric_features_to_use = [col for col in numeric_features_initial if col in df_price2.columns]
date_features_to_use = [col for col in date_features_initial if col in df_price2.columns]

# Definicja cech ignorowanych
ignore_features_list = [
    'SaleId', 'OriginalId', 'PortalId', 'Title', 'Description',
    'OfferPrice', 'RealPriceAfterRenovation', 'OriginalPrice',
    'PricePerSquareMeter', 'DateAddedToDatabase', 'DateAdded',
    'DateLastModification', 'DateLastRaises', 'NewestDate',
    'AvailableFrom', 'Link', 'Phone', 'MainImage', 'OtherImages',
    'NumberOfDuplicates', 'NumberOfRaises', 'NumberOfModifications',
    'IsDuplicatePriceLower', 'IsDuplicatePrivateOwner', 'Score', 'ScorePrecision',
    'NumberOfCommunityComments', 'NumberOfCommunityOpinions', 'Archive',
    'SubRegionNumber', 'EncryptedId',
    'StreetNumber' # Ignorujemy, bo może mieć zbyt wiele unikalnych wartości
]
# Filtruj ignorowane cechy, aby upewnić się, że są w DataFrame
ignore_features_list = [col for col in ignore_features_list if col in df_price2.columns]

transformed_exp = setup(
    data=df_price2,
    target='Price',
    verbose=True, # Ustaw na True dla debugowania setup
    session_id=123,
    log_experiment=True,
    experiment_name=MLFLOW_EXPERIMENT_NAME, 
    log_data=True, 
    log_plots=True, 
    categorical_features=categorical_features_to_use,
    numeric_features=numeric_features_to_use,
    date_features=date_features_to_use,
    # text_features=['Location'], # Usunięte na razie, przeniesione do categorical
    ignore_features=ignore_features_list,
    ordinal_features={'BuildingType': ['Pozostałe', 'Blok', 'Apartamentowiec', 'Kamienica'],
                      'BuildingCondition': ['For_Renovation', 'Good', 'After_Renovation', 'Developer_State']},
    # Dla starszych wersji PyCaret, obsługa wysokiej kardynalności jest często domyślna    # lub można spróbować:
    # high_cardinality_method = 'frequency' # jeśli 'Location' ma dużo kategorii
    # lub zostawić domyślne zachowanie PyCaret dla cech kategorycznych
)
best_transformed_model = transformed_exp.compare_models()
transformed_metrics_df = pull()
# Out:
# <style type="text/css">
# #T_2597e_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2597e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2597e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2597e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2597e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2597e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2597e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2597e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2597e_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2597e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2597e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2597e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2597e_row3_col1" class="data row3 col1" >(968696, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2597e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2597e_row4_col1" class="data row4 col1" >(968696, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2597e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2597e_row5_col1" class="data row5 col1" >(678087, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2597e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2597e_row6_col1" class="data row6 col1" >(290609, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2597e_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_2597e_row7_col1" class="data row7 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2597e_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_2597e_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2597e_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_2597e_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2597e_row10_col0" class="data row10 col0" >Date features</td>
#       <td id="T_2597e_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2597e_row11_col0" class="data row11 col0" >Categorical features</td>
#       <td id="T_2597e_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2597e_row12_col0" class="data row12 col0" >Rows with missing values</td>
#       <td id="T_2597e_row12_col1" class="data row12 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2597e_row13_col0" class="data row13 col0" >Preprocess</td>
#       <td id="T_2597e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2597e_row14_col0" class="data row14 col0" >Imputation type</td>
#       <td id="T_2597e_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2597e_row15_col0" class="data row15 col0" >Numeric imputation</td>
#       <td id="T_2597e_row15_col1" class="data row15 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2597e_row16_col0" class="data row16 col0" >Categorical imputation</td>
#       <td id="T_2597e_row16_col1" class="data row16 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2597e_row17_col0" class="data row17 col0" >Maximum one-hot encoding</td>
#       <td id="T_2597e_row17_col1" class="data row17 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2597e_row18_col0" class="data row18 col0" >Encoding method</td>
#       <td id="T_2597e_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2597e_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_2597e_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2597e_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_2597e_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2597e_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_2597e_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2597e_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_2597e_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2597e_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_2597e_row23_col1" class="data row23 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2597e_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_2597e_row24_col1" class="data row24 col1" >Investoro_Ceny</td>
#     </tr>
#     <tr>
#       <th id="T_2597e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2597e_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_2597e_row25_col1" class="data row25 col1" >c83a</td>
#     </tr>
#   </tbody>
# </table>
# 2025/05/22 11:39:01 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          11:39:13
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Regression
# <style type="text/css">
# #T_3ad88 th {
#   text-align: left;
# }
# #T_3ad88_row0_col0, #T_3ad88_row0_col1, #T_3ad88_row0_col2, #T_3ad88_row0_col3, #T_3ad88_row0_col4, #T_3ad88_row0_col5, #T_3ad88_row0_col6, #T_3ad88_row0_col7, #T_3ad88_row1_col0, #T_3ad88_row1_col1, #T_3ad88_row1_col2, #T_3ad88_row1_col3, #T_3ad88_row1_col4, #T_3ad88_row1_col5, #T_3ad88_row1_col6, #T_3ad88_row1_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_3ad88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ad88_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ad88_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3ad88_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3ad88_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3ad88_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3ad88_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3ad88_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3ad88_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ad88_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_3ad88_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_3ad88_row0_col1" class="data row0 col1" >90306.6090</td>
#       <td id="T_3ad88_row0_col2" class="data row0 col2" >15667325341.3267</td>
#       <td id="T_3ad88_row0_col3" class="data row0 col3" >125167.7285</td>
#       <td id="T_3ad88_row0_col4" class="data row0 col4" >0.7317</td>
#       <td id="T_3ad88_row0_col5" class="data row0 col5" >0.4528</td>
#       <td id="T_3ad88_row0_col6" class="data row0 col6" >38.3658</td>
#       <td id="T_3ad88_row0_col7" class="data row0 col7" >2.3800</td>
#     </tr>
#     <tr>
#       <th id="T_3ad88_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_3ad88_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_3ad88_row1_col1" class="data row1 col1" >90306.2722</td>
#       <td id="T_3ad88_row1_col2" class="data row1 col2" >15667413176.7649</td>
#       <td id="T_3ad88_row1_col3" class="data row1 col3" >125168.0779</td>
#       <td id="T_3ad88_row1_col4" class="data row1 col4" >0.7317</td>
#       <td id="T_3ad88_row1_col5" class="data row1 col5" >0.4528</td>
#       <td id="T_3ad88_row1_col6" class="data row1 col6" >38.3647</td>
#       <td id="T_3ad88_row1_col7" class="data row1 col7" >12.7690</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
transformed_exp.X_train_transformed.info()

# %%
transformed_exp.X_train_transformed.head()

# %%
from pycaret.regression import get_config
import matplotlib.pyplot as plt
import seaborn as sns

# Wyciągnij dane oryginalne i przetransformowane
df_raw = df_price2.copy()
df_transformed = get_config("X_train").copy()
df_transformed["Price"] = get_config("y_train")

# Rysowanie wykresów
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(df_raw["Price"], ax=axes[0])
axes[0].set_title("Raw Data")

sns.histplot(df_transformed["Price"], ax=axes[1])
axes[1].set_title("Transformed Data")

plt.tight_layout()
plt.show()

# %%
transformed_exp.dataset.head()

# %%
transformed_exp.dataset_transformed.head()

# %%
df_transformed.plot.scatter(x='Area', y='Price');

# %%
df_transformed.plot.scatter(x='BuiltYear', y='Price');

# %%
plt.figure(figsize=(12, 6))
plt.barh(transformed_metrics_df['Model'], transformed_metrics_df['R2'], color='skyblue')
plt.xlabel('R2')
plt.title('Porównanie dokładności modeli')
plt.gca().invert_yaxis()  # najlepszy model na górze
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
transformed_exp.plot_model(best_transformed_model, plot='error')

# %%
transformed_exp.plot_model(best_transformed_model, plot='feature')

# %%
tuned_model = transformed_exp.tune_model(best_transformed_model, n_iter=3, optimize='R2',choose_better=True)

# %%
#RF nie posiada parametru tuned_model - pominąć w przypadku rf
#tuned_best_models = [best_transformed_model.tune_model(m, optimize='R2') for m in tuned_model]

# %%
# pominąć dla rf
#best_model = transformed_exp.compare_models([tuned_best_models, tuned_model],choose_better=True)

# %%
best_model = transformed_exp.compare_models(tuned_model, sort='R2')

# %%
transformed_exp.predict_model(best_model)

# %%
transformed_exp.plot_model(best_model, plot='error')

# %%
transformed_exp.plot_model(best_model, plot='feature')

# %%
transformed_exp.predict_model(best_model).head(10)

# %%
transformed_exp.plot_model(best_model, plot='error')

# %%
transformed_exp.plot_model(best_model, plot='feature')

# %%
best_final_model = transformed_exp.finalize_model(best_model, experiment_custom_tags={"step": "final"})
best_final_model

# %%
transformed_exp.save_model(best_final_model, '0_full-basic-model')

# %%
transformed_exp.predict_model(best_final_model, data=holdout_df)
predict_holdout_df = transformed_exp.pull()

# %%
mlflow_exp = mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
runs_df = mlflow.search_runs([mlflow_exp.experiment_id], order_by=["start_time DESC"])
run_id = runs_df['run_id'].values[0]
metrics = predict_holdout_df.drop(columns=["Model"]).to_dict(orient='records')[0]

with mlflow.start_run(run_id=run_id, nested=True):
    for key, value in metrics.items():
        mlflow.log_metric(key, value)

# %%
#predictions = transformed_exp.predict_model(best_final_model)
holdout_predictions = transformed_exp.predict_model(best_final_model) # Zapisz wynik predykcji
display(holdout_predictions.head()) # Wyświetl kilka pierwszych predykcji

# %%
#predicted_column = predict_holdout_df['prediction_label']
#print(predicted_column)
holdout_metrics_df = transformed_exp.pull() # Teraz pobierz metryki z tej predykcji
display(holdout_metrics_df)
predicted_column = holdout_predictions['prediction_label'] # Jeśli chcesz samą kolumnę predykcji
print(predicted_column)

# %%
print(holdout_predictions[['prediction_label']].applymap('{:,.0f}'.format))

# %%
df_last=holdout_predictions[['prediction_label','Price', ]].applymap('{:,.0f}'.format)

# %%
df_last.to_csv('0_new_prices.csv')

# %%
print(df_last.columns)

# %%
print(df_last.head())

# %%
df_last = df_last.reset_index()  
print(df_last.columns)

# %%
df_last.rename(columns={'index': 'SaleId'}, inplace=True)

# %%
saleflats_df = pd.read_csv('sale_2024_0.csv')

# %%
new_prices_df = pd.read_csv('0_new_prices.csv')

# %%
print("saleflats_df.columns:", saleflats_df.columns.tolist())

# %%
print("new_prices_df.columns:", new_prices_df.columns.tolist())

# %%
new_prices_df = new_prices_df.rename(columns={'Unnamed: 0': 'SaleId', 'Price': 'NewPrice'})

# %%
print("new_prices_df.columns:", new_prices_df.columns.tolist())

# %%
print(new_prices_df.columns)

# %%
print(saleflats_df.columns)

# %%
merged_df = pd.merge(
    saleflats_df,
    new_prices_df[['SaleId', 'NewPrice']],
    left_on='SaleId',  # Kolumna w saleflats_df
    right_on='SaleId',  # Kolumna w new_prices_df
    how='left'
)

# %%
merged_df

# %%
# Krok 2: usuwanie dodatkowej kolumny klucza (opcjonalnie, bo mamy już 'SaleId')
#merged_df.drop(columns=['SaleID'], inplace=True)

# Krok 3: przestawienie kolumny 'NewPrice' obok 'Price'
cols = merged_df.columns.tolist()

# znajdź indeks kolumny 'Price'
price_index = cols.index('Price')

# usuń NewPrice z listy i dodaj ją zaraz po Price
cols.remove('NewPrice')
cols.insert(price_index + 1, 'NewPrice')

# ustaw nową kolejność kolumn
merged_df = merged_df[cols]

# %%
merged_df

# %%
merged_df[merged_df.duplicated()]

# %%
prediction_df = merged_df.copy()

# %%
from pycaret.regression import predict_model

# %%
prediction_df['BuiltYear'] = pd.to_datetime(prediction_df['BuiltYear'], format='%Y', errors='coerce')

# %%
prediction_df_clean = prediction_df.drop(columns=['Price'], errors='ignore')
predictions = predict_model(best_final_model, data=prediction_df_clean)

# %%
predictions['RealPrice'] = prediction_df['Price']

# %%
merged_df['PredictedPrice'] = predictions['prediction_label']

# %%
predictions=predictions[['prediction_label',]].applymap('{:,.0f}'.format)

# %%
# Przenieś kolumnę 'PredictedPrice' za 'NewPrice'
cols = list(merged_df.columns)
new_price_index = cols.index('NewPrice')
# Usuń z listy kolumn
cols.remove('PredictedPrice')
# Dodaj w odpowiednie miejsce
cols.insert(new_price_index + 1, 'PredictedPrice')
# Przekształć DataFrame
merged_df = merged_df[cols]

# %%
merged_df.to_csv('0_new_prices_full.csv')

# %%
merged_df = pd.read_csv('0_new_prices_full.csv')

# %%
merged_df

# %%
merged_df2=merged_df[['PredictedPrice',]].applymap('{:,.0f}'.format)

# %%
merged_df2

# %%
merged_df['PredictedPrice'] = merged_df2['PredictedPrice']

# %%
merged_df.drop(columns=['NewPrice'], inplace=True)

# %%
merged_df

# %%
merged_df.to_csv('full_uzup_mieszkania_ceny.csv')

# %%
# df_p = pd.read_csv('sale_2024_6.csv')

# %% [markdown]
# # 1. Kopia oryginalnej dużej tabeli
# df = df_p.copy()
#
# # 2. Dopinamy kolumnę z predykcjami po SaleId
# if 'NewPrices' in merged_df.columns:
#     df = df.merge(merged_df[['SaleId', 'NewPrices']], on='SaleId', how='left')
# elif 'PredictedPrice' in merged_df.columns:
#     df = df.merge(merged_df[['SaleId', 'PredictedPrice']].rename(columns={'PredictedPrice': 'NewPrices'}), on='SaleId', how='left')
# else:
#     raise ValueError("W merged_df nie znaleziono kolumny 'NewPrices' ani 'PredictedPrice'")
#
# # 3. Tam, gdzie jest dostępna cena ('Price'), kopiujemy ją do 'NewPrices'
# df.loc[df['Price'].notna(), 'NewPrices'] = df.loc[df['Price'].notna(), 'Price']
#
# # 4. Przenosimy kolumnę 'NewPrices' za 'Price'
# cols = df.columns.tolist()
# if 'NewPrices' in cols:
#     cols.remove('NewPrices')
#     price_idx = cols.index('Price')
#     cols.insert(price_idx + 1, 'NewPrices')
#     df = df[cols]
#
# # 5. Załaduj model z PyCaret
# model = load_model('6_best_price_modelLGBM')
#
# # 6. Przygotuj dane bez kolumny 'Price', by uniknąć błędu z NaN
# df_for_prediction = df.drop(columns=['Price'], errors='ignore')
#
# # 7. Przeprowadź predykcję
# predicted_df = predict_model(model, data=df_for_prediction)
#
# # 8. Powiąż wynik predykcji po SaleID
# df = df.merge(predicted_df[['SaleID', 'prediction_label']], on='SaleID', how='left', suffixes=('', '_new'))
#
# # 9. Nadpisz kolumnę 'NewPrices' nowymi przewidywaniami
# df['NewPrices'] = df['prediction_label']
#
# # 10. Przenosimy kolumnę 'NewPrices' za 'Price' (jeszcze raz)
# cols = df.columns.tolist()
# if 'NewPrices' in cols:
#     cols.remove('NewPrices')
#     price_idx = cols.index('Price')
#     cols.insert(price_idx + 1, 'NewPrices')
#     df = df[cols]
#
# # 11. Zaktualizuj saleflats_b
# saleflats_b = df

# %% [markdown]
# df2=df[['NewPrices',]].applymap('{:,.0f}'.format)

# %% [markdown]
# # Nadpisanie kolumny 'NewPrices' w df sformatowaną wersją
# df['NewPrices'] = df2['NewPrices']

# %% [markdown]
# df

# %% [markdown]
# df.to_csv('6_new_prices_FULL2.csv')

# %% [markdown]
# df.sample(100)
