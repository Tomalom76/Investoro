# %%
# === SEKCJA 1: IMPORT I WCZYTANIE DANYCH ===
import pandas as pd
import numpy as np
import re
import os
import pickle
import matplotlib.pyplot as plt
import warnings

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Concatenate, Dense, Dropout, BatchNormalization, LeakyReLU, Reshape, Flatten
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Ignorowanie specyficznych ostrzeżeń
warnings.filterwarnings('ignore', category=pd.errors.DtypeWarning)
# Wstępna konfiguracja GPU, jeśli jest dostępne
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

print("--- Wczytywanie danych ---\n")
try:
    df_main_raw = pd.read_csv('saleflats_mazowieckie_c.csv', sep=',', header=None, on_bad_lines='skip', low_memory=False)
    df_slownik = pd.read_csv('slownik_finalny_z_hierarchia.csv', sep=';')
    print("Pliki wczytane pomyślnie.")
except FileNotFoundError as e:
    print(f"BŁĄD: Nie znaleziono pliku: {e.filename}.")
    raise

# --- Przygotowanie danych (identyczne jak w Twoim notatniku) ---
print("\n--- Przygotowanie danych do modelu ---")
df_main = df_main_raw.copy()
df_main.columns = [i for i in range(53)] + ['WojewodztwoID', 'PowiatID', 'GminaID', 'RodzajGminyID', 'MiastoID', 'DzielnicaID', 'UlicaID']
main_cols_map = {0: 'SaleId', 4: 'Description', 5: 'Area', 6: 'Price', 17: 'NumberOfRooms', 35: 'Floor', 36: 'Floors'}
df_main.rename(columns=main_cols_map, inplace=True)

numeric_features = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors']
id_features = ['UlicaID']
for col in numeric_features + id_features:
    df_main[col] = pd.to_numeric(df_main[col], errors='coerce')
df_main.dropna(subset=['Description'] + numeric_features + id_features, inplace=True)
df_main['UlicaID'] = df_main['UlicaID'].astype(int)

df_merged = pd.merge(df_main, df_slownik, on='UlicaID', how='inner')
print(f"Liczba ofert po połączeniu ze słownikiem: {len(df_merged)}")

df_model_ready = df_merged.copy()
df_model_ready['description_enriched'] = (df_model_ready['Dzielnica_Name'] + " " + df_model_ready['Ulica_Name'] + " ") * 5 + df_model_ready['Description']
def clean_text(text): return re.sub(r'[^a-ząęółśżźćń ]', '', str(text).lower())
df_model_ready['description_clean'] = df_model_ready['description_enriched'].apply(clean_text)

MAX_WORDS, MAX_LEN = 20000, 250
tokenizer = Tokenizer(num_words=MAX_WORDS, oov_token="<unk>")
tokenizer.fit_on_texts(df_model_ready['description_clean'])
X_text = pad_sequences(tokenizer.texts_to_sequences(df_model_ready['description_clean']), maxlen=MAX_LEN)

df_model_ready['Price_per_sqm'] = df_model_ready['Price'] / df_model_ready['Area']
df_model_ready['Price_per_sqm'].replace([np.inf, -np.inf], np.nan, inplace=True)
numeric_features_cols = ['Area', 'Price', 'NumberOfRooms', 'Floor', 'Floors', 'Price_per_sqm']
numeric_pipeline = Pipeline([('imputer', SimpleImputer(strategy='median')), ('scaler', StandardScaler())])
X_numeric = numeric_pipeline.fit_transform(df_model_ready[numeric_features_cols])

le_dzielnica = LabelEncoder()
y_dzielnica = le_dzielnica.fit_transform(df_model_ready['Dzielnica_Name'])
num_classes_dzielnica = len(le_dzielnica.classes_)
le_ulica = LabelEncoder()
y_ulica = le_ulica.fit_transform(df_model_ready['Ulica_Name'])
num_classes_ulica = len(le_ulica.classes_)

print(f"\nProblem przygotowany do modelowania:")
print(f" - Liczba klas (dzielnice): {num_classes_dzielnica}")
print(f" - Liczba klas (ulice): {num_classes_ulica}")

# Podział na zbiory TRENINGOWY i WALIDACYJNY
# To jest KLUCZOWE: zbiór walidacyjny pozostanie NIETKNIĘTY. Augmentować będziemy TYLKO zbiór treningowy.
train_indices, val_indices = train_test_split(range(len(df_model_ready)), test_size=0.2, random_state=42, stratify=y_dzielnica)

X_train_text, X_val_text = X_text[train_indices], X_text[val_indices]
X_train_num, X_val_num = X_numeric[train_indices], X_numeric[val_indices]
y_train_dzielnica, y_val_dzielnica = y_dzielnica[train_indices], y_dzielnica[val_indices]
y_train_ulica, y_val_ulica = y_ulica[train_indices], y_ulica[val_indices]

print("\nDane podzielone na zbiory treningowe i walidacyjne.")
print(f"Rozmiar zbioru treningowego: {len(X_train_text)}")
print(f"Rozmiar zbioru walidacyjnego: {len(X_val_text)}")
# Out:
# --- Wczytywanie danych ---
#
# Pliki wczytane pomyślnie.
#
# --- Przygotowanie danych do modelu ---
# Liczba ofert po połączeniu ze słownikiem: 9548
#
# Problem przygotowany do modelowania:
#  - Liczba klas (dzielnice): 18
#  - Liczba klas (ulice): 703
#
# Dane podzielone na zbiory treningowe i walidacyjne.
# Rozmiar zbioru treningowego: 7638
# Rozmiar zbioru walidacyjnego: 1910
# C:\Users\Ai\AppData\Local\Temp\ipykernel_5388\3355088492.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_model_ready['Price_per_sqm'].replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# === SEKCJA 2: BUDOWA I KOMPILACJA MODELU Z PRIORYTETEM DLA TEKSTU ===

def build_priority_classifier(num_classes_d, num_classes_u, max_words, max_len, num_numeric_features):
    """Definiuje architekturę modelu z trzema głowami wyjściowymi."""
    # --- Wejścia ---
    input_text = Input(shape=(max_len,), name='text_input')
    input_numeric = Input(shape=(num_numeric_features,), name='numeric_input')
    
    # --- Trzon tekstowy ---
    text_embedding = Embedding(input_dim=max_words, output_dim=128)(input_text)
    lstm_out = LSTM(128, dropout=0.3, name='lstm_layer')(text_embedding)
    
    # --- Gałąź wyjściowa TYLKO dla tekstu (dla dzielnicy) ---
    text_only_branch = Dense(64, activation='relu')(lstm_out)
    text_only_branch = Dropout(0.5)(text_only_branch)
    output_dzielnica_text = Dense(num_classes_d, activation='softmax', name='output_dzielnica_text')(text_only_branch)

    # --- Gałąź połączona (tekst + dane numeryczne) ---
    concatenated = Concatenate()([lstm_out, input_numeric])
    common_dense = Dense(128, activation='relu')(concatenated)
    common_dense = Dropout(0.5)(common_dense)

    # Wyjście dla dzielnicy z danych połączonych
    dzielnica_combined_branch = Dense(64, activation='relu')(common_dense)
    output_dzielnica_combined = Dense(num_classes_d, activation='softmax', name='output_dzielnica_combined')(dzielnica_combined_branch)
    
    # Wyjście dla ulicy z danych połączonych
    ulica_combined_branch = Dense(256, activation='relu')(common_dense)
    output_ulica_combined = Dense(num_classes_u, activation='softmax', name='output_ulica_combined')(ulica_combined_branch)
    
    # --- Model z trzema wyjściami ---
    model = Model(
        inputs=[input_text, input_numeric], 
        outputs=[output_dzielnica_text, output_dzielnica_combined, output_ulica_combined]
    )
    
    # --- Definicja strat i wag ---
    losses = {
        "output_dzielnica_text": "sparse_categorical_crossentropy",
        "output_dzielnica_combined": "sparse_categorical_crossentropy",
        "output_ulica_combined": "sparse_categorical_crossentropy",
    }
    
    loss_weights = {
        "output_dzielnica_text": 2.0,      # <-- Błąd tutaj jest karany 2x mocniej!
        "output_dzielnica_combined": 1.0,  # <-- Standardowa waga
        "output_ulica_combined": 0.5       # <-- Mniejsza waga, bo to trudniejsze zadanie
    }
    
    metrics = {
        "output_dzielnica_text": "accuracy",
        "output_dzielnica_combined": "accuracy",
        "output_ulica_combined": "accuracy"
    }
    
    model.compile(
        optimizer='adam',
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )
    return model

print("\n--- Budowa i kompilacja modelu z priorytetem dla tekstu ---")
# Tworzymy instancję nowego modelu
priority_model = build_priority_classifier(
    num_classes_d=num_classes_dzielnica,
    num_classes_u=num_classes_ulica,
    max_words=MAX_WORDS,
    max_len=MAX_LEN,
    num_numeric_features=X_train_num.shape[1]
)
priority_model.summary()
# Out:
# --- Budowa i kompilacja modelu z priorytetem dla tekstu ---
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)       │ (None, 250)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 250, 128)          │       2,560,000 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_layer (LSTM)             │ (None, 128)               │         131,584 │ embedding[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ numeric_input (InputLayer)    │ (None, 6)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 134)               │               0 │ lstm_layer[0][0],          │
# │                               │                           │                 │ numeric_input[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │          17,280 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64)                │           8,256 │ lstm_layer[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 64)                │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64)                │           8,256 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │          33,024 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ output_dzielnica_text (Dense) │ (None, 18)                │           1,170 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ output_dzielnica_combined     │ (None, 18)                │           1,170 │ dense_2[0][0]              │
# │ (Dense)                       │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ output_ulica_combined (Dense) │ (None, 703)               │         180,671 │ dense_3[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,941,411 (11.22 MB)
#  Trainable params: 2,941,411 (11.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# === SEKCJA 3: TRENING MODELU Z PRIORYTETEM ---

# Przygotowanie danych wejściowych i wyjściowych
X_train = [X_train_text, X_train_num]
y_train = {
    'output_dzielnica_text': y_train_dzielnica,
    'output_dzielnica_combined': y_train_dzielnica,
    'output_ulica_combined': y_train_ulica
}

X_val = [X_val_text, X_val_num]
y_val = {
    'output_dzielnica_text': y_val_dzielnica,
    'output_dzielnica_combined': y_val_dzielnica,
    'output_ulica_combined': y_val_ulica
}

# Definicja callbacków
callbacks = [
    EarlyStopping(monitor='val_output_ulica_combined_accuracy', patience=5, restore_best_weights=True, verbose=1, mode='max'),
    ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1)
]

print("\n--- Rozpoczynam trening modelu z priorytetem ---")
history_priority = priority_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)
# Out:
# --- Rozpoczynam trening modelu z priorytetem ---
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 395ms/step - loss: 10.6614 - output_dzielnica_combined_accuracy: 0.2416 - output_dzielnica_combined_loss: 2.5224 - output_dzielnica_text_accuracy: 0.2572 - output_dzielnica_text_loss: 2.5977 - output_ulica_combined_accuracy: 0.1259 - output_ulica_combined_loss: 5.8869 - val_loss: 8.1940 - val_output_dzielnica_combined_accuracy: 0.4178 - val_output_dzielnica_combined_loss: 1.8276 - val_output_dzielnica_text_accuracy: 0.3230 - val_output_dzielnica_text_loss: 2.0074 - val_output_ulica_combined_accuracy: 0.1832 - val_output_ulica_combined_loss: 4.7018 - learning_rate: 0.0010
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 368ms/step - loss: 8.1620 - output_dzielnica_combined_accuracy: 0.4236 - output_dzielnica_combined_loss: 1.8285 - output_dzielnica_text_accuracy: 0.3283 - output_dzielnica_text_loss: 2.0266 - output_ulica_combined_accuracy: 0.2049 - output_ulica_combined_loss: 4.5607 - val_loss: 7.8494 - val_output_dzielnica_combined_accuracy: 0.4733 - val_output_dzielnica_combined_loss: 1.7076 - val_output_dzielnica_text_accuracy: 0.3461 - val_output_dzielnica_text_loss: 1.9331 - val_output_ulica_combined_accuracy: 0.2058 - val_output_ulica_combined_loss: 4.5492 - learning_rate: 0.0010
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 369ms/step - loss: 7.6031 - output_dzielnica_combined_accuracy: 0.4605 - output_dzielnica_combined_loss: 1.6730 - output_dzielnica_text_accuracy: 0.3598 - output_dzielnica_text_loss: 1.8743 - output_ulica_combined_accuracy: 0.2032 - output_ulica_combined_loss: 4.3628 - val_loss: 7.0782 - val_output_dzielnica_combined_accuracy: 0.5257 - val_output_dzielnica_combined_loss: 1.5166 - val_output_dzielnica_text_accuracy: 0.4351 - val_output_dzielnica_text_loss: 1.6911 - val_output_ulica_combined_accuracy: 0.2220 - val_output_ulica_combined_loss: 4.3583 - learning_rate: 0.0010
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 366ms/step - loss: 6.9365 - output_dzielnica_combined_accuracy: 0.5466 - output_dzielnica_combined_loss: 1.4791 - output_dzielnica_text_accuracy: 0.4331 - output_dzielnica_text_loss: 1.7037 - output_ulica_combined_accuracy: 0.2341 - output_ulica_combined_loss: 4.1006 - val_loss: 7.9196 - val_output_dzielnica_combined_accuracy: 0.4942 - val_output_dzielnica_combined_loss: 1.7265 - val_output_dzielnica_text_accuracy: 0.3702 - val_output_dzielnica_text_loss: 1.9731 - val_output_ulica_combined_accuracy: 0.2079 - val_output_ulica_combined_loss: 4.4906 - learning_rate: 0.0010
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 371ms/step - loss: 8.3000 - output_dzielnica_combined_accuracy: 0.4454 - output_dzielnica_combined_loss: 1.8093 - output_dzielnica_text_accuracy: 0.3307 - output_dzielnica_text_loss: 2.1635 - output_ulica_combined_accuracy: 0.2141 - output_ulica_combined_loss: 4.3275 - val_loss: 7.2583 - val_output_dzielnica_combined_accuracy: 0.5408 - val_output_dzielnica_combined_loss: 1.5401 - val_output_dzielnica_text_accuracy: 0.4346 - val_output_dzielnica_text_loss: 1.7750 - val_output_ulica_combined_accuracy: 0.2225 - val_output_ulica_combined_loss: 4.3344 - learning_rate: 0.0010
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 369ms/step - loss: 7.4719 - output_dzielnica_combined_accuracy: 0.5035 - output_dzielnica_combined_loss: 1.6191 - output_dzielnica_text_accuracy: 0.3986 - output_dzielnica_text_loss: 1.9088 - output_ulica_combined_accuracy: 0.2202 - output_ulica_combined_loss: 4.0700 - val_loss: 7.0190 - val_output_dzielnica_combined_accuracy: 0.5592 - val_output_dzielnica_combined_loss: 1.4513 - val_output_dzielnica_text_accuracy: 0.4309 - val_output_dzielnica_text_loss: 1.7220 - val_output_ulica_combined_accuracy: 0.2340 - val_output_ulica_combined_loss: 4.2439 - learning_rate: 0.0010
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 371ms/step - loss: 6.9241 - output_dzielnica_combined_accuracy: 0.5484 - output_dzielnica_combined_loss: 1.4803 - output_dzielnica_text_accuracy: 0.4285 - output_dzielnica_text_loss: 1.7444 - output_ulica_combined_accuracy: 0.2381 - output_ulica_combined_loss: 3.9100 - val_loss: 6.8975 - val_output_dzielnica_combined_accuracy: 0.5634 - val_output_dzielnica_combined_loss: 1.4265 - val_output_dzielnica_text_accuracy: 0.4503 - val_output_dzielnica_text_loss: 1.6771 - val_output_ulica_combined_accuracy: 0.2335 - val_output_ulica_combined_loss: 4.2313 - learning_rate: 0.0010
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - loss: 6.9500 - output_dzielnica_combined_accuracy: 0.5412 - output_dzielnica_combined_loss: 1.4792 - output_dzielnica_text_accuracy: 0.4205 - output_dzielnica_text_loss: 1.7618 - output_ulica_combined_accuracy: 0.2232 - output_ulica_combined_loss: 3.8943 - val_loss: 6.9486 - val_output_dzielnica_combined_accuracy: 0.5691 - val_output_dzielnica_combined_loss: 1.4291 - val_output_dzielnica_text_accuracy: 0.4450 - val_output_dzielnica_text_loss: 1.7052 - val_output_ulica_combined_accuracy: 0.2403 - val_output_ulica_combined_loss: 4.2157 - learning_rate: 0.0010
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - loss: 6.6287 - output_dzielnica_combined_accuracy: 0.5673 - output_dzielnica_combined_loss: 1.4133 - output_dzielnica_text_accuracy: 0.4537 - output_dzielnica_text_loss: 1.6711 - output_ulica_combined_accuracy: 0.2378 - output_ulica_combined_loss: 3.7463 - val_loss: 6.7809 - val_output_dzielnica_combined_accuracy: 0.5717 - val_output_dzielnica_combined_loss: 1.3875 - val_output_dzielnica_text_accuracy: 0.4613 - val_output_dzielnica_text_loss: 1.6547 - val_output_ulica_combined_accuracy: 0.2361 - val_output_ulica_combined_loss: 4.1652 - learning_rate: 0.0010
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 369ms/step - loss: 6.2929 - output_dzielnica_combined_accuracy: 0.6061 - output_dzielnica_combined_loss: 1.3181 - output_dzielnica_text_accuracy: 0.4991 - output_dzielnica_text_loss: 1.5697 - output_ulica_combined_accuracy: 0.2520 - output_ulica_combined_loss: 3.6710 - val_loss: 6.8092 - val_output_dzielnica_combined_accuracy: 0.5749 - val_output_dzielnica_combined_loss: 1.3984 - val_output_dzielnica_text_accuracy: 0.4702 - val_output_dzielnica_text_loss: 1.6604 - val_output_ulica_combined_accuracy: 0.2429 - val_output_ulica_combined_loss: 4.1794 - learning_rate: 0.0010
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 373ms/step - loss: 6.2951 - output_dzielnica_combined_accuracy: 0.5936 - output_dzielnica_combined_loss: 1.3308 - output_dzielnica_text_accuracy: 0.5057 - output_dzielnica_text_loss: 1.5715 - output_ulica_combined_accuracy: 0.2528 - output_ulica_combined_loss: 3.6422 - val_loss: 6.3843 - val_output_dzielnica_combined_accuracy: 0.6089 - val_output_dzielnica_combined_loss: 1.2960 - val_output_dzielnica_text_accuracy: 0.5429 - val_output_dzielnica_text_loss: 1.5193 - val_output_ulica_combined_accuracy: 0.2586 - val_output_ulica_combined_loss: 4.1004 - learning_rate: 0.0010
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 373ms/step - loss: 5.7591 - output_dzielnica_combined_accuracy: 0.6375 - output_dzielnica_combined_loss: 1.1831 - output_dzielnica_text_accuracy: 0.5742 - output_dzielnica_text_loss: 1.4061 - output_ulica_combined_accuracy: 0.2510 - output_ulica_combined_loss: 3.5280 - val_loss: 6.0608 - val_output_dzielnica_combined_accuracy: 0.6440 - val_output_dzielnica_combined_loss: 1.2159 - val_output_dzielnica_text_accuracy: 0.5812 - val_output_dzielnica_text_loss: 1.3950 - val_output_ulica_combined_accuracy: 0.2435 - val_output_ulica_combined_loss: 4.1091 - learning_rate: 0.0010
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 376ms/step - loss: 5.4919 - output_dzielnica_combined_accuracy: 0.6614 - output_dzielnica_combined_loss: 1.1116 - output_dzielnica_text_accuracy: 0.5952 - output_dzielnica_text_loss: 1.3169 - output_ulica_combined_accuracy: 0.2595 - output_ulica_combined_loss: 3.4935 - val_loss: 7.2208 - val_output_dzielnica_combined_accuracy: 0.5346 - val_output_dzielnica_combined_loss: 1.5141 - val_output_dzielnica_text_accuracy: 0.4503 - val_output_dzielnica_text_loss: 1.7679 - val_output_ulica_combined_accuracy: 0.2293 - val_output_ulica_combined_loss: 4.3404 - learning_rate: 0.0010
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - loss: 6.5264 - output_dzielnica_combined_accuracy: 0.5581 - output_dzielnica_combined_loss: 1.4063 - output_dzielnica_text_accuracy: 0.4745 - output_dzielnica_text_loss: 1.6390 - output_ulica_combined_accuracy: 0.2384 - output_ulica_combined_loss: 3.6842 - val_loss: 6.1346 - val_output_dzielnica_combined_accuracy: 0.6403 - val_output_dzielnica_combined_loss: 1.2181 - val_output_dzielnica_text_accuracy: 0.5649 - val_output_dzielnica_text_loss: 1.4383 - val_output_ulica_combined_accuracy: 0.2524 - val_output_ulica_combined_loss: 4.0784 - learning_rate: 0.0010
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 377ms/step - loss: 5.3482 - output_dzielnica_combined_accuracy: 0.6621 - output_dzielnica_combined_loss: 1.1007 - output_dzielnica_text_accuracy: 0.6060 - output_dzielnica_text_loss: 1.2812 - output_ulica_combined_accuracy: 0.2695 - output_ulica_combined_loss: 3.3702 - val_loss: 5.6171 - val_output_dzielnica_combined_accuracy: 0.6759 - val_output_dzielnica_combined_loss: 1.1013 - val_output_dzielnica_text_accuracy: 0.6141 - val_output_dzielnica_text_loss: 1.2684 - val_output_ulica_combined_accuracy: 0.2660 - val_output_ulica_combined_loss: 3.9568 - learning_rate: 0.0010
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 378ms/step - loss: 4.8879 - output_dzielnica_combined_accuracy: 0.6982 - output_dzielnica_combined_loss: 0.9758 - output_dzielnica_text_accuracy: 0.6387 - output_dzielnica_text_loss: 1.1387 - output_ulica_combined_accuracy: 0.2779 - output_ulica_combined_loss: 3.2699 - val_loss: 6.5290 - val_output_dzielnica_combined_accuracy: 0.6005 - val_output_dzielnica_combined_loss: 1.3228 - val_output_dzielnica_text_accuracy: 0.5393 - val_output_dzielnica_text_loss: 1.5535 - val_output_ulica_combined_accuracy: 0.2471 - val_output_ulica_combined_loss: 4.1994 - learning_rate: 0.0010
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 380ms/step - loss: 5.5548 - output_dzielnica_combined_accuracy: 0.6411 - output_dzielnica_combined_loss: 1.1492 - output_dzielnica_text_accuracy: 0.5748 - output_dzielnica_text_loss: 1.3437 - output_ulica_combined_accuracy: 0.2583 - output_ulica_combined_loss: 3.4366 - val_loss: 5.5600 - val_output_dzielnica_combined_accuracy: 0.6995 - val_output_dzielnica_combined_loss: 1.0600 - val_output_dzielnica_text_accuracy: 0.6178 - val_output_dzielnica_text_loss: 1.2540 - val_output_ulica_combined_accuracy: 0.2743 - val_output_ulica_combined_loss: 3.9800 - learning_rate: 0.0010
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 380ms/step - loss: 4.5799 - output_dzielnica_combined_accuracy: 0.7288 - output_dzielnica_combined_loss: 0.8795 - output_dzielnica_text_accuracy: 0.6787 - output_dzielnica_text_loss: 1.0492 - output_ulica_combined_accuracy: 0.2698 - output_ulica_combined_loss: 3.2042 - val_loss: 5.0361 - val_output_dzielnica_combined_accuracy: 0.7298 - val_output_dzielnica_combined_loss: 0.9470 - val_output_dzielnica_text_accuracy: 0.6890 - val_output_dzielnica_text_loss: 1.0680 - val_output_ulica_combined_accuracy: 0.2770 - val_output_ulica_combined_loss: 3.9049 - learning_rate: 0.0010
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 381ms/step - loss: 4.0862 - output_dzielnica_combined_accuracy: 0.7667 - output_dzielnica_combined_loss: 0.7641 - output_dzielnica_text_accuracy: 0.7262 - output_dzielnica_text_loss: 0.8972 - output_ulica_combined_accuracy: 0.2855 - output_ulica_combined_loss: 3.0557 - val_loss: 5.2518 - val_output_dzielnica_combined_accuracy: 0.7178 - val_output_dzielnica_combined_loss: 1.0008 - val_output_dzielnica_text_accuracy: 0.6764 - val_output_dzielnica_text_loss: 1.1381 - val_output_ulica_combined_accuracy: 0.2775 - val_output_ulica_combined_loss: 3.9489 - learning_rate: 0.0010
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 380ms/step - loss: 4.0663 - output_dzielnica_combined_accuracy: 0.7677 - output_dzielnica_combined_loss: 0.7701 - output_dzielnica_text_accuracy: 0.7357 - output_dzielnica_text_loss: 0.8830 - output_ulica_combined_accuracy: 0.2851 - output_ulica_combined_loss: 3.0601 - val_loss: 5.0277 - val_output_dzielnica_combined_accuracy: 0.7272 - val_output_dzielnica_combined_loss: 0.9432 - val_output_dzielnica_text_accuracy: 0.6990 - val_output_dzielnica_text_loss: 1.0707 - val_output_ulica_combined_accuracy: 0.2885 - val_output_ulica_combined_loss: 3.8850 - learning_rate: 0.0010
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 381ms/step - loss: 3.8443 - output_dzielnica_combined_accuracy: 0.7805 - output_dzielnica_combined_loss: 0.7011 - output_dzielnica_text_accuracy: 0.7476 - output_dzielnica_text_loss: 0.8266 - output_ulica_combined_accuracy: 0.3019 - output_ulica_combined_loss: 2.9801 - val_loss: 5.0285 - val_output_dzielnica_combined_accuracy: 0.7340 - val_output_dzielnica_combined_loss: 0.9522 - val_output_dzielnica_text_accuracy: 0.7047 - val_output_dzielnica_text_loss: 1.0673 - val_output_ulica_combined_accuracy: 0.2895 - val_output_ulica_combined_loss: 3.8815 - learning_rate: 0.0010
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 383ms/step - loss: 3.8528 - output_dzielnica_combined_accuracy: 0.7848 - output_dzielnica_combined_loss: 0.7105 - output_dzielnica_text_accuracy: 0.7524 - output_dzielnica_text_loss: 0.8388 - output_ulica_combined_accuracy: 0.3026 - output_ulica_combined_loss: 2.9294 - val_loss: 5.0077 - val_output_dzielnica_combined_accuracy: 0.7298 - val_output_dzielnica_combined_loss: 0.9389 - val_output_dzielnica_text_accuracy: 0.6927 - val_output_dzielnica_text_loss: 1.0628 - val_output_ulica_combined_accuracy: 0.2874 - val_output_ulica_combined_loss: 3.8839 - learning_rate: 0.0010
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 380ms/step - loss: 3.9729 - output_dzielnica_combined_accuracy: 0.7667 - output_dzielnica_combined_loss: 0.7601 - output_dzielnica_text_accuracy: 0.7399 - output_dzielnica_text_loss: 0.8669 - output_ulica_combined_accuracy: 0.3039 - output_ulica_combined_loss: 2.9580 - val_loss: 4.8373 - val_output_dzielnica_combined_accuracy: 0.7471 - val_output_dzielnica_combined_loss: 0.8943 - val_output_dzielnica_text_accuracy: 0.7063 - val_output_dzielnica_text_loss: 1.0081 - val_output_ulica_combined_accuracy: 0.2864 - val_output_ulica_combined_loss: 3.8503 - learning_rate: 0.0010
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 381ms/step - loss: 3.8666 - output_dzielnica_combined_accuracy: 0.7722 - output_dzielnica_combined_loss: 0.7257 - output_dzielnica_text_accuracy: 0.7468 - output_dzielnica_text_loss: 0.8305 - output_ulica_combined_accuracy: 0.2885 - output_ulica_combined_loss: 2.9603 - val_loss: 6.5532 - val_output_dzielnica_combined_accuracy: 0.6319 - val_output_dzielnica_combined_loss: 1.2672 - val_output_dzielnica_text_accuracy: 0.5325 - val_output_dzielnica_text_loss: 1.5948 - val_output_ulica_combined_accuracy: 0.2518 - val_output_ulica_combined_loss: 4.1957 - learning_rate: 0.0010
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 386ms/step - loss: 4.5853 - output_dzielnica_combined_accuracy: 0.7210 - output_dzielnica_combined_loss: 0.9055 - output_dzielnica_text_accuracy: 0.6568 - output_dzielnica_text_loss: 1.0741 - output_ulica_combined_accuracy: 0.2838 - output_ulica_combined_loss: 3.0630 - val_loss: 5.0262 - val_output_dzielnica_combined_accuracy: 0.7424 - val_output_dzielnica_combined_loss: 0.9532 - val_output_dzielnica_text_accuracy: 0.6958 - val_output_dzielnica_text_loss: 1.0697 - val_output_ulica_combined_accuracy: 0.2953 - val_output_ulica_combined_loss: 3.8679 - learning_rate: 0.0010
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 3.9212 - output_dzielnica_combined_accuracy: 0.7712 - output_dzielnica_combined_loss: 0.7410 - output_dzielnica_text_accuracy: 0.7290 - output_dzielnica_text_loss: 0.8713 - output_ulica_combined_accuracy: 0.2994 - output_ulica_combined_loss: 2.8752
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 384ms/step - loss: 3.9213 - output_dzielnica_combined_accuracy: 0.7712 - output_dzielnica_combined_loss: 0.7410 - output_dzielnica_text_accuracy: 0.7290 - output_dzielnica_text_loss: 0.8712 - output_ulica_combined_accuracy: 0.2994 - output_ulica_combined_loss: 2.8757 - val_loss: 5.1029 - val_output_dzielnica_combined_accuracy: 0.7325 - val_output_dzielnica_combined_loss: 0.9623 - val_output_dzielnica_text_accuracy: 0.6937 - val_output_dzielnica_text_loss: 1.0890 - val_output_ulica_combined_accuracy: 0.2827 - val_output_ulica_combined_loss: 3.9248 - learning_rate: 0.0010
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 383ms/step - loss: 3.7291 - output_dzielnica_combined_accuracy: 0.7880 - output_dzielnica_combined_loss: 0.6892 - output_dzielnica_text_accuracy: 0.7502 - output_dzielnica_text_loss: 0.8159 - output_ulica_combined_accuracy: 0.2996 - output_ulica_combined_loss: 2.8165 - val_loss: 4.9795 - val_output_dzielnica_combined_accuracy: 0.7361 - val_output_dzielnica_combined_loss: 0.9365 - val_output_dzielnica_text_accuracy: 0.7037 - val_output_dzielnica_text_loss: 1.0557 - val_output_ulica_combined_accuracy: 0.2969 - val_output_ulica_combined_loss: 3.8633 - learning_rate: 1.0000e-04
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 383ms/step - loss: 3.6933 - output_dzielnica_combined_accuracy: 0.7869 - output_dzielnica_combined_loss: 0.6829 - output_dzielnica_text_accuracy: 0.7503 - output_dzielnica_text_loss: 0.8136 - output_ulica_combined_accuracy: 0.3148 - output_ulica_combined_loss: 2.7665 - val_loss: 4.9658 - val_output_dzielnica_combined_accuracy: 0.7387 - val_output_dzielnica_combined_loss: 0.9343 - val_output_dzielnica_text_accuracy: 0.7152 - val_output_dzielnica_text_loss: 1.0510 - val_output_ulica_combined_accuracy: 0.3021 - val_output_ulica_combined_loss: 3.8590 - learning_rate: 1.0000e-04
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 3.6704 - output_dzielnica_combined_accuracy: 0.7854 - output_dzielnica_combined_loss: 0.6774 - output_dzielnica_text_accuracy: 0.7562 - output_dzielnica_text_loss: 0.8072 - output_ulica_combined_accuracy: 0.3060 - output_ulica_combined_loss: 2.7570
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 385ms/step - loss: 3.6709 - output_dzielnica_combined_accuracy: 0.7854 - output_dzielnica_combined_loss: 0.6776 - output_dzielnica_text_accuracy: 0.7562 - output_dzielnica_text_loss: 0.8074 - output_ulica_combined_accuracy: 0.3062 - output_ulica_combined_loss: 2.7570 - val_loss: 4.9903 - val_output_dzielnica_combined_accuracy: 0.7319 - val_output_dzielnica_combined_loss: 0.9389 - val_output_dzielnica_text_accuracy: 0.7120 - val_output_dzielnica_text_loss: 1.0540 - val_output_ulica_combined_accuracy: 0.2958 - val_output_ulica_combined_loss: 3.8888 - learning_rate: 1.0000e-04
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 385ms/step - loss: 3.8115 - output_dzielnica_combined_accuracy: 0.7766 - output_dzielnica_combined_loss: 0.7221 - output_dzielnica_text_accuracy: 0.7497 - output_dzielnica_text_loss: 0.8502 - output_ulica_combined_accuracy: 0.3110 - output_ulica_combined_loss: 2.7780 - val_loss: 4.9832 - val_output_dzielnica_combined_accuracy: 0.7340 - val_output_dzielnica_combined_loss: 0.9380 - val_output_dzielnica_text_accuracy: 0.7147 - val_output_dzielnica_text_loss: 1.0512 - val_output_ulica_combined_accuracy: 0.2984 - val_output_ulica_combined_loss: 3.8879 - learning_rate: 1.0000e-05
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 383ms/step - loss: 3.7404 - output_dzielnica_combined_accuracy: 0.7784 - output_dzielnica_combined_loss: 0.7081 - output_dzielnica_text_accuracy: 0.7473 - output_dzielnica_text_loss: 0.8307 - output_ulica_combined_accuracy: 0.3194 - output_ulica_combined_loss: 2.7415 - val_loss: 4.9687 - val_output_dzielnica_combined_accuracy: 0.7340 - val_output_dzielnica_combined_loss: 0.9346 - val_output_dzielnica_text_accuracy: 0.7168 - val_output_dzielnica_text_loss: 1.0462 - val_output_ulica_combined_accuracy: 0.2990 - val_output_ulica_combined_loss: 3.8840 - learning_rate: 1.0000e-05
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 3.7213 - output_dzielnica_combined_accuracy: 0.7845 - output_dzielnica_combined_loss: 0.6995 - output_dzielnica_text_accuracy: 0.7511 - output_dzielnica_text_loss: 0.8220 - output_ulica_combined_accuracy: 0.3127 - output_ulica_combined_loss: 2.7555
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 387ms/step - loss: 3.7203 - output_dzielnica_combined_accuracy: 0.7846 - output_dzielnica_combined_loss: 0.6993 - output_dzielnica_text_accuracy: 0.7512 - output_dzielnica_text_loss: 0.8217 - output_ulica_combined_accuracy: 0.3128 - output_ulica_combined_loss: 2.7552 - val_loss: 4.9480 - val_output_dzielnica_combined_accuracy: 0.7351 - val_output_dzielnica_combined_loss: 0.9287 - val_output_dzielnica_text_accuracy: 0.7152 - val_output_dzielnica_text_loss: 1.0402 - val_output_ulica_combined_accuracy: 0.3016 - val_output_ulica_combined_loss: 3.8783 - learning_rate: 1.0000e-05
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 388ms/step - loss: 3.6123 - output_dzielnica_combined_accuracy: 0.7884 - output_dzielnica_combined_loss: 0.6748 - output_dzielnica_text_accuracy: 0.7636 - output_dzielnica_text_loss: 0.7891 - output_ulica_combined_accuracy: 0.3266 - output_ulica_combined_loss: 2.7186 - val_loss: 4.9495 - val_output_dzielnica_combined_accuracy: 0.7356 - val_output_dzielnica_combined_loss: 0.9292 - val_output_dzielnica_text_accuracy: 0.7152 - val_output_dzielnica_text_loss: 1.0407 - val_output_ulica_combined_accuracy: 0.3010 - val_output_ulica_combined_loss: 3.8786 - learning_rate: 1.0000e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %%
# === SEKCJA 4: OCENA I ZAPIS MODELU ---

print("\n--- Trening zakończony. Ocena modelu ---")
results = priority_model.evaluate(X_val, y_val, verbose=0)

# Wyświetlanie wyników
print("\nWyniki na zbiorze walidacyjnym:")
print(f" - Całkowita strata: {results[0]:.4f}")
print(f" - Dokładność (dzielnica z tekstu):     {results[4]:.4f}")
print(f" - Dokładność (dzielnica połączona):    {results[5]:.4f}")
print(f" - Dokładność (ulica połączona):        {results[6]:.4f} <--- Kluczowy wynik")

# --- Zapis artefaktów do produkcji ---
artifacts_dir_priority = 'model_artifacts_priority'
os.makedirs(artifacts_dir_priority, exist_ok=True)

# 1. Zapis modelu
priority_model.save(os.path.join(artifacts_dir_priority, 'priority_model.keras'))

# 2. Zapis pozostałych artefaktów (są takie same jak wcześniej)
with open(os.path.join(artifacts_dir_priority, 'tokenizer.pkl'), 'wb') as f: pickle.dump(tokenizer, f)
with open(os.path.join(artifacts_dir_priority, 'numeric_pipeline.pkl'), 'wb') as f: pickle.dump(numeric_pipeline, f)
with open(os.path.join(artifacts_dir_priority, 'le_dzielnica.pkl'), 'wb') as f: pickle.dump(le_dzielnica, f)
with open(os.path.join(artifacts_dir_priority, 'le_ulica.pkl'), 'wb') as f: pickle.dump(le_ulica, f)
    
print(f"\nWszystkie artefakty dla nowego modelu zostały zapisane w folderze: '{artifacts_dir_priority}'")
# Out:
# --- Trening zakończony. Ocena modelu ---
#
# Wyniki na zbiorze walidacyjnym:
#  - Całkowita strata: 4.9658
#  - Dokładność (dzielnica z tekstu):     0.7387
#  - Dokładność (dzielnica połączona):    0.7152
#  - Dokładność (ulica połączona):        0.3021 <--- Kluczowy wynik
#
# Wszystkie artefakty dla nowego modelu zostały zapisane w folderze: 'model_artifacts_priority'

# %%
# === SEKCJA 5: TESTOWANIE NOWEGO MODELU NA PROBLEMATYCZNYM PRZYKŁADZIE ===

# ========= POPRAWKA: Dodajemy brakujące importy =========
from tensorflow.keras.models import load_model
import json
import re # re jest używane w funkcji clean_text
# =========================================================

# --- Wczytanie artefaktów (dla pewności, że używamy zapisanych) ---
artifacts_dir_priority = 'model_artifacts_priority'
try:
    loaded_priority_model = load_model(os.path.join(artifacts_dir_priority, 'priority_model.keras'))
    with open(os.path.join(artifacts_dir_priority, 'tokenizer.pkl'), 'rb') as f: loaded_tokenizer = pickle.load(f)
    with open(os.path.join(artifacts_dir_priority, 'numeric_pipeline.pkl'), 'rb') as f: loaded_pipeline = pickle.load(f)
    with open(os.path.join(artifacts_dir_priority, 'le_dzielnica.pkl'), 'rb') as f: loaded_le_d = pickle.load(f)
    with open(os.path.join(artifacts_dir_priority, 'le_ulica.pkl'), 'rb') as f: loaded_le_u = pickle.load(f)
    print("\nArtefakty dla modelu z priorytetem wczytane pomyślnie.")
except Exception as e:
    print(f"Błąd wczytywania, używam zmiennych z pamięci: {e}")
    # W razie problemu użyj zmiennych z pamięci
    loaded_priority_model, loaded_tokenizer, loaded_pipeline, loaded_le_d, loaded_le_u = \
    priority_model, tokenizer, numeric_pipeline, le_dzielnica, le_ulica


# --- Zmodyfikowana funkcja predykcyjna ---
def predict_location_priority(json_data, model, tokenizer, pipeline, le_d, le_u):
    data = json.loads(json_data)
    
    def clean_text(text): return re.sub(r'[^a-ząęółśżźćń ]', '', str(text).lower())
    clean_desc = clean_text(data['Description'])
    text_sequence = tokenizer.texts_to_sequences([clean_desc])
    padded_text = pad_sequences(text_sequence, maxlen=250)

    price_per_sqm = data['Price'] / data['Area'] if data['Area'] > 0 else 0
    numeric_values = np.array([data['Area'], data['Price'], data['NumberOfRooms'], data['Floor'], data['Floors'], price_per_sqm]).reshape(1, -1)
    scaled_numeric = pipeline.transform(numeric_values)
    
    predictions = model.predict([padded_text, scaled_numeric], verbose=0)
    pred_dzielnica_text_probs, pred_dzielnica_combined_probs, pred_ulica_combined_probs = predictions
    
    pred_dzielnica_combined_index = np.argmax(pred_dzielnica_combined_probs, axis=1)[0]
    pred_ulica_combined_index = np.argmax(pred_ulica_combined_probs, axis=1)[0]
    pred_dzielnica_text_index = np.argmax(pred_dzielnica_text_probs, axis=1)[0]
    
    return {
        "predicted_district_text_only": le_d.inverse_transform([pred_dzielnica_text_index])[0],
        "district_text_confidence": f"{pred_dzielnica_text_probs[0][pred_dzielnica_text_index]:.2%}",
        "predicted_district_combined": le_d.inverse_transform([pred_dzielnica_combined_index])[0],
        "district_combined_confidence": f"{pred_dzielnica_combined_probs[0][pred_dzielnica_combined_index]:.2%}",
        "predicted_street_combined": le_u.inverse_transform([pred_ulica_combined_index])[0],
        "street_combined_confidence": f"{pred_ulica_combined_probs[0][pred_ulica_combined_index]:.2%}"
    }

# --- Uruchomienie predykcji ---
json_input_data = """
{
  "Description": "Sprzedam słoneczne, trzypokojowe mieszkanie na Mokotowie. Doskonała lokalizacja przy ulicy Puławskiej zapewnia świetną komunikację z centrum. W pobliżu metro Racławicka. Mieszkanie w zadbanej kamienicy z cegły.",
  "Area": 68.0,
  "Price": 980000,
  "NumberOfRooms": 3,
  "Floor": 3,
  "Floors": 5
}
"""

print("\n\n--- TESTOWANIE NOWEGO MODELU NA PROBLEMATYCZNYM PRZYKŁADZIE ---")
final_prediction = predict_location_priority(
    json_input_data, 
    loaded_priority_model, 
    loaded_tokenizer, 
    loaded_pipeline, 
    loaded_le_d, 
    loaded_le_u
)

print("\n--- WYNIK PREDYKCJI (model z priorytetem) ---")
print(f"Predykcja samej gałęzi tekstowej: {final_prediction['predicted_district_text_only']} (Pewność: {final_prediction['district_text_confidence']})")
print("--------------------------------------------------")
print(f"Finalna predykcja Dzielnicy: {final_prediction['predicted_district_combined']} (Pewność: {final_prediction['district_combined_confidence']})")
print(f"Finalna predykcja Ulicy:     {final_prediction['predicted_street_combined']} (Pewność: {final_prediction['street_combined_confidence']})")
# Out:
# Artefakty dla modelu z priorytetem wczytane pomyślnie.
#
#
# --- TESTOWANIE NOWEGO MODELU NA PROBLEMATYCZNYM PRZYKŁADZIE ---
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# --- WYNIK PREDYKCJI (model z priorytetem) ---
# Predykcja samej gałęzi tekstowej: Wawer (Pewność: 17.27%)
# --------------------------------------------------
# Finalna predykcja Dzielnicy: Wawer (Pewność: 21.05%)
# Finalna predykcja Ulicy:     Wojciecha gersona (Pewność: 18.27%)
