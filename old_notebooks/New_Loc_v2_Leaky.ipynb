# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
import os
import re
from IPython.display import display

# %%
print("Krok 0: Konfiguracja środowiska")

# Tworzenie katalogów na artefakty i wyniki
ARTIFACTS_DIR = "Artifacts_Polska"
os.makedirs(ARTIFACTS_DIR, exist_ok=True)

# Nazwy plików
LOC_FILE = 'lokalizacja.csv'
DATA_FILE_1 = 'saleflats_2024_dateAdded_polska.csv'
DATA_FILE_2 = 'saleflats_2024_newestDate_polska.csv'
OUTPUT_FILE = 'Location_Polska.csv'

# Hiperparametry
MAX_TEXT_FEATURES = 20000
# Out:
# Krok 0: Konfiguracja środowiska

# %%
print("--- START: Budowa finalnego zbioru danych ---")

# --- Krok 1: Wczytanie i przygotowanie pliku lokalizacja.csv ---
print("Wczytywanie i przygotowywanie pliku lokalizacja.csv...")
try:
    df_lokalizacja_raw = pd.read_csv(
        'lokalizacja.csv', sep=',', header=None,
        names=['Id', 'ParentId', 'Name', 'AdditionalName', 'FullName'], dtype=str
    )
    df_lokalizacja = df_lokalizacja_raw.copy()
    df_lokalizacja['Id'] = pd.to_numeric(df_lokalizacja['Id'], errors='coerce')
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].replace('\\N', pd.NA)
    df_lokalizacja['ParentId'] = pd.to_numeric(df_lokalizacja['ParentId'], errors='coerce')
    df_lokalizacja.dropna(subset=['Id'], inplace=True)
    df_lokalizacja['Id'] = df_lokalizacja['Id'].astype(int)
    df_lokalizacja['ParentId'] = df_lokalizacja['ParentId'].astype('Int64')
    
    location_dict = df_lokalizacja.set_index('Id').to_dict('index')
    id_to_name = df_lokalizacja.set_index('Id')['Name'].to_dict()
    id_to_parent = df_lokalizacja.set_index('Id')['ParentId'].to_dict()
    
    # Tworzenie struktur do walidacji hierarchii
    miasta_ids = df_lokalizacja[df_lokalizacja['AdditionalName'].str.contains('Miasto', na=False)]['Id'].tolist()
    dzielnice_ids = df_lokalizacja[df_lokalizacja['AdditionalName'].str.contains('Dzielnica|Osiedle', na=False)]['Id'].tolist()
    city_to_districts = df_lokalizacja[df_lokalizacja['Id'].isin(dzielnice_ids)].groupby('ParentId')['Id'].apply(list).to_dict()
    district_to_streets = df_lokalizacja[df_lokalizacja['AdditionalName'] == 'Ulica'].groupby('ParentId')['Id'].apply(list).to_dict()
    
    print(f"Plik lokalizacja.csv wczytany. Mamy {len(location_dict)} unikalnych lokalizacji.")
except FileNotFoundError:
    print("BŁĄD KRYTYCZNY: Nie znaleziono pliku lokalizacja.csv")
    exit()

# --- Krok 2: Ekstrakcja danych z plików ofert za pomocą 'usecols' ---
# UWAGA: Indeksy kolumn mogą wymagać weryfikacji. Na podstawie przykładów i błędów,
# zakładamy, że plik ma więcej kolumn, a `locationPath` jest na końcu.
# Próbujemy znaleźć ostatnią kolumnę, ale jeśli to zawiedzie, użyjemy stałej.
try:
    # Szybki odczyt pierwszego wiersza, żeby znaleźć ostatnią kolumnę
    first_row = pd.read_csv('saleflats_2024_dateAdded_polska.csv', sep=',', header=None, nrows=1, on_bad_lines='skip')
    last_col_index = first_row.shape[1] - 1
    print(f"Automatycznie wykryto, że ostatnia kolumna ma indeks: {last_col_index}")
except:
    last_col_index = 64 # Wartość awaryjna
    print(f"Nie udało się wykryć ostatniej kolumny, używam wartości awaryjnej: {last_col_index}")

COLS_TO_EXTRACT = {
    3: 'Title', 4: 'Description', 5: 'Area', 6: 'Price',
    9: 'NumberOfRooms', 14: 'Floor', 15: 'Floors', 16: 'BuiltYear',
    last_col_index: 'locationPath' # Używamy wykrytego indeksu
}

all_offers_df = []
FILES = ['saleflats_2024_dateAdded_polska.csv', 'saleflats_2024_newestDate_polska.csv']
for filepath in FILES:
    print(f"\nEkstrakcja danych z pliku: {filepath}...")
    try:
        df_chunk = pd.read_csv(
            filepath, sep=',', header=None, on_bad_lines='skip',
            usecols=list(COLS_TO_EXTRACT.keys()), low_memory=False, dtype=str, encoding='utf-8'
        )
        df_chunk.rename(columns=COLS_TO_EXTRACT, inplace=True)
        all_offers_df.append(df_chunk)
        print(f"Udało się wyekstrahować {len(df_chunk)} wierszy.")
    except Exception as e:
        print(f"Błąd podczas ekstrakcji z {filepath}: {e}")

if not all_offers_df:
    print("BŁĄD KRYTYCZNY: Nie udało się wczytać żadnych danych z plików ofert.")
    exit()

df = pd.concat(all_offers_df, ignore_index=True)
df.dropna(subset=['locationPath'], inplace=True)
df.drop_duplicates(subset=['Title', 'Description', 'locationPath'], keep='first', inplace=True)
print(f"\nPołączono i uzyskano {len(df)} unikalnych ofert.")


# --- Krok 3: Parsowanie ścieżki i tworzenie kolumn docelowych ---
print("Parsowanie ścieżek i tworzenie kolumn docelowych...")
path_cols = ['Wojewodztwo_ID', 'Powiat_ID', 'Gmina_ID', 'Miasto_ID', 'Dzielnica_ID', 'PodDzielnica_ID', 'Ulica_ID']
split_paths = df['locationPath'].str.split(',')
path_df = pd.DataFrame(split_paths.tolist(), index=df.index)
if path_df.shape[1] > 7: path_df = path_df.iloc[:, :7]
while path_df.shape[1] < 7: path_df[path_df.shape[1]] = None
path_df.columns = path_cols
path_df = path_df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
df = pd.concat([df.reset_index(drop=True), path_df.reset_index(drop=True)], axis=1)

df['target_district_id'] = np.where(df['PodDzielnica_ID'] != 0, df['PodDzielnica_ID'], df['Dzielnica_ID'])
df['target_city_id'] = df['Miasto_ID']
df['target_street_id'] = df['Ulica_ID']

# Filtrujemy, wymagając tylko, aby miasto było określone
df = df[df['target_city_id'] != 0].copy()
df.reset_index(drop=True, inplace=True)

if len(df) == 0:
    print("BŁĄD KRYTYCZNY: Po filtrowaniu nie pozostały żadne wiersze z określonym miastem.")
else:
    print(f"Liczba ogłoszeń z określonym miastem do treningu: {len(df)}")
# Out:
# --- START: Budowa finalnego zbioru danych ---
# Wczytywanie i przygotowywanie pliku lokalizacja.csv...
# Plik lokalizacja.csv wczytany. Mamy 398832 unikalnych lokalizacji.
# Automatycznie wykryto, że ostatnia kolumna ma indeks: 52
#
# Ekstrakcja danych z pliku: saleflats_2024_dateAdded_polska.csv...
# Udało się wyekstrahować 793664 wierszy.
#
# Ekstrakcja danych z pliku: saleflats_2024_newestDate_polska.csv...
# Udało się wyekstrahować 755679 wierszy.
#
# Połączono i uzyskano 773591 unikalnych ofert.
# Parsowanie ścieżek i tworzenie kolumn docelowych...
# Liczba ogłoszeń z określonym miastem do treningu: 709104

# %%
print("\nKrok 2: Inżynieria Cech (Uproszczona i Niezawodna)")
from sklearn.impute import SimpleImputer

# --- Przetwarzanie cech numerycznych (tylko pewne kolumny) ---
# ZMIANA: Skupiamy się tylko na 'Area' i 'Price', które na pewno są poprawne.
num_features = ['Area', 'Price']
for col in num_features:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Używamy SimpleImputer, aby uzupełnić ewentualne braki
imputer = SimpleImputer(strategy='median')
df[num_features] = imputer.fit_transform(df[num_features])

scaler = StandardScaler()
X_num = scaler.fit_transform(df[num_features])
joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, 'scaler.joblib'))

# --- Przetwarzanie cech tekstowych (ze zredukowaną złożonością) ---
df['text_features'] = df['Title'].fillna('') + ' ' + df['Description'].fillna('')
df['text_features'] = df['text_features'].apply(lambda x: re.sub(r'\s+', ' ', x.lower()))

MAX_TEXT_FEATURES_REDUCED = 5000
vectorizer = TfidfVectorizer(max_features=MAX_TEXT_FEATURES_REDUCED, ngram_range=(1, 1))

print("Rozpoczynam wektoryzację tekstu ze zredukowanymi parametrami...")
X_text = vectorizer.fit_transform(df['text_features'])
joblib.dump(vectorizer, os.path.join(ARTIFACTS_DIR, 'vectorizer.joblib'))

# Aktualizujemy globalną zmienną
MAX_TEXT_FEATURES = MAX_TEXT_FEATURES_REDUCED

print(f"Przygotowano cechy: {X_text.shape[1]} tekstowych (TF-IDF) i {X_num.shape[1]} numerycznych.")
print(f"Kształt macierzy X_text: {X_text.shape}")
print(f"Kształt macierzy X_num: {X_num.shape}")
# Out:
# Krok 2: Inżynieria Cech (Uproszczona i Niezawodna)
# Rozpoczynam wektoryzację tekstu ze zredukowanymi parametrami...
# Przygotowano cechy: 5000 tekstowych (TF-IDF) i 2 numerycznych.
# Kształt macierzy X_text: (709104, 5000)
# Kształt macierzy X_num: (709104, 2)

# %%
print("\nKrok 3: Przygotowanie Celów (Target Variables) jako indeksy")

# Mapowanie ID na indeksy 0..N-1 (tak jak wcześniej)
city_ids = sorted(df['target_city_id'].unique())
district_ids = sorted(df['target_district_id'].unique())
street_ids = sorted(df['target_street_id'].unique())

if 0 not in district_ids: district_ids.insert(0,0)
if 0 not in street_ids: street_ids.insert(0,0)

city_id_map = {id: i for i, id in enumerate(city_ids)}
district_id_map = {id: i for i, id in enumerate(district_ids)}
street_id_map = {id: i for i, id in enumerate(street_ids)}

# Zapisanie mapowań
joblib.dump(city_id_map, os.path.join(ARTIFACTS_DIR, 'city_id_map.joblib'))
joblib.dump(district_id_map, os.path.join(ARTIFACTS_DIR, 'district_id_map.joblib'))
joblib.dump(street_id_map, os.path.join(ARTIFACTS_DIR, 'street_id_map.joblib'))

inv_city_id_map = {i: id for id, i in city_id_map.items()}
inv_district_id_map = {i: id for id, i in district_id_map.items()}
inv_street_id_map = {i: id for id, i in street_id_map.items()}
joblib.dump(inv_city_id_map, os.path.join(ARTIFACTS_DIR, 'inv_city_id_map.joblib'))
joblib.dump(inv_district_id_map, os.path.join(ARTIFACTS_DIR, 'inv_district_id_map.joblib'))
joblib.dump(inv_street_id_map, os.path.join(ARTIFACTS_DIR, 'inv_street_id_map.joblib'))

# KLUCZOWA ZMIANA: y to teraz wektory z indeksami, a nie macierze one-hot
y_city = df['target_city_id'].map(city_id_map).values
y_district = df['target_district_id'].map(district_id_map).values
y_street = df['target_street_id'].map(street_id_map).values

print(f"Przygotowano zmienne docelowe jako wektory indeksów. Liczba unikalnych klas:")
print(f"Miasta: {len(city_ids)}")
print(f"Dzielnice: {len(district_ids)}")
print(f"Ulice: {len(street_ids)}")
# Out:
# Krok 3: Przygotowanie Celów (Target Variables) jako indeksy
# Przygotowano zmienne docelowe jako wektory indeksów. Liczba unikalnych klas:
# Miasta: 6933
# Dzielnice: 1940
# Ulice: 28177

# %%
# Podział na zbiór treningowy i walidacyjny
# Ten kod teraz zadziała, bo nie operuje na gigantycznych macierzach y
X_text_train, X_text_val, X_num_train, X_num_val, y_city_train, y_city_val, y_district_train, y_district_val, y_street_train, y_street_val = train_test_split(
    X_text, X_num, y_city, y_district, y_street, test_size=0.2, random_state=42
)

print(f"Rozmiar zbioru treningowego: {X_text_train.shape[0]}")
print(f"Rozmiar zbioru walidacyjnego: {X_text_val.shape[0]}")
# Out:
# Rozmiar zbioru treningowego: 567283
# Rozmiar zbioru walidacyjnego: 141821

# %%
print("\nKrok 4: Budowa i Kompilacja Modelu (Architektura z LeakyReLU)")

# Wejścia
input_text = Input(shape=(MAX_TEXT_FEATURES,), name='text_input', sparse=True) 
input_num = Input(shape=(X_num_train.shape[1],), name='num_input')

# --- Ścieżka tekstowa z LeakyReLU ---
x1 = Dense(128)(input_text)
x1 = LeakyReLU(alpha=0.2)(x1) # ZMIANA: Zamiast activation='relu'
x1 = Dropout(0.5)(x1)

# --- Ścieżka numeryczna z LeakyReLU ---
x2 = Dense(64)(input_num)
x2 = LeakyReLU(alpha=0.2)(x2) # ZMIANA
x2 = Dense(32)(x2)
x2 = LeakyReLU(alpha=0.2)(x2) # ZMIANA

# Połączenie
combined = Concatenate()([x1, x2])
z = Dense(256)(combined)
z = LeakyReLU(alpha=0.2)(z) # ZMIANA
z = Dropout(0.5)(z)

# Głowy wyjściowe
output_city = Dense(len(city_ids), activation='softmax', name='city_output')(z)
output_district = Dense(len(district_ids), activation='softmax', name='district_output')(z)
output_street = Dense(len(street_ids), activation='softmax', name='street_output')(z)

# Finalny model
model_leaky = Model(inputs=[input_text, input_num], outputs=[output_city, output_district, output_street])

# Kompilacja (bez zmian)
model_leaky.compile(
    optimizer='adam',
    loss={
        'city_output': 'sparse_categorical_crossentropy',
        'district_output': 'sparse_categorical_crossentropy',
        'street_output': 'sparse_categorical_crossentropy'
    },
    metrics={
        'city_output': 'accuracy',
        'district_output': 'accuracy',
        'street_output': 'accuracy'
    }
)

model_leaky.summary()
# Out:
# Krok 4: Budowa i Kompilacja Modelu (Architektura z LeakyReLU)
# C:\Users\Ai\AppData\Local\miniconda3\envs\projekt_stan\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ num_input (InputLayer)        │ (None, 2)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ text_input (InputLayer)       │ (None, 5000)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64)                │             192 │ num_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │         640,128 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 64)                │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 32)                │           2,080 │ leaky_re_lu_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ leaky_re_lu[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32)                │               0 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 160)               │               0 │ dropout[0][0],             │
# │                               │                           │                 │ leaky_re_lu_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256)               │          41,216 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 256)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 256)               │               0 │ leaky_re_lu_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_output (Dense)           │ (None, 6933)              │       1,781,781 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ district_output (Dense)       │ (None, 1940)              │         498,580 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ street_output (Dense)         │ (None, 28177)             │       7,241,489 │ dropout_1[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 10,205,466 (38.93 MB)
#  Trainable params: 10,205,466 (38.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\nKrok 5: Trening Modelu (LeakyReLU)")

# ... (definicje X_train_list, y_train_dict itd. są takie same) ...
X_train_list = [X_text_train, X_num_train]
y_train_dict = {'city_output': y_city_train, 'district_output': y_district_train, 'street_output': y_street_train}

X_val_list = [X_text_val, X_num_val]
y_val_dict = {'city_output': y_city_val, 'district_output': y_district_val, 'street_output': y_street_val}

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Trening nowego modelu
history_leaky = model_leaky.fit(
    X_train_list,
    y_train_dict,
    validation_data=(X_val_list, y_val_dict),
    epochs=25,
    batch_size=256,
    callbacks=[early_stopping]
)

# Zapis nowego modelu
model_leaky.save(os.path.join(ARTIFACTS_DIR, 'location_prediction_model_leaky.h5'))
print("Model LeakyReLU został wytrenowany i zapisany.")
# Out:
# Krok 5: Trening Modelu (LeakyReLU)
# Epoch 1/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 158s 70ms/step - city_output_accuracy: 0.2616 - city_output_loss: 4.3558 - district_output_accuracy: 0.4965 - district_output_loss: 3.6590 - loss: 12.1696 - street_output_accuracy: 0.6633 - street_output_loss: 4.1547 - val_city_output_accuracy: 0.6063 - val_city_output_loss: 2.3782 - val_district_output_accuracy: 0.5335 - val_district_output_loss: 2.2792 - val_loss: 7.7753 - val_street_output_accuracy: 0.6718 - val_street_output_loss: 3.1179
# Epoch 2/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 155s 70ms/step - city_output_accuracy: 0.5973 - city_output_loss: 2.4032 - district_output_accuracy: 0.5275 - district_output_loss: 2.3159 - loss: 7.8897 - street_output_accuracy: 0.6676 - street_output_loss: 3.1706 - val_city_output_accuracy: 0.6542 - val_city_output_loss: 2.0517 - val_district_output_accuracy: 0.5776 - val_district_output_loss: 1.8870 - val_loss: 6.7409 - val_street_output_accuracy: 0.6749 - val_street_output_loss: 2.8022
# Epoch 3/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 159s 71ms/step - city_output_accuracy: 0.6304 - city_output_loss: 2.1435 - district_output_accuracy: 0.5546 - district_output_loss: 2.0268 - loss: 7.0449 - street_output_accuracy: 0.6681 - street_output_loss: 2.8746 - val_city_output_accuracy: 0.6760 - val_city_output_loss: 1.9080 - val_district_output_accuracy: 0.5957 - val_district_output_loss: 1.7204 - val_loss: 6.2488 - val_street_output_accuracy: 0.6783 - val_street_output_loss: 2.6204
# Epoch 4/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 160s 72ms/step - city_output_accuracy: 0.6478 - city_output_loss: 2.0079 - district_output_accuracy: 0.5669 - district_output_loss: 1.9022 - loss: 6.5972 - street_output_accuracy: 0.6688 - street_output_loss: 2.6871 - val_city_output_accuracy: 0.6888 - val_city_output_loss: 1.8130 - val_district_output_accuracy: 0.6110 - val_district_output_loss: 1.6234 - val_loss: 5.9384 - val_street_output_accuracy: 0.6838 - val_street_output_loss: 2.5019
# Epoch 5/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 167s 75ms/step - city_output_accuracy: 0.6550 - city_output_loss: 1.9426 - district_output_accuracy: 0.5776 - district_output_loss: 1.8161 - loss: 6.3113 - street_output_accuracy: 0.6715 - street_output_loss: 2.5525 - val_city_output_accuracy: 0.6985 - val_city_output_loss: 1.7484 - val_district_output_accuracy: 0.6195 - val_district_output_loss: 1.5661 - val_loss: 5.7367 - val_street_output_accuracy: 0.6878 - val_street_output_loss: 2.4222
# Epoch 6/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 186s 84ms/step - city_output_accuracy: 0.6636 - city_output_loss: 1.8800 - district_output_accuracy: 0.5849 - district_output_loss: 1.7643 - loss: 6.1038 - street_output_accuracy: 0.6724 - street_output_loss: 2.4595 - val_city_output_accuracy: 0.7048 - val_city_output_loss: 1.7048 - val_district_output_accuracy: 0.6279 - val_district_output_loss: 1.5325 - val_loss: 5.5911 - val_street_output_accuracy: 0.6904 - val_street_output_loss: 2.3538
# Epoch 7/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 179s 81ms/step - city_output_accuracy: 0.6690 - city_output_loss: 1.8320 - district_output_accuracy: 0.5909 - district_output_loss: 1.7237 - loss: 5.9396 - street_output_accuracy: 0.6741 - street_output_loss: 2.3839 - val_city_output_accuracy: 0.7132 - val_city_output_loss: 1.6681 - val_district_output_accuracy: 0.6303 - val_district_output_loss: 1.5029 - val_loss: 5.4691 - val_street_output_accuracy: 0.6929 - val_street_output_loss: 2.2982
# Epoch 8/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 186s 84ms/step - city_output_accuracy: 0.6743 - city_output_loss: 1.7975 - district_output_accuracy: 0.5942 - district_output_loss: 1.6968 - loss: 5.8311 - street_output_accuracy: 0.6745 - street_output_loss: 2.3369 - val_city_output_accuracy: 0.7182 - val_city_output_loss: 1.6372 - val_district_output_accuracy: 0.6353 - val_district_output_loss: 1.4729 - val_loss: 5.3748 - val_street_output_accuracy: 0.6949 - val_street_output_loss: 2.2647
# Epoch 9/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 199s 90ms/step - city_output_accuracy: 0.6800 - city_output_loss: 1.7582 - district_output_accuracy: 0.5954 - district_output_loss: 1.6788 - loss: 5.7187 - street_output_accuracy: 0.6756 - street_output_loss: 2.2817 - val_city_output_accuracy: 0.7219 - val_city_output_loss: 1.6083 - val_district_output_accuracy: 0.6390 - val_district_output_loss: 1.4482 - val_loss: 5.2837 - val_street_output_accuracy: 0.6962 - val_street_output_loss: 2.2271
# Epoch 10/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 196s 89ms/step - city_output_accuracy: 0.6823 - city_output_loss: 1.7430 - district_output_accuracy: 0.6000 - district_output_loss: 1.6545 - loss: 5.6331 - street_output_accuracy: 0.6779 - street_output_loss: 2.2356 - val_city_output_accuracy: 0.7271 - val_city_output_loss: 1.5857 - val_district_output_accuracy: 0.6419 - val_district_output_loss: 1.4327 - val_loss: 5.2147 - val_street_output_accuracy: 0.6968 - val_street_output_loss: 2.1963
# Epoch 11/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 192s 87ms/step - city_output_accuracy: 0.6844 - city_output_loss: 1.7209 - district_output_accuracy: 0.6007 - district_output_loss: 1.6407 - loss: 5.5650 - street_output_accuracy: 0.6785 - street_output_loss: 2.2035 - val_city_output_accuracy: 0.7293 - val_city_output_loss: 1.5653 - val_district_output_accuracy: 0.6436 - val_district_output_loss: 1.4226 - val_loss: 5.1603 - val_street_output_accuracy: 0.6993 - val_street_output_loss: 2.1725
# Epoch 12/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 188s 85ms/step - city_output_accuracy: 0.6871 - city_output_loss: 1.7063 - district_output_accuracy: 0.6036 - district_output_loss: 1.6256 - loss: 5.5112 - street_output_accuracy: 0.6784 - street_output_loss: 2.1793 - val_city_output_accuracy: 0.7310 - val_city_output_loss: 1.5490 - val_district_output_accuracy: 0.6447 - val_district_output_loss: 1.4192 - val_loss: 5.1176 - val_street_output_accuracy: 0.7001 - val_street_output_loss: 2.1494
# Epoch 13/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 195s 88ms/step - city_output_accuracy: 0.6899 - city_output_loss: 1.6798 - district_output_accuracy: 0.6051 - district_output_loss: 1.6174 - loss: 5.4553 - street_output_accuracy: 0.6792 - street_output_loss: 2.1581 - val_city_output_accuracy: 0.7356 - val_city_output_loss: 1.5329 - val_district_output_accuracy: 0.6474 - val_district_output_loss: 1.4017 - val_loss: 5.0684 - val_street_output_accuracy: 0.7004 - val_street_output_loss: 2.1338
# Epoch 14/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 199s 90ms/step - city_output_accuracy: 0.6902 - city_output_loss: 1.6741 - district_output_accuracy: 0.6075 - district_output_loss: 1.6029 - loss: 5.4101 - street_output_accuracy: 0.6800 - street_output_loss: 2.1331 - val_city_output_accuracy: 0.7373 - val_city_output_loss: 1.5200 - val_district_output_accuracy: 0.6498 - val_district_output_loss: 1.3928 - val_loss: 5.0299 - val_street_output_accuracy: 0.7023 - val_street_output_loss: 2.1172
# Epoch 15/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 202s 91ms/step - city_output_accuracy: 0.6925 - city_output_loss: 1.6600 - district_output_accuracy: 0.6086 - district_output_loss: 1.5992 - loss: 5.3769 - street_output_accuracy: 0.6797 - street_output_loss: 2.1177 - val_city_output_accuracy: 0.7390 - val_city_output_loss: 1.5084 - val_district_output_accuracy: 0.6516 - val_district_output_loss: 1.3859 - val_loss: 4.9962 - val_street_output_accuracy: 0.7032 - val_street_output_loss: 2.1019
# Epoch 16/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 211s 95ms/step - city_output_accuracy: 0.6941 - city_output_loss: 1.6540 - district_output_accuracy: 0.6111 - district_output_loss: 1.5848 - loss: 5.3365 - street_output_accuracy: 0.6808 - street_output_loss: 2.0977 - val_city_output_accuracy: 0.7413 - val_city_output_loss: 1.4968 - val_district_output_accuracy: 0.6516 - val_district_output_loss: 1.3783 - val_loss: 4.9657 - val_street_output_accuracy: 0.7036 - val_street_output_loss: 2.0907
# Epoch 17/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 217s 98ms/step - city_output_accuracy: 0.6960 - city_output_loss: 1.6378 - district_output_accuracy: 0.6118 - district_output_loss: 1.5810 - loss: 5.2945 - street_output_accuracy: 0.6818 - street_output_loss: 2.0757 - val_city_output_accuracy: 0.7426 - val_city_output_loss: 1.4916 - val_district_output_accuracy: 0.6529 - val_district_output_loss: 1.3747 - val_loss: 4.9453 - val_street_output_accuracy: 0.7046 - val_street_output_loss: 2.0789
# Epoch 18/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 224s 101ms/step - city_output_accuracy: 0.6957 - city_output_loss: 1.6340 - district_output_accuracy: 0.6120 - district_output_loss: 1.5736 - loss: 5.2677 - street_output_accuracy: 0.6834 - street_output_loss: 2.0601 - val_city_output_accuracy: 0.7437 - val_city_output_loss: 1.4781 - val_district_output_accuracy: 0.6548 - val_district_output_loss: 1.3613 - val_loss: 4.9070 - val_street_output_accuracy: 0.7057 - val_street_output_loss: 2.0676
# Epoch 19/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 216s 98ms/step - city_output_accuracy: 0.6985 - city_output_loss: 1.6193 - district_output_accuracy: 0.6136 - district_output_loss: 1.5703 - loss: 5.2320 - street_output_accuracy: 0.6832 - street_output_loss: 2.0424 - val_city_output_accuracy: 0.7441 - val_city_output_loss: 1.4701 - val_district_output_accuracy: 0.6513 - val_district_output_loss: 1.3800 - val_loss: 4.9057 - val_street_output_accuracy: 0.7057 - val_street_output_loss: 2.0556
# Epoch 20/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 219s 99ms/step - city_output_accuracy: 0.6987 - city_output_loss: 1.6169 - district_output_accuracy: 0.6134 - district_output_loss: 1.5668 - loss: 5.2221 - street_output_accuracy: 0.6830 - street_output_loss: 2.0383 - val_city_output_accuracy: 0.7468 - val_city_output_loss: 1.4635 - val_district_output_accuracy: 0.6557 - val_district_output_loss: 1.3552 - val_loss: 4.8669 - val_street_output_accuracy: 0.7065 - val_street_output_loss: 2.0481
# Epoch 21/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 222s 100ms/step - city_output_accuracy: 0.6984 - city_output_loss: 1.6259 - district_output_accuracy: 0.6146 - district_output_loss: 1.5615 - loss: 5.2195 - street_output_accuracy: 0.6837 - street_output_loss: 2.0322 - val_city_output_accuracy: 0.7487 - val_city_output_loss: 1.4574 - val_district_output_accuracy: 0.6561 - val_district_output_loss: 1.3561 - val_loss: 4.8567 - val_street_output_accuracy: 0.7060 - val_street_output_loss: 2.0432
# Epoch 22/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 226s 102ms/step - city_output_accuracy: 0.6988 - city_output_loss: 1.6066 - district_output_accuracy: 0.6143 - district_output_loss: 1.5574 - loss: 5.1841 - street_output_accuracy: 0.6845 - street_output_loss: 2.0200 - val_city_output_accuracy: 0.7485 - val_city_output_loss: 1.4537 - val_district_output_accuracy: 0.6560 - val_district_output_loss: 1.3610 - val_loss: 4.8501 - val_street_output_accuracy: 0.7066 - val_street_output_loss: 2.0354
# Epoch 23/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 230s 104ms/step - city_output_accuracy: 0.7015 - city_output_loss: 1.5921 - district_output_accuracy: 0.6159 - district_output_loss: 1.5479 - loss: 5.1399 - street_output_accuracy: 0.6853 - street_output_loss: 1.9999 - val_city_output_accuracy: 0.7480 - val_city_output_loss: 1.4471 - val_district_output_accuracy: 0.6579 - val_district_output_loss: 1.3555 - val_loss: 4.8322 - val_street_output_accuracy: 0.7072 - val_street_output_loss: 2.0296
# Epoch 24/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 236s 106ms/step - city_output_accuracy: 0.7026 - city_output_loss: 1.5925 - district_output_accuracy: 0.6157 - district_output_loss: 1.5484 - loss: 5.1448 - street_output_accuracy: 0.6837 - street_output_loss: 2.0038 - val_city_output_accuracy: 0.7490 - val_city_output_loss: 1.4458 - val_district_output_accuracy: 0.6593 - val_district_output_loss: 1.3548 - val_loss: 4.8223 - val_street_output_accuracy: 0.7083 - val_street_output_loss: 2.0217
# Epoch 25/25
# 2216/2216 ━━━━━━━━━━━━━━━━━━━━ 243s 109ms/step - city_output_accuracy: 0.7020 - city_output_loss: 1.5878 - district_output_accuracy: 0.6181 - district_output_loss: 1.5410 - loss: 5.1242 - street_output_accuracy: 0.6841 - street_output_loss: 1.9954 - val_city_output_accuracy: 0.7519 - val_city_output_loss: 1.4392 - val_district_output_accuracy: 0.6602 - val_district_output_loss: 1.3380 - val_loss: 4.7905 - val_street_output_accuracy: 0.7074 - val_street_output_loss: 2.0134
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model LeakyReLU został wytrenowany i zapisany.

# %%
import gc
import tensorflow as tf
from tqdm.notebook import tqdm # Lepszy pasek postępu dla notatników

print("\nKrok 6: Predykcja i Zastosowanie Logiki Hierarchicznej (Ręczna Iteracja po Paczkach)")

# --- Tworzenie potoku danych TensorFlow (tak jak wcześniej) ---
coo = X_text.tocoo()
sparse_text_tensor = tf.SparseTensor(
    indices=np.mat([coo.row, coo.col]).transpose(),
    values=coo.data,
    dense_shape=coo.shape
)
reordered_sparse_text_tensor = tf.sparse.reorder(sparse_text_tensor)
text_dataset = tf.data.Dataset.from_tensor_slices(reordered_sparse_text_tensor)
num_dataset = tf.data.Dataset.from_tensor_slices(X_num)

combined_dataset = tf.data.Dataset.zip((text_dataset, num_dataset))
def map_fn(sparse_text, dense_num):
    return {'text_input': sparse_text, 'num_input': dense_num}
predict_dataset = combined_dataset.map(map_fn)

PREDICT_BATCH_SIZE = 512 # Możemy użyć mniejszej paczki dla większej stabilności
predict_dataset = predict_dataset.batch(PREDICT_BATCH_SIZE)

# --- KLUCZOWA ZMIANA: Ręczna pętla i przetwarzanie wyników w locie ---
print(f"Rozpoczynam predykcję na {X_text.shape[0]} próbkach w paczkach po {PREDICT_BATCH_SIZE}...")

predicted_city_ids = []
predicted_district_ids = []
predicted_street_ids = []

# Używamy tqdm do śledzenia postępu pętli
for batch in tqdm(predict_dataset, total=int(np.ceil(X_text.shape[0] / PREDICT_BATCH_SIZE))):
    # 1. Predykcja TYLKO na jednej, małej paczce
    pred_city_batch, pred_district_batch, pred_street_batch = model_leaky.predict(batch, verbose=0)
    
    # 2. Przetwarzanie wyników z tej paczki NATYCHMIAST
    for i in range(pred_city_batch.shape[0]):
        # Ta logika jest taka sama jak wcześniej, ale operuje na `_batch`
        city_pred_index = np.argmax(pred_city_batch[i])
        city_id = inv_city_id_map.get(city_pred_index, 0)
        
        valid_districts_for_city = city_to_districts.get(city_id, [])
        district_pred_index = np.argmax(pred_district_batch[i]) 
        if valid_districts_for_city:
            district_mask = np.zeros_like(pred_district_batch[i])
            valid_indices = [district_id_map.get(d_id) for d_id in valid_districts_for_city if district_id_map.get(d_id) is not None]
            if valid_indices:
                district_mask[valid_indices] = 1
                if np.sum(district_mask) > 0:
                    district_pred_index = np.argmax(pred_district_batch[i] * district_mask)
        
        district_id = inv_district_id_map.get(district_pred_index, 0)
        
        valid_streets_for_district = district_to_streets.get(district_id, [])
        street_pred_index = np.argmax(pred_street_batch[i]) 
        if valid_streets_for_district:
            street_mask = np.zeros_like(pred_street_batch[i])
            valid_indices = [street_id_map.get(s_id) for s_id in valid_streets_for_district if street_id_map.get(s_id) is not None]
            if valid_indices:
                street_mask[valid_indices] = 1
                if np.sum(street_mask) > 0:
                    street_pred_index = np.argmax(pred_street_batch[i] * street_mask)

        street_id = inv_street_id_map.get(street_pred_index, 0)
        
        # 3. Zapisujemy tylko małe, przetworzone wyniki (ID)
        predicted_city_ids.append(city_id)
        predicted_district_ids.append(district_id)
        predicted_street_ids.append(street_id)
        
    # 4. Ręczne zwolnienie pamięci po każdej paczce (opcjonalne, ale dobra praktyka)
    del pred_city_batch, pred_district_batch, pred_street_batch
    gc.collect()

# Na koniec, dodajemy skompletowane listy do ramki danych
df['predicted_city_id'] = predicted_city_ids
df['predicted_district_id'] = predicted_district_ids
df['predicted_street_id'] = predicted_street_ids

print("Zakończono predykcję z logiką hierarchiczną.")
# Out:
# Krok 6: Predykcja i Zastosowanie Logiki Hierarchicznej (Ręczna Iteracja po Paczkach)
# Rozpoczynam predykcję na 709104 próbkach w paczkach po 512...
#   0%|          | 0/1385 [00:00<?, ?it/s]
# Zakończono predykcję z logiką hierarchiczną.

# %%
print("Odtwarzam ramkę danych 'df_original'...")

# Ponownie wczytujemy dane w ten sam sposób, co w komórce 3,
# aby mieć pewność, że df_original ma identyczną strukturę jak df przed filtrowaniem.

# Szybki odczyt pierwszego wiersza, żeby znaleźć ostatnią kolumnę
try:
    first_row = pd.read_csv('saleflats_2024_dateAdded_polska.csv', sep=',', header=None, nrows=1, on_bad_lines='skip')
    last_col_index = first_row.shape[1] - 1
except:
    last_col_index = 64 # Wartość awaryjna

COLS_TO_EXTRACT = {
    3: 'Title', 4: 'Description', 5: 'Area', 6: 'Price',
    9: 'NumberOfRooms', 14: 'Floor', 15: 'Floors', 16: 'BuiltYear',
    last_col_index: 'locationPath'
}

all_offers_df_orig = []
FILES = ['saleflats_2024_dateAdded_polska.csv', 'saleflats_2024_newestDate_polska.csv']
for filepath in FILES:
    try:
        df_chunk = pd.read_csv(
            filepath, sep=',', header=None, on_bad_lines='skip',
            usecols=list(COLS_TO_EXTRACT.keys()), low_memory=False, dtype=str, encoding='utf-8'
        )
        df_chunk.rename(columns=COLS_TO_EXTRACT, inplace=True)
        all_offers_df_orig.append(df_chunk)
    except Exception:
        pass # Ignorujemy błędy, bo już raz wczytaliśmy

df_original = pd.concat(all_offers_df_orig, ignore_index=True)
df_original.drop_duplicates(subset=['Title', 'Description', 'locationPath'], keep='first', inplace=True)

print("'df_original' został pomyślnie odtworzony.")
# Out:
# Odtwarzam ramkę danych 'df_original'...
# 'df_original' został pomyślnie odtworzony.

# %%
print("\nKrok 7: Generowanie i Zapis Wyników")

def create_loc_string(row):
    city = id_to_name.get(row['predicted_city_id'], "?")
    district = id_to_name.get(row['predicted_district_id'], "?")
    street = id_to_name.get(row['predicted_street_id'], "?")
    
    # Zwracamy "?" dla nieokreślonych (ID=0)
    if row['predicted_district_id'] == 0: district = '?'
    if row['predicted_street_id'] == 0: street = '?'
        
    return f"{city} > {district} > {street}"

df['Predict_Loc'] = df.apply(create_loc_string, axis=1)

# Przygotowujemy do scalenia z oryginalnym DF
df_to_merge = df[['Title', 'Description', 'Predict_Loc']].copy()
# Tworzymy unikalny klucz do merge'owania, żeby uniknąć problemów
df_to_merge['merge_key'] = df_to_merge['Title'].fillna('') + df_to_merge['Description'].fillna('')
df_original['merge_key'] = df_original['Title'].fillna('') + df_original['Description'].fillna('')

# Scalenie
df_final = pd.merge(df_original, df_to_merge[['merge_key', 'Predict_Loc']], on='merge_key', how='left')
df_final.drop(columns=['merge_key'], inplace=True, errors='ignore')
df_final.drop_duplicates(subset=['Title', 'Description'], inplace=True)
df_final['Predict_Loc'].fillna('Brak predykcji', inplace=True)

# Zapis do pliku CSV
OUTPUT_FILE = 'Location_Polska.csv'
df_final.to_csv(OUTPUT_FILE, index=False, sep=';', encoding='utf-8-sig')
print(f"Wyniki zostały zapisane do pliku: {OUTPUT_FILE}")
# Out:
# Krok 7: Generowanie i Zapis Wyników
# Wyniki zostały zapisane do pliku: Location_Polska.csv

# %%
print("\nPrzykładowe 20 wierszy z wynikami:")

predicted_df = df_final[df_final['Predict_Loc'] != 'Brak predykcji']
if len(predicted_df) > 20:
    sample = predicted_df.sample(20)
else:
    sample = predicted_df.head(20)

display_cols = ['Title', 'locationPath', 'Predict_Loc']
sample_display = sample[display_cols]

def highlight_col(s):
    return ['background-color: #ffff99' if c == 'Predict_Loc' else '' for c in s.index]

styled_sample = sample_display.style.apply(highlight_col, axis=1)

display(styled_sample)
# Out:
# Przykładowe 20 wierszy z wynikami:
# <style type="text/css">
# #T_139cc_row0_col2, #T_139cc_row1_col2, #T_139cc_row2_col2, #T_139cc_row3_col2, #T_139cc_row4_col2, #T_139cc_row5_col2, #T_139cc_row6_col2, #T_139cc_row7_col2, #T_139cc_row8_col2, #T_139cc_row9_col2, #T_139cc_row10_col2, #T_139cc_row11_col2, #T_139cc_row12_col2, #T_139cc_row13_col2, #T_139cc_row14_col2, #T_139cc_row15_col2, #T_139cc_row16_col2, #T_139cc_row17_col2, #T_139cc_row18_col2, #T_139cc_row19_col2 {
#   background-color: #ffff99;
# }
# </style>
# <table id="T_139cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_139cc_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_139cc_level0_col1" class="col_heading level0 col1" >locationPath</th>
#       <th id="T_139cc_level0_col2" class="col_heading level0 col2" >Predict_Loc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_139cc_level0_row0" class="row_heading level0 row0" >15188</th>
#       <td id="T_139cc_row0_col0" class="data row0 col0" >Mieszkanie, Wrocław, Krzyki, 101 m²</td>
#       <td id="T_139cc_row0_col1" class="data row0 col1" >16,0,0,366,0,0,0</td>
#       <td id="T_139cc_row0_col2" class="data row0 col2" >Wrocław > Krzyki > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row1" class="row_heading level0 row1" >511448</th>
#       <td id="T_139cc_row1_col0" class="data row1 col0" >Mieszkanie, Gliwice, Kopernik, 59 m²</td>
#       <td id="T_139cc_row1_col1" class="data row1 col1" >2,0,0,386,0,0,0</td>
#       <td id="T_139cc_row1_col2" class="data row1 col2" >Gliwice > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row2" class="row_heading level0 row2" >372073</th>
#       <td id="T_139cc_row2_col0" class="data row2 col0" >Mieszkanie, Chrzanów, 39 m²</td>
#       <td id="T_139cc_row2_col1" class="data row2 col1" >14,159,0,18566,0,0,0</td>
#       <td id="T_139cc_row2_col2" class="data row2 col2" >Chrzanów > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row3" class="row_heading level0 row3" >626977</th>
#       <td id="T_139cc_row3_col0" class="data row3 col0" >Mieszkanie, 40,02 m², Mokre</td>
#       <td id="T_139cc_row3_col1" class="data row3 col1" >10,299,0,48342,0,0,0</td>
#       <td id="T_139cc_row3_col2" class="data row3 col2" >Grudziądz > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row4" class="row_heading level0 row4" >508981</th>
#       <td id="T_139cc_row4_col0" class="data row4 col0" >Przytulne mieszkanie Suchy Las/Poznań</td>
#       <td id="T_139cc_row4_col1" class="data row4 col1" >12,80,0,26478,0,0,0</td>
#       <td id="T_139cc_row4_col2" class="data row4 col2" >Suchy las > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row5" class="row_heading level0 row5" >38673</th>
#       <td id="T_139cc_row5_col0" class="data row5 col0" >Mieszkanie dwupokojowe na sprzedaż</td>
#       <td id="T_139cc_row5_col1" class="data row5 col1" >16,0,0,366,3273,79440,438630</td>
#       <td id="T_139cc_row5_col2" class="data row5 col2" >Wrocław > Ołtaszyn > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row6" class="row_heading level0 row6" >174535</th>
#       <td id="T_139cc_row6_col0" class="data row6 col0" >Mieszkanie, Hel, Pucki (pow.), 69 m²</td>
#       <td id="T_139cc_row6_col1" class="data row6 col1" >11,131,0,54946,0,0,0</td>
#       <td id="T_139cc_row6_col2" class="data row6 col2" >Hel > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row7" class="row_heading level0 row7" >57700</th>
#       <td id="T_139cc_row7_col0" class="data row7 col0" >Mieszkanie dla Studenta</td>
#       <td id="T_139cc_row7_col1" class="data row7 col1" >11,0,0,388,0,104414,537947</td>
#       <td id="T_139cc_row7_col2" class="data row7 col2" >Gdynia > Grabówek > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row8" class="row_heading level0 row8" >66107</th>
#       <td id="T_139cc_row8_col0" class="data row8 col0" >Osiedle Santo II Etap 2 pokoje 36,85 m2</td>
#       <td id="T_139cc_row8_col1" class="data row8 col1" >2,0,0,339,0,105650,0</td>
#       <td id="T_139cc_row8_col2" class="data row8 col2" >Częstochowa > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row9" class="row_heading level0 row9" >325791</th>
#       <td id="T_139cc_row9_col0" class="data row9 col0" >3-pokojowe mieszkanie na Włochach</td>
#       <td id="T_139cc_row9_col1" class="data row9 col1" >9,0,0,368,3256,90501,292284</td>
#       <td id="T_139cc_row9_col2" class="data row9 col2" >Warszawa > Ursus > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row10" class="row_heading level0 row10" >496779</th>
#       <td id="T_139cc_row10_col0" class="data row10 col0" >Mieszkanie dla pary lub rodziny</td>
#       <td id="T_139cc_row10_col1" class="data row10 col1" >9,0,0,368,3267,78352,456007</td>
#       <td id="T_139cc_row10_col2" class="data row10 col2" >Warszawa > Białołęka > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row11" class="row_heading level0 row11" >584405</th>
#       <td id="T_139cc_row11_col0" class="data row11 col0" >Mieszkanie na sprzedaż</td>
#       <td id="T_139cc_row11_col1" class="data row11 col1" >5,69,0,49100,0,0,0</td>
#       <td id="T_139cc_row11_col2" class="data row11 col2" >Szczecin > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row12" class="row_heading level0 row12" >636941</th>
#       <td id="T_139cc_row12_col0" class="data row12 col0" >Mieszkanie, Łódź, Polesie, 51 m²</td>
#       <td id="T_139cc_row12_col1" class="data row12 col1" >15,0,0,378,3250,97758,0</td>
#       <td id="T_139cc_row12_col2" class="data row12 col2" >Łódź > Polesie > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row13" class="row_heading level0 row13" >33009</th>
#       <td id="T_139cc_row13_col0" class="data row13 col0" >4 pokojowe mieszkanie Bielany ul. Bogusławskiego</td>
#       <td id="T_139cc_row13_col1" class="data row13 col1" >9,0,0,368,3266,82779,511019</td>
#       <td id="T_139cc_row13_col2" class="data row13 col2" >Warszawa > Bielany > Wojciecha bogusławskiego</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row14" class="row_heading level0 row14" >252760</th>
#       <td id="T_139cc_row14_col0" class="data row14 col0" >Słoneczny Nowy Otok | mieszkanie 5F</td>
#       <td id="T_139cc_row14_col1" class="data row14 col1" >16,134,0,62619,0,84318,416843</td>
#       <td id="T_139cc_row14_col2" class="data row14 col2" >Oława > Nowy otok > Malownicza</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row15" class="row_heading level0 row15" >394275</th>
#       <td id="T_139cc_row15_col0" class="data row15 col0" >Mieszkanie, ul. Papierni Prądnickich</td>
#       <td id="T_139cc_row15_col1" class="data row15 col1" >14,0,0,337,3257,96506,386274</td>
#       <td id="T_139cc_row15_col2" class="data row15 col2" >Kraków > Górka narodowa > Papierni prądnickich</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row16" class="row_heading level0 row16" >671640</th>
#       <td id="T_139cc_row16_col0" class="data row16 col0" >Mieszkanie 3 pokojowe w Lubinie</td>
#       <td id="T_139cc_row16_col1" class="data row16 col1" >16,81,0,13136,0,0,0</td>
#       <td id="T_139cc_row16_col2" class="data row16 col2" >Lubin > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row17" class="row_heading level0 row17" >214208</th>
#       <td id="T_139cc_row17_col0" class="data row17 col0" >Bez Prowizji! Mieszkanie 52m2 w Mszczonowie</td>
#       <td id="T_139cc_row17_col1" class="data row17 col1" >9,106,0,50168,0,0,0</td>
#       <td id="T_139cc_row17_col2" class="data row17 col2" >Mszczonów > ? > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row18" class="row_heading level0 row18" >782990</th>
#       <td id="T_139cc_row18_col0" class="data row18 col0" >Sprzedam 54, 3 m2 + 2 ogródki ( 79, 3 m2 ) + garaż</td>
#       <td id="T_139cc_row18_col1" class="data row18 col1" >9,0,0,368,3253,73493,0</td>
#       <td id="T_139cc_row18_col2" class="data row18 col2" >Warszawa > Targówek > ?</td>
#     </tr>
#     <tr>
#       <th id="T_139cc_level0_row19" class="row_heading level0 row19" >408925</th>
#       <td id="T_139cc_row19_col0" class="d
