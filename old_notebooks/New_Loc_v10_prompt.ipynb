# %% [markdown]
# # Część 1: Przygotowanie Danych i Inżynieria Cech
# Ta część jest odpowiedzialna za wczytanie, oczyszczenie i przetworzenie danych w celu przygotowania ich do treningu modelu. Zapiszemy również wszystkie niezbędne artefakty (mapy, transformatory) na dysku.

# %%
import pandas as pd
import numpy as np
import os
import re
import joblib
import gc
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy.sparse

# Definicja stałych globalnych
ARTIFACTS_DIR = 'artifacts'
PROCESSED_DATA_DIR = 'processed_data'
MAX_TEXT_FEATURES = 20000 # Zwiększono z 10000 do 20000
RANDOM_STATE = 42

# Tworzenie katalogów, jeśli nie istnieją
os.makedirs(ARTIFACTS_DIR, exist_ok=True)
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

print(f"Katalogi '{ARTIFACTS_DIR}' i '{PROCESSED_DATA_DIR}' są gotowe.")
# Out:
# Katalogi 'artifacts' i 'processed_data' są gotowe.

# %% [markdown]
# ## Wczytywanie Danych
# W tej komórce wczytujemy wszystkie niezbędne pliki CSV: dane o ofertach, definicję hierarchii lokalizacji oraz mapę do standaryzacji nazw.

# %%
def load_location_data(location_path='lokalizacja.csv'):
    """Wczytuje dane o hierarchii lokalizacji."""
    print(f"Wczytywanie pliku: {location_path}")
    df_loc = pd.read_csv(
        location_path,
        na_values=['\\N', 'NULL'],
        sep=',',
        header=None,
        names=['id', 'parent_id', 'name', 'type', 'full_name']
    )
    return df_loc

def load_offers_data(offers_path='saleflats_2024_2025.csv'):
    """Wczytuje dane o ofertach, dynamicznie znajdując ostatnią kolumnę."""
    print(f"Wczytywanie pliku: {offers_path}")
    column_names = ['title', 'description', 'area', 'price', 'locationPath']
    
    try:
        first_row = pd.read_csv(offers_path, header=None, sep=',', nrows=1, on_bad_lines='skip')
        last_col_index = first_row.shape[1] - 1
        print(f"Wykryto {last_col_index + 1} kolumn. Ostatnia kolumna ma indeks: {last_col_index}")
        
        usecols = [3, 4, 5, 6, last_col_index]
        
        df_offers = pd.read_csv(offers_path, header=None, sep=',', usecols=usecols, on_bad_lines='skip')
        df_offers.columns = column_names
        
    except Exception as e:
        print(f"Wystąpił błąd: {e}. Upewnij się, że plik '{offers_path}' ma co najmniej 7 kolumn i używa przecinka jako separatora.")
        df_offers = pd.DataFrame(columns=column_names)
        
    return df_offers

# Wywołanie funkcji
df_loc = load_location_data()
df_offers = load_offers_data()

# Wyświetlenie informacji o wczytanych danych
print("\n--- Informacje o danych lokalizacyjnych (df_loc) ---\n")
df_loc.info()
print("\n--- Nagłówek danych lokalizacyjnych ---\n")
print(df_loc.head())

print("\n--- Informacje o danych ofert (df_offers) ---\n")
df_offers.info()
print("\n--- Nagłówek danych ofert ---\n")
print(df_offers.head())
# Out:
# Wczytywanie pliku: lokalizacja.csv
# Wczytywanie pliku: saleflats_2024_2025.csv
# Wykryto 53 kolumn. Ostatnia kolumna ma indeks: 52
#
# --- Informacje o danych lokalizacyjnych (df_loc) ---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398832 entries, 0 to 398831
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         398832 non-null  int64
#  1   parent_id  398816 non-null  float64
#  2   name       398832 non-null  object
#  3   type       398832 non-null  object
#  4   full_name  398832 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 15.2+ MB
#
# --- Nagłówek danych lokalizacyjnych ---
#
#    id  parent_id                name         type           full_name
# 0   1        NaN      Świętokrzyskie  Województwo      Świętokrzyskie
# 1   2        NaN             Śląskie  Województwo             Śląskie
# 2   3        NaN           Podlaskie  Województwo           Podlaskie
# 3   4        NaN            Opolskie  Województwo            Opolskie
# 4   5        NaN  Zachodniopomorskie  Województwo  Zachodniopomorskie
#
# --- Informacje o danych ofert (df_offers) ---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305524 entries, 0 to 1305523
# Data columns (total 5 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   title         1305524 non-null  object
#  1   description   1298082 non-null  object
#  2   area          1301710 non-null  object
#  3   price         1249662 non-null  object
#  4   locationPath  1279824 non-null  object
# dtypes: object(5)
# memory usage: 49.8+ MB
#
# --- Nagłówek danych ofert ---
#
#                                                title  \
# 0                Mieszkanie trzypokojowe na sprzedaż
# 1  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2      Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki
# 3                Mieszkanie trzypokojowe na sprzedaż
# 4                 3 Pokoje- 48M2-Osiedle Dziesięciny
#
#                                          description   area   price  \
# 0  Mieszkanie o powierzchni 73m2 znajduje się na ...     73  766500
# 1  Sprzedam mieszkanie na parterze 64.8m2 w 3-pię...   64.8  540000
# 2  SPRZEDAŻ WYŁĄCZNIE BEZPOŚREDNIA. Agencjom nier...     51  540000
# 3  ***Oferta bez prowizji biura i podatku PCC!***...  67.62  544000
# 4  Przedstawiamy na sprzedaż 3 pokojowe mieszkani...     48  459000
#
#                locationPath
# 0      3,0,0,352,0,103786,0
# 1       3,0,0,352,0,99764,0
# 2       3,0,0,352,0,74375,0
# 3  3,0,0,352,0,74375,517513
# 4       3,0,0,352,0,95559,0

# %% [markdown]
# ## Budowa Hierarchii i Standaryzacja
# Tworzymy kluczowe mapy (`id_to_name`, `hierarchy_map`) na podstawie danych o lokalizacjach. Standaryzujemy również nazwy w obu ramkach danych, aby zapewnić spójność.

# %%
# 1. Stworzenie i zapisanie mapy id -> nazwa
id_to_name = dict(zip(df_loc['id'], df_loc['name']))
joblib.dump(id_to_name, os.path.join(ARTIFACTS_DIR, 'id_to_name.joblib'))
print(f"Mapa 'id_to_name' została stworzona i zapisana. Liczba wpisów: {len(id_to_name)}")

# 2. Stworzenie i zapisanie mapy hierarchii
hierarchy_map = dict(zip(df_loc['id'], df_loc['parent_id']))
joblib.dump(hierarchy_map, os.path.join(ARTIFACTS_DIR, 'hierarchy_map.joblib'))
print(f"Mapa 'hierarchy_map' została stworzona i zapisana. Liczba wpisów: {len(hierarchy_map)}")
# Out:
# Mapa 'id_to_name' została stworzona i zapisana. Liczba wpisów: 398832
# Mapa 'hierarchy_map' została stworzona i zapisana. Liczba wpisów: 398832

# %% [markdown]
# ## Inżynieria Cech i Definicja Zmiennej Celu
# W tej sekcji tworzymy zmienną celu (`target_location_id`) oraz cechy, które posłużą do treningu modelu: połączone cechy tekstowe, cechy numeryczne oraz cechę kategoryczną (miasto).

# %%
# --- Cechy Numeryczne (z nową cechą) ---
df_offers['area'] = pd.to_numeric(df_offers['area'], errors='coerce')
df_offers['price'] = pd.to_numeric(df_offers['price'], errors='coerce')
df_offers.dropna(subset=['area', 'price'], inplace=True)
df_offers = df_offers[df_offers['area'] > 0]
df_offers['price_per_meter'] = df_offers['price'] / df_offers['area']

# --- Nowa definicja celów dla modelu Multi-Head ---
path_cols = ['woj_id', 'pow_id', 'gmi_id', 'city_id', 'district_id', 'subdistrict_id', 'street_id']
path_df = df_offers['locationPath'].str.split(',', expand=True)
path_df = path_df.iloc[:, :len(path_cols)]
path_df.columns = path_cols[:path_df.shape[1]]
path_df = path_df.apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)
df_offers = pd.concat([df_offers.reset_index(drop=True), path_df.reset_index(drop=True)], axis=1)

df_offers['target_district_id'] = np.where(df_offers['subdistrict_id'] != 0, df_offers['subdistrict_id'], df_offers['district_id'])
df_offers['target_street_id'] = df_offers['street_id']

# --- Tworzenie i zapis artefaktu do post-processingu ---
print("Tworzenie mapy district -> streets do weryfikacji hierarchii...")
district_to_streets = df_loc[df_loc['type'] == 'STREET'].groupby('parent_id')['id'].apply(list).to_dict()
joblib.dump(district_to_streets, os.path.join(ARTIFACTS_DIR, 'district_to_streets.joblib'))
print(f"Mapa 'district_to_streets' została stworzona i zapisana. Liczba wpisów: {len(district_to_streets)}")

# --- Finalne czyszczenie i tworzenie df_processed ---
df_offers.dropna(subset=['city_id'], inplace=True)
df_offers = df_offers[df_offers['city_id'] != 0]

df_processed = df_offers[[
    'title', 'description', 'area', 'price', 'price_per_meter', 
    'city_id', 'target_district_id', 'target_street_id'
]].copy()
df_processed['text_features'] = df_processed['title'].fillna('') + " " + df_processed['description'].fillna('')
df_processed.drop(columns=['title', 'description'], inplace=True)
df_processed.dropna(inplace=True)

print("\n--- Informacje o finalnym, przetworzonym DataFrame (df_processed) ---\n")
df_processed.info()
print("\n--- Nagłówek df_processed ---\n")
print(df_processed.head())
# Out:
# Tworzenie mapy district -> streets do weryfikacji hierarchii...
# Mapa 'district_to_streets' została stworzona i zapisana. Liczba wpisów: 0
#
# --- Informacje o finalnym, przetworzonym DataFrame (df_processed) ---
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1112222 entries, 0 to 1122941
# Data columns (total 7 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   area                1112222 non-null  float64
#  1   price               1112222 non-null  float64
#  2   price_per_meter     1112222 non-null  float64
#  3   city_id             1112222 non-null  int32
#  4   target_district_id  1112222 non-null  int32
#  5   target_street_id    1112222 non-null  int32
#  6   text_features       1112222 non-null  object
# dtypes: float64(3), int32(3), object(1)
# memory usage: 55.2+ MB
#
# --- Nagłówek df_processed ---
#
#     area     price  price_per_meter  city_id  target_district_id  \
# 0  73.00  766500.0     10500.000000      352              103786
# 1  64.80  540000.0      8333.333333      352               99764
# 2  51.00  540000.0     10588.235294      352               74375
# 3  67.62  544000.0      8044.957113      352               74375
# 4  48.00  459000.0      9562.500000      352               95559
#
#    target_street_id                                      text_features
# 0                 0  Mieszkanie trzypokojowe na sprzedaż Mieszkanie...
# 1                 0  Sprzedam mieszkanie na parterze 64.8m2 Białyst...
# 2                 0  Mieszkanie bezczynszowe, 3 pokoje, 2 łazienki ...
# 3            517513  Mieszkanie trzypokojowe na sprzedaż ***Oferta ...
# 4                 0  3 Pokoje- 48M2-Osiedle Dziesięciny Przedstawia...

# %% [markdown]
# ## Transformacja Cech i Podział na Zbiory
# Dzielimy dane na zbiory treningowy i walidacyjny. Następnie dopasowujemy transformatory (imputer, scaler, vectorizer) na zbiorze treningowym i zapisujemy je, aby móc ich użyć w przyszłości.

# %%
print("Sprawdzanie liczności klas dla stratyfikacji...")
city_counts = df_processed['city_id'].value_counts()
valid_cities = city_counts[city_counts > 1].index
df_filtered = df_processed[df_processed['city_id'].isin(valid_cities)].copy()
print(f"Usunięto {len(df_processed) - len(df_filtered)} wierszy należących do miast z tylko jednym ogłoszeniem.")

# Podział na zbiory
X = df_filtered.drop(columns=['target_district_id', 'target_street_id'])
y = df_filtered[['target_district_id', 'target_street_id']]

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=X['city_id']
)

print(f"Podział danych: {len(X_train)} próbek treningowych, {len(X_val)} próbek walidacyjnych.")

# --- Przetwarzanie Cech Numerycznych ---
numeric_features = ['area', 'price', 'price_per_meter']
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

X_train_num_imputed = imputer.fit_transform(X_train[numeric_features])
X_train_num = scaler.fit_transform(X_train_num_imputed)

joblib.dump(imputer, os.path.join(ARTIFACTS_DIR, 'imputer.joblib'))
joblib.dump(scaler, os.path.join(ARTIFACTS_DIR, 'scaler.joblib'))
print("Imputer i Scaler zostały dopasowane i zapisane.")

X_val_num_imputed = imputer.transform(X_val[numeric_features])
X_val_num = scaler.transform(X_val_num_imputed)

# --- Przetwarzanie Cech Tekstowych ---
vectorizer = TfidfVectorizer(max_features=MAX_TEXT_FEATURES, ngram_range=(1, 2))
X_train_text = vectorizer.fit_transform(X_train['text_features'])

joblib.dump(vectorizer, os.path.join(ARTIFACTS_DIR, 'vectorizer.joblib'))
print("TfidfVectorizer został dopasowany i zapisany.")

X_val_text = vectorizer.transform(X_val['text_features'])

# --- Przygotowanie pozostałych cech ---
X_train_city = X_train['city_id'].values
X_val_city = X_val['city_id'].values

# --- Przygotowanie oddzielnych celów ---
y_district_train = y_train['target_district_id'].values
y_street_train = y_train['target_street_id'].values
y_district_val = y_val['target_district_id'].values
y_street_val = y_val['target_street_id'].values
# Out:
# Sprawdzanie liczności klas dla stratyfikacji...
# Usunięto 2757 wierszy należących do miast z tylko jednym ogłoszeniem.
# Podział danych: 887572 próbek treningowych, 221893 próbek walidacyjnych.
# Imputer i Scaler zostały dopasowane i zapisane.
# TfidfVectorizer został dopasowany i zapisany.

# %% [markdown]
# ## Zapisanie Wyników do Plików
# Wszystkie przetworzone dane oraz kluczowe ramki danych są zapisywane na dysku. Umożliwi to ich wczytanie w drugiej części notebooka bez potrzeby ponownego przetwarzania.

# %%
# Zapis macierzy TF-IDF
scipy.sparse.save_npz(os.path.join(PROCESSED_DATA_DIR, 'X_train_text.npz'), X_train_text)
scipy.sparse.save_npz(os.path.join(PROCESSED_DATA_DIR, 'X_val_text.npz'), X_val_text)

# Zapis macierzy numerycznych
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_train_num.npy'), X_train_num)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_val_num.npy'), X_val_num)

# Zapis ID miast
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_train_city.npy'), X_train_city)
np.save(os.path.join(PROCESSED_DATA_DIR, 'X_val_city.npy'), X_val_city)

# Zapis oddzielnych zmiennych docelowych
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_district_train.npy'), y_district_train)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_street_train.npy'), y_street_train)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_district_val.npy'), y_district_val)
np.save(os.path.join(PROCESSED_DATA_DIR, 'y_street_val.npy'), y_street_val)

print("Wszystkie przetworzone zbiory danych zostały zapisane.")

# Zwolnienie pamięci
del df_loc, df_offers, df_processed, X, y, X_train, X_val, y_train, y_val
del X_train_text, X_val_text, X_train_num, X_val_num, X_train_city, X_val_city
gc.collect()

print("\n" + "="*80)
print("CZĘŚĆ 1 ZAKOŃCZONA POWODZENIEM.")
print("TERAZ NALEŻY ZRESTARTOWAĆ KERNEL PRZED URUCHOMIENIEM CZĘŚCI 2.")
print("="*80)
# Out:
# Wszystkie przetworzone zbiory danych zostały zapisane.
#
# ================================================================================
# CZĘŚĆ 1 ZAKOŃCZONA POWODZENIEM.
# TERAZ NALEŻY ZRESTARTOWAĆ KERNEL PRZED URUCHOMIENIEM CZĘŚCI 2.
# ================================================================================

# %% [markdown]
# # Część 2: Budowa, Trening i Inferencia Modelu
# Witaj w nowej sesji kernela! Ta część wczyta przetworzone dane i artefakty, a następnie zdefiniuje, wytrenuje i wykorzysta model sieci neuronowej do predykcji lokalizacji z uwzględnieniem spójności hierarchicznej.

# %%
import pandas as pd
import numpy as np
import joblib
import os
import gc
import scipy.sparse
import tensorflow as tf
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Dropout, Embedding, Flatten, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import register_keras_serializable

# Ponowna definicja stałych
ARTIFACTS_DIR = 'artifacts'
PROCESSED_DATA_DIR = 'processed_data'
RANDOM_STATE = 42
MAX_TEXT_FEATURES = 20000
MODEL_PATH = os.path.join(ARTIFACTS_DIR, 'best_location_model_v10.keras')

# %% [markdown]
# ## Wczytywanie Przetworzonych Danych i Artefaktów
# Wczytujemy wszystkie niezbędne pliki wygenerowane w Części 1.

# %%
# Wczytanie artefaktów
print("Wczytywanie artefaktów...")
hierarchy_map = joblib.load(os.path.join(ARTIFACTS_DIR, 'hierarchy_map.joblib'))
id_to_name = joblib.load(os.path.join(ARTIFACTS_DIR, 'id_to_name.joblib'))
scaler = joblib.load(os.path.join(ARTIFACTS_DIR, 'scaler.joblib'))
imputer = joblib.load(os.path.join(ARTIFACTS_DIR, 'imputer.joblib'))
vectorizer = joblib.load(os.path.join(ARTIFACTS_DIR, 'vectorizer.joblib'))
district_to_streets = joblib.load(os.path.join(ARTIFACTS_DIR, 'district_to_streets.joblib'))
print("Artefakty wczytane.")

# Wczytanie przetworzonych danych
print("Wczytywanie przetworzonych danych...")
X_train_text = scipy.sparse.load_npz(os.path.join(PROCESSED_DATA_DIR, 'X_train_text.npz'))
X_val_text = scipy.sparse.load_npz(os.path.join(PROCESSED_DATA_DIR, 'X_val_text.npz'))
X_train_num = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_train_num.npy'))
X_val_num = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_val_num.npy'))
X_train_city = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_train_city.npy'))
X_val_city = np.load(os.path.join(PROCESSED_DATA_DIR, 'X_val_city.npy'))
y_district_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_district_train.npy'))
y_street_train = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_street_train.npy'))
y_district_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_district_val.npy'))
y_street_val = np.load(os.path.join(PROCESSED_DATA_DIR, 'y_street_val.npy'))
print("Dane wczytane.")
# Out:
# Wczytywanie artefaktów...
# Artefakty wczytane.
# Wczytywanie przetworzonych danych...
# Dane wczytane.

# %%
print("Definiowanie hierarchicznej funkcji straty...")
print("Wczytywanie pliku lokalizacja.csv na potrzeby funkcji straty...")
df_loc = pd.read_csv(
    'lokalizacja.csv', na_values=['\\N', 'NULL'], sep=',', header=None,
    names=['id', 'parent_id', 'name', 'type', 'full_name']
)

id_to_parent = dict(zip(df_loc['id'], df_loc['parent_id']))
id_to_type = dict(zip(df_loc['id'], df_loc['type']))

def get_city_for_id(loc_id, id_to_parent_map, id_to_type_map):
    current_id = loc_id
    for _ in range(5):
        if pd.isna(current_id) or current_id == 0: return 0
        if id_to_type_map.get(current_id) == 'CITY': return int(current_id)
        current_id = id_to_parent_map.get(current_id)
    return 0

all_ids = list(id_to_parent.keys())
id_to_city_map = {loc_id: get_city_for_id(loc_id, id_to_parent, id_to_type) for loc_id in all_ids}
joblib.dump(id_to_city_map, os.path.join(ARTIFACTS_DIR, 'id_to_city_map.joblib'))
print("Mapa 'id_to_city' stworzona i zapisana.")

@register_keras_serializable()
class HierarchicalLoss(tf.keras.losses.Loss):
    def __init__(self, id_to_parent_map, id_to_city_map, penalty_config, **kwargs):
        super().__init__(**kwargs)
        self.base_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction='none')
        self.id_to_parent_map = id_to_parent_map
        self.id_to_city_map = id_to_city_map
        self.penalty_config = penalty_config
        self.penalty_wrong_parent = penalty_config.get('wrong_parent', 2.0)
        self.penalty_wrong_city = penalty_config.get('wrong_city', 5.0)
        
        keys = list(id_to_parent_map.keys()); values = [int(v) if pd.notna(v) else 0 for v in id_to_parent_map.values()]
        self.parent_table = tf.lookup.StaticHashTable(tf.lookup.KeyValueTensorInitializer(keys, values, key_dtype=tf.int64, value_dtype=tf.int64), 0)
        
        keys = list(id_to_city_map.keys()); values = [int(v) for v in id_to_city_map.values()]
        self.city_table = tf.lookup.StaticHashTable(tf.lookup.KeyValueTensorInitializer(keys, values, key_dtype=tf.int64, value_dtype=tf.int64), 0)

    def call(self, y_true, y_pred):
        y_true_tensor = tf.cast(y_true, dtype=tf.int64)
        y_pred_ids = tf.cast(tf.argmax(y_pred, axis=-1), dtype=tf.int64)
        base_loss = self.base_loss_fn(y_true_tensor, y_pred)
        
        true_parents = self.parent_table.lookup(y_true_tensor); pred_parents = self.parent_table.lookup(y_pred_ids)
        true_cities = self.city_table.lookup(y_true_tensor); pred_cities = self.city_table.lookup(y_pred_ids)
        
        penalties = tf.ones_like(base_loss) * self.penalty_wrong_city
        penalties = tf.where(tf.equal(true_cities, pred_cities), tf.ones_like(base_loss) * self.penalty_wrong_parent, penalties)
        penalties = tf.where(tf.equal(true_parents, pred_parents), tf.ones_like(base_loss) * 1.2, penalties)
        penalties = tf.where(tf.equal(y_true_tensor, y_pred_ids), tf.ones_like(base_loss), penalties)

        return tf.reduce_mean(base_loss * penalties)

    def get_config(self):
        base_config = super().get_config()
        config = {"id_to_parent_map": self.id_to_parent_map, "id_to_city_map": self.id_to_city_map, "penalty_config": self.penalty_config}
        return {**base_config, **config}

    @classmethod
    def from_config(cls, config):
        return cls(**config)

print("Hierarchiczna funkcja straty zdefiniowana i gotowa do serializacji.")
# Out:
# Definiowanie hierarchicznej funkcji straty...
# Wczytywanie pliku lokalizacja.csv na potrzeby funkcji straty...
# Mapa 'id_to_city' stworzona i zapisana.
# Hierarchiczna funkcja straty zdefiniowana i gotowa do serializacji.

# %% [markdown]
# ## Definicja Architektury Modelu (Multi-Input, Single-Output)
# Budujemy model Keras z trzema oddzielnymi wejściami (tekst, cechy numeryczne, miasto), które są łączone i przetwarzane przez wspólne warstwy gęste.

# %%
# Mapowanie ID Dzielnic na ciągłe indeksy
unique_districts = np.unique(np.concatenate([y_district_train, y_district_val]))
district_map = {val: i for i, val in enumerate(unique_districts)}
y_district_train_mapped = np.array([district_map.get(val, 0) for val in y_district_train])
y_district_val_mapped = np.array([district_map.get(val, 0) for val in y_district_val])

# Mapowanie ID Ulic na ciągłe indeksy
unique_streets = np.unique(np.concatenate([y_street_train, y_street_val]))
street_map = {val: i for i, val in enumerate(unique_streets)}
y_street_train_mapped = np.array([street_map.get(val, 0) for val in y_street_train])
y_street_val_mapped = np.array([street_map.get(val, 0) for val in y_street_val])

# Mapowanie ID Miast (wejście) na ciągłe indeksy
unique_cities = np.unique(np.concatenate([X_train_city, X_val_city]))
city_map = {val: i for i, val in enumerate(unique_cities)}
X_train_city_mapped = np.array([city_map.get(val, 0) for val in X_train_city])
X_val_city_mapped = np.array([city_map.get(val, 0) for val in X_val_city])
joblib.dump(city_map, os.path.join(ARTIFACTS_DIR, 'city_map.joblib'))

# Definicja parametrów
NUM_DISTRICTS = len(unique_districts)
NUM_STREETS = len(unique_streets)
NUM_CITIES = len(unique_cities)
NUM_FEATURES = X_train_num.shape[1]

# Definicja modelu
input_text = Input(shape=(MAX_TEXT_FEATURES,), name='text_input', sparse=True)
input_num = Input(shape=(NUM_FEATURES,), name='num_input')
input_city = Input(shape=(1,), name='city_input')

# Wspólna część modelu (ciało)
text_branch = Dense(128, activation='relu')(input_text); text_branch = Dropout(0.3)(text_branch)
num_branch = Dense(64, activation='relu')(input_num); num_branch = Dense(32, activation='relu')(num_branch)
city_branch = Embedding(input_dim=NUM_CITIES, output_dim=50, name='city_embedding')(input_city); city_branch = Flatten()(city_branch)
combined = Concatenate()([text_branch, num_branch, city_branch])
z = Dense(512, activation='relu')(combined); z = Dropout(0.5)(z)
z = Dense(256, activation='relu')(z); z = Dropout(0.5)(z)

# Oddzielne głowice wyjściowe
output_district = Dense(NUM_DISTRICTS, activation='softmax', name='district_output')(z)
output_street = Dense(NUM_STREETS, activation='softmax', name='street_output')(z)

model = Model(inputs=[input_text, input_num, input_city], outputs=[output_district, output_street])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)       │ (None, 20000)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ num_input (InputLayer)        │ (None, 3)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_input (InputLayer)       │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │       2,560,128 │ text_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64)                │             256 │ num_input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ city_embedding (Embedding)    │ (None, 1, 50)             │         276,800 │ city_input[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 32)                │           2,080 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 50)                │               0 │ city_embedding[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 210)               │               0 │ dropout[0][0],             │
# │                               │                           │                 │ dense_2[0][0],             │
# │                               │                           │                 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 512)               │         108,032 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 512)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 256)               │         131,328 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 256)               │               0 │ dense_4[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ district_output (Dense)       │ (None, 2204)              │         566,428 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ street_output (Dense)         │ (None, 33604)             │       8,636,228 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 12,281,280 (46.85 MB)
#  Trainable params: 12,281,280 (46.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Trening Modelu
# Uruchamiamy proces treningu z wykorzystaniem `EarlyStopping` w celu uniknięcia przeuczenia oraz `ModelCheckpoint` do zapisania najlepszej wersji modelu.

# %%
# Przygotowanie map hierarchii dla funkcji straty
id_to_parent_map = joblib.load(os.path.join(ARTIFACTS_DIR, 'hierarchy_map.joblib'))
id_to_city_map = joblib.load(os.path.join(ARTIFACTS_DIR, 'id_to_city_map.joblib'))

# Stworzenie instancji funkcji straty
penalty_config = {'wrong_parent': 2.0, 'wrong_city': 5.0}
district_loss = HierarchicalLoss(id_to_parent_map, id_to_city_map, penalty_config, name='district_hierarchical_loss')
street_loss = HierarchicalLoss(id_to_parent_map, id_to_city_map, penalty_config, name='street_hierarchical_loss')

# Kompilacja modelu
model.compile(
    optimizer='adam',
    loss={'district_output': district_loss, 'street_output': street_loss},
    loss_weights={'district_output': 1.5, 'street_output': 1.0},
    metrics={'district_output': 'accuracy', 'street_output': 'accuracy'}
)

# Callbacks
model_checkpoint = ModelCheckpoint(MODEL_PATH, monitor='val_loss', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

# Przygotowanie słowników danych
X_train_dict = {'text_input': X_train_text, 'num_input': X_train_num, 'city_input': X_train_city_mapped}
X_val_dict = {'text_input': X_val_text, 'num_input': X_val_num, 'city_input': X_val_city_mapped}
y_train_dict = {'district_output': y_district_train_mapped, 'street_output': y_street_train_mapped}
y_val_dict = {'district_output': y_district_val_mapped, 'street_output': y_street_val_mapped}

# Trening
history = model.fit(
    X_train_dict, y_train_dict,
    validation_data=(X_val_dict, y_val_dict),
    epochs=20, batch_size=128,
    callbacks=[model_checkpoint, early_stopping]
)
# Out:
# Epoch 1/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - district_output_accuracy: 0.4811 - district_output_loss: 5.1368 - loss: 14.8855 - street_output_accuracy: 0.6365 - street_output_loss: 7.1803
# Epoch 1: val_loss improved from inf to 9.35351, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 773s 111ms/step - district_output_accuracy: 0.4811 - district_output_loss: 5.1366 - loss: 14.8851 - street_output_accuracy: 0.6365 - street_output_loss: 7.1802 - val_district_output_accuracy: 0.5952 - val_district_output_loss: 2.8931 - val_loss: 9.3535 - val_street_output_accuracy: 0.6494 - val_street_output_loss: 5.0142
# Epoch 2/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - district_output_accuracy: 0.5775 - district_output_loss: 2.9498 - loss: 9.4855 - street_output_accuracy: 0.6457 - street_output_loss: 5.0607
# Epoch 2: val_loss improved from 9.35351 to 7.86230, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 793s 114ms/step - district_output_accuracy: 0.5775 - district_output_loss: 2.9498 - loss: 9.4854 - street_output_accuracy: 0.6457 - street_output_loss: 5.0607 - val_district_output_accuracy: 0.6373 - val_district_output_loss: 2.3851 - val_loss: 7.8623 - val_street_output_accuracy: 0.6611 - val_street_output_loss: 4.2849
# Epoch 3/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - district_output_accuracy: 0.6128 - district_output_loss: 2.5348 - loss: 8.2017 - street_output_accuracy: 0.6508 - street_output_loss: 4.3995
# Epoch 3: val_loss improved from 7.86230 to 7.27411, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 827s 119ms/step - district_output_accuracy: 0.6128 - district_output_loss: 2.5348 - loss: 8.2017 - street_output_accuracy: 0.6508 - street_output_loss: 4.3995 - val_district_output_accuracy: 0.6568 - val_district_output_loss: 2.1962 - val_loss: 7.2741 - val_street_output_accuracy: 0.6681 - val_street_output_loss: 3.9800
# Epoch 4/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - district_output_accuracy: 0.6304 - district_output_loss: 2.3612 - loss: 7.6369 - street_output_accuracy: 0.6527 - street_output_loss: 4.0950
# Epoch 4: val_loss improved from 7.27411 to 6.96629, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 843s 122ms/step - district_output_accuracy: 0.6304 - district_output_loss: 2.3612 - loss: 7.6369 - street_output_accuracy: 0.6527 - street_output_loss: 4.0950 - val_district_output_accuracy: 0.6663 - val_district_output_loss: 2.0915 - val_loss: 6.9663 - val_street_output_accuracy: 0.6722 - val_street_output_loss: 3.8293
# Epoch 5/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - district_output_accuracy: 0.6411 - district_output_loss: 2.2505 - loss: 7.3151 - street_output_accuracy: 0.6544 - street_output_loss: 3.9393
# Epoch 5: val_loss improved from 6.96629 to 6.78768, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 866s 125ms/step - district_output_accuracy: 0.6411 - district_output_loss: 2.2505 - loss: 7.3151 - street_output_accuracy: 0.6544 - street_output_loss: 3.9393 - val_district_output_accuracy: 0.6728 - val_district_output_loss: 2.0334 - val_loss: 6.7877 - val_street_output_accuracy: 0.6742 - val_street_output_loss: 3.7378
# Epoch 6/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - district_output_accuracy: 0.6495 - district_output_loss: 2.1855 - loss: 7.1205 - street_output_accuracy: 0.6563 - street_output_loss: 3.8422
# Epoch 6: val_loss improved from 6.78768 to 6.68268, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 891s 128ms/step - district_output_accuracy: 0.6495 - district_output_loss: 2.1855 - loss: 7.1205 - street_output_accuracy: 0.6563 - street_output_loss: 3.8422 - val_district_output_accuracy: 0.6787 - val_district_output_loss: 1.9965 - val_loss: 6.6827 - val_street_output_accuracy: 0.6750 - val_street_output_loss: 3.6882
# Epoch 7/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - district_output_accuracy: 0.6554 - district_output_loss: 2.1331 - loss: 6.9771 - street_output_accuracy: 0.6560 - street_output_loss: 3.7775
# Epoch 7: val_loss improved from 6.68268 to 6.59089, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 922s 133ms/step - district_output_accuracy: 0.6554 - district_output_loss: 2.1331 - loss: 6.9771 - street_output_accuracy: 0.6560 - street_output_loss: 3.7775 - val_district_output_accuracy: 0.6810 - val_district_output_loss: 1.9688 - val_loss: 6.5909 - val_street_output_accuracy: 0.6761 - val_street_output_loss: 3.6379
# Epoch 8/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - district_output_accuracy: 0.6590 - district_output_loss: 2.0955 - loss: 6.8655 - street_output_accuracy: 0.6571 - street_output_loss: 3.7223
# Epoch 8: val_loss improved from 6.59089 to 6.53214, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 947s 136ms/step - district_output_accuracy: 0.6590 - district_output_loss: 2.0955 - loss: 6.8655 - street_output_accuracy: 0.6571 - street_output_loss: 3.7223 - val_district_output_accuracy: 0.6854 - val_district_output_loss: 1.9457 - val_loss: 6.5321 - val_street_output_accuracy: 0.6773 - val_street_output_loss: 3.6138
# Epoch 9/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - district_output_accuracy: 0.6626 - district_output_loss: 2.0694 - loss: 6.7871 - street_output_accuracy: 0.6576 - street_output_loss: 3.6829
# Epoch 9: val_loss improved from 6.53214 to 6.47865, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 968s 140ms/step - district_output_accuracy: 0.6626 - district_output_loss: 2.0694 - loss: 6.7871 - street_output_accuracy: 0.6576 - street_output_loss: 3.6829 - val_district_output_accuracy: 0.6879 - val_district_output_loss: 1.9249 - val_loss: 6.4786 - val_street_output_accuracy: 0.6776 - val_street_output_loss: 3.5914
# Epoch 10/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - district_output_accuracy: 0.6664 - district_output_loss: 2.0420 - loss: 6.7235 - street_output_accuracy: 0.6587 - street_output_loss: 3.6605
# Epoch 10: val_loss improved from 6.47865 to 6.43314, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1005s 145ms/step - district_output_accuracy: 0.6664 - district_output_loss: 2.0420 - loss: 6.7235 - street_output_accuracy: 0.6587 - street_output_loss: 3.6605 - val_district_output_accuracy: 0.6907 - val_district_output_loss: 1.9017 - val_loss: 6.4331 - val_street_output_accuracy: 0.6772 - val_street_output_loss: 3.5807
# Epoch 11/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - district_output_accuracy: 0.6691 - district_output_loss: 2.0194 - loss: 6.6705 - street_output_accuracy: 0.6587 - street_output_loss: 3.6414
# Epoch 11: val_loss improved from 6.43314 to 6.42958, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1022s 147ms/step - district_output_accuracy: 0.6691 - district_output_loss: 2.0194 - loss: 6.6706 - street_output_accuracy: 0.6587 - street_output_loss: 3.6414 - val_district_output_accuracy: 0.6910 - val_district_output_loss: 1.9010 - val_loss: 6.4296 - val_street_output_accuracy: 0.6782 - val_street_output_loss: 3.5782
# Epoch 12/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - district_output_accuracy: 0.6697 - district_output_loss: 2.0166 - loss: 6.6538 - street_output_accuracy: 0.6592 - street_output_loss: 3.6289
# Epoch 12: val_loss improved from 6.42958 to 6.41237, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1055s 152ms/step - district_output_accuracy: 0.6697 - district_output_loss: 2.0166 - loss: 6.6538 - street_output_accuracy: 0.6592 - street_output_loss: 3.6289 - val_district_output_accuracy: 0.6921 - val_district_output_loss: 1.8932 - val_loss: 6.4124 - val_street_output_accuracy: 0.6782 - val_street_output_loss: 3.5729
# Epoch 13/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - district_output_accuracy: 0.6725 - district_output_loss: 2.0037 - loss: 6.6081 - street_output_accuracy: 0.6609 - street_output_loss: 3.6025
# Epoch 13: val_loss improved from 6.41237 to 6.40209, saving model to artifacts\best_location_model_v10.keras
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1072s 155ms/step - district_output_accuracy: 0.6725 - district_output_loss: 2.0037 - loss: 6.6081 - street_output_accuracy: 0.6609 - street_output_loss: 3.6025 - val_district_output_accuracy: 0.6925 - val_district_output_loss: 1.8905 - val_loss: 6.4021 - val_street_output_accuracy: 0.6786 - val_street_output_loss: 3.5666
# Epoch 14/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - district_output_accuracy: 0.6750 - district_output_loss: 1.9839 - loss: 6.5877 - street_output_accuracy: 0.6586 - street_output_loss: 3.6118
# Epoch 14: val_loss did not improve from 6.40209
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1068s 154ms/step - district_output_accuracy: 0.6750 - district_output_loss: 1.9839 - loss: 6.5877 - street_output_accuracy: 0.6586 - street_output_loss: 3.6118 - val_district_output_accuracy: 0.6923 - val_district_output_loss: 1.8911 - val_loss: 6.4192 - val_street_output_accuracy: 0.6783 - val_street_output_loss: 3.5827
# Epoch 15/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - district_output_accuracy: 0.6760 - district_output_loss: 1.9835 - loss: 6.5813 - street_output_accuracy: 0.6586 - street_output_loss: 3.6061
# Epoch 15: val_loss did not improve from 6.40209
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1109s 160ms/step - district_output_accuracy: 0.6760 - district_output_loss: 1.9835 - loss: 6.5813 - street_output_accuracy: 0.6586 - street_output_loss: 3.6061 - val_district_output_accuracy: 0.6933 - val_district_output_loss: 1.8886 - val_loss: 6.4131 - val_street_output_accuracy: 0.6786 - val_street_output_loss: 3.5805
# Epoch 16/20
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - district_output_accuracy: 0.6763 - district_output_loss: 1.9753 - loss: 6.5669 - street_output_accuracy: 0.6602 - street_output_loss: 3.6039
# Epoch 16: val_loss did not improve from 6.40209
# 6935/6935 ━━━━━━━━━━━━━━━━━━━━ 1139s 164ms/step - district_output_accuracy: 0.6763 - district_output_loss: 1.9754 - loss: 6.5669 - street_output_accuracy: 0.6602 - street_output_loss: 3.6039 - val_district_output_accuracy: 0.6944 - val_district_output_loss: 1.8877 - val_loss: 6.4080 - val_street_output_accuracy: 0.6803 - val_street_output_loss: 3.5767
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %% [markdown]
# ## Przygotowanie do Predykcji Hierarchicznej
# Definiujemy funkcje pomocnicze, które zaimplementują kluczową logikę biznesową: odtworzenie pełnej ścieżki lokalizacji i weryfikację jej zgodności z miastem wejściowym.

# %%
import tensorflow as tf
import pandas as pd

class HierarchicalLoss(tf.keras.losses.Loss):
    def __init__(self, id_to_parent_map, id_to_city_map, penalty_config, **kwargs):
        super().__init__(**kwargs)
        # Przechowujemy oryginalne mapy do serializacji
        self.id_to_parent_map = id_to_parent_map
        self.id_to_city_map = id_to_city_map
        self.penalty_config = penalty_config

        # --- Logika inicjalizacji tabel ---
        # Tutaj klucze mogą być stringami lub int, w zależności od tego,
        # czy obiekt jest tworzony po raz pierwszy, czy z konfiguracji.
        # Dlatego konwersja na `int` jest kluczowa.
        parent_keys = [int(k) for k in id_to_parent_map.keys()]
        parent_values = [int(v) if pd.notna(v) else 0 for v in id_to_parent_map.values()]
        self.parent_table = tf.lookup.StaticHashTable(
            tf.lookup.KeyValueTensorInitializer(parent_keys, parent_values, key_dtype=tf.int64, value_dtype=tf.int64), 0
        )

        city_keys = [int(k) for k in id_to_city_map.keys()]
        city_values = [int(v) for v in id_to_city_map.values()]
        self.city_table = tf.lookup.StaticHashTable(
            tf.lookup.KeyValueTensorInitializer(city_keys, city_values, key_dtype=tf.int64, value_dtype=tf.int64), 0
        )
        
        self.wrong_city_penalty = tf.constant(penalty_config.get('wrong_city', 2.0), dtype=tf.float32)
        # ... inne stałe, jeśli je masz ...

    def call(self, y_true, y_pred):
        # Tutaj Twoja logika obliczania straty (bez zmian)
        # Poniżej jest tylko przykład, wstaw tu swój kod
        y_true_district, y_true_street = y_true[:, 0], y_true[:, 1]
        y_pred_district, y_pred_street = y_pred[:, 0], y_pred[:, 1]
        
        # Przykładowa, uproszczona logika - zastąp swoją
        loss = tf.keras.losses.sparse_categorical_crossentropy(y_true_district, y_pred_district)
        return loss

    def get_config(self):
        # Ta metoda mówi Kerasowi, co zapisać w konfiguracji modelu
        config = super().get_config()
        config.update({
            "id_to_parent_map": self.id_to_parent_map,
            "id_to_city_map": self.id_to_city_map,
            "penalty_config": self.penalty_config
        })
        return config

    @classmethod
    def from_config(cls, config):
        # Ta metoda mówi Kerasowi, jak odtworzyć obiekt z konfiguracji.
        # Keras automatycznie wywoła `__init__` z argumentami ze słownika `config`.
        # Nie musimy tu nic modyfikować, ponieważ całą logikę konwersji
        # umieściliśmy w `__init__`.
        return cls(**config)

# %% [markdown]
# ## Wykonanie i Ocena Predykcji na Zbiorze Walidacyjnym
# Używamy zdefiniowanych funkcji do przeprowadzenia predykcji na zbiorze walidacyjnym i obliczamy ogólną dokładność naszego podejścia.

# %%
# KOMÓRKA 12 (Kod) - OSTATECZNA POPRAWIONA WERSJA

print(f"Wczytywanie najlepszego modelu (tylko do predykcji) z: {MODEL_PATH}")
best_model = tf.keras.models.load_model(MODEL_PATH, compile=False)
print("Model wczytany pomyślnie.")

# Wczytujemy mapy odwrotne
inv_district_map = {v: k for k, v in district_map.items()}
inv_street_map = {v: k for k, v in street_map.items()}

# Wybierzmy podzbiór danych walidacyjnych
num_samples = 1000
indices = np.random.choice(range(len(y_district_val)), num_samples, replace=False)

predicted_districts, predicted_streets, true_districts, true_streets, is_correct_list = [], [], [], [], []

print(f"Przeprowadzanie predykcji na {num_samples} próbkach...")
for i in indices:
    original_city_id = X_val_city[i]
    mapped_city_id = city_map.get(original_city_id, 0)

    # --- OSTATECZNA POPRAWKA: Konwersja macierzy rzadkiej na gęstą tablicę ---
    # Pobieramy macierz rzadką dla danej próbki
    sparse_matrix_sample = X_val_text[i]
    # Konwertujemy ją na gęstą tablicę NumPy, której oczekuje model
    dense_vector_sample = sparse_matrix_sample.toarray()
    
    # Tworzymy słownik wejściowy
    input_sample = {
        'text_input': dense_vector_sample,  # Przekazujemy gęstą tablicę
        'num_input': np.expand_dims(X_val_num[i], axis=0),
        'city_input': np.expand_dims(mapped_city_id, axis=0)
    }
    # --- KONIEC POPRAWKI ---
    
    # Wykonujemy predykcję
    pred_district_probs, pred_street_probs = best_model.predict(input_sample, verbose=0)
    
    # Znajdujemy najbardziej prawdopodobne INDEKSY
    pred_district_idx = np.argmax(pred_district_probs[0])
    pred_street_idx = np.argmax(pred_street_probs[0])
    
    # Reszta kodu bez zmian...
    predicted_district_id = inv_district_map.get(pred_district_idx, 0)
    true_district_id = inv_district_map.get(y_district_val[i], 0)
    predicted_street_id = inv_street_map.get(pred_street_idx, 0)
    true_street_id = inv_street_map.get(y_street_val[i], 0)
    
    is_correct = (predicted_district_id == true_district_id) and \
                 ((true_street_id == 0) or (predicted_street_id == true_street_id))
    
    predicted_districts.append(predicted_district_id)
    predicted_streets.append(predicted_street_id)
    true_districts.append(true_district_id)
    true_streets.append(true_street_id)
    is_correct_list.append(is_correct)

# Reszta kodu do wyświetlania wyników bez zmian
df_results = pd.DataFrame({
    'Original_District_ID': true_districts, 'Predicted_District_ID': predicted_districts,
    'Original_Street_ID': true_streets, 'Predicted_Street_ID': predicted_streets,
    'Is_Correct': is_correct_list
})
accuracy = df_results['Is_Correct'].mean()
print(f"\nDokładność predykcji (Dzielnica + Ulica) na {num_samples} próbkach: {accuracy:.2%}")

df_results['Original_District_Name'] = df_results['Original_District_ID'].apply(lambda x: id_to_name.get(x, 'Brak'))
df_results['Predicted_District_Name'] = df_results['Predicted_District_ID'].apply(lambda x: id_to_name.get(x, 'Brak'))
df_results['Original_Street_Name'] = df_results['Original_Street_ID'].apply(lambda x: id_to_name.get(x, 'Brak'))
df_results['Predicted_Street_Name'] = df_results['Predicted_Street_ID'].apply(lambda x: id_to_name.get(x, 'Brak'))

display(df_results.head(20))
# Out:
# Wczytywanie najlepszego modelu (tylko do predykcji) z: artifacts\best_location_model_v10.keras
# Model wczytany pomyślnie.
# Przeprowadzanie predykcji na 1000 próbkach...
#
# Dokładność predykcji (Dzielnica + Ulica) na 1000 próbkach: 50.60%
#     Original_District_ID  Predicted_District_ID  Original_Street_ID  \
# 0                      0                      0                   0
# 1                      0                      0                   0
# 2                      0                  69149                   0
# 3                      0                      0                   0
# 4                      0                   3249                   0
# 5                      0                      0                   0
# 6                      0                  94723                   0
# 7                      0                  82779                   0
# 8                      0                      0                   0
# 9                      0                      0                   0
# 10                     0                  77300                   0
# 11                     0                  85722                   0
# 12                     0                      0                   0
# 13                     0                      0                   0
# 14                     0                      0                   0
# 15                     0                      0                   0
# 16                     0                      0                   0
# 17                     0                  95200                   0
# 18                     0                      0                   0
# 19                     0                      0                   0
#
#     Predicted_Street_ID  Is_Correct Original_District_Name  \
# 0                     0        True                   Brak
# 1                     0        True                   Brak
# 2                     0       False                   Brak
# 3                     0        True                   Brak
# 4                     0       False                   Brak
# 5                     0        True                   Brak
# 6                405131       False                   Brak
# 7                     0       False                   Brak
# 8                528984        True                   Brak
# 9                     0        True                   Brak
# 10                    0       False                   Brak
# 11                    0       False                   Brak
# 12                    0        True                   Brak
# 13               381661        True                   Brak
# 14                    0        True                   Brak
# 15                    0        True                   Brak
# 16                    0        True                   Brak
# 17                    0       False                   Brak
# 18                    0        True                   Brak
# 19                    0        True                   Brak
#
#    Predicted_District_Name Original_Street_Name Predicted_Street_Name
# 0                     Brak                 Brak                  Brak
# 1                     Brak                 Brak                  Brak
# 2                   Bałuty                 Brak                  Brak
# 3                     Brak                 Brak                  Brak
# 4                   Bemowo                 Brak                  Brak
# 5                     Brak                 Brak                  Brak
# 6                Bocianowo                 Brak              Rycerska
# 7              Chomiczówka                 Brak                  Brak
# 8                     Brak                 Brak         Jana pawła ii
# 9                     Brak                 Brak                  Brak
# 10               Nowodwory                 Brak                  Brak
# 11                  Stegny                 Brak                  Brak
# 12                    Brak                 Brak                  Brak
# 13                    Brak                 Brak               Gdańska
# 14                    Brak                 Brak                  Brak
# 15                    Brak                 Brak                  Brak
# 16                    Brak                 Brak                  Brak
# 17             Śródmieście                 Brak                  Brak
# 18                    Brak                 Brak                  Brak
# 19                    Brak                 Brak                  Brak

# %% [markdown]
# ## Wizualizacja Wyników Predykcji
# Wyświetlamy losowe przykłady predykcji, kolorując wiersze na zielono (poprawne) i czerwono (błędne), aby wizualnie ocenić jakość działania modelu.

# %%
def highlight_correct(s):
    """Koloruje tło wiersza na podstawie wartości w kolumnie 'Is_Correct'."""
    return ['background-color: #d4edda' if s.Is_Correct else 'background-color: #f8d7da'] * len(s)

# Wyświetlenie 20 losowych wierszy ze stylizacją
styled_results = df_results.sample(min(20, len(df_results)), random_state=RANDOM_STATE).style.apply(highlight_correct, axis=1)

print("\n--- Losowe wyniki predykcji (Zielony = Poprawna, Czerwony = Błędna) ---")
display(styled_results)
# Out:
# --- Losowe wyniki predykcji (Zielony = Poprawna, Czerwony = Błędna) ---
# <style type="text/css">
# #T_0bc30_row0_col0, #T_0bc30_row0_col1, #T_0bc30_row0_col2, #T_0bc30_row0_col3, #T_0bc30_row0_col4, #T_0bc30_row0_col5, #T_0bc30_row0_col6, #T_0bc30_row0_col7, #T_0bc30_row0_col8, #T_0bc30_row1_col0, #T_0bc30_row1_col1, #T_0bc30_row1_col2, #T_0bc30_row1_col3, #T_0bc30_row1_col4, #T_0bc30_row1_col5, #T_0bc30_row1_col6, #T_0bc30_row1_col7, #T_0bc30_row1_col8, #T_0bc30_row2_col0, #T_0bc30_row2_col1, #T_0bc30_row2_col2, #T_0bc30_row2_col3, #T_0bc30_row2_col4, #T_0bc30_row2_col5, #T_0bc30_row2_col6, #T_0bc30_row2_col7, #T_0bc30_row2_col8, #T_0bc30_row5_col0, #T_0bc30_row5_col1, #T_0bc30_row5_col2, #T_0bc30_row5_col3, #T_0bc30_row5_col4, #T_0bc30_row5_col5, #T_0bc30_row5_col6, #T_0bc30_row5_col7, #T_0bc30_row5_col8, #T_0bc30_row9_col0, #T_0bc30_row9_col1, #T_0bc30_row9_col2, #T_0bc30_row9_col3, #T_0bc30_row9_col4, #T_0bc30_row9_col5, #T_0bc30_row9_col6, #T_0bc30_row9_col7, #T_0bc30_row9_col8, #T_0bc30_row10_col0, #T_0bc30_row10_col1, #T_0bc30_row10_col2, #T_0bc30_row10_col3, #T_0bc30_row10_col4, #T_0bc30_row10_col5, #T_0bc30_row10_col6, #T_0bc30_row10_col7, #T_0bc30_row10_col8, #T_0bc30_row14_col0, #T_0bc30_row14_col1, #T_0bc30_row14_col2, #T_0bc30_row14_col3, #T_0bc30_row14_col4, #T_0bc30_row14_col5, #T_0bc30_row14_col6, #T_0bc30_row14_col7, #T_0bc30_row14_col8, #T_0bc30_row15_col0, #T_0bc30_row15_col1, #T_0bc30_row15_col2, #T_0bc30_row15_col3, #T_0bc30_row15_col4, #T_0bc30_row15_col5, #T_0bc30_row15_col6, #T_0bc30_row15_col7, #T_0bc30_row15_col8, #T_0bc30_row16_col0, #T_0bc30_row16_col1, #T_0bc30_row16_col2, #T_0bc30_row16_col3, #T_0bc30_row16_col4, #T_0bc30_row16_col5, #T_0bc30_row16_col6, #T_0bc30_row16_col7, #T_0bc30_row16_col8, #T_0bc30_row17_col0, #T_0bc30_row17_col1, #T_0bc30_row17_col2, #T_0bc30_row17_col3, #T_0bc30_row17_col4, #T_0bc30_row17_col5, #T_0bc30_row17_col6, #T_0bc30_row17_col7, #T_0bc30_row17_col8, #T_0bc30_row18_col0, #T_0bc30_row18_col1, #T_0bc30_row18_col2, #T_0bc30_row18_col3, #T_0bc30_row18_col4, #T_0bc30_row18_col5, #T_0bc30_row18_col6, #T_0bc30_row18_col7, #T_0bc30_row18_col8 {
#   background-color: #d4edda;
# }
# #T_0bc30_row3_col0, #T_0bc30_row3_col1, #T_0bc30_row3_col2, #T_0bc30_row3_col3, #T_0bc30_row3_col4, #T_0bc30_row3_col5, #T_0bc30_row3_col6, #T_0bc30_row3_col7, #T_0bc30_row3_col8, #T_0bc30_row4_col0, #T_0bc30_row4_col1, #T_0bc30_row4_col2, #T_0bc30_row4_col3, #T_0bc30_row4_col4, #T_0bc30_row4_col5, #T_0bc30_row4_col6, #T_0bc30_row4_col7, #T_0bc30_row4_col8, #T_0bc30_row6_col0, #T_0bc30_row6_col1, #T_0bc30_row6_col2, #T_0bc30_row6_col3, #T_0bc30_row6_col4, #T_0bc30_row6_col5, #T_0bc30_row6_col6, #T_0bc30_row6_col7, #T_0bc30_row6_col8, #T_0bc30_row7_col0, #T_0bc30_row7_col1, #T_0bc30_row7_col2, #T_0bc30_row7_col3, #T_0bc30_row7_col4, #T_0bc30_row7_col5, #T_0bc30_row7_col6, #T_0bc30_row7_col7, #T_0bc30_row7_col8, #T_0bc30_row8_col0, #T_0bc30_row8_col1, #T_0bc30_row8_col2, #T_0bc30_row8_col3, #T_0bc30_row8_col4, #T_0bc30_row8_col5, #T_0bc30_row8_col6, #T_0bc30_row8_col7, #T_0bc30_row8_col8, #T_0bc30_row11_col0, #T_0bc30_row11_col1, #T_0bc30_row11_col2, #T_0bc30_row11_col3, #T_0bc30_row11_col4, #T_0bc30_row11_col5, #T_0bc30_row11_col6, #T_0bc30_row11_col7, #T_0bc30_row11_col8, #T_0bc30_row12_col0, #T_0bc30_row12_col1, #T_0bc30_row12_col2, #T_0bc30_row12_col3, #T_0bc30_row12_col4, #T_0bc30_row12_col5, #T_0bc30_row12_col6, #T_0bc30_row12_col7, #T_0bc30_row12_col8, #T_0bc30_row13_col0, #T_0bc30_row13_col1, #T_0bc30_row13_col2, #T_0bc30_row13_col3, #T_0bc30_row13_col4, #T_0bc30_row13_col5, #T_0bc30_row13_col6, #T_0bc30_row13_col7, #T_0bc30_row13_col8, #T_0bc30_row19_col0, #T_0bc30_row19_col1, #T_0bc30_row19_col2, #T_0bc30_row19_col3, #T_0bc30_row19_col4, #T_0bc30_row19_col5, #T_0bc30_row19_col6, #T_0bc30_row19_col7, #T_0bc30_row19_col8 {
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_0bc30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bc30_level0_col0" class="col_heading level0 col0" >Original_District_ID</th>
#       <th id="T_0bc30_level0_col1" class="col_heading level0 col1" >Predicted_District_ID</th>
#       <th id="T_0bc30_level0_col2" class="col_heading level0 col2" >Original_Street_ID</th>
#       <th id="T_0bc30_level0_col3" class="col_heading level0 col3" >Predicted_Street_ID</th>
#       <th id="T_0bc30_level0_col4" class="col_heading level0 col4" >Is_Correct</th>
#       <th id="T_0bc30_level0_col5" class="col_heading level0 col5" >Original_District_Name</th>
#       <th id="T_0bc30_level0_col6" class="col_heading level0 col6" >Predicted_District_Name</th>
#       <th id="T_0bc30_level0_col7" class="col_heading level0 col7" >Original_Street_Name</th>
#       <th id="T_0bc30_level0_col8" class="col_heading level0 col8" >Predicted_Street_Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bc30_level0_row0" class="row_heading level0 row0" >521</th>
#       <td id="T_0bc30_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0bc30_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0bc30_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0bc30_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0bc30_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_0bc30_row0_col5" class="data row0 col5" >Brak</td>
#       <td id="T_0bc30_row0_col6" class="data row0 col6" >Brak</td>
#       <td id="T_0bc30_row0_col7" class="data row0 col7" >Brak</td>
#       <td id="T_0bc30_row0_col8" class="data row0 col8" >Brak</td>
#     </tr>
#     <tr>
#       <th id="T_0bc30_level0_row1" class="row_heading level0 row1" >737</th>
#       <td id="T_0bc30_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0bc30_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0bc30_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0bc30_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_0bc30_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_0bc30_row1_col5" class="data row1 col5" >Brak</td>
#       <td id="T_0bc30_row1_col6" class="data row1 col6" >Brak</td>
#       <td id="T_0bc30_row1_col7" class="data row1 col7" >Brak</td>
#       <td id="T_0bc30_row1_col8" class="data row1 col8" >Brak</td>
#     </tr>
#     <tr>
#       <th id="T_0bc30_level0_row2" class="row_heading level0 row2" >740</th>
#       <td id="T_0bc30_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_0bc30_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0bc30_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0bc30_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_0bc30_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_0bc30_row2_col5" class="data row2 col5" >Brak</td>
#       <td id="T_0bc30_row2_col6" class="data row2 col6" >Brak</td>
#       <td id="T_0bc30_row2_col7" class="data row2 col7" >Brak</td>
#       <td id="T_0bc30_row2_col8" class="data row2 col8" >Brak</td>
#     </tr>
#     <tr>
#       <th id="T_0bc30_level0_row3" class="row_heading level0 row3" >660</th>
#       <td id="T_0bc30_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_0bc30_row3_col1" class="data row3 col1" >72674</td>
#       <td id="T_0bc30_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0bc30_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_0bc30_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_0bc30_row3_col5" class="data row3 col5" >Brak</td>
#       <td id="T_0bc30_row3_col6" class="data row3 col6" >Fabryczna</td>
#       <td id="T_0bc30_row3_col7" class="data row3 col7" >Brak</td>
#       <td id="T_0bc30_row3_col8" class="data row3 col8" >Brak</td>
#     </tr>
#     <tr>
#       <th id="T_0bc30_level0_row4" class="row_heading level0 row4" >411</th>
#       <td id="T_0bc30_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_0bc30_row4_col1" class="data row4 col1" >76855</td>
#       <td id="T_0bc30_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0bc30_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_0bc30_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_0bc30_row4_col5" class="data row4 col5" >Brak</td>
#       <td id="T_0bc
